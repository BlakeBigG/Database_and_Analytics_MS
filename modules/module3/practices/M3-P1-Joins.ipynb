# %% [markdown]
# # Joins
#
#
# In M1-M2, we worked with SELECT statement for fetching data from a table (only one table is used in FROM clause). In a real-world scenario, a database would have multiple tables and we need to fetch data from more than one tables to satisfy a query. Fetching data from multiple tables is achieved using a **join** operation.
#
# ## References
#
# 1. Joining Tables: https://www.tutorialspoint.com/sql/sql-using-joins.htm
# 1. Inner Join: http://www.tutorialspoint.com/sql/sql-inner-joins.htm
# 1. Left Join or Left Outer Join: http://www.tutorialspoint.com/sql/sql-left-joins.htm
# 1. Right Join or Right Outer Join: http://www.tutorialspoint.com/sql/sql-right-joins.htm

# %% [markdown]
# <img src="../images/join.png" alt="Join Overview" style="width:600px;height:400px;">
#
# <center><b>Fig: An overview of different types of join operations</b></center>

# %% [markdown]
# ## Connecting to PostgreSQL
#
# We will connect to a postgreSQL database using the following notebook commands:

# %%
# %load_ext sql
# %sql postgres://dsa_ro_user:readonly@pgsql.dsa.lan/dsa_ro
# Out:
# 'Connected: dsa_ro_user@dsa_ro'

# %% [markdown]
# ## Joining Tables
#
# Now we will do our first basic join of the us_second_order_divisions table and the util_us_states table.
#
# We must first view both these tables and see where our data overlaps and we can join them.
#
# If we use the terminal, the following two commands will let us see the column metadata, to see where the data overlaps:
#
# ```SQL
# dsa_ro=> \d us_second_order_divisions
#         Table "public.us_second_order_divisions"
#        Column       |          Type          | Modifiers
# --------------------+------------------------+-----------
#  state_number_code  | smallint               | not null
#  county_number_code | character varying(5)   | not null
#  county_name        | character varying(100) |
# Indexes:
#     "us_second_order_divisions_pkey" PRIMARY KEY, btree (state_number_code, county_number_code)
#
# dsa_ro=> \d util_us_states
#              Table "public.util_us_states"
#       Column       |         Type          | Modifiers
# -------------------+-----------------------+-----------
#  state_alpha_code  | character(2)          | not null
#  state_number_code | smallint              |
#  state_name        | character varying(50) |
# Indexes:
#     "util_us_states_pkey" PRIMARY KEY, btree (state_alpha_code)
#     "util_us_states_state_number_code" btree (state_number_code)
#
#
# ```
#
# We can see the column names for the two tables by running the following two SELECT statements using Jupyter's sql extension:

# %%
# %sql SELECT * FROM us_second_order_divisions LIMIT 0;
# Out:
#  * postgres://dsa_ro_user:***@pgsql.dsa.lan/dsa_ro
# 0 rows affected.
# []

# %%
# %sql SELECT * FROM util_us_states LIMIT 0;
# Out:
#  * postgres://dsa_ro_user:***@pgsql.dsa.lan/dsa_ro
# 0 rows affected.
# []

# %% [markdown]
# If we look at both these tables, we will see that they both contain a **`state_number_code`**!
#
# This means that we can join these two tables over that **`state_number_code`**.
# To join the tables means to take the data from both tables and connect them into one output, linking the rows based on the common columns.
#
# ```SQL
# SELECT *
# FROM us_second_order_divisions AS sod
# JOIN util_us_states AS uus
#   ON sod.state_number_code = uus.state_number_code;
# ```
#
# **Note:** In the above statement, we have utilized table aliases, e.g., `util_us_states AS uus`. Without the aliases, it would look like this:
#
# ```SQL
# SELECT *
# FROM us_second_order_divisions
# JOIN util_us_states
#   ON us_second_order_divisions.state_number_code = util_us_states.state_number_code;
# ```
#
#
#
# **Note:** The below query will return 3295 rows.
# You should click under the resulting `Out[#]` to turn on _cell scrolling_.

# %%
# %%sql
# SELECT *
# FROM us_second_order_divisions AS sod
# JOIN util_us_states AS uus
#   ON sod.state_number_code = uus.state_number_code;
# Out:
#  * postgres://dsa_ro_user:***@pgsql.dsa.lan/dsa_ro
# 3295 rows affected.
# [(1, '001', 'Autauga', 'AL', 1, 'ALABAMA'),
#  (1, '003', 'Baldwin', 'AL', 1, 'ALABAMA'),
#  (1, '005', 'Barbour', 'AL', 1, 'ALABAMA'),
#  (1, '007', 'Bibb', 'AL', 1, 'ALABAMA'),
#  (1, '009', 'Blount', 'AL', 1, 'ALABAMA'),
#  (1, '011', 'Bullock', 'AL', 1, 'ALABAMA'),
#  (1, '013', 'Butler', 'AL', 1, 'ALABAMA'),
#  (1, '015', 'Calhoun', 'AL', 1, 'ALABAMA'),
#  (1, '017', 'Chambers', 'AL', 1, 'ALABAMA'),
#  (1, '019', 'Cherokee', 'AL', 1, 'ALABAMA'),
#  (1, '021', 'Chilton', 'AL', 1, 'ALABAMA'),
#  (1, '023', 'Choctaw', 'AL', 1, 'ALABAMA'),
#  (1, '025', 'Clarke', 'AL', 1, 'ALABAMA'),
#  (1, '027', 'Clay', 'AL', 1, 'ALABAMA'),
#  (1, '029', 'Cleburne', 'AL', 1, 'ALABAMA'),
#  (1, '031', 'Coffee', 'AL', 1, 'ALABAMA'),
#  (1, '033', 'Colbert', 'AL', 1, 'ALABAMA'),
#  (1, '035', 'Conecuh', 'AL', 1, 'ALABAMA'),
#  (1, '037', 'Coosa', 'AL', 1, 'ALABAMA'),
#  (1, '039', 'Covington', 'AL', 1, 'ALABAMA'),
#  (1, '041', 'Crenshaw', 'AL', 1, 'ALABAMA'),
#  (1, '043', 'Cullman', 'AL', 1, 'ALABAMA'),
#  (1, '045', 'Dale', 'AL', 1, 'ALABAMA'),
#  (1, '047', 'Dallas', 'AL', 1, 'ALABAMA'),
#  (1, '049', 'DeKalb', 'AL', 1, 'ALABAMA'),
#  (1, '051', 'Elmore', 'AL', 1, 'ALABAMA'),
#  (1, '053', 'Escambia', 'AL', 1, 'ALABAMA'),
#  (1, '055', 'Etowah', 'AL', 1, 'ALABAMA'),
#  (1, '057', 'Fayette', 'AL', 1, 'ALABAMA'),
#  (1, '059', 'Franklin', 'AL', 1, 'ALABAMA'),
#  (1, '061', 'Geneva', 'AL', 1, 'ALABAMA'),
#  (1, '063', 'Greene', 'AL', 1, 'ALABAMA'),
#  (1, '065', 'Hale', 'AL', 1, 'ALABAMA'),
#  (1, '067', 'Henry', 'AL', 1, 'ALABAMA'),
#  (1, '069', 'Houston', 'AL', 1, 'ALABAMA'),
#  (1, '071', 'Jackson', 'AL', 1, 'ALABAMA'),
#  (1, '073', 'Jefferson', 'AL', 1, 'ALABAMA'),
#  (1, '075', 'Lamar', 'AL', 1, 'ALABAMA'),
#  (1, '077', 'Lauderdale', 'AL', 1, 'ALABAMA'),
#  (1, '079', 'Lawrence', 'AL', 1, 'ALABAMA'),
#  (1, '081', 'Lee', 'AL', 1, 'ALABAMA'),
#  (1, '083', 'Limestone', 'AL', 1, 'ALABAMA'),
#  (1, '085', 'Lowndes', 'AL', 1, 'ALABAMA'),
#  (1, '087', 'Macon', 'AL', 1, 'ALABAMA'),
#  (1, '089', 'Madison', 'AL', 1, 'ALABAMA'),
#  (1, '091', 'Marengo', 'AL', 1, 'ALABAMA'),
#  (1, '093', 'Marion', 'AL', 1, 'ALABAMA'),
#  (1, '095', 'Marshall', 'AL', 1, 'ALABAMA'),
#  (1, '097', 'Mobile', 'AL', 1, 'ALABAMA'),
#  (1, '099', 'Monroe', 'AL', 1, 'ALABAMA'),
#  (1, '101', 'Montgomery', 'AL', 1, 'ALABAMA'),
#  (1, '103', 'Morgan', 'AL', 1, 'ALABAMA'),
#  (1, '105', 'Perry', 'AL', 1, 'ALABAMA'),
#  (1, '107', 'Pickens', 'AL', 1, 'ALABAMA'),
#  (1, '109', 'Pike', 'AL', 1, 'ALABAMA'),
#  (1, '111', 'Randolph', 'AL', 1, 'ALABAMA'),
#  (1, '113', 'Russell', 'AL', 1, 'ALABAMA'),
#  (1, '115', 'St. Clair', 'AL', 1, 'ALABAMA'),
#  (1, '117', 'Shelby', 'AL', 1, 'ALABAMA'),
#  (1, '119', 'Sumter', 'AL', 1, 'ALABAMA'),
#  (1, '121', 'Talladega', 'AL', 1, 'ALABAMA'),
#  (1, '123', 'Tallapoosa', 'AL', 1, 'ALABAMA'),
#  (1, '125', 'Tuscaloosa', 'AL', 1, 'ALABAMA'),
#  (1, '127', 'Walker', 'AL', 1, 'ALABAMA'),
#  (1, '129', 'Washington', 'AL', 1, 'ALABAMA'),
#  (1, '131', 'Wilcox', 'AL', 1, 'ALABAMA'),
#  (1, '133', 'Winston', 'AL', 1, 'ALABAMA'),
#  (2, '013', 'Aleutians East', 'AK', 2, 'ALASKA'),
#  (2, '016', 'Aleutians West (CA)', 'AK', 2, 'ALASKA'),
#  (2, '020', 'Anchorage', 'AK', 2, 'ALASKA'),
#  (2, '050', 'Bethel (CA)', 'AK', 2, 'ALASKA'),
#  (2, '060', 'Bristol Bay', 'AK', 2, 'ALASKA'),
#  (2, '068', 'Denali', 'AK', 2, 'ALASKA'),
#  (2, '070', 'Dillingham (CA)', 'AK', 2, 'ALASKA'),
#  (2, '090', 'Fairbanks North Star', 'AK', 2, 'ALASKA'),
#  (2, '100', 'Haines', 'AK', 2, 'ALASKA'),
#  (2, '105', 'Hoonah-Angoon (CA)', 'AK', 2, 'ALASKA'),
#  (2, '110', 'Juneau', 'AK', 2, 'ALASKA'),
#  (2, '122', 'Kenai Peninsula', 'AK', 2, 'ALASKA'),
#  (2, '130', 'Ketchikan Gateway', 'AK', 2, 'ALASKA'),
#  (2, '150', 'Kodiak Island', 'AK', 2, 'ALASKA'),
#  (2, '164', 'Lake and Peninsula', 'AK', 2, 'ALASKA'),
#  (2, '170', 'Matanuska-Susitna', 'AK', 2, 'ALASKA'),
#  (2, '180', 'Nome (CA)', 'AK', 2, 'ALASKA'),
#  (2, '185', 'North Slope', 'AK', 2, 'ALASKA'),
#  (2, '188', 'Northwest Arctic', 'AK', 2, 'ALASKA'),
#  (2, '201', 'P. of Wales-O. Ketchikan (CA)', 'AK', 2, 'ALASKA'),
#  (2, '220', 'Sitka', 'AK', 2, 'ALASKA'),
#  (2, '230', 'Skagway', 'AK', 2, 'ALASKA'),
#  (2, '240', 'Southeast Fairbanks (CA)', 'AK', 2, 'ALASKA'),
#  (2, '261', 'Valdez-Cordova (CA)', 'AK', 2, 'ALASKA'),
#  (2, '270', 'Wade Hampton (CA)', 'AK', 2, 'ALASKA'),
#  (2, '280', 'Wrangell-Petersburg (CA)', 'AK', 2, 'ALASKA'),
#  (2, '282', 'Yakutat', 'AK', 2, 'ALASKA'),
#  (2, '290', 'Yukon-Koyukuk (CA)', 'AK', 2, 'ALASKA'),
#  (4, '001', 'Apache', 'AZ', 4, 'ARIZONA'),
#  (4, '003', 'Cochise', 'AZ', 4, 'ARIZONA'),
#  (4, '005', 'Coconino', 'AZ', 4, 'ARIZONA'),
#  (4, '007', 'Gila', 'AZ', 4, 'ARIZONA'),
#  (4, '009', 'Graham', 'AZ', 4, 'ARIZONA'),
#  (4, '011', 'Greenlee', 'AZ', 4, 'ARIZONA'),
#  (4, '012', 'La Paz', 'AZ', 4, 'ARIZONA'),
#  (4, '013', 'Maricopa', 'AZ', 4, 'ARIZONA'),
#  (4, '015', 'Mohave', 'AZ', 4, 'ARIZONA'),
#  (4, '017', 'Navajo', 'AZ', 4, 'ARIZONA'),
#  (4, '019', 'Pima', 'AZ', 4, 'ARIZONA'),
#  (4, '021', 'Pinal', 'AZ', 4, 'ARIZONA'),
#  (4, '023', 'Santa Cruz', 'AZ', 4, 'ARIZONA'),
#  (4, '025', 'Yavapai', 'AZ', 4, 'ARIZONA'),
#  (4, '027', 'Yuma', 'AZ', 4, 'ARIZONA'),
#  (5, '001', 'Arkansas', 'AR', 5, 'ARKANSAS'),
#  (5, '003', 'Ashley', 'AR', 5, 'ARKANSAS'),
#  (5, '005', 'Baxter', 'AR', 5, 'ARKANSAS'),
#  (5, '007', 'Benton', 'AR', 5, 'ARKANSAS'),
#  (5, '009', 'Boone', 'AR', 5, 'ARKANSAS'),
#  (5, '011', 'Bradley', 'AR', 5, 'ARKANSAS'),
#  (5, '013', 'Calhoun', 'AR', 5, 'ARKANSAS'),
#  (5, '015', 'Carroll', 'AR', 5, 'ARKANSAS'),
#  (5, '017', 'Chicot', 'AR', 5, 'ARKANSAS'),
#  (5, '019', 'Clark', 'AR', 5, 'ARKANSAS'),
#  (5, '021', 'Clay', 'AR', 5, 'ARKANSAS'),
#  (5, '023', 'Cleburne', 'AR', 5, 'ARKANSAS'),
#  (5, '025', 'Cleveland', 'AR', 5, 'ARKANSAS'),
#  (5, '027', 'Columbia', 'AR', 5, 'ARKANSAS'),
#  (5, '029', 'Conway', 'AR', 5, 'ARKANSAS'),
#  (5, '031', 'Craighead', 'AR', 5, 'ARKANSAS'),
#  (5, '033', 'Crawford', 'AR', 5, 'ARKANSAS'),
#  (5, '035', 'Crittenden', 'AR', 5, 'ARKANSAS'),
#  (5, '037', 'Cross', 'AR', 5, 'ARKANSAS'),
#  (5, '127', 'Scott', 'AR', 5, 'ARKANSAS'),
#  (5, '129', 'Searcy', 'AR', 5, 'ARKANSAS'),
#  (5, '131', 'Sebastian', 'AR', 5, 'ARKANSAS'),
#  (5, '133', 'Sevier', 'AR', 5, 'ARKANSAS'),
#  (5, '135', 'Sharp', 'AR', 5, 'ARKANSAS'),
#  (5, '137', 'Stone', 'AR', 5, 'ARKANSAS'),
#  (5, '139', 'Union', 'AR', 5, 'ARKANSAS'),
#  (5, '141', 'Van Buren', 'AR', 5, 'ARKANSAS'),
#  (5, '143', 'Washington', 'AR', 5, 'ARKANSAS'),
#  (5, '145', 'White', 'AR', 5, 'ARKANSAS'),
#  (5, '147', 'Woodruff', 'AR', 5, 'ARKANSAS'),
#  (5, '149', 'Yell', 'AR', 5, 'ARKANSAS'),
#  (6, '001', 'Alameda', 'CA', 6, 'CALIFORNIA'),
#  (6, '003', 'Alpine', 'CA', 6, 'CALIFORNIA'),
#  (6, '005', 'Amador', 'CA', 6, 'CALIFORNIA'),
#  (6, '007', 'Butte', 'CA', 6, 'CALIFORNIA'),
#  (6, '009', 'Calaveras', 'CA', 6, 'CALIFORNIA'),
#  (6, '011', 'Colusa', 'CA', 6, 'CALIFORNIA'),
#  (6, '013', 'Contra Costa', 'CA', 6, 'CALIFORNIA'),
#  (6, '015', 'Del Norte', 'CA', 6, 'CALIFORNIA'),
#  (6, '017', 'El Dorado', 'CA', 6, 'CALIFORNIA'),
#  (6, '019', 'Fresno', 'CA', 6, 'CALIFORNIA'),
#  (6, '021', 'Glenn', 'CA', 6, 'CALIFORNIA'),
#  (6, '023', 'Humboldt', 'CA', 6, 'CALIFORNIA'),
#  (6, '025', 'Imperial', 'CA', 6, 'CALIFORNIA'),
#  (6, '027', 'Inyo', 'CA', 6, 'CALIFORNIA'),
#  (6, '029', 'Kern', 'CA', 6, 'CALIFORNIA'),
#  (6, '031', 'Kings', 'CA', 6, 'CALIFORNIA'),
#  (6, '033', 'Lake', 'CA', 6, 'CALIFORNIA'),
#  (6, '035', 'Lassen', 'CA', 6, 'CALIFORNIA'),
#  (6, '037', 'Los Angeles', 'CA', 6, 'CALIFORNIA'),
#  (6, '039', 'Madera', 'CA', 6, 'CALIFORNIA'),
#  (6, '041', 'Marin', 'CA', 6, 'CALIFORNIA'),
#  (6, '043', 'Mariposa', 'CA', 6, 'CALIFORNIA'),
#  (6, '045', 'Mendocino', 'CA', 6, 'CALIFORNIA'),
#  (6, '047', 'Merced', 'CA', 6, 'CALIFORNIA'),
#  (6, '049', 'Modoc', 'CA', 6, 'CALIFORNIA'),
#  (6, '051', 'Mono', 'CA', 6, 'CALIFORNIA'),
#  (6, '053', 'Monterey', 'CA', 6, 'CALIFORNIA'),
#  (6, '055', 'Napa', 'CA', 6, 'CALIFORNIA'),
#  (6, '057', 'Nevada', 'CA', 6, 'CALIFORNIA'),
#  (6, '059', 'Orange', 'CA', 6, 'CALIFORNIA'),
#  (6, '061', 'Placer', 'CA', 6, 'CALIFORNIA'),
#  (6, '063', 'Plumas', 'CA', 6, 'CALIFORNIA'),
#  (6, '065', 'Riverside', 'CA', 6, 'CALIFORNIA'),
#  (6, '067', 'Sacramento', 'CA', 6, 'CALIFORNIA'),
#  (6, '069', 'San Benito', 'CA', 6, 'CALIFORNIA'),
#  (6, '071', 'San Bernardino', 'CA', 6, 'CALIFORNIA'),
#  (6, '073', 'San Diego', 'CA', 6, 'CALIFORNIA'),
#  (6, '075', 'San Francisco', 'CA', 6, 'CALIFORNIA'),
#  (6, '077', 'San Joaquin', 'CA', 6, 'CALIFORNIA'),
#  (6, '079', 'San Luis Obispo', 'CA', 6, 'CALIFORNIA'),
#  (6, '081', 'San Mateo', 'CA', 6, 'CALIFORNIA'),
#  (6, '083', 'Santa Barbara', 'CA', 6, 'CALIFORNIA'),
#  (6, '085', 'Santa Clara', 'CA', 6, 'CALIFORNIA'),
#  (6, '087', 'Santa Cruz', 'CA', 6, 'CALIFORNIA'),
#  (6, '089', 'Shasta', 'CA', 6, 'CALIFORNIA'),
#  (6, '091', 'Sierra', 'CA', 6, 'CALIFORNIA'),
#  (6, '093', 'Siskiyou', 'CA', 6, 'CALIFORNIA'),
#  (6, '095', 'Solano', 'CA', 6, 'CALIFORNIA'),
#  (6, '097', 'Sonoma', 'CA', 6, 'CALIFORNIA'),
#  (6, '099', 'Stanislaus', 'CA', 6, 'CALIFORNIA'),
#  (6, '101', 'Sutter', 'CA', 6, 'CALIFORNIA'),
#  (6, '103', 'Tehama', 'CA', 6, 'CALIFORNIA'),
#  (6, '105', 'Trinity', 'CA', 6, 'CALIFORNIA'),
#  (6, '107', 'Tulare', 'CA', 6, 'CALIFORNIA'),
#  (6, '109', 'Tuolumne', 'CA', 6, 'CALIFORNIA'),
#  (6, '111', 'Ventura', 'CA', 6, 'CALIFORNIA'),
#  (6, '113', 'Yolo', 'CA', 6, 'CALIFORNIA'),
#  (6, '115', 'Yuba', 'CA', 6, 'CALIFORNIA'),
#  (8, '001', 'Adams', 'CO', 8, 'COLORADO'),
#  (8, '003', 'Alamosa', 'CO', 8, 'COLORADO'),
#  (8, '005', 'Arapahoe', 'CO', 8, 'COLORADO'),
#  (8, '007', 'Archuleta', 'CO', 8, 'COLORADO'),
#  (8, '009', 'Baca', 'CO', 8, 'COLORADO'),
#  (8, '011', 'Bent', 'CO', 8, 'COLORADO'),
#  (8, '013', 'Boulder', 'CO', 8, 'COLORADO'),
#  (8, '014', 'Broomfield', 'CO', 8, 'COLORADO'),
#  (8, '015', 'Chaffee', 'CO', 8, 'COLORADO'),
#  (8, '017', 'Cheyenne', 'CO', 8, 'COLORADO'),
#  (8, '019', 'Clear Creek', 'CO', 8, 'COLORADO'),
#  (8, '021', 'Conejos', 'CO', 8, 'COLORADO'),
#  (8, '023', 'Costilla', 'CO', 8, 'COLORADO'),
#  (8, '025', 'Crowley', 'CO', 8, 'COLORADO'),
#  (8, '027', 'Custer', 'CO', 8, 'COLORADO'),
#  (8, '029', 'Delta', 'CO', 8, 'COLORADO'),
#  (13, '291', 'Union', 'GA', 13, 'GEORGIA'),
#  (13, '293', 'Upson', 'GA', 13, 'GEORGIA'),
#  (13, '295', 'Walker', 'GA', 13, 'GEORGIA'),
#  (13, '297', 'Walton', 'GA', 13, 'GEORGIA'),
#  (13, '299', 'Ware', 'GA', 13, 'GEORGIA'),
#  (13, '301', 'Warren', 'GA', 13, 'GEORGIA'),
#  (13, '303', 'Washington', 'GA', 13, 'GEORGIA'),
#  (13, '305', 'Wayne', 'GA', 13, 'GEORGIA'),
#  (13, '307', 'Webster', 'GA', 13, 'GEORGIA'),
#  (13, '309', 'Wheeler', 'GA', 13, 'GEORGIA'),
#  (13, '311', 'White', 'GA', 13, 'GEORGIA'),
#  (13, '313', 'Whitfield', 'GA', 13, 'GEORGIA'),
#  (13, '315', 'Wilcox', 'GA', 13, 'GEORGIA'),
#  (13, '317', 'Wilkes', 'GA', 13, 'GEORGIA'),
#  (13, '319', 'Wilkinson', 'GA', 13, 'GEORGIA'),
#  (13, '321', 'Worth', 'GA', 13, 'GEORGIA'),
#  (15, '001', 'Hawaii', 'HI', 15, 'HAWAII'),
#  (15, '003', 'Honolulu', 'HI', 15, 'HAWAII'),
#  (15, '005', 'Kalawao', 'HI', 15, 'HAWAII'),
#  (15, '007', 'Kauai', 'HI', 15, 'HAWAII'),
#  (15, '009', 'Maui', 'HI', 15, 'HAWAII'),
#  (16, '001', 'Ada', 'ID', 16, 'IDAHO'),
#  (16, '003', 'Adams', 'ID', 16, 'IDAHO'),
#  (16, '005', 'Bannock', 'ID', 16, 'IDAHO'),
#  (16, '007', 'Bear Lake', 'ID', 16, 'IDAHO'),
#  (16, '009', 'Benewah', 'ID', 16, 'IDAHO'),
#  (16, '011', 'Bingham', 'ID', 16, 'IDAHO'),
#  (16, '013', 'Blaine', 'ID', 16, 'IDAHO'),
#  (16, '015', 'Boise', 'ID', 16, 'IDAHO'),
#  (16, '017', 'Bonner', 'ID', 16, 'IDAHO'),
#  (16, '019', 'Bonneville', 'ID', 16, 'IDAHO'),
#  (16, '021', 'Boundary', 'ID', 16, 'IDAHO'),
#  (16, '023', 'Butte', 'ID', 16, 'IDAHO'),
#  (16, '025', 'Camas', 'ID', 16, 'IDAHO'),
#  (16, '027', 'Canyon', 'ID', 16, 'IDAHO'),
#  (16, '029', 'Caribou', 'ID', 16, 'IDAHO'),
#  (16, '031', 'Cassia', 'ID', 16, 'IDAHO'),
#  (16, '033', 'Clark', 'ID', 16, 'IDAHO'),
#  (16, '035', 'Clearwater', 'ID', 16, 'IDAHO'),
#  (16, '037', 'Custer', 'ID', 16, 'IDAHO'),
#  (16, '039', 'Elmore', 'ID', 16, 'IDAHO'),
#  (16, '041', 'Franklin', 'ID', 16, 'IDAHO'),
#  (16, '043', 'Fremont', 'ID', 16, 'IDAHO'),
#  (16, '045', 'Gem', 'ID', 16, 'IDAHO'),
#  (16, '047', 'Gooding', 'ID', 16, 'IDAHO'),
#  (16, '049', 'Idaho', 'ID', 16, 'IDAHO'),
#  (19, '027', 'Carroll', 'IA', 19, 'IOWA'),
#  (19, '029', 'Cass', 'IA', 19, 'IOWA'),
#  (19, '031', 'Cedar', 'IA', 19, 'IOWA'),
#  (19, '033', 'Cerro Gordo', 'IA', 19, 'IOWA'),
#  (19, '035', 'Cherokee', 'IA', 19, 'IOWA'),
#  (19, '037', 'Chickasaw', 'IA', 19, 'IOWA'),
#  (19, '039', 'Clarke', 'IA', 19, 'IOWA'),
#  (19, '041', 'Clay', 'IA', 19, 'IOWA'),
#  (19, '043', 'Clayton', 'IA', 19, 'IOWA'),
#  (19, '045', 'Clinton', 'IA', 19, 'IOWA'),
#  (19, '047', 'Crawford', 'IA', 19, 'IOWA'),
#  (19, '049', 'Dallas', 'IA', 19, 'IOWA'),
#  (19, '051', 'Davis', 'IA', 19, 'IOWA'),
#  (19, '053', 'Decatur', 'IA', 19, 'IOWA'),
#  (19, '055', 'Delaware', 'IA', 19, 'IOWA'),
#  (19, '057', 'Des Moines', 'IA', 19, 'IOWA'),
#  (19, '059', 'Dickinson', 'IA', 19, 'IOWA'),
#  (19, '061', 'Dubuque', 'IA', 19, 'IOWA'),
#  (19, '063', 'Emmet', 'IA', 19, 'IOWA'),
#  (19, '065', 'Fayette', 'IA', 19, 'IOWA'),
#  (19, '067', 'Floyd', 'IA', 19, 'IOWA'),
#  (19, '069', 'Franklin', 'IA', 19, 'IOWA'),
#  (19, '071', 'Fremont', 'IA', 19, 'IOWA'),
#  (19, '073', 'Greene', 'IA', 19, 'IOWA'),
#  (19, '075', 'Grundy', 'IA', 19, 'IOWA'),
#  (19, '077', 'Guthrie', 'IA', 19, 'IOWA'),
#  (19, '079', 'Hamilton', 'IA', 19, 'IOWA'),
#  (19, '081', 'Hancock', 'IA', 19, 'IOWA'),
#  (19, '083', 'Hardin', 'IA', 19, 'IOWA'),
#  (19, '085', 'Harrison', 'IA', 19, 'IOWA'),
#  (19, '087', 'Henry', 'IA', 19, 'IOWA'),
#  (19, '089', 'Howard', 'IA', 19, 'IOWA'),
#  (19, '091', 'Humboldt', 'IA', 19, 'IOWA'),
#  (19, '093', 'Ida', 'IA', 19, 'IOWA'),
#  (19, '095', 'Iowa', 'IA', 19, 'IOWA'),
#  (19, '097', 'Jackson', 'IA', 19, 'IOWA'),
#  (19, '099', 'Jasper', 'IA', 19, 'IOWA'),
#  (19, '101', 'Jefferson', 'IA', 19, 'IOWA'),
#  (19, '103', 'Johnson', 'IA', 19, 'IOWA'),
#  (19, '105', 'Jones', 'IA', 19, 'IOWA'),
#  (19, '107', 'Keokuk', 'IA', 19, 'IOWA'),
#  (19, '109', 'Kossuth', 'IA', 19, 'IOWA'),
#  (19, '111', 'Lee', 'IA', 19, 'IOWA'),
#  (19, '113', 'Linn', 'IA', 19, 'IOWA'),
#  (19, '115', 'Louisa', 'IA', 19, 'IOWA'),
#  (19, '117', 'Lucas', 'IA', 19, 'IOWA'),
#  (19, '119', 'Lyon', 'IA', 19, 'IOWA'),
#  (19, '121', 'Madison', 'IA', 19, 'IOWA'),
#  (19, '123', 'Mahaska', 'IA', 19, 'IOWA'),
#  (19, '125', 'Marion', 'IA', 19, 'IOWA'),
#  (19, '127', 'Marshall', 'IA', 19, 'IOWA'),
#  (19, '129', 'Mills', 'IA', 19, 'IOWA'),
#  (19, '131', 'Mitchell', 'IA', 19, 'IOWA'),
#  (19, '133', 'Monona', 'IA', 19, 'IOWA'),
#  (19, '135', 'Monroe', 'IA', 19, 'IOWA'),
#  (19, '137', 'Montgomery', 'IA', 19, 'IOWA'),
#  (19, '139', 'Muscatine', 'IA', 19, 'IOWA'),
#  (19, '141', "O'Brien", 'IA', 19, 'IOWA'),
#  (19, '143', 'Osceola', 'IA', 19, 'IOWA'),
#  (19, '145', 'Page', 'IA', 19, 'IOWA'),
#  (19, '147', 'Palo Alto', 'IA', 19, 'IOWA'),
#  (19, '149', 'Plymouth', 'IA', 19, 'IOWA'),
#  (19, '151', 'Pocahontas', 'IA', 19, 'IOWA'),
#  (19, '153', 'Polk', 'IA', 19, 'IOWA'),
#  (19, '155', 'Pottawattamie', 'IA', 19, 'IOWA'),
#  (19, '157', 'Poweshiek', 'IA', 19, 'IOWA'),
#  (19, '159', 'Ringgold', 'IA', 19, 'IOWA'),
#  (19, '161', 'Sac', 'IA', 19, 'IOWA'),
#  (19, '163', 'Scott', 'IA', 19, 'IOWA'),
#  (19, '165', 'Shelby', 'IA', 19, 'IOWA'),
#  (19, '167', 'Sioux', 'IA', 19, 'IOWA'),
#  (19, '169', 'Story', 'IA', 19, 'IOWA'),
#  (19, '171', 'Tama', 'IA', 19, 'IOWA'),
#  (19, '173', 'Taylor', 'IA', 19, 'IOWA'),
#  (19, '175', 'Union', 'IA', 19, 'IOWA'),
#  (19, '177', 'Van Buren', 'IA', 19, 'IOWA'),
#  (19, '179', 'Wapello', 'IA', 19, 'IOWA'),
#  (19, '181', 'Warren', 'IA', 19, 'IOWA'),
#  (19, '183', 'Washington', 'IA', 19, 'IOWA'),
#  (19, '185', 'Wayne', 'IA', 19, 'IOWA'),
#  (19, '187', 'Webster', 'IA', 19, 'IOWA'),
#  (19, '189', 'Winnebago', 'IA', 19, 'IOWA'),
#  (19, '191', 'Winneshiek', 'IA', 19, 'IOWA'),
#  (19, '193', 'Woodbury', 'IA', 19, 'IOWA'),
#  (19, '195', 'Worth', 'IA', 19, 'IOWA'),
#  (19, '197', 'Wright', 'IA', 19, 'IOWA'),
#  (20, '001', 'Allen', 'KS', 20, 'KANSAS'),
#  (20, '003', 'Anderson', 'KS', 20, 'KANSAS'),
#  (20, '005', 'Atchison', 'KS', 20, 'KANSAS'),
#  (20, '007', 'Barber', 'KS', 20, 'KANSAS'),
#  (20, '009', 'Barton', 'KS', 20, 'KANSAS'),
#  (20, '011', 'Bourbon', 'KS', 20, 'KANSAS'),
#  (20, '013', 'Brown', 'KS', 20, 'KANSAS'),
#  (20, '015', 'Butler', 'KS', 20, 'KANSAS'),
#  (20, '017', 'Chase', 'KS', 20, 'KANSAS'),
#  (20, '019', 'Chautauqua', 'KS', 20, 'KANSAS'),
#  (20, '021', 'Cherokee', 'KS', 20, 'KANSAS'),
#  (20, '023', 'Cheyenne', 'KS', 20, 'KANSAS'),
#  (20, '025', 'Clark', 'KS', 20, 'KANSAS'),
#  (20, '027', 'Clay', 'KS', 20, 'KANSAS'),
#  (20, '029', 'Cloud', 'KS', 20, 'KANSAS'),
#  (20, '031', 'Coffey', 'KS', 20, 'KANSAS'),
#  (20, '033', 'Comanche', 'KS', 20, 'KANSAS'),
#  (20, '035', 'Cowley', 'KS', 20, 'KANSAS'),
#  (20, '037', 'Crawford', 'KS', 20, 'KANSAS'),
#  (20, '039', 'Decatur', 'KS', 20, 'KANSAS'),
#  (20, '041', 'Dickinson', 'KS', 20, 'KANSAS'),
#  (20, '043', 'Doniphan', 'KS', 20, 'KANSAS'),
#  (20, '045', 'Douglas', 'KS', 20, 'KANSAS'),
#  (20, '047', 'Edwards', 'KS', 20, 'KANSAS'),
#  (20, '049', 'Elk', 'KS', 20, 'KANSAS'),
#  (20, '051', 'Ellis', 'KS', 20, 'KANSAS'),
#  (20, '053', 'Ellsworth', 'KS', 20, 'KANSAS'),
#  (20, '055', 'Finney', 'KS', 20, 'KANSAS'),
#  (20, '057', 'Ford', 'KS', 20, 'KANSAS'),
#  (20, '059', 'Franklin', 'KS', 20, 'KANSAS'),
#  (20, '061', 'Geary', 'KS', 20, 'KANSAS'),
#  (20, '063', 'Gove', 'KS', 20, 'KANSAS'),
#  (20, '065', 'Graham', 'KS', 20, 'KANSAS'),
#  (20, '067', 'Grant', 'KS', 20, 'KANSAS'),
#  (20, '069', 'Gray', 'KS', 20, 'KANSAS'),
#  (20, '071', 'Greeley', 'KS', 20, 'KANSAS'),
#  (20, '073', 'Greenwood', 'KS', 20, 'KANSAS'),
#  (20, '075', 'Hamilton', 'KS', 20, 'KANSAS'),
#  (20, '077', 'Harper', 'KS', 20, 'KANSAS'),
#  (20, '079', 'Harvey', 'KS', 20, 'KANSAS'),
#  (20, '081', 'Haskell', 'KS', 20, 'KANSAS'),
#  (20, '083', 'Hodgeman', 'KS', 20, 'KANSAS'),
#  (20, '085', 'Jackson', 'KS', 20, 'KANSAS'),
#  (20, '087', 'Jefferson', 'KS', 20, 'KANSAS'),
#  (20, '089', 'Jewell', 'KS', 20, 'KANSAS'),
#  (20, '091', 'Johnson', 'KS', 20, 'KANSAS'),
#  (20, '093', 'Kearny', 'KS', 20, 'KANSAS'),
#  (20, '095', 'Kingman', 'KS', 20, 'KANSAS'),
#  (20, '097', 'Kiowa', 'KS', 20, 'KANSAS'),
#  (20, '099', 'Labette', 'KS', 20, 'KANSAS'),
#  (20, '101', 'Lane', 'KS', 20, 'KANSAS'),
#  (20, '103', 'Leavenworth', 'KS', 20, 'KANSAS'),
#  (20, '105', 'Lincoln', 'KS', 20, 'KANSAS'),
#  (20, '107', 'Linn', 'KS', 20, 'KANSAS'),
#  (20, '109', 'Logan', 'KS', 20, 'KANSAS'),
#  (20, '111', 'Lyon', 'KS', 20, 'KANSAS'),
#  (20, '113', 'McPherson', 'KS', 20, 'KANSAS'),
#  (20, '115', 'Marion', 'KS', 20, 'KANSAS'),
#  (20, '117', 'Marshall', 'KS', 20, 'KANSAS'),
#  (20, '119', 'Meade', 'KS', 20, 'KANSAS'),
#  (20, '121', 'Miami', 'KS', 20, 'KANSAS'),
#  (20, '123', 'Mitchell', 'KS', 20, 'KANSAS'),
#  (20, '125', 'Montgomery', 'KS', 20, 'KANSAS'),
#  (20, '127', 'Morris', 'KS', 20, 'KANSAS'),
#  (20, '129', 'Morton', 'KS', 20, 'KANSAS'),
#  (20, '131', 'Nemaha', 'KS', 20, 'KANSAS'),
#  (20, '133', 'Neosho', 'KS', 20, 'KANSAS'),
#  (20, '135', 'Ness', 'KS', 20, 'KANSAS'),
#  (20, '137', 'Norton', 'KS', 20, 'KANSAS'),
#  (20, '139', 'Osage', 'KS', 20, 'KANSAS'),
#  (20, '141', 'Osborne', 'KS', 20, 'KANSAS'),
#  (20, '143', 'Ottawa', 'KS', 20, 'KANSAS'),
#  (20, '145', 'Pawnee', 'KS', 20, 'KANSAS'),
#  (20, '147', 'Phillips', 'KS', 20, 'KANSAS'),
#  (20, '149', 'Pottawatomie', 'KS', 20, 'KANSAS'),
#  (20, '151', 'Pratt', 'KS', 20, 'KANSAS'),
#  (20, '153', 'Rawlins', 'KS', 20, 'KANSAS'),
#  (20, '155', 'Reno', 'KS', 20, 'KANSAS'),
#  (20, '157', 'Republic', 'KS', 20, 'KANSAS'),
#  (20, '159', 'Rice', 'KS', 20, 'KANSAS'),
#  (20, '161', 'Riley', 'KS', 20, 'KANSAS'),
#  (20, '163', 'Rooks', 'KS', 20, 'KANSAS'),
#  (20, '165', 'Rush', 'KS', 20, 'KANSAS'),
#  (20, '167', 'Russell', 'KS', 20, 'KANSAS'),
#  (20, '169', 'Saline', 'KS', 20, 'KANSAS'),
#  (20, '171', 'Scott', 'KS', 20, 'KANSAS'),
#  (20, '173', 'Sedgwick', 'KS', 20, 'KANSAS'),
#  (20, '175', 'Seward', 'KS', 20, 'KANSAS'),
#  (20, '177', 'Shawnee', 'KS', 20, 'KANSAS'),
#  (20, '179', 'Sheridan', 'KS', 20, 'KANSAS'),
#  (20, '181', 'Sherman', 'KS', 20, 'KANSAS'),
#  (20, '183', 'Smith', 'KS', 20, 'KANSAS'),
#  (20, '185', 'Stafford', 'KS', 20, 'KANSAS'),
#  (20, '187', 'Stanton', 'KS', 20, 'KANSAS'),
#  (20, '189', 'Stevens', 'KS', 20, 'KANSAS'),
#  (20, '191', 'Sumner', 'KS', 20, 'KANSAS'),
#  (20, '193', 'Thomas', 'KS', 20, 'KANSAS'),
#  (20, '195', 'Trego', 'KS', 20, 'KANSAS'),
#  (20, '197', 'Wabaunsee', 'KS', 20, 'KANSAS'),
#  (20, '199', 'Wallace', 'KS', 20, 'KANSAS'),
#  (20, '201', 'Washington', 'KS', 20, 'KANSAS'),
#  (20, '203', 'Wichita', 'KS', 20, 'KANSAS'),
#  (20, '205', 'Wilson', 'KS', 20, 'KANSAS'),
#  (20, '207', 'Woodson', 'KS', 20, 'KANSAS'),
#  (20, '209', 'Wyandotte', 'KS', 20, 'KANSAS'),
#  (21, '001', 'Adair', 'KY', 21, 'KENTUCKY'),
#  (21, '003', 'Allen', 'KY', 21, 'KENTUCKY'),
#  (21, '005', 'Anderson', 'KY', 21, 'KENTUCKY'),
#  (21, '007', 'Ballard', 'KY', 21, 'KENTUCKY'),
#  (21, '009', 'Barren', 'KY', 21, 'KENTUCKY'),
#  (21, '011', 'Bath', 'KY', 21, 'KENTUCKY'),
#  (21, '013', 'Bell', 'KY', 21, 'KENTUCKY'),
#  (21, '015', 'Boone', 'KY', 21, 'KENTUCKY'),
#  ...]

# %% [markdown]
# ### Explain and Query Plan Preview
#
# You can examine the estimated cost and rows by using `EXPLAIN` in front of the SQL command.
# The cell below shows an example of explaining a query, using the query above.
#
# Compare the two explain commands below. One is a proper join, the other is an accidental cross-product (explained below).

# %%
# %%sql
# EXPLAIN
# SELECT *
# FROM us_second_order_divisions AS sod JOIN util_us_states AS uus
#   ON sod.state_number_code = uus.state_number_code;
# Out:
#  * postgres://dsa_ro_user:***@pgsql.dsa.lan/dsa_ro
# 5 rows affected.
# [('Hash Join  (cost=2.35..99.61 rows=3295 width=29)',),
#  ('  Hash Cond: (sod.state_number_code = uus.state_number_code)',),
#  ('  ->  Seq Scan on us_second_order_divisions sod  (cost=0.00..51.95 rows=3295 width=14)',),
#  ('  ->  Hash  (cost=1.60..1.60 rows=60 width=15)',),
#  ('        ->  Seq Scan on util_us_states uus  (cost=0.00..1.60 rows=60 width=15)',)]

# %%
# %%sql
# EXPLAIN
# SELECT *
# FROM us_second_order_divisions AS sod, util_us_states AS uus
# Out:
#  * postgres://dsa_ro_user:***@pgsql.dsa.lan/dsa_ro
# 4 rows affected.
# [('Nested Loop  (cost=0.00..2524.95 rows=197700 width=29)',),
#  ('  ->  Seq Scan on us_second_order_divisions sod  (cost=0.00..51.95 rows=3295 width=14)',),
#  ('  ->  Materialize  (cost=0.00..1.90 rows=60 width=15)',),
#  ('        ->  Seq Scan on util_us_states uus  (cost=0.00..1.60 rows=60 width=15)',)]

# %% [markdown]
# Note in the first plan, the total cost is low and estimated <span style='background:yellow'>rows=3295</span>.
# ```
# Hash Join (cost=2.35..99.61 rows=3295 width=29)
# ```
#
# However, the second plan the rows explode to 197,700;  <span style='background:yellow'>rows=197700</span>
# ```
# Nested Loop (cost=0.00..2524.95 rows=197700 width=29)
# ```
#
# ---
#
# **<span style="background:yellow">WARNING:</span>**
# When combining data from multiple tables, you must give your query a _join condition_.
# Otherwise, the tables will be combined in a cartesian product, also known as a _cross join_.
# A cross join will combine every row of each table together, even when the overlapping columns do not match.

# %%
# %%sql
# SELECT count(*)
# FROM us_second_order_divisions AS sod, util_us_states AS uus;
# Out:
#  * postgres://dsa_ro_user:***@pgsql.dsa.lan/dsa_ro
# 1 rows affected.
# [(197700,)]

# %% [markdown]
# **Notice, in the cross join the number of rows explodes to 197,700 instead of the less than 4000 rows of the proper join.**
# We just executed a count because the data would be to large for this notebook learning environment.

# %% [markdown]
# ## <span style="background:yellow">Your Turn</span>
#
# 1. Write a `SELECT` statement that joins the tables "us_second_order_divisions" and "util_us_states", then shows the `state_name` and `county_name`.

# %%
# %%sql
# SELECT state_name, county_name
# FROM us_second_order_divisions AS sod
# JOIN util_us_states AS uus
#   ON sod.state_number_code = uus.state_number_code;
# Out:
#  * postgres://dsa_ro_user:***@pgsql.dsa.lan/dsa_ro
#
#  ('ALASKA', 'Bethel (CA)'),
#  ('ALASKA', 'Bristol Bay'),
#  ('ALASKA', 'Denali'),
#  ('ALASKA', 'Dillingham (CA)'),
#  ('ALASKA', 'Fairbanks North Star'),
#  ('ALASKA', 'Haines'),
#  ('ALASKA', 'Hoonah-Angoon (CA)'),
#  ('ALASKA', 'Juneau'),
#  ('ALASKA', 'Kenai Peninsula'),
#  ('ALASKA', 'Ketchikan Gateway'),
#  ('ALASKA', 'Kodiak Island'),
#  ('ALASKA', 'Lake and Peninsula'),
#  ('ALASKA', 'Matanuska-Susitna'),
#  ('ALASKA', 'Nome (CA)'),
#  ('ALASKA', 'North Slope'),
#  ('ALASKA', 'Northwest Arctic'),
#  ('ALASKA', 'P. of Wales-O. Ketchikan (CA)'),
#  ('ALASKA', 'Sitka'),
#  ('ALASKA', 'Skagway'),
#  ('ALASKA', 'Southeast Fairbanks (CA)'),
#  ('ALASKA', 'Valdez-Cordova (CA)'),
#  ('ALASKA', 'Wade Hampton (CA)'),
#  ('ALASKA', 'Wrangell-Petersburg (CA)'),
#  ('ALASKA', 'Yakutat'),
#  ('ALASKA', 'Yukon-Koyukuk (CA)'),
#  ('ARIZONA', 'Apache'),
#  ('ARIZONA', 'Cochise'),
#  ('ARIZONA', 'Coconino'),
#  ('ARIZONA', 'Gila'),
#  ('ARIZONA', 'Graham'),
#  ('ARIZONA', 'Greenlee'),
#  ('ARIZONA', 'La Paz'),
#  ('ARIZONA', 'Maricopa'),
#  ('ARIZONA', 'Mohave'),
#  ('ARIZONA', 'Navajo'),
#  ('ARIZONA', 'Pima'),
#  ('ARIZONA', 'Pinal'),
#  ('ARIZONA', 'Santa Cruz'),
#  ('ARIZONA', 'Yavapai'),
#  ('ARIZONA', 'Yuma'),
#  ('ARKANSAS', 'Arkansas'),
#  ('ARKANSAS', 'Ashley'),
#  ('ARKANSAS', 'Baxter'),
#  ('ARKANSAS', 'Benton'),
#  ('ARKANSAS', 'Boone'),
#  ('ARKANSAS', 'Bradley'),
#  ('ARKANSAS', 'Calhoun'),
#  ('ARKANSAS', 'Carroll'),
#  ('ARKANSAS', 'Chicot'),
#  ('ARKANSAS', 'Clark'),
#  ('ARKANSAS', 'Clay'),
#  ('ARKANSAS', 'Cleburne'),
#  ('ARKANSAS', 'Cleveland'),
#  ('ARKANSAS', 'Columbia'),
#  ('ARKANSAS', 'Conway'),
#  ('ARKANSAS', 'Craighead'),
#  ('ARKANSAS', 'Crawford'),
#  ('ARKANSAS', 'Crittenden'),
#  ('ARKANSAS', 'Cross'),
#  ('ARKANSAS', 'Dallas'),
#  ('ARKANSAS', 'Desha'),
#  ('ARKANSAS', 'Drew'),
#  ('ARKANSAS', 'Faulkner'),
#  ('ARKANSAS', 'Franklin'),
#  ('ARKANSAS', 'Fulton'),
#  ('ARKANSAS', 'Garland'),
#  ('ARKANSAS', 'Grant'),
#  ('ARKANSAS', 'Greene'),
#  ('ARKANSAS', 'Hempstead'),
#  ('ARKANSAS', 'Hot Spring'),
#  ('CALIFORNIA', 'Napa'),
#  ('CALIFORNIA', 'Nevada'),
#  ('CALIFORNIA', 'Orange'),
#  ('CALIFORNIA', 'Placer'),
#  ('CALIFORNIA', 'Plumas'),
#  ('CALIFORNIA', 'Riverside'),
#  ('CALIFORNIA', 'Sacramento'),
#  ('CALIFORNIA', 'San Benito'),
#  ('CALIFORNIA', 'San Bernardino'),
#  ('CALIFORNIA', 'San Diego'),
#  ('CALIFORNIA', 'San Francisco'),
#  ('CALIFORNIA', 'San Joaquin'),
#  ('CALIFORNIA', 'San Luis Obispo'),
#  ('CALIFORNIA', 'San Mateo'),
#  ('CALIFORNIA', 'Santa Barbara'),
#  ('CALIFORNIA', 'Santa Clara'),
#  ('CALIFORNIA', 'Santa Cruz'),
#  ('CALIFORNIA', 'Shasta'),
#  ('CALIFORNIA', 'Sierra'),
#  ('CALIFORNIA', 'Siskiyou'),
#  ('CALIFORNIA', 'Solano'),
#  ('CALIFORNIA', 'Sonoma'),
#  ('CALIFORNIA', 'Stanislaus'),
#  ('CALIFORNIA', 'Sutter'),
#  ('CALIFORNIA', 'Tehama'),
#  ('CALIFORNIA', 'Trinity'),
#  ('CALIFORNIA', 'Tulare'),
#  ('CALIFORNIA', 'Tuolumne'),
#  ('CALIFORNIA', 'Ventura'),
#  ('CALIFORNIA', 'Yolo'),
#  ('CALIFORNIA', 'Yuba'),
#  ('COLORADO', 'Adams'),
#  ('COLORADO', 'Alamosa'),
#  ('COLORADO', 'Arapahoe'),
#  ('COLORADO', 'Archuleta'),
#  ('COLORADO', 'Baca'),
#  ('COLORADO', 'Bent'),
#  ('COLORADO', 'Boulder'),
#  ('COLORADO', 'Broomfield'),
#  ('COLORADO', 'Chaffee'),
#  ('COLORADO', 'Cheyenne'),
#  ('COLORADO', 'Clear Creek'),
#  ('COLORADO', 'Conejos'),
#  ('COLORADO', 'Costilla'),
#  ('COLORADO', 'Crowley'),
#  ('COLORADO', 'Custer'),
#  ('COLORADO', 'Delta'),
#  ('COLORADO', 'Denver'),
#  ('COLORADO', 'Dolores'),
#  ('COLORADO', 'Douglas'),
#  ('COLORADO', 'Eagle'),
#  ('COLORADO', 'Elbert'),
#  ('COLORADO', 'El Paso'),
#  ('COLORADO', 'Fremont'),
#  ('COLORADO', 'Garfield'),
#  ('COLORADO', 'Gilpin'),
#  ('COLORADO', 'Grand'),
#  ('COLORADO', 'Gunnison'),
#  ('COLORADO', 'Hinsdale'),
#  ('COLORADO', 'Huerfano'),
#  ('COLORADO', 'Jackson'),
#  ('COLORADO', 'Jefferson'),
#  ('COLORADO', 'Kiowa'),
#  ('COLORADO', 'Kit Carson'),
#  ('COLORADO', 'Lake'),
#  ('COLORADO', 'La Plata'),
#  ('COLORADO', 'Larimer'),
#  ('COLORADO', 'Las Animas'),
#  ('COLORADO', 'Lincoln'),
#  ('COLORADO', 'Logan'),
#  ('COLORADO', 'Mesa'),
#  ('COLORADO', 'Mineral'),
#  ('COLORADO', 'Moffat'),
#  ('COLORADO', 'Montezuma'),
#  ('COLORADO', 'Montrose'),
#  ('COLORADO', 'Morgan'),
#  ('COLORADO', 'Otero'),
#  ('COLORADO', 'Ouray'),
#  ('COLORADO', 'Park'),
#  ('COLORADO', 'Phillips'),
#  ('COLORADO', 'Pitkin'),
#  ('COLORADO', 'Prowers'),
#  ('COLORADO', 'Pueblo'),
#  ('COLORADO', 'Rio Blanco'),
#  ('COLORADO', 'Rio Grande'),
#  ('COLORADO', 'Routt'),
#  ('COLORADO', 'Saguache'),
#  ('COLORADO', 'San Juan'),
#  ('COLORADO', 'San Miguel'),
#  ('COLORADO', 'Sedgwick'),
#  ('COLORADO', 'Summit'),
#  ('COLORADO', 'Teller'),
#  ('COLORADO', 'Washington'),
#  ('COLORADO', 'Weld'),
#  ('COLORADO', 'Yuma'),
#  ('CONNECTICUT', 'Fairfield'),
#  ('CONNECTICUT', 'Hartford'),
#  ('CONNECTICUT', 'Litchfield'),
#  ('CONNECTICUT', 'Middlesex'),
#  ('CONNECTICUT', 'New Haven'),
#  ('CONNECTICUT', 'New London'),
#  ('CONNECTICUT', 'Tolland'),
#  ('CONNECTICUT', 'Windham'),
#  ('DELAWARE', 'Kent'),
#  ('DELAWARE', 'New Castle'),
#  ('DELAWARE', 'Sussex'),
#  ('DISTRICT OF COLUMBIA', 'District of Columbia'),
#  ('FLORIDA', 'Alachua'),
#  ('FLORIDA', 'Baker'),
#  ('FLORIDA', 'Bay'),
#  ('FLORIDA', 'Bradford'),
#  ('FLORIDA', 'Brevard'),
#  ('FLORIDA', 'Broward'),
#  ('FLORIDA', 'Calhoun'),
#  ('FLORIDA', 'Charlotte'),
#  ('FLORIDA', 'Citrus'),
#  ('FLORIDA', 'Clay'),
#  ('FLORIDA', 'Collier'),
#  ('FLORIDA', 'Columbia'),
#  ('FLORIDA', 'DeSoto'),
#  ('FLORIDA', 'Dixie'),
#  ('FLORIDA', 'Duval'),
#  ('FLORIDA', 'Escambia'),
#  ('FLORIDA', 'Flagler'),
#  ('FLORIDA', 'Franklin'),
#  ('FLORIDA', 'Gadsden'),
#  ('FLORIDA', 'Gilchrist'),
#  ('FLORIDA', 'Glades'),
#  ('FLORIDA', 'Gulf'),
#  ('FLORIDA', 'Hamilton'),
#  ('FLORIDA', 'Hardee'),
#  ('FLORIDA', 'Hendry'),
#  ('FLORIDA', 'Hernando'),
#  ('FLORIDA', 'Highlands'),
#  ('FLORIDA', 'Hillsborough'),
#  ('FLORIDA', 'Holmes'),
#  ('FLORIDA', 'Indian River'),
#  ('FLORIDA', 'Jackson'),
#  ('FLORIDA', 'Jefferson'),
#  ('FLORIDA', 'Lafayette'),
#  ('FLORIDA', 'Lake'),
#  ('FLORIDA', 'Lee'),
#  ('FLORIDA', 'Leon'),
#  ('FLORIDA', 'Levy'),
#  ('FLORIDA', 'Liberty'),
#  ('FLORIDA', 'Madison'),
#  ('FLORIDA', 'Manatee'),
#  ('FLORIDA', 'Marion'),
#  ('FLORIDA', 'Martin'),
#  ('FLORIDA', 'Miami-Dade'),
#  ('FLORIDA', 'Monroe'),
#  ('FLORIDA', 'Nassau'),
#  ('FLORIDA', 'Okaloosa'),
#  ('FLORIDA', 'Okeechobee'),
#  ('FLORIDA', 'Orange'),
#  ('FLORIDA', 'Osceola'),
#  ('FLORIDA', 'Palm Beach'),
#  ('FLORIDA', 'Pasco'),
#  ('FLORIDA', 'Pinellas'),
#  ('FLORIDA', 'Polk'),
#  ('FLORIDA', 'Putnam'),
#  ('FLORIDA', 'St. Johns'),
#  ('FLORIDA', 'St. Lucie'),
#  ('FLORIDA', 'Santa Rosa'),
#  ('FLORIDA', 'Sarasota'),
#  ('FLORIDA', 'Seminole'),
#  ('FLORIDA', 'Sumter'),
#  ('FLORIDA', 'Suwannee'),
#  ('FLORIDA', 'Taylor'),
#  ('FLORIDA', 'Union'),
#  ('FLORIDA', 'Volusia'),
#  ('FLORIDA', 'Wakulla'),
#  ('FLORIDA', 'Walton'),
#  ('FLORIDA', 'Washington'),
#  ('GEORGIA', 'Appling'),
#  ('GEORGIA', 'Atkinson'),
#  ('GEORGIA', 'Bacon'),
#  ('GEORGIA', 'Baker'),
#  ('GEORGIA', 'Baldwin'),
#  ('GEORGIA', 'Banks'),
#  ('GEORGIA', 'Barrow'),
#  ('GEORGIA', 'Bartow'),
#  ('GEORGIA', 'Ben Hill'),
#  ('GEORGIA', 'Berrien'),
#  ('GEORGIA', 'Bibb'),
#  ('GEORGIA', 'Bleckley'),
#  ('GEORGIA', 'Brantley'),
#  ('GEORGIA', 'Brooks'),
#  ('GEORGIA', 'Bryan'),
#  ('GEORGIA', 'Bulloch'),
#  ('GEORGIA', 'Burke'),
#  ('GEORGIA', 'Butts'),
#  ('GEORGIA', 'Calhoun'),
#  ('GEORGIA', 'Camden'),
#  ('GEORGIA', 'Candler'),
#  ('GEORGIA', 'Carroll'),
#  ('GEORGIA', 'Catoosa'),
#  ('GEORGIA', 'Charlton'),
#  ('GEORGIA', 'Chatham'),
#  ('GEORGIA', 'Chattahoochee'),
#  ('GEORGIA', 'Chattooga'),
#  ('GEORGIA', 'Cherokee'),
#  ('GEORGIA', 'Clarke'),
#  ('GEORGIA', 'Clay'),
#  ('GEORGIA', 'Clayton'),
#  ('GEORGIA', 'Clinch'),
#  ('GEORGIA', 'Cobb'),
#  ('GEORGIA', 'Coffee'),
#  ('GEORGIA', 'Colquitt'),
#  ('GEORGIA', 'Columbia'),
#  ('GEORGIA', 'Cook'),
#  ('GEORGIA', 'Coweta'),
#  ('GEORGIA', 'Crawford'),
#  ('GEORGIA', 'Crisp'),
#  ('GEORGIA', 'Dade'),
#  ('GEORGIA', 'Dawson'),
#  ('GEORGIA', 'Decatur'),
#  ('GEORGIA', 'DeKalb'),
#  ('GEORGIA', 'Dodge'),
#  ('GEORGIA', 'Dooly'),
#  ('GEORGIA', 'Dougherty'),
#  ('GEORGIA', 'Douglas'),
#  ('GEORGIA', 'Early'),
#  ('GEORGIA', 'Echols'),
#  ('GEORGIA', 'Effingham'),
#  ('GEORGIA', 'Stewart'),
#  ('GEORGIA', 'Sumter'),
#  ('GEORGIA', 'Talbot'),
#  ('GEORGIA', 'Taliaferro'),
#  ('GEORGIA', 'Tattnall'),
#  ('GEORGIA', 'Taylor'),
#  ('GEORGIA', 'Telfair'),
#  ('GEORGIA', 'Terrell'),
#  ('GEORGIA', 'Thomas'),
#  ('GEORGIA', 'Tift'),
#  ('GEORGIA', 'Toombs'),
#  ('GEORGIA', 'Towns'),
#  ('GEORGIA', 'Treutlen'),
#  ('GEORGIA', 'Troup'),
#  ('GEORGIA', 'Turner'),
#  ('GEORGIA', 'Twiggs'),
#  ('GEORGIA', 'Union'),
#  ('GEORGIA', 'Upson'),
#  ('GEORGIA', 'Walker'),
#  ('GEORGIA', 'Walton'),
#  ('GEORGIA', 'Ware'),
#  ('GEORGIA', 'Warren'),
#  ('GEORGIA', 'Washington'),
#  ('GEORGIA', 'Wayne'),
#  ('GEORGIA', 'Webster'),
#  ('GEORGIA', 'Wheeler'),
#  ('GEORGIA', 'White'),
#  ('GEORGIA', 'Whitfield'),
#  ('GEORGIA', 'Wilcox'),
#  ('GEORGIA', 'Wilkes'),
#  ('GEORGIA', 'Wilkinson'),
#  ('GEORGIA', 'Worth'),
#  ('HAWAII', 'Hawaii'),
#  ('HAWAII', 'Honolulu'),
#  ('HAWAII', 'Kalawao'),
#  ('HAWAII', 'Kauai'),
#  ('HAWAII', 'Maui'),
#  ('IDAHO', 'Ada'),
#  ('IDAHO', 'Adams'),
#  ('IDAHO', 'Bannock'),
#  ('IDAHO', 'Bear Lake'),
#  ('IDAHO', 'Benewah'),
#  ('IDAHO', 'Bingham'),
#  ('IDAHO', 'Blaine'),
#  ('IDAHO', 'Boise'),
#  ('IDAHO', 'Bonner'),
#  ('IDAHO', 'Bonneville'),
#  ('IDAHO', 'Boundary'),
#  ('IDAHO', 'Butte'),
#  ('IDAHO', 'Camas'),
#  ('IDAHO', 'Canyon'),
#  ('IDAHO', 'Caribou'),
#  ('IDAHO', 'Cassia'),
#  ('IDAHO', 'Clark'),
#  ('IDAHO', 'Clearwater'),
#  ('IDAHO', 'Custer'),
#  ('IDAHO', 'Elmore'),
#  ('IDAHO', 'Franklin'),
#  ('IDAHO', 'Fremont'),
#  ('IDAHO', 'Gem'),
#  ('IDAHO', 'Gooding'),
#  ('IDAHO', 'Idaho'),
#  ('IDAHO', 'Jefferson'),
#  ('IDAHO', 'Jerome'),
#  ('IDAHO', 'Kootenai'),
#  ('IDAHO', 'Latah'),
#  ('IDAHO', 'Lemhi'),
#  ('IDAHO', 'Lewis'),
#  ('IDAHO', 'Lincoln'),
#  ('IDAHO', 'Madison'),
#  ('IDAHO', 'Minidoka'),
#  ('IDAHO', 'Nez Perce'),
#  ('IDAHO', 'Oneida'),
#  ('IDAHO', 'Owyhee'),
#  ('IDAHO', 'Payette'),
#  ('IDAHO', 'Power'),
#  ('IDAHO', 'Shoshone'),
#  ('IDAHO', 'Teton'),
#  ('IDAHO', 'Twin Falls'),
#  ('IDAHO', 'Valley'),
#  ('IDAHO', 'Washington'),
#  ('ILLINOIS', 'Adams'),
#  ('ILLINOIS', 'Alexander'),
#  ('ILLINOIS', 'Bond'),
#  ('ILLINOIS', 'Boone'),
#  ('ILLINOIS', 'Brown'),
#  ('ILLINOIS', 'Bureau'),
#  ('ILLINOIS', 'Calhoun'),
#  ('ILLINOIS', 'Carroll'),
#  ('ILLINOIS', 'Cass'),
#  ('ILLINOIS', 'Champaign'),
#  ('ILLINOIS', 'Christian'),
#  ('ILLINOIS', 'Clark'),
#  ('ILLINOIS', 'Clay'),
#  ('ILLINOIS', 'Clinton'),
#  ('ILLINOIS', 'Coles'),
#  ('ILLINOIS', 'Cook'),
#  ('ILLINOIS', 'Crawford'),
#  ('ILLINOIS', 'Cumberland'),
#  ('ILLINOIS', 'DeKalb'),
#  ('ILLINOIS', 'De Witt'),
#  ('ILLINOIS', 'Douglas'),
#  ('ILLINOIS', 'DuPage'),
#  ('ILLINOIS', 'Edgar'),
#  ('ILLINOIS', 'Edwards'),
#  ('ILLINOIS', 'Effingham'),
#  ('ILLINOIS', 'Fayette'),
#  ('ILLINOIS', 'Ford'),
#  ('ILLINOIS', 'Franklin'),
#  ('ILLINOIS', 'Fulton'),
#  ('ILLINOIS', 'Gallatin'),
#  ('ILLINOIS', 'Greene'),
#  ('ILLINOIS', 'Grundy'),
#  ('ILLINOIS', 'Hamilton'),
#  ('ILLINOIS', 'Hancock'),
#  ('ILLINOIS', 'Hardin'),
#  ('ILLINOIS', 'Henderson'),
#  ('ILLINOIS', 'Henry'),
#  ('ILLINOIS', 'Iroquois'),
#  ('ILLINOIS', 'Jackson'),
#  ('ILLINOIS', 'Jasper'),
#  ('ILLINOIS', 'Jefferson'),
#  ('ILLINOIS', 'Jersey'),
#  ('ILLINOIS', 'Jo Daviess'),
#  ('ILLINOIS', 'Johnson'),
#  ('ILLINOIS', 'Kane'),
#  ('ILLINOIS', 'Kankakee'),
#  ('ILLINOIS', 'Kendall'),
#  ('ILLINOIS', 'Knox'),
#  ('ILLINOIS', 'Lake'),
#  ('ILLINOIS', 'La Salle'),
#  ('ILLINOIS', 'Lawrence'),
#  ('ILLINOIS', 'Lee'),
#  ('ILLINOIS', 'Livingston'),
#  ('ILLINOIS', 'Logan'),
#  ('ILLINOIS', 'McDonough'),
#  ('ILLINOIS', 'McHenry'),
#  ('ILLINOIS', 'McLean'),
#  ('ILLINOIS', 'Macon'),
#  ('ILLINOIS', 'Macoupin'),
#  ('ILLINOIS', 'Madison'),
#  ('ILLINOIS', 'Marion'),
#  ('ILLINOIS', 'Marshall'),
#  ('ILLINOIS', 'Mason'),
#  ('ILLINOIS', 'Massac'),
#  ('ILLINOIS', 'Menard'),
#  ('ILLINOIS', 'Mercer'),
#  ('ILLINOIS', 'Monroe'),
#  ('ILLINOIS', 'Montgomery'),
#  ('ILLINOIS', 'Morgan'),
#  ('ILLINOIS', 'Moultrie'),
#  ('ILLINOIS', 'Ogle'),
#  ('ILLINOIS', 'Peoria'),
#  ('ILLINOIS', 'Perry'),
#  ('ILLINOIS', 'Piatt'),
#  ('ILLINOIS', 'Pike'),
#  ('ILLINOIS', 'Pope'),
#  ('ILLINOIS', 'Pulaski'),
#  ('ILLINOIS', 'Putnam'),
#  ('ILLINOIS', 'Randolph'),
#  ('ILLINOIS', 'Richland'),
#  ('ILLINOIS', 'Rock Island'),
#  ('ILLINOIS', 'St. Clair'),
#  ('ILLINOIS', 'Saline'),
#  ('ILLINOIS', 'Sangamon'),
#  ('ILLINOIS', 'Schuyler'),
#  ('ILLINOIS', 'Scott'),
#  ('ILLINOIS', 'Shelby'),
#  ('ILLINOIS', 'Stark'),
#  ('ILLINOIS', 'Stephenson'),
#  ('ILLINOIS', 'Tazewell'),
#  ('ILLINOIS', 'Union'),
#  ('ILLINOIS', 'Vermilion'),
#  ('ILLINOIS', 'Wabash'),
#  ('ILLINOIS', 'Warren'),
#  ('ILLINOIS', 'Washington'),
#  ('ILLINOIS', 'Wayne'),
#  ('ILLINOIS', 'White'),
#  ('ILLINOIS', 'Whiteside'),
#  ('ILLINOIS', 'Will'),
#  ('ILLINOIS', 'Williamson'),
#  ('ILLINOIS', 'Winnebago'),
#  ('ILLINOIS', 'Woodford'),
#  ('INDIANA', 'Adams'),
#  ('INDIANA', 'Allen'),
#  ('INDIANA', 'Bartholomew'),
#  ('INDIANA', 'Benton'),
#  ('INDIANA', 'Blackford'),
#  ('INDIANA', 'Boone'),
#  ('INDIANA', 'Brown'),
#  ('INDIANA', 'Carroll'),
#  ('INDIANA', 'Cass'),
#  ('INDIANA', 'Clark'),
#  ('INDIANA', 'Clay'),
#  ('INDIANA', 'Clinton'),
#  ('INDIANA', 'Crawford'),
#  ('INDIANA', 'Daviess'),
#  ('INDIANA', 'Dearborn'),
#  ('INDIANA', 'Decatur'),
#  ('INDIANA', 'DeKalb'),
#  ('INDIANA', 'Delaware'),
#  ('INDIANA', 'Dubois'),
#  ('INDIANA', 'Elkhart'),
#  ('INDIANA', 'Fayette'),
#  ('INDIANA', 'Floyd'),
#  ('INDIANA', 'Fountain'),
#  ('INDIANA', 'Franklin'),
#  ('INDIANA', 'Fulton'),
#  ('INDIANA', 'Gibson'),
#  ('INDIANA', 'Grant'),
#  ('INDIANA', 'Greene'),
#  ('INDIANA', 'Hamilton'),
#  ('INDIANA', 'Hancock'),
#  ('INDIANA', 'Harrison'),
#  ('INDIANA', 'Hendricks'),
#  ('INDIANA', 'Henry'),
#  ('INDIANA', 'Howard'),
#  ('INDIANA', 'Huntington'),
#  ('INDIANA', 'Jackson'),
#  ('INDIANA', 'Jasper'),
#  ('INDIANA', 'Jay'),
#  ('INDIANA', 'Jefferson'),
#  ('INDIANA', 'Jennings'),
#  ('INDIANA', 'Johnson'),
#  ('INDIANA', 'Knox'),
#  ('INDIANA', 'Kosciusko'),
#  ('INDIANA', 'LaGrange'),
#  ('INDIANA', 'Lake'),
#  ('INDIANA', 'LaPorte'),
#  ('INDIANA', 'Lawrence'),
#  ('INDIANA', 'Madison'),
#  ('INDIANA', 'Marion'),
#  ('INDIANA', 'Marshall'),
#  ('INDIANA', 'Martin'),
#  ('INDIANA', 'Miami'),
#  ('INDIANA', 'Monroe'),
#  ('INDIANA', 'Montgomery'),
#  ('INDIANA', 'Morgan'),
#  ('INDIANA', 'Newton'),
#  ('INDIANA', 'Noble'),
#  ('INDIANA', 'Ohio'),
#  ('INDIANA', 'Orange'),
#  ('INDIANA', 'Owen'),
#  ('INDIANA', 'Parke'),
#  ('INDIANA', 'Perry'),
#  ('INDIANA', 'Pike'),
#  ('INDIANA', 'Porter'),
#  ('INDIANA', 'Posey'),
#  ('INDIANA', 'Pulaski'),
#  ('INDIANA', 'Putnam'),
#  ('INDIANA', 'Randolph'),
#  ('INDIANA', 'Ripley'),
#  ('INDIANA', 'Rush'),
#  ('INDIANA', 'St. Joseph'),
#  ('INDIANA', 'Scott'),
#  ('INDIANA', 'Shelby'),
#  ('INDIANA', 'Spencer'),
#  ('INDIANA', 'Starke'),
#  ('INDIANA', 'Steuben'),
#  ('INDIANA', 'Sullivan'),
#  ('INDIANA', 'Switzerland'),
#  ('INDIANA', 'Tippecanoe'),
#  ('INDIANA', 'Tipton'),
#  ('INDIANA', 'Union'),
#  ('INDIANA', 'Vanderburgh'),
#  ('INDIANA', 'Vermillion'),
#  ('INDIANA', 'Vigo'),
#  ('INDIANA', 'Wabash'),
#  ('INDIANA', 'Warren'),
#  ('INDIANA', 'Warrick'),
#  ('INDIANA', 'Washington'),
#  ('INDIANA', 'Wayne'),
#  ('INDIANA', 'Wells'),
#  ('INDIANA', 'White'),
#  ('INDIANA', 'Whitley'),
#  ('IOWA', 'Adair'),
#  ('IOWA', 'Adams'),
#  ('IOWA', 'Allamakee'),
#  ('IOWA', 'Appanoose'),
#  ('IOWA', 'Audubon'),
#  ('IOWA', 'Benton'),
#  ('IOWA', 'Black Hawk'),
#  ('IOWA', 'Boone'),
#  ('IOWA', 'Bremer'),
#  ('IOWA', 'Buchanan'),
#  ('IOWA', 'Buena Vista'),
#  ('IOWA', 'Butler'),
#  ('IOWA', 'Calhoun'),
#  ('IOWA', 'Carroll'),
#  ('IOWA', 'Cass'),
#  ('IOWA', 'Cedar'),
#  ('IOWA', 'Cerro Gordo'),
#  ('IOWA', 'Cherokee'),
#  ('IOWA', 'Chickasaw'),
#  ('IOWA', 'Clarke'),
#  ('IOWA', 'Clay'),
#  ('IOWA', 'Clayton'),
#  ('IOWA', 'Clinton'),
#  ('IOWA', 'Crawford'),
#  ('IOWA', 'Dallas'),
#  ('IOWA', 'Davis'),
#  ('IOWA', 'Decatur'),
#  ('IOWA', 'Delaware'),
#  ('IOWA', 'Des Moines'),
#  ('IOWA', 'Dickinson'),
#  ('IOWA', 'Dubuque'),
#  ('IOWA', 'Emmet'),
#  ('IOWA', 'Fayette'),
#  ('IOWA', 'Floyd'),
#  ('IOWA', 'Franklin'),
#  ('IOWA', 'Fremont'),
#  ('IOWA', 'Greene'),
#  ('IOWA', 'Grundy'),
#  ('IOWA', 'Guthrie'),
#  ('IOWA', 'Hamilton'),
#  ('IOWA', 'Hancock'),
#  ('IOWA', 'Hardin'),
#  ('IOWA', 'Harrison'),
#  ('IOWA', 'Henry'),
#  ('IOWA', 'Howard'),
#  ('IOWA', 'Humboldt'),
#  ('IOWA', 'Ida'),
#  ('IOWA', 'Iowa'),
#  ('IOWA', 'Jackson'),
#  ('IOWA', 'Jasper'),
#  ('IOWA', 'Jefferson'),
#  ('IOWA', 'Johnson'),
#  ('IOWA', 'Jones'),
#  ('IOWA', 'Keokuk'),
#  ('IOWA', 'Kossuth'),
#  ('IOWA', 'Lee'),
#  ('IOWA', 'Linn'),
#  ('IOWA', 'Louisa'),
#  ('IOWA', 'Lucas'),
#  ('IOWA', 'Lyon'),
#  ('IOWA', 'Madison'),
#  ('IOWA', 'Mahaska'),
#  ('IOWA', 'Marion'),
#  ('IOWA', 'Marshall'),
#  ('IOWA', 'Mills'),
#  ('IOWA', 'Mitchell'),
#  ('IOWA', 'Monona'),
#  ('IOWA', 'Monroe'),
#  ('IOWA', 'Montgomery'),
#  ('IOWA', 'Muscatine'),
#  ('IOWA', "O'Brien"),
#  ('IOWA', 'Osceola'),
#  ('IOWA', 'Page'),
#  ('IOWA', 'Palo Alto'),
#  ('IOWA', 'Plymouth'),
#  ('IOWA', 'Pocahontas'),
#  ('IOWA', 'Polk'),
#  ('IOWA', 'Pottawattamie'),
#  ('IOWA', 'Poweshiek'),
#  ('IOWA', 'Ringgold'),
#  ('IOWA', 'Sac'),
#  ('IOWA', 'Scott'),
#  ('IOWA', 'Shelby'),
#  ('IOWA', 'Sioux'),
#  ('IOWA', 'Story'),
#  ('IOWA', 'Tama'),
#  ('IOWA', 'Taylor'),
#  ('IOWA', 'Union'),
#  ('IOWA', 'Van Buren'),
#  ('IOWA', 'Wapello'),
#  ('IOWA', 'Warren'),
#  ('IOWA', 'Washington'),
#  ('IOWA', 'Wayne'),
#  ('IOWA', 'Webster'),
#  ('IOWA', 'Winnebago'),
#  ('IOWA', 'Winneshiek'),
#  ('IOWA', 'Woodbury'),
#  ('IOWA', 'Worth'),
#  ('IOWA', 'Wright'),
#  ('KANSAS', 'Allen'),
#  ('KANSAS', 'Anderson'),
#  ('KANSAS', 'Atchison'),
#  ('KANSAS', 'Barber'),
#  ('KANSAS', 'Barton'),
#  ('KANSAS', 'Bourbon'),
#  ('KANSAS', 'Brown'),
#  ('KANSAS', 'Butler'),
#  ('KANSAS', 'Chase'),
#  ('KANSAS', 'Chautauqua'),
#  ('KANSAS', 'Cherokee'),
#  ('KANSAS', 'Cheyenne'),
#  ('KANSAS', 'Clark'),
#  ('KANSAS', 'Clay'),
#  ('KANSAS', 'Cloud'),
#  ('KANSAS', 'Coffey'),
#  ('KANSAS', 'Comanche'),
#  ('KANSAS', 'Cowley'),
#  ('KANSAS', 'Crawford'),
#  ('KANSAS', 'Decatur'),
#  ('KANSAS', 'Dickinson'),
#  ('KANSAS', 'Doniphan'),
#  ('KANSAS', 'Douglas'),
#  ('KANSAS', 'Edwards'),
#  ('KANSAS', 'Elk'),
#  ('KANSAS', 'Ellis'),
#  ('KANSAS', 'Ellsworth'),
#  ('KANSAS', 'Finney'),
#  ('KANSAS', 'Ford'),
#  ('KANSAS', 'Franklin'),
#  ('KANSAS', 'Geary'),
#  ('KANSAS', 'Gove'),
#  ('KANSAS', 'Graham'),
#  ('KANSAS', 'Grant'),
#  ('KANSAS', 'Gray'),
#  ('KANSAS', 'Greeley'),
#  ('KANSAS', 'Greenwood'),
#  ('KANSAS', 'Hamilton'),
#  ('KANSAS', 'Harper'),
#  ('KANSAS', 'Harvey'),
#  ('KANSAS', 'Haskell'),
#  ('KANSAS', 'Hodgeman'),
#  ('KANSAS', 'Jackson'),
#  ('KANSAS', 'Jefferson'),
#  ('KANSAS', 'Jewell'),
#  ('KANSAS', 'Johnson'),
#  ('KANSAS', 'Kearny'),
#  ('KANSAS', 'Kingman'),
#  ('KANSAS', 'Kiowa'),
#  ('KANSAS', 'Labette'),
#  ('KANSAS', 'Lane'),
#  ('KANSAS', 'Leavenworth'),
#  ('KANSAS', 'Lincoln'),
#  ('KANSAS', 'Linn'),
#  ('KANSAS', 'Logan'),
#  ('KANSAS', 'Lyon'),
#  ('KANSAS', 'McPherson'),
#  ('KANSAS', 'Marion'),
#  ('KANSAS', 'Marshall'),
#  ('KANSAS', 'Meade'),
#  ('KANSAS', 'Miami'),
#  ('KANSAS', 'Mitchell'),
#  ('KANSAS', 'Montgomery'),
#  ('KANSAS', 'Morris'),
#  ('KANSAS', 'Morton'),
#  ('KANSAS', 'Nemaha'),
#  ('KANSAS', 'Neosho'),
#  ('KANSAS', 'Ness'),
#  ('KANSAS', 'Norton'),
#  ('KANSAS', 'Osage'),
#  ('KANSAS', 'Osborne'),
#  ('KANSAS', 'Ottawa'),
#  ('KANSAS', 'Pawnee'),
#  ('KANSAS', 'Phillips'),
#  ('KANSAS', 'Pottawatomie'),
#  ('KANSAS', 'Pratt'),
#  ('KANSAS', 'Rawlins'),
#  ('KANSAS', 'Reno'),
#  ('KANSAS', 'Republic'),
#  ('KANSAS', 'Rice'),
#  ('KANSAS', 'Riley'),
#  ('KANSAS', 'Rooks'),
#  ('KANSAS', 'Rush'),
#  ('KANSAS', 'Russell'),
#  ('KANSAS', 'Saline'),
#  ('KANSAS', 'Scott'),
#  ('KANSAS', 'Sedgwick'),
#  ('KANSAS', 'Seward'),
#  ('KANSAS', 'Shawnee'),
#  ('KANSAS', 'Sheridan'),
#  ('KANSAS', 'Sherman'),
#  ('KANSAS', 'Smith'),
#  ('KANSAS', 'Stafford'),
#  ('KANSAS', 'Stanton'),
#  ('KANSAS', 'Stevens'),
#  ('KANSAS', 'Sumner'),
#  ('KANSAS', 'Thomas'),
#  ('KANSAS', 'Trego'),
#  ('KANSAS', 'Wabaunsee'),
#  ('KANSAS', 'Wallace'),
#  ('KANSAS', 'Washington'),
#  ('KANSAS', 'Wichita'),
#  ('KANSAS', 'Wilson'),
#  ('KANSAS', 'Woodson'),
#  ('KANSAS', 'Wyandotte'),
#  ('KENTUCKY', 'Adair'),
#  ('KENTUCKY', 'Allen'),
#  ('KENTUCKY', 'Anderson'),
#  ('KENTUCKY', 'Ballard'),
#  ('KENTUCKY', 'Barren'),
#  ('KENTUCKY', 'Bath'),
#  ('KENTUCKY', 'Bell'),
#  ('KENTUCKY', 'Boone'),
#  ...]

# %% [markdown]
# ## Viewing New Data Sets
#
# For this next part we will be using two new tables in the database.
# We will be using the `customers` table and the `orders` table.
#
# Again, we examine these tables to determine where they overlap and with which attributes, we can join the two tables.
#
# Describing the tables in the PostgreSQL database:
#
# ```SQL
# dsa_ro=> \d orders
#        Table "public.orders"
#    Column    |  Type   | Modifiers
# -------------+---------+-----------
#  order_id    | integer |
#  customer_id | integer |
#  employee_id | integer |
#  order_price | integer |
#
# dsa_ro=> \d customers
#              Table "public.customers"
#     Column     |         Type          | Modifiers
# ---------------+-----------------------+-----------
#  customer_id   | integer               |
#  customer_name | character varying(32) |
#  contact_name  | character varying(32) |
#  address       | character varying(64) |
#  city          | character varying(16) |
#  zipcode       | integer               |
#  country       | character varying(16) |
#
# ```

# %% [markdown]
# ## <span style="background:yellow">Your Turn</span>
#
# Take some time to use what you learned to query these tables and see what all of the data is and how it is all related.
#
# Look at the first 5 rows in the `orders`

# %%
# %%sql
# SELECT *
# FROM orders
# LIMIT 5;
# Out:
#  * postgres://dsa_ro_user:***@pgsql.dsa.lan/dsa_ro
# 5 rows affected.
# [(10135, 2, 1, 15),
#  (10136, 3, 1, 25),
#  (10137, 3, 1, 62),
#  (10138, 4, 2, 32),
#  (10139, 4, 2, 12)]

# %% [markdown]
# Look at the first 5 rows in the `customers`

# %%
# %%sql
# SELECT *
# FROM customers
# LIMIT 5;
# Out:
#  * postgres://dsa_ro_user:***@pgsql.dsa.lan/dsa_ro
# 5 rows affected.
# [(1, 'James Vanderbeek', 'Maria Anders', '123 State Ave.', 'St. Louis ', 63122, 'United States'),
#  (2, 'Will Starmes', 'Maria Anders', '216 Main St.', 'Okawville', 62271, 'United States'),
#  (3, 'Richard James', 'Ana Trujillo', '303 Foxfire Dr.', 'Columbia', 65201, 'United States'),
#  (4, 'Matt England', 'Antonio Moreno', '612 Rollins St.', 'Raliegh', 56842, 'United States'),
#  (5, 'George Blackwood', 'Antonio Moreno', '205 Broadway Ave', 'Columbia', 65201, 'United States')]

# %% [markdown]
# We can see that the `customer_id` column in each table is likely the same.
# In many cases, database definitions will include foreign key references for a key.
# An example of this is provided below.
#
# ---
# #### Example database table with three FKs
#
#
# ```SQL
#                                     Table "atc.task"
#   Column   |            Type             |                  Modifiers
# -----------+-----------------------------+----------------------------------------------
#  jobid     | bigint                      | not null
#  taskid    | integer                     | not null
#  tasktype  | character varying(50)       | not null
#  starttime | timestamp without time zone |
#  status    | character varying(10)       | not null default 'QUEUED'::character varying
#  statusmsg | text                        |
#  stoptime  | timestamp without time zone |
#  priority  | integer                     | not null default 500
#  descr     | text                        |
# Indexes:
#     "pk_task" PRIMARY KEY, btree (jobid, taskid)
# Foreign-key constraints:
#     "fk_task_job" FOREIGN KEY (jobid) REFERENCES atc.job(jobid) ON UPDATE CASCADE ON DELETE CASCADE
#     "fk_task_status" FOREIGN KEY (status) REFERENCES atc.task_status_type(status)
#     "fk_task_tasktype" FOREIGN KEY (tasktype) REFERENCES atc.task_type_tbl(tasktype) ON UPDATE CASCADE ON DELETE CASCADE
# ```
# ---
#
# We now continue by looking at some JOIN SQL examples.
#
#
# ## Inner Join
#
# To INNER JOIN the `orders` and `customers` we will use the `orders.customer_id = customers.customer_id` join condition.
#
# #### Example: List the Order ID and Shipping Address for all orders
#  1. Traditional SQL, INNER JOIN
#  1. Just JOIN, defaults to INNER
#  1. NATURAL JOIN is a short-cut in some databases, such as PostgreSQL. The NATURAL JOIN implicitly joins on all like named columns between the tables.  In this case, `customer_id`.
#  1. Join with cross product (using a comma between tables) and WHERE clause _join condition_
#  1. USING shortcut, list of like named columns between the tables.  In this case, `customer_id`.
#  1. Switched Join Order
#  1. Using Table Aliases

# %%
# %%sql
#
# SELECT order_id, address, city, zipcode, country
# FROM orders INNER JOIN customers
# ON orders.customer_id = customers.customer_id;
# Out:
#  * postgres://dsa_ro_user:***@pgsql.dsa.lan/dsa_ro
# 7 rows affected.
# [(10135, '216 Main St.', 'Okawville', 62271, 'United States'),
#  (10136, '303 Foxfire Dr.', 'Columbia', 65201, 'United States'),
#  (10137, '303 Foxfire Dr.', 'Columbia', 65201, 'United States'),
#  (10138, '612 Rollins St.', 'Raliegh', 56842, 'United States'),
#  (10139, '612 Rollins St.', 'Raliegh', 56842, 'United States'),
#  (10140, '612 Rollins St.', 'Raliegh', 56842, 'United States'),
#  (10141, '612 Rollins St.', 'Raliegh', 56842, 'United States')]

# %% [markdown]
# ## %%sql
#
# SELECT order_id, address, city, zipcode, country
# FROM orders JOIN customers
# ON orders.customer_id = customers.customer_id;

# %%
# %%sql
#
# SELECT order_id, address, city, zipcode, country
# FROM orders NATURAL JOIN customers;
# Out:
#  * postgres://dsa_ro_user:***@pgsql.dsa.lan/dsa_ro
# 7 rows affected.
# [(10135, '216 Main St.', 'Okawville', 62271, 'United States'),
#  (10136, '303 Foxfire Dr.', 'Columbia', 65201, 'United States'),
#  (10137, '303 Foxfire Dr.', 'Columbia', 65201, 'United States'),
#  (10138, '612 Rollins St.', 'Raliegh', 56842, 'United States'),
#  (10139, '612 Rollins St.', 'Raliegh', 56842, 'United States'),
#  (10140, '612 Rollins St.', 'Raliegh', 56842, 'United States'),
#  (10141, '612 Rollins St.', 'Raliegh', 56842, 'United States')]

# %%
# %%sql
#
# SELECT order_id, address, city, zipcode, country
# FROM orders, customers
# WHERE orders.customer_id = customers.customer_id;
# Out:
#  * postgres://dsa_ro_user:***@pgsql.dsa.lan/dsa_ro
# 7 rows affected.
# [(10135, '216 Main St.', 'Okawville', 62271, 'United States'),
#  (10136, '303 Foxfire Dr.', 'Columbia', 65201, 'United States'),
#  (10137, '303 Foxfire Dr.', 'Columbia', 65201, 'United States'),
#  (10138, '612 Rollins St.', 'Raliegh', 56842, 'United States'),
#  (10139, '612 Rollins St.', 'Raliegh', 56842, 'United States'),
#  (10140, '612 Rollins St.', 'Raliegh', 56842, 'United States'),
#  (10141, '612 Rollins St.', 'Raliegh', 56842, 'United States')]

# %%
# %%sql
#
# SELECT order_id, address, city, zipcode, country
# FROM orders INNER JOIN customers
# USING (customer_id);
# Out:
#  * postgres://dsa_ro_user:***@pgsql.dsa.lan/dsa_ro
# 7 rows affected.
# [(10135, '216 Main St.', 'Okawville', 62271, 'United States'),
#  (10136, '303 Foxfire Dr.', 'Columbia', 65201, 'United States'),
#  (10137, '303 Foxfire Dr.', 'Columbia', 65201, 'United States'),
#  (10138, '612 Rollins St.', 'Raliegh', 56842, 'United States'),
#  (10139, '612 Rollins St.', 'Raliegh', 56842, 'United States'),
#  (10140, '612 Rollins St.', 'Raliegh', 56842, 'United States'),
#  (10141, '612 Rollins St.', 'Raliegh', 56842, 'United States')]

# %%
# %%sql
#
# SELECT order_id, address, city, zipcode, country
# FROM customers JOIN  orders
# ON orders.customer_id = customers.customer_id;
# Out:
#  * postgres://dsa_ro_user:***@pgsql.dsa.lan/dsa_ro
# 7 rows affected.
# [(10135, '216 Main St.', 'Okawville', 62271, 'United States'),
#  (10136, '303 Foxfire Dr.', 'Columbia', 65201, 'United States'),
#  (10137, '303 Foxfire Dr.', 'Columbia', 65201, 'United States'),
#  (10138, '612 Rollins St.', 'Raliegh', 56842, 'United States'),
#  (10139, '612 Rollins St.', 'Raliegh', 56842, 'United States'),
#  (10140, '612 Rollins St.', 'Raliegh', 56842, 'United States'),
#  (10141, '612 Rollins St.', 'Raliegh', 56842, 'United States')]

# %%
# %%sql
#
# SELECT order_id, address, city, zipcode, country
# FROM orders AS o JOIN  customers AS c
# ON o.customer_id = c.customer_id;
# Out:
#  * postgres://dsa_ro_user:***@pgsql.dsa.lan/dsa_ro
# 7 rows affected.
# [(10135, '216 Main St.', 'Okawville', 62271, 'United States'),
#  (10136, '303 Foxfire Dr.', 'Columbia', 65201, 'United States'),
#  (10137, '303 Foxfire Dr.', 'Columbia', 65201, 'United States'),
#  (10138, '612 Rollins St.', 'Raliegh', 56842, 'United States'),
#  (10139, '612 Rollins St.', 'Raliegh', 56842, 'United States'),
#  (10140, '612 Rollins St.', 'Raliegh', 56842, 'United States'),
#  (10141, '612 Rollins St.', 'Raliegh', 56842, 'United States')]

# %% [markdown]
# ## <span style="background:yellow">Your Turn</span>
#
# Write a SELECT statement that displays all of the customers' names and zip codes that have placed an order

# %%
# %%sql
# SELECT customer_name, zipcode
# FROM orders AS o INNER JOIN customers AS c
# ON o.customer_id = c.customer_id;
# Out:
#  * postgres://dsa_ro_user:***@pgsql.dsa.lan/dsa_ro
# 7 rows affected.
# [('Will Starmes', 62271),
#  ('Richard James', 65201),
#  ('Richard James', 65201),
#  ('Matt England', 56842),
#  ('Matt England', 56842),
#  ('Matt England', 56842),
#  ('Matt England', 56842)]

# %% [markdown]
# ## Left Join
#
# You will see that not all the customers or orders are included in this result - only the ones that had a `customer_id` which appeared in both lists.
#
# To ensure we see all the `customers`, even those without orders, we need to use a `LEFT JOIN` with the customers as the left table.
#
# Recall the INNER JOIN only shows `customers` that match the orders.
# So, to get the desired result we will align `customers` as the left table and use a LEFT JOIN.

# %%
# %%sql
#
# SELECT order_id, address, city, zipcode, country
# FROM customers LEFT JOIN orders
# ON orders.customer_id = customers.customer_id;
# Out:
#  * postgres://dsa_ro_user:***@pgsql.dsa.lan/dsa_ro
# 9 rows affected.
# [(10135, '216 Main St.', 'Okawville', 62271, 'United States'),
#  (10136, '303 Foxfire Dr.', 'Columbia', 65201, 'United States'),
#  (10137, '303 Foxfire Dr.', 'Columbia', 65201, 'United States'),
#  (10138, '612 Rollins St.', 'Raliegh', 56842, 'United States'),
#  (10139, '612 Rollins St.', 'Raliegh', 56842, 'United States'),
#  (10140, '612 Rollins St.', 'Raliegh', 56842, 'United States'),
#  (10141, '612 Rollins St.', 'Raliegh', 56842, 'United States'),
#  (None, '205 Broadway Ave', 'Columbia', 65201, 'United States'),
#  (None, '123 State Ave.', 'St. Louis ', 63122, 'United States')]

# %% [markdown]
# **Notice** we have retrieved two additional rows, 9 in total.
#
# We see the last two rows are rendered with `None` in the `order_id` column.
# That is because this value comes from the right table and does not have matching rows to supply data.
#
# Looking at the `orders` as the left table.

# %%
# %%sql
#
# SELECT order_id, address, city, zipcode, country
# FROM orders LEFT JOIN customers
# ON orders.customer_id = customers.customer_id;
# Out:
#  * postgres://dsa_ro_user:***@pgsql.dsa.lan/dsa_ro
# 10 rows affected.
# [(10135, '216 Main St.', 'Okawville', 62271, 'United States'),
#  (10136, '303 Foxfire Dr.', 'Columbia', 65201, 'United States'),
#  (10137, '303 Foxfire Dr.', 'Columbia', 65201, 'United States'),
#  (10138, '612 Rollins St.', 'Raliegh', 56842, 'United States'),
#  (10139, '612 Rollins St.', 'Raliegh', 56842, 'United States'),
#  (10140, '612 Rollins St.', 'Raliegh', 56842, 'United States'),
#  (10141, '612 Rollins St.', 'Raliegh', 56842, 'United States'),
#  (10142, None, None, None, None),
#  (10143, None, None, None, None),
#  (10144, None, None, None, None)]

# %% [markdown]
# You will see in the results that we have 3 orders with no customer related to it.
#
# We still see the data in our results because we used a Left Join and the left table in our query was the `orders` table.

# %% [markdown]
# ## <span style="background:yellow">Your Turn</span>
#
#   Write a SELECT statement to display all customer names along with the price of their orders, if they have one
#
#
# * Make sure to use a left join

# %%
# %%sql
#
# SELECT customer_name, order_price
# FROM customers LEFT JOIN orders
# ON orders.customer_id = customers.customer_id;
# Out:
#  * postgres://dsa_ro_user:***@pgsql.dsa.lan/dsa_ro
# 9 rows affected.
# [('Will Starmes', 15),
#  ('Richard James', 25),
#  ('Richard James', 62),
#  ('Matt England', 32),
#  ('Matt England', 12),
#  ('Matt England', 52),
#  ('Matt England', 63),
#  ('George Blackwood', None),
#  ('James Vanderbeek', None)]

# %% [markdown]
# Write a SELECT statement to display all order ids and order prices, along with zip code and country from which they were made, if there is one
# * Make sure to use a left join

# %%
# %%sql
#
# SELECT order_id, order_price, zipcode, country
# FROM orders LEFT JOIN customers
# ON orders.customer_id = customers.customer_id;
# Out:
#  * postgres://dsa_ro_user:***@pgsql.dsa.lan/dsa_ro
# 10 rows affected.
# [(10135, 15, 62271, 'United States'),
#  (10136, 25, 65201, 'United States'),
#  (10137, 62, 65201, 'United States'),
#  (10138, 32, 56842, 'United States'),
#  (10139, 12, 56842, 'United States'),
#  (10140, 52, 56842, 'United States'),
#  (10141, 63, 56842, 'United States'),
#  (10142, 12, None, None),
#  (10143, 63, None, None),
#  (10144, 15, None, None)]

# %% [markdown]
# ## Right Join
#
# Now it's time for Right Join!
#
# This join is the opposite of the Left Join.
#
# This join will show all of the data from the right table, `customers`, in our query and provide `None` values for the rows that do not match.

# %%
# %%sql
#
# SELECT order_id, address, city, zipcode, country
# FROM orders RIGHT JOIN customers
# ON orders.customer_id = customers.customer_id;
# Out:
#  * postgres://dsa_ro_user:***@pgsql.dsa.lan/dsa_ro
# 9 rows affected.
# [(10135, '216 Main St.', 'Okawville', 62271, 'United States'),
#  (10136, '303 Foxfire Dr.', 'Columbia', 65201, 'United States'),
#  (10137, '303 Foxfire Dr.', 'Columbia', 65201, 'United States'),
#  (10138, '612 Rollins St.', 'Raliegh', 56842, 'United States'),
#  (10139, '612 Rollins St.', 'Raliegh', 56842, 'United States'),
#  (10140, '612 Rollins St.', 'Raliegh', 56842, 'United States'),
#  (10141, '612 Rollins St.', 'Raliegh', 56842, 'United States'),
#  (None, '205 Broadway Ave', 'Columbia', 65201, 'United States'),
#  (None, '123 State Ave.', 'St. Louis ', 63122, 'United States')]

# %% [markdown]
#
# You will see again that we have 2 customers who have never made an order with us. But these are still shown in the results because our Right Join will show all of the data from the right table (customers).

# %% [markdown]
# ## <span style="background:yellow">Your Turn</span>
#
# Write a SELECT statement to display customer names and order ids for all orders, even if there is no customer associated with an order
#
#
# * Make sure to use a right join

# %%
# %%sql
#
# SELECT customer_name, order_id
# FROM customers RIGHT JOIN orders
# ON orders.customer_id = customers.customer_id;
# Out:
#  * postgres://dsa_ro_user:***@pgsql.dsa.lan/dsa_ro
# 10 rows affected.
# [('Will Starmes', 10135),
#  ('Richard James', 10136),
#  ('Richard James', 10137),
#  ('Matt England', 10138),
#  ('Matt England', 10139),
#  ('Matt England', 10140),
#  ('Matt England', 10141),
#  (None, 10142),
#  (None, 10143),
#  (None, 10144)]

# %% [markdown]
# Change your statement from the previous step to display customer names and order ids for all customers, even if there is no order associated with a customer
# * Make sure to use a right join

# %%
# %%sql
#
# SELECT customer_name, order_id
# FROM orders RIGHT JOIN customers
# ON orders.customer_id = customers.customer_id;
# Out:
#  * postgres://dsa_ro_user:***@pgsql.dsa.lan/dsa_ro
# 9 rows affected.
# [('Will Starmes', 10135),
#  ('Richard James', 10136),
#  ('Richard James', 10137),
#  ('Matt England', 10138),
#  ('Matt England', 10139),
#  ('Matt England', 10140),
#  ('Matt England', 10141),
#  ('George Blackwood', None),
#  ('James Vanderbeek', None)]

# %% [markdown]
# ## Outer Join
#
# Recall that an OUTER JOIN produces the combined rows of the RIGHT JOIN and the LEFT JOIN.
#
# The syntax for PostgreSQL is
# ```SQL
# FROM
#     TableA FULL OUTER JOIN TableB
#     ...
# ```

# %%
# %%sql
#
# SELECT order_id, address, city, zipcode, country
# FROM orders FULL OUTER JOIN customers
# ON orders.customer_id = customers.customer_id;
# Out:
#  * postgres://dsa_ro_user:***@pgsql.dsa.lan/dsa_ro
# 12 rows affected.
# [(10135, '216 Main St.', 'Okawville', 62271, 'United States'),
#  (10136, '303 Foxfire Dr.', 'Columbia', 65201, 'United States'),
#  (10137, '303 Foxfire Dr.', 'Columbia', 65201, 'United States'),
#  (10138, '612 Rollins St.', 'Raliegh', 56842, 'United States'),
#  (10139, '612 Rollins St.', 'Raliegh', 56842, 'United States'),
#  (10140, '612 Rollins St.', 'Raliegh', 56842, 'United States'),
#  (10141, '612 Rollins St.', 'Raliegh', 56842, 'United States'),
#  (10142, None, None, None, None),
#  (10143, None, None, None, None),
#  (10144, None, None, None, None),
#  (None, '205 Broadway Ave', 'Columbia', 65201, 'United States'),
#  (None, '123 State Ave.', 'St. Louis ', 63122, 'United States')]

# %% [markdown]
# The results of the OUTER JOIN are composed of three sets of rows:
#   1. We see the first seven rows, 1 - 7, are from the INNER JOIN.
#   1. Then we see the four rows formed from the LEFT JOIN with `None` in address fields, where the `order_id` was supplied by the left table (`orders`).
#   1. Finally, we see the two rows formed from the RIGHT JOIN with `None` in `order_id` fields, where the address fields were supplied by the right table (`customers`).

# %% [markdown]
# ## <span style="background:yellow">Your Turn</span>
#
#    Write a SELECT statement to show the customer names, order ids, and price of all orders and customers

# %%
# %%sql
#
# SELECT customer_name, order_id, order_price
# FROM customers FULL OUTER JOIN orders
# ON orders.customer_id = customers.customer_id;
# Out:
#  * postgres://dsa_ro_user:***@pgsql.dsa.lan/dsa_ro
# 12 rows affected.
# [('Will Starmes', 10135, 15),
#  ('Richard James', 10136, 25),
#  ('Richard James', 10137, 62),
#  ('Matt England', 10138, 32),
#  ('Matt England', 10139, 12),
#  ('Matt England', 10140, 52),
#  ('Matt England', 10141, 63),
#  (None, 10142, 12),
#  (None, 10143, 63),
#  (None, 10144, 15),
#  ('George Blackwood', None, None),
#  ('James Vanderbeek', None, None)]

# %% [markdown]
# Change your query from step 1 to display the contact name, country, customer id, and employee id for all customers and orders.

# %%
# %%sql
#
# SELECT contact_name, country, orders.customer_id, customers.customer_id, employee_id # Using just customer_id resulted in an error
# FROM orders FULL OUTER JOIN customers
# ON orders.customer_id = customers.customer_id;
# Out:
#  * postgres://dsa_ro_user:***@pgsql.dsa.lan/dsa_ro
# 12 rows affected.
# [('Maria Anders', 'United States', 2, 2, 1),
#  ('Ana Trujillo', 'United States', 3, 3, 1),
#  ('Ana Trujillo', 'United States', 3, 3, 1),
#  ('Antonio Moreno', 'United States', 4, 4, 2),
#  ('Antonio Moreno', 'United States', 4, 4, 2),
#  ('Antonio Moreno', 'United States', 4, 4, 2),
#  ('Antonio Moreno', 'United States', 4, 4, 1),
#  (None, None, 16, None, 3),
#  (None, None, 62, None, 3),
#  (None, None, 7, None, 2),
#  ('Antonio Moreno', 'United States', None, 5, None),
#  ('Maria Anders', 'United States', None, 1, None)]

# %% [markdown]
# # Preview
#
# The true power of the relational model begins to emerge with the JOIN.
# As you continue through the course you will learn how to use aggregation and statistics and see more advanced concepts.
# Almost always, these other concepts are leveraging JOIN to integrate the data of multiple tables.

# %% [markdown]
# # Save your Notebook, then `File > Close and Halt`

# %% [markdown]
# ---
