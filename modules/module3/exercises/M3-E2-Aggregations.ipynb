# %% [markdown]
# # Basic Statistics Practice
#
# Please remember to use the `EXPLAIN` before you execute a query to help avoid unnecessary load on the DBMS and indefinite waits by you for results.
#
# Therefore, for each question, we are providing a cell for the `EXPLAIN` as well as the final SQL.
#
#
# ## Our practice schema:
#
# We will use the same database as in the Day 1 practice.
#
# A PDF of the _Entity-Relationship Diagrams_ (ERD) is available [here](https://web.dsa.missouri.edu/static/PDF/DVD_Rental_ERD2.pdf).
# Printing it out is recommended.

# %%
# %load_ext sql
# %sql postgres://dsa_ro_user:readonly@pgsql.dsa.lan/dvdrental
# Out:
# 'Connected: dsa_ro_user@dvdrental'

# %% [markdown]
# # 1
#
# ### List the average length of the movies (film.length) in the database.

# %%
# %%sql
# EXPLAIN
# SELECT AVG(length)
# FROM film
# Out:
#  * postgres://dsa_ro_user:***@pgsql.dsa.lan/dvdrental
# 2 rows affected.
# [('Aggregate  (cost=66.50..66.51 rows=1 width=32)',),
#  ('  ->  Seq Scan on film  (cost=0.00..64.00 rows=1000 width=2)',)]

# %%
# %%sql
# SELECT AVG(length)
# FROM film
# Out:
#  * postgres://dsa_ro_user:***@pgsql.dsa.lan/dvdrental
# 1 rows affected.
# [(Decimal('115.2720000000000000'),)]

# %% [markdown]
# [Helpful Hints](https://youtu.be/yMrP0cr_rqo)
#
#
# ---
#
# # 2
#
# ### List the number of rows in the payment table.

# %%
# %%sql
# EXPLAIN
# SELECT COUNT(*)
# FROM payment
# Out:
#  * postgres://dsa_ro_user:***@pgsql.dsa.lan/dvdrental
# 2 rows affected.
# [('Aggregate  (cost=290.45..290.46 rows=1 width=8)',),
#  ('  ->  Seq Scan on payment  (cost=0.00..253.96 rows=14596 width=0)',)]

# %%
# %%sql
# SELECT COUNT(*)
# FROM payment
# Out:
#  * postgres://dsa_ro_user:***@pgsql.dsa.lan/dvdrental
# 1 rows affected.
# [(14596,)]

# %% [markdown]
# # 3
#
# ### List each category (`category.name`) and the number of films in that category.

# %%
# %%sql
# EXPLAIN
# SELECT name, COUNT(*)
# FROM category
# INNER JOIN film_category
#     ON category.category_id = film_category.category_id
# INNER JOIN film
#     ON film_category.film_id = film.film_id
# GROUP BY name
# Out:
#  * postgres://dsa_ro_user:***@pgsql.dsa.lan/dvdrental
# 11 rows affected.
# [('HashAggregate  (cost=104.81..104.97 rows=16 width=76)',),
#  ('  Group Key: category.name',),
#  ('  ->  Hash Join  (cost=77.86..99.81 rows=1000 width=68)',),
#  ('        Hash Cond: (film_category.film_id = film.film_id)',),
#  ('        ->  Hash Join  (cost=1.36..20.67 rows=1000 width=70)',),
#  ('              Hash Cond: (film_category.category_id = category.category_id)',),
#  ('              ->  Seq Scan on film_category  (cost=0.00..16.00 rows=1000 width=4)',),
#  ('              ->  Hash  (cost=1.16..1.16 rows=16 width=72)',),
#  ('                    ->  Seq Scan on category  (cost=0.00..1.16 rows=16 width=72)',),
#  ('        ->  Hash  (cost=64.00..64.00 rows=1000 width=4)',),
#  ('              ->  Seq Scan on film  (cost=0.00..64.00 rows=1000 width=4)',)]

# %%
# %%sql
# SELECT name, COUNT(*)
# FROM category
# INNER JOIN film_category
#     ON category.category_id = film_category.category_id
# INNER JOIN film
#     ON film_category.film_id = film.film_id
# GROUP BY name
# Out:
#  * postgres://dsa_ro_user:***@pgsql.dsa.lan/dvdrental
# 16 rows affected.
# [('Family', 69),
#  ('Games', 61),
#  ('Animation', 66),
#  ('Classics', 57),
#  ('Documentary', 68),
#  ('New', 63),
#  ('Sports', 74),
#  ('Children', 60),
#  ('Music', 51),
#  ('Travel', 57),
#  ('Foreign', 73),
#  ('Drama', 62),
#  ('Horror', 56),
#  ('Action', 64),
#  ('Sci-Fi', 61),
#  ('Comedy', 58)]

# %% [markdown]
# [Helpful Hints](https://youtu.be/YRMI8myh9WY)
#
#
# ---
#
# # 4
#
# ### List each film title and the number of actors in that film.

# %%
# %%sql
# EXPLAIN
# SELECT title, COUNT(*)
# FROM film
# INNER JOIN film_actor
#     ON film.film_id = film_actor.film_id
# GROUP BY title
# Out:
#  * postgres://dsa_ro_user:***@pgsql.dsa.lan/dvdrental
# 7 rows affected.
# [('HashAggregate  (cost=202.82..212.82 rows=1000 width=23)',),
#  ('  Group Key: film.title',),
#  ('  ->  Hash Join  (cost=76.50..175.51 rows=5462 width=15)',),
#  ('        Hash Cond: (film_actor.film_id = film.film_id)',),
#  ('        ->  Seq Scan on film_actor  (cost=0.00..84.62 rows=5462 width=2)',),
#  ('        ->  Hash  (cost=64.00..64.00 rows=1000 width=19)',),
#  ('              ->  Seq Scan on film  (cost=0.00..64.00 rows=1000 width=19)',)]

# %%
# %%sql
# SELECT title, COUNT(*)
# FROM film
# INNER JOIN film_actor
#     ON film.film_id = film_actor.film_id
# GROUP BY title
# Out:
#  * postgres://dsa_ro_user:***@pgsql.dsa.lan/dvdrental
# 997 rows affected.
# [('Graceland Dynamite', 6),
#  ('Opus Ice', 4),
#  ('Braveheart Human', 4),
#  ('Wonderful Drop', 4),
#  ('Rush Goodfellas', 5),
#  ('Purple Movie', 8),
#  ('Minority Kiss', 1),
#  ('Luke Mummy', 9),
#  ('Fantasy Troopers', 9),
#  ('Grinch Massage', 6),
#  ('Gaslight Crusade', 5),
#  ('Microcosmos Paradise', 6),
#  ('Saturn Name', 2),
#  ('Memento Zoolander', 6),
#  ('Sunset Racer', 3),
#  ('Zoolander Fiction', 5),
#  ('Carol Texas', 7),
#  ('Stepmom Dream', 4),
#  ('Minds Truman', 6),
#  ('Gump Date', 6),
#  ('Arabia Dogma', 12),
#  ('Baked Cleopatra', 1),
#  ('Closer Bang', 6),
#  ('Enough Raging', 9),
#  ('Grosse Wonderful', 4),
#  ('Innocent Usual', 3),
#  ('Sleepless Monsoon', 4),
#  ('Suit Walls', 5),
#  ('Wizard Coldblooded', 9),
#  ('Lonely Elephant', 12),
#  ('Victory Academy', 5),
#  ('Bedazzled Married', 7),
#  ('Tadpole Park', 8),
#  ('Maker Gables', 11),
#  ('Private Drop', 5),
#  ('Worker Tarzan', 9),
#  ('Gosford Donnie', 3),
#  ('Annie Identity', 3),
#  ('Drop Waterfront', 8),
#  ('Lesson Cleopatra', 12),
#  ('Wanda Chamber', 7),
#  ('Dwarfs Alter', 1),
#  ('Garden Island', 3),
#  ('Graduate Lord', 2),
#  ('Patriot Roman', 4),
#  ('Novocaine Flight', 6),
#  ('Necklace Outbreak', 8),
#  ('Menagerie Rushmore', 2),
#  ('Sleeping Suspects', 4),
#  ('Uncut Suicides', 7),
#  ('Midnight Westward', 9),
#  ('Rock Instinct', 8),
#  ('Jersey Sassy', 9),
#  ('Magnificent Chitty', 7),
#  ('Clones Pinocchio', 5),
#  ('Insects Stone', 4),
#  ('Giant Troopers', 1),
#  ('Loser Hustler', 5),
#  ('Heavyweights Beast', 5),
#  ('Boondock Ballroom', 13),
#  ('Entrapment Satisfaction', 4),
#  ('Firehouse Vietnam', 5),
#  ('Core Suit', 4),
#  ('Butch Panther', 3),
#  ('Cyclone Family', 3),
#  ('Cabin Flash', 4),
#  ('Jaws Harry', 5),
#  ('Fellowship Autumn', 7),
#  ('Bowfinger Gables', 5),
#  ('Birdcage Casper', 4),
#  ('Forever Candidate', 1),
#  ('Dangerous Uptown', 8),
#  ('Guys Falcon', 5),
#  ('Warlock Werewolf', 6),
#  ('None Spiking', 6),
#  ('Bringing Hysterical', 2),
#  ('Haunting Pianist', 5),
#  ('Agent Truman', 7),
#  ('Motions Details', 8),
#  ('Tenenbaums Command', 5),
#  ('Secrets Paradise', 6),
#  ('Tarzan Videotape', 3),
#  ('Double Wrath', 8),
#  ('Greatest North', 6),
#  ('Birch Antitrust', 6),
#  ('Sense Greek', 7),
#  ('Walls Artist', 5),
#  ('Invasion Cyclone', 7),
#  ('Secretary Rouge', 6),
#  ('Congeniality Quest', 3),
#  ('Daughter Madigan', 4),
#  ('Crossroads Casualties', 8),
#  ('Canyon Stock', 6),
#  ('Reef Salute', 4),
#  ('French Holiday', 7),
#  ('Rugrats Shakespeare', 6),
#  ('Highball Potter', 5),
#  ('Papi Necklace', 3),
#  ('Translation Summer', 3),
#  ('Peak Forever', 5),
#  ('Tycoon Gathering', 6),
#  ('Loverboy Attacks', 9),
#  ('Earring Instinct', 5),
#  ('Ship Wonderland', 8),
#  ('Rouge Squad', 4),
#  ('Clue Grail', 6),
#  ('Wonderland Christmas', 5),
#  ('Finding Anaconda', 5),
#  ('Thin Sagebrush', 2),
#  ('Nash Chocolat', 7),
#  ('Wrath Mile', 4),
#  ('Harold French', 7),
#  ('Forrest Sons', 5),
#  ('Pure Runner', 2),
#  ('Witches Panic', 4),
#  ('Turn Star', 3),
#  ('Anthem Luke', 2),
#  ('Duffel Apocalypse', 3),
#  ('Shrek License', 3),
#  ('Heaven Freedom', 10),
#  ('Impossible Prejudice', 3),
#  ('Peach Innocent', 5),
#  ('Dazed Punk', 6),
#  ('Frisco Forrest', 9),
#  ('Reds Pocus', 5),
#  ('Music Boondock', 3),
#  ('Chisum Behavior', 4),
#  ('Volcano Texas', 5),
#  ('Daisy Menagerie', 7),
#  ('Lost Bird', 3),
#  ('Caribbean Liberty', 8),
#  ('Conversation Downhill', 3),
#  ('Lambs Cincinatti', 15),
#  ('Escape Metropolis', 4),
#  ('Dumbo Lust', 9),
#  ('Pizza Jumanji', 5),
#  ('Hills Neighbors', 6),
#  ('Truman Crazy', 6),
#  ('Chance Resurrection', 6),
#  ('Candidate Perdition', 4),
#  ('Spiking Element', 6),
#  ('Fight Jawbreaker', 3),
#  ('Apache Divine', 4),
#  ('Shining Roses', 5),
#  ('Ishtar Rocketeer', 4),
#  ('Flying Hook', 8),
#  ('Desperate Trainspotting', 4),
#  ('Greedy Roots', 8),
#  ('Forrester Comancheros', 3),
#  ('Dirty Ace', 5),
#  ('Trading Pinocchio', 3),
#  ('Graffiti Love', 6),
#  ('Paths Control', 5),
#  ('Amelie Hellfighters', 6),
#  ('Pickup Driving', 5),
#  ('Panic Club', 3),
#  ('Crazy Home', 13),
#  ('Forward Temple', 3),
#  ('Vertigo Northwest', 4),
#  ('Jericho Mulan', 4),
#  ('Gunfighter Mussolini', 4),
#  ('Bilko Anonymous', 3),
#  ('Blade Polish', 5),
#  ('Spice Sorority', 11),
#  ('Massage Image', 9),
#  ('Home Pity', 6),
#  ('Boulevard Mob', 8),
#  ('Dalmations Sweden', 6),
#  ('Hunter Alter', 4),
#  ('Zorro Ark', 3),
#  ('Silence Kane', 4),
#  ('Taxi Kick', 6),
#  ('Resurrection Silverado', 5),
#  ('Suspects Quills', 8),
#  ('Dracula Crystal', 13),
#  ('Harper Dying', 4),
#  ('Simon North', 3),
#  ('Vacation Boondock', 6),
#  ('Chitty Lock', 13),
#  ('Ballroom Mockingbird', 7),
#  ('Legally Secretary', 6),
#  ('Gladiator Westward', 6),
#  ('Barefoot Manchurian', 8),
#  ('Cruelty Unforgiven', 2),
#  ('Smoking Barbarella', 6),
#  ('Soldiers Evolution', 9),
#  ('Robbers Joon', 5),
#  ('Telemark Heartbreakers', 11),
#  ('Westward Seabiscuit', 6),
#  ('Notorious Reunion', 2),
#  ('Million Ace', 5),
#  ('Ali Forever', 5),
#  ('Coneheads Smoochy', 9),
#  ('Suicides Silence', 3),
#  ('Bird Independence', 2),
#  ('Intrigue Worst', 7),
#  ('Mask Peach', 11),
#  ('Scissorhands Slums', 5),
#  ('Boiled Dares', 8),
#  ('Majestic Floats', 5),
#  ('Past Suicides', 6),
#  ('Masked Bubble', 3),
#  ('Bull Shawshank', 8),
#  ('Gunfight Moon', 4),
#  ('Sagebrush Clueless', 7),
#  ('Reap Unfaithful', 4),
#  ('Lock Rear', 2),
#  ('Beethoven Exorcist', 6),
#  ('Vietnam Smoochy', 2),
#  ('Breaking Home', 6),
#  ('Runaway Tenenbaums', 3),
#  ('Head Stranger', 2),
#  ('Quest Mussolini', 5),
#  ('Ace Goldfinger', 4),
#  ('Dancing Fever', 6),
#  ('Image Princess', 11),
#  ('Fool Mockingbird', 2),
#  ('Panther Reds', 5),
#  ('Holocaust Highball', 5),
#  ('Bright Encounters', 4),
#  ('Adaptation Holes', 5),
#  ('Deceiver Betrayed', 4),
#  ('Antitrust Tomatoes', 7),
#  ('Fatal Haunted', 6),
#  ('Sons Interview', 6),
#  ('Yentl Idaho', 1),
#  ('Modern Dorado', 5),
#  ('Rage Games', 7),
#  ('Monsoon Cause', 5),
#  ('Uprising Uptown', 5),
#  ('Jason Trap', 5),
#  ('Sweet Brotherhood', 6),
#  ('Crusade Honey', 9),
#  ('Arachnophobia Rollercoaster', 8),
#  ('Stallion Sundance', 7),
#  ('Crossing Divorce', 2),
#  ('Creatures Shakespeare', 3),
#  ('Easy Gladiator', 3),
#  ('Snatchers Montezuma', 9),
#  ('Shock Cabin', 1),
#  ('Island Exorcist', 3),
#  ('Seattle Expecations', 6),
#  ('Liberty Magnificent', 7),
#  ('Gun Bonnie', 5),
#  ('Alabama Devil', 9),
#  ('Train Bunch', 4),
#  ('Identity Lover', 4),
#  ('Clyde Theory', 4),
#  ('Troopers Metal', 5),
#  ('Primary Glass', 7),
#  ('Frankenstein Stranger', 2),
#  ('Excitement Eve', 8),
#  ('Affair Prejudice', 5),
#  ('Impact Aladdin', 3),
#  ('Fury Murder', 4),
#  ('Deep Crusade', 7),
#  ('Sierra Divide', 5),
#  ('Dinosaur Secretary', 6),
#  ('Kill Brotherhood', 5),
#  ('Muppet Mile', 8),
#  ('Mosquito Armageddon', 4),
#  ('Freedom Cleopatra', 5),
#  ('Jungle Closer', 6),
#  ('Indian Love', 10),
#  ('Glass Dying', 4),
#  ('Born Spinal', 9),
#  ('Life Twisted', 8),
#  ('Massacre Usual', 3),
#  ('Kissing Dolls', 3),
#  ('Greek Everyone', 4),
#  ('Meet Chocolate', 6),
#  ('Dorado Notting', 4),
#  ('Titans Jerk', 7),
#  ('Hanging Deep', 7),
#  ('Streetcar Intentions', 7),
#  ('Hardly Robbers', 3),
#  ('War Notting', 9),
#  ('Diary Panic', 4),
#  ('Instinct Airport', 11),
#  ('Bikini Borrowers', 2),
#  ('Rebel Airport', 6),
#  ('Flamingos Connecticut', 9),
#  ('Cincinatti Whisperer', 4),
#  ('Trainspotting Strangers', 4),
#  ('Pelican Comforts', 5),
#  ('Madre Gables', 4),
#  ('Lord Arizona', 6),
#  ('Feathers Metal', 9),
#  ('Hook Chariots', 4),
#  ('Groove Fiction', 7),
#  ('Window Side', 4),
#  ('Silverado Goldfinger', 5),
#  ('Mannequin Worst', 5),
#  ('Willow Tracy', 2),
#  ('Hocus Frida', 3),
#  ('Natural Stock', 4),
#  ('Karate Moon', 8),
#  ('Roses Treasure', 5),
#  ('Racer Egg', 6),
#  ('Jawbreaker Brooklyn', 5),
#  ('Alice Fantasia', 4),
#  ('Mixed Doors', 6),
#  ('Potter Connecticut', 7),
#  ('Order Betrayed', 7),
#  ('Mighty Luck', 8),
#  ('Sabrina Midnight', 4),
#  ('Roxanne Rebel', 5),
#  ('Fidelity Devil', 4),
#  ('Madness Attacks', 7),
#  ('Mussolini Spoilers', 7),
#  ('Star Operation', 5),
#  ('Vanilla Day', 2),
#  ('Bunch Minds', 8),
#  ('Sweethearts Suspects', 5),
#  ('Lola Agent', 6),
#  ('Won Dares', 5),
#  ('Reunion Witches', 7),
#  ('Unfaithful Kill', 8),
#  ('Encino Elf', 6),
#  ('Hustler Party', 4),
#  ('Rollercoaster Bringing', 3),
#  ('Spirit Flintstones', 11),
#  ('Details Packer', 2),
#  ('Pianist Outfield', 5),
#  ('Luck Opus', 6),
#  ('Butterfly Chocolat', 7),
#  ('Mallrats United', 5),
#  ('Queen Luke', 6),
#  ('Desire Alien', 7),
#  ('Glory Tracy', 6),
#  ('Bound Cheaper', 2),
#  ('Academy Dinosaur', 10),
#  ('Igby Maker', 5),
#  ('Gentlemen Stage', 8),
#  ('Pollock Deliverance', 6),
#  ('Sleuth Orient', 7),
#  ('Freddy Storm', 3),
#  ('Odds Boogie', 5),
#  ('Prejudice Oleander', 10),
#  ('Cowboy Doom', 5),
#  ('Valentine Vanishing', 2),
#  ('Show Lord', 2),
#  ('Confidential Interview', 2),
#  ('Armageddon Lost', 7),
#  ('Edge Kissing', 3),
#  ('Grail Frankenstein', 5),
#  ('Half Outfield', 6),
#  ('Love Suicides', 4),
#  ('Seven Swarm', 7),
#  ('Oscar Gold', 6),
#  ('Lies Treatment', 7),
#  ('Chocolat Harry', 5),
#  ('Wind Phantom', 3),
#  ('Casablanca Super', 4),
#  ('Random Go', 13),
#  ('Newsies Story', 8),
#  ('Knock Warlock', 6),
#  ('Leathernecks Dwarfs', 7),
#  ('Joon Northwest', 2),
#  ('Pajama Jawbreaker', 5),
#  ('Stage World', 2),
#  ('American Circus', 5),
#  ('Rear Trading', 8),
#  ('Siege Madre', 7),
#  ('Angels Life', 9),
#  ('Crooked Frogmen', 6),
#  ('Jingle Sagebrush', 2),
#  ('Tramp Others', 6),
#  ('Artist Coldblooded', 7),
#  ('Beverly Outlaw', 4),
#  ('Doom Dancing', 8),
#  ('Mine Titans', 2),
#  ('Hunting Musketeers', 5),
#  ('Rings Heartbreakers', 11),
#  ('Lights Deer', 2),
#  ('Mars Roman', 7),
#  ('Champion Flatliners', 4),
#  ('Temple Attraction', 5),
#  ('Roman Punk', 2),
#  ('Dragon Squad', 8),
#  ('Moulin Wake', 3),
#  ('Fiction Christmas', 8),
#  ('Princess Giant', 5),
#  ('Empire Malkovich', 9),
#  ('Fish Opus', 2),
#  ('Tequila Past', 3),
#  ('Rocketeer Mother', 7),
#  ('Theory Mermaid', 6),
#  ('Divine Resurrection', 5),
#  ('Manchurian Curtain', 2),
#  ('Casper Dragonfly', 5),
#  ('Mulan Moon', 5),
#  ('Newton Labyrinth', 4),
#  ('Bubble Grosse', 3),
#  ('Lebowski Soldiers', 3),
#  ('Berets Agent', 10),
#  ('Searchers Wait', 4),
#  ('South Wait', 2),
#  ('Uptown Young', 7),
#  ('Center Dinosaur', 4),
#  ('Spartacus Cheaper', 3),
#  ('Wedding Apollo', 10),
#  ('Dawn Pond', 6),
#  ('Perfect Groove', 6),
#  ('Ties Hunger', 6),
#  ('Satisfaction Confidential', 5),
#  ('Speed Suit', 6),
#  ('Halloween Nuts', 7),
#  ('Vision Torque', 5),
#  ('Blackout Private', 5),
#  ('Iron Moon', 8),
#  ('Bonnie Holocaust', 9),
#  ('Coma Head', 3),
#  ('Disciple Mother', 7),
#  ('Vanishing Rocky', 5),
#  ('Floats Garden', 5),
#  ('Paris Weekend', 6),
#  ('Bill Others', 6),
#  ('Expendable Stallion', 4),
#  ('Mob Duffel', 6),
#  ('Patton Interview', 9),
#  ('Club Graffiti', 4),
#  ('Alien Center', 6),
#  ('Jade Bunch', 8),
#  ('Network Peak', 3),
#  ('Name Detective', 3),
#  ('Outfield Massacre', 4),
#  ('Watership Frontier', 6),
#  ('Trojan Tomorrow', 8),
#  ('Apocalypse Flamingos', 5),
#  ('Cat Coneheads', 4),
#  ('Varsity Trip', 3),
#  ('Strangelove Desire', 9),
#  ('Egypt Tenenbaums', 5),
#  ('Pirates Roxanne', 1),
#  ('Divorce Shining', 6),
#  ('Vampire Whale', 5),
#  ('Oz Liaisons', 11),
#  ('Ghostbusters Elf', 1),
#  ('Traffic Hobbit', 4),
#  ('Whale Bikini', 5),
#  ('Nuts Ties', 2),
#  ('Moonwalker Fool', 7),
#  ('Cheaper Clyde', 2),
#  ('Watch Tracy', 5),
#  ('Lust Lock', 7),
#  ('Citizen Shrek', 8),
#  ('Command Darling', 8),
#  ('Heartbreakers Bright', 5),
#  ('Patient Sister', 4),
#  ('Outbreak Divine', 5),
#  ('Bed Highball', 5),
#  ('Requiem Tycoon', 8),
#  ('National Story', 7),
#  ('Jeepers Wedding', 6),
#  ('Frida Slipper', 5),
#  ('Mourning Purple', 7),
#  ('Language Cowboy', 6),
#  ('Doors President', 9),
#  ('Barbarella Streetcar', 5),
#  ('Hoosiers Birdcage', 10),
#  ('Blindness Gun', 3),
#  ('Maltese Hope', 1),
#  ('Chamber Italian', 7),
#  ('Moon Bunch', 1),
#  ('Tomatoes Hellfighters', 9),
#  ('Army Flintstones', 7),
#  ('Wonka Sea', 2),
#  ('Hedwig Alter', 4),
#  ('Honey Ties', 5),
#  ('Hurricane Affair', 3),
#  ('Nightmare Chill', 2),
#  ('Matrix Snowman', 3),
#  ('Shootist Superfly', 3),
#  ('Hanky October', 3),
#  ('Orient Closer', 4),
#  ('Lawrence Love', 2),
#  ('Usual Untouchables', 5),
#  ('Squad Fish', 5),
#  ('Shakespeare Saddle', 6),
#  ('Shepherd Midsummer', 5),
#  ('Wisdom Worker', 7),
#  ('African Egg', 5),
#  ('Family Sweet', 9),
#  ('Wait Cider', 9),
#  ('October Submarine', 5),
#  ('World Leathernecks', 8),
#  ('Encounters Curtain', 4),
#  ('California Birds', 2),
#  ('Apollo Teen', 8),
#  ('Brooklyn Desert', 5),
#  ('Dream Pickup', 4),
#  ('Phantom Glory', 2),
#  ('Arizona Bang', 4),
#  ('Midsummer Groundhog', 2),
#  ('Alaska Phantom', 7),
#  ('Stampede Disturbing', 6),
#  ('Attraction Newton', 4),
#  ('Earth Vision', 3),
#  ('Telegraph Voyage', 7),
#  ('Clueless Bucket', 8),
#  ('King Evolution', 6),
#  ('Hall Cassidy', 5),
#  ('Slums Duck', 3),
#  ('Desert Poseidon', 5),
#  ('Bride Intrigue', 1),
#  ('Wardrobe Phantom', 8),
#  ('Gangs Pride', 4),
#  ('Games Bowfinger', 8),
#  ('Sensibility Rear', 6),
#  ('Pluto Oleander', 7),
#  ('Homicide Peach', 8),
#  ('Kick Savannah', 6),
#  ('Darko Dorado', 4),
#  ('Ladybugs Armageddon', 4),
#  ('Lion Uncut', 3),
#  ('Creepers Kane', 6),
#  ('Superfly Trip', 7),
#  ('Song Hedwig', 5),
#  ('President Bang', 5),
#  ('Loathing Legally', 5),
#  ('Northwest Polish', 8),
#  ('Gilmore Boiled', 6),
#  ('Tracy Cider', 3),
#  ('Doctor Grail', 6),
#  ('Wars Pluto', 4),
#  ('Jumanji Blade', 6),
#  ('Noon Papi', 6),
#  ('Bang Kwai', 7),
#  ('Disturbing Scarface', 4),
#  ('Robbery Bright', 2),
#  ('Vanished Garden', 2),
#  ('Dolls Rage', 1),
#  ('Borrowers Bedazzled', 7),
#  ('Crystal Breaking', 5),
#  ('Tootsie Pilot', 5),
#  ('Spy Mile', 8),
#  ('Operation Operation', 3),
#  ('Destiny Saturday', 7),
#  ('Homeward Cider', 7),
#  ('Galaxy Sweethearts', 3),
#  ('Sorority Queen', 4),
#  ('Groundhog Uncut', 7),
#  ('Santa Paris', 6),
#  ('Pittsburgh Hunchback', 5),
#  ('Hyde Doctor', 6),
#  ('Open African', 9),
#  ('Jacket Frisco', 10),
#  ('Untouchables Sunrise', 5),
#  ('Sugar Wonka', 5),
#  ('Videotape Arsenic', 5),
#  ('English Bulworth', 5),
#  ('Chill Luck', 5),
#  ('Packer Madigan', 1),
#  ('Metropolis Coma', 6),
#  ('Chainsaw Uptown', 2),
#  ('Autumn Crow', 3),
#  ('Roots Remember', 10),
#  ('Divide Monster', 6),
#  ('Frost Head', 7),
#  ('Saints Bride', 10),
#  ('Lucky Flying', 10),
#  ('Caddyshack Jedi', 7),
#  ('Airport Pollock', 4),
#  ('Raiders Antitrust', 6),
#  ('Express Lonely', 8),
#  ('Date Speed', 4),
#  ('Happiness United', 5),
#  ('Thief Pelican', 7),
#  ('Moonshine Cabin', 5),
#  ('Submarine Bed', 11),
#  ('Clerks Angels', 4),
#  ('Unforgiven Zoolander', 7),
#  ('Amadeus Holy', 6),
#  ('Musketeers Wait', 1),
#  ('Malkovich Pet', 7),
#  ('Heavenly Gun', 6),
#  ('Chaplin License', 6),
#  ('Anything Savannah', 3),
#  ('Elizabeth Shane', 3),
#  ('Outlaw Hanky', 7),
#  ('Blues Instinct', 4),
#  ('Maiden Home', 8),
#  ('Torque Bound', 5),
#  ('Airplane Sierra', 5),
#  ('Weekend Personal', 10),
#  ('Werewolf Lola', 7),
#  ('Bucket Brotherhood', 6),
#  ('Hellfighters Sierra', 12),
#  ('Bear Graceland', 3),
#  ('School Jacket', 8),
#  ('Strangers Graffiti', 5),
#  ('Zhivago Core', 6),
#  ('Inch Jet', 5),
#  ('Driver Annie', 8),
#  ('Tourist Pelican', 3),
#  ('Beneath Rush', 7),
#  ('Goodfellas Salute', 8),
#  ('Conquerer Nuts', 6),
#  ('Polish Brooklyn', 10),
#  ('Elf Murder', 5),
#  ('Japanese Run', 9),
#  ('Stagecoach Armageddon', 6),
#  ('Ark Ridgemont', 3),
#  ('Hanover Galaxy', 7),
#  ('Italian African', 2),
#  ('Rainbow Shock', 6),
#  ('Amistad Midsummer', 4),
#  ('League Hellfighters', 6),
#  ('Fever Empire', 3),
#  ('Trip Newton', 4),
#  ('Reign Gentlemen', 3),
#  ('Perdition Fargo', 5),
#  ('Flatliners Killer', 9),
#  ('Villain Desperate', 2),
#  ('Spinal Rocky', 8),
#  ('Early Home', 6),
#  ('Clockwork Paradise', 5),
#  ('Jet Neighbors', 6),
#  ('Breakfast Goldfinger', 5),
#  ('Sunrise League', 5),
#  ('Paradise Sabrina', 4),
#  ('Speakeasy Date', 3),
#  ('Wash Heavenly', 5),
#  ('Tights Dawn', 5),
#  ('Backlash Undefeated', 7),
#  ('Sea Virgin', 8),
#  ('Legend Jedi', 4),
#  ('Control Anthem', 3),
#  ('Cider Desire', 5),
#  ('Prix Undefeated', 7),
#  ('Behavior Runaway', 5),
#  ('Downhill Enough', 4),
#  ('Dances None', 5),
#  ('Fargo Gandhi', 5),
#  ('Volume House', 5),
#  ('Gandhi Kwai', 8),
#  ('Kentuckian Giant', 4),
#  ('Fiddler Lost', 11),
#  ('Rules Human', 5),
#  ('Super Wyoming', 3),
#  ('Aladdin Calendar', 8),
#  ('Exorcist Sting', 5),
#  ('Magic Mallrats', 4),
#  ('Harry Idaho', 6),
#  ('Basic Easy', 6),
#  ('Orange Grapes', 5),
#  ('Contact Anonymous', 5),
#  ('Cassidy Wyoming', 7),
#  ('Kane Exorcist', 5),
#  ('Sweden Shining', 5),
#  ('Mission Zoolander', 5),
#  ('Model Fish', 8),
#  ('Alone Trip', 8),
#  ('Youth Kick', 5),
#  ('Town Ark', 4),
#  ('Darling Breaking', 2),
#  ('Crow Grease', 10),
#  ('Sun Confessions', 5),
#  ('Day Unfaithful', 5),
#  ('Pilot Hoosiers', 7),
#  ('Psycho Shrunk', 1),
#  ('Philadelphia Wife', 2),
#  ('Wife Turn', 6),
#  ('Holes Brannigan', 11),
#  ('Valley Packer', 4),
#  ('Coldblooded Darling', 4),
#  ('Horror Reign', 5),
#  ('Color Philadelphia', 7),
#  ('Banger Pinocchio', 6),
#  ('Streak Ridgemont', 3),
#  ('Steel Santa', 3),
#  ('Teen Apollo', 5),
#  ('Bulworth Commandments', 4),
#  ('Neighbors Charade', 7),
#  ('Trap Guys', 7),
#  ('Boogie Amelie', 6),
#  ('Grit Clockwork', 3),
#  ('Haunted Antitrust', 5),
#  ('Eagles Panky', 6),
#  ('Shane Darkness', 3),
#  ('Stone Fire', 1),
#  ('Effect Gladiator', 7),
#  ('Young Language', 5),
#  ('Candles Grapes', 7),
#  ('Darn Forrester', 9),
#  ('Hotel Happiness', 4),
#  ('Chinatown Gladiator', 10),
#  ('Splendor Patton', 10),
#  ('Alamo Videotape', 4),
#  ('Hunger Roof', 1),
#  ('Independence Hotel', 9),
#  ('Arsenic Independence', 3),
#  ('Hysterical Grail', 9),
#  ('Mermaid Insects', 6),
#  ('Brannigan Sunrise', 2),
#  ('Unbreakable Karate', 8),
#  ('High Encino', 7),
#  ('Hamlet Wisdom', 5),
#  ('Lose Inch', 4),
#  ('Devil Desire', 5),
#  ('Everyone Craft', 5),
#  ('Hunchback Impossible', 2),
#  ('Virtual Spoilers', 3),
#  ('Run Pacific', 6),
#  ('Connecticut Tramp', 7),
#  ('Ice Crossing', 6),
#  ('Daddy Pittsburgh', 5),
#  ('Betrayed Rear', 4),
#  ('Factory Dragon', 6),
#  ('Analyze Hoosiers', 5),
#  ('Working Microcosmos', 5),
#  ('Flintstones Happiness', 4),
#  ('Mod Secretary', 6),
#  ('Ferris Mother', 1),
#  ('Fire Wolves', 5),
#  ('Lawless Vision', 4),
#  ('Splash Gump', 10),
#  ('Comancheros Enemy', 5),
#  ('Jumping Wrath', 8),
#  ('Shawshank Bubble', 10),
#  ('Voice Peach', 3),
#  ('Waterfront Deliverance', 6),
#  ('Personal Ladybugs', 9),
#  ('Wrong Behavior', 9),
#  ('Cause Date', 6),
#  ('Bugsy Song', 2),
#  ('Montezuma Command', 2),
#  ('Curtain Videotape', 3),
#  ('Worst Banger', 4),
#  ('Holiday Games', 6),
#  ('Fireball Philadelphia', 5),
#  ('Eve Resurrection', 6),
#  ('Gables Metropolis', 8),
#  ('Talented Homicide', 5),
#  ('Words Hunter', 6),
#  ('Records Zorro', 8),
#  ('Element Freddy', 4),
#  ('Spirited Casualties', 5),
#  ('Egg Igby', 5),
#  ('Seabiscuit Punk', 3),
#  ('Magnolia Forrester', 7),
#  ('Cupboard Sinners', 8),
#  ('Tuxedo Mile', 3),
#  ('Beach Heartbreakers', 7),
#  ('Human Graffiti', 4),
#  ('Louisiana Harry', 3),
#  ('Donnie Alley', 7),
#  ('Something Duck', 3),
#  ('Pity Bound', 5),
#  ('Evolution Alter', 6),
#  ('Hope Tootsie', 4),
#  ('Treatment Jekyll', 5),
#  ('Flash Wars', 7),
#  ('Crowds Telemark', 4),
#  ('Pocus Pulp', 5),
#  ('Voyage Legally', 5),
#  ('Trouble Date', 8),
#  ('Sky Miracle', 12),
#  ('Alley Evolution', 5),
#  ('Hollywood Anonymous', 6),
#  ('Coast Rainbow', 10),
#  ('Mummy Creatures', 13),
#  ('Room Roman', 2),
#  ('Dozen Lion', 6),
#  ('Casualties Encino', 5),
#  ('Frontier Cabin', 6),
#  ('Velvet Terminator', 9),
#  ('Money Harold', 7),
#  ('Sling Luke', 3),
#  ('Pacific Amistad', 8),
#  ('Eyes Driving', 5),
#  ('Wasteland Divine', 6),
#  ('Dares Pluto', 10),
#  ('Gleaming Jawbreaker', 8),
#  ('Fantasia Park', 3),
#  ('Saturday Lambs', 9),
#  ('Beast Hunchback', 5),
#  ('Commandments Express', 4),
#  ('Roof Champion', 5),
#  ('Kramer Chocolate', 8),
#  ('Pinocchio Simon', 11),
#  ('Catch Amistad', 5),
#  ('Wolves Desire', 6),
#  ('Wyoming Storm', 6),
#  ('Maguire Apache', 4),
#  ('Carrie Bunch', 7),
#  ('Jeopardy Encino', 5),
#  ('Labyrinth League', 6),
#  ('Juggler Hardly', 9),
#  ('Brotherhood Blanket', 5),
#  ('Poseidon Forever', 6),
#  ('Texas Watch', 6),
#  ('Women Dorado', 5),
#  ('Strictly Scarface', 4),
#  ('Charade Duffel', 3),
#  ('Summer Scarface', 8),
#  ('Lolita World', 1),
#  ('Mile Mulan', 3),
#  ('Rocky War', 3),
#  ('Cleopatra Devil', 7),
#  ('Kiss Glory', 7),
#  ('Pride Alamo', 4),
#  ('Jedi Beneath', 4),
#  ('Ridgemont Submarine', 5),
#  ('Chariots Conspiracy', 2),
#  ('Redemption Comforts', 5),
#  ('Informer Double', 3),
#  ('Scarface Bang', 7),
#  ('Titanic Boondock', 12),
#  ('Interview Liaisons', 5),
#  ('Smoochy Control', 2),
#  ('Steers Armageddon', 4),
#  ('Runner Madigan', 8),
#  ('Range Moonwalker', 4),
#  ('Remember Diary', 4),
#  ('Wild Apollo', 4),
#  ('Go Purple', 3),
#  ('Jekyll Frogmen', 3),
#  ('Opposite Necklace', 6),
#  ('Pet Haunting', 7),
#  ('Scalawag Duck', 5),
#  ('Enemy Odds', 4),
#  ('Camelot Vacation', 2),
#  ('Illusion Amelie', 7),
#  ('Chocolate Duck', 7),
#  ('Bingo Talented', 5),
#  ('Twisted Pirates', 3),
#  ('Gold River', 2),
#  ('Miracle Virtual', 1),
#  ('Dude Blindness', 7),
#  ('Undefeated Dalmations', 3),
#  ('Kwai Homeward', 5),
#  ('Insider Arizona', 9),
#  ('Campus Remember', 3),
#  ('Jerk Paycheck', 8),
#  ('Baby Hall', 8),
#  ('Killer Innocent', 5),
#  ('Sassy Packer', 3),
#  ('Sleepy Japanese', 6),
#  ('Blanket Beverly', 4),
#  ('Treasure Command', 7),
#  ('Platoon Instinct', 5),
#  ('Chicken Hellfighters', 2),
#  ('Pulp Beverly', 7),
#  ('Quills Bull', 4),
#  ('Shrunk Divine', 4),
#  ('Dragonfly Strangers', 3),
#  ('Lady Stage', 8),
#  ('Virgin Daisy', 8),
#  ('Argonauts Town', 5),
#  ('Gorgeous Bingo', 7),
#  ('Storm Happiness', 8),
#  ('Stock Glass', 7),
#  ('Sinners Atlantis', 4),
#  ('Monterey Labyrinth', 6),
#  ('Hours Rage', 6),
#  ('Driving Polish', 7),
#  ('Grease Youth', 3),
#  ('West Lion', 9),
#  ('Ghost Groundhog', 5),
#  ('Snatch Slipper', 3),
#  ('Horn Working', 8),
#  ('Lovely Jingle', 6),
#  ('Hawk Chill', 7),
#  ('Terminator Club', 2),
#  ('Rushmore Mermaid', 7),
#  ('Deer Virginian', 3),
#  ('Alter Victory', 4),
#  ('Darkness War', 2),
#  ('Falcon Volume', 4),
#  ('Mother Oleander', 5),
#  ('Shanghai Tycoon', 8),
#  ('Attacks Hate', 4),
#  ('Paycheck Wait', 3),
#  ('Rider Caddyshack', 9),
#  ('Drifter Commandments', 7),
#  ('Swarm Gold', 6),
#  ('Married Go', 3),
#  ('Badman Dawn', 8),
#  ('License Weekend', 8),
#  ('United Pilot', 6),
#  ('Scorpion Apollo', 8),
#  ('Atlantis Cause', 9),
#  ('Timberland Sky', 4),
#  ('Feud Frogmen', 4),
#  ('Reservoir Adaptation', 8),
#  ('Celebrity Horn', 4),
#  ('Mystic Truman', 4),
#  ('Straight Hours', 3),
#  ('Holy Tadpole', 3),
#  ('Goldmine Tycoon', 7),
#  ('Punk Divorce', 7),
#  ('Oklahoma Jumanji', 9),
#  ('Extraordinary Conquerer', 7),
#  ('Godfather Diary', 6),
#  ('Liaisons Sweet', 6),
#  ('Chasing Fight', 5),
#  ('Others Soup', 4),
#  ('Wagon Jaws', 6),
#  ('Hobbit Alien', 8),
#  ('Gone Trouble', 5),
#  ('Anonymous Human', 9),
#  ('Metal Armageddon', 8),
#  ('Grapes Fury', 5),
#  ('Goldfinger Sensibility', 4),
#  ('Whisperer Giant', 3),
#  ('Sting Personal', 7),
#  ('Deliverance Mulholland', 3),
#  ('Craft Outfield', 6),
#  ('Dogma Family', 7),
#  ('Cranes Reservoir', 6),
#  ('Salute Apollo', 4),
#  ('Frogmen Breaking', 6),
#  ('Spoilers Hellfighters', 7),
#  ('Towers Hurricane', 4),
#  ('Potluck Mixed', 6),
#  ('Intentions Empire', 2),
#  ('Gilbert Pelican', 4),
#  ('Blood Argonauts', 4),
#  ('Durham Panky', 9),
#  ('Comforts Rush', 5),
#  ('Movie Shakespeare', 8),
#  ('House Dynamite', 9),
#  ('Sister Freddy', 3),
#  ('Madigan Dorado', 6),
#  ('Saddle Antitrust', 3),
#  ('Panky Submarine', 8),
#  ('Caper Motions', 7),
#  ('Side Ark', 6),
#  ('Wake Jaws', 5),
#  ('Raging Airplane', 3),
#  ('Stranger Strangers', 9),
#  ('Confessions Maguire', 4),
#  ('Monster Spartacus', 7),
#  ('Connection Microcosmos', 7),
#  ('Handicap Boondock', 7),
#  ('Duck Racer', 2),
#  ('Madison Trap', 5),
#  ('State Wasteland', 7),
#  ('Confused Candles', 6),
#  ('Muscle Bright', 5),
#  ('Hollow Jeopardy', 2),
#  ('Clash Freddy', 7),
#  ('Elephant Trojan', 5),
#  ('Sundance Invasion', 7),
#  ('Idols Snatchers', 8),
#  ('Snowman Rollercoaster', 3),
#  ('Conspiracy Spirit', 4),
#  ('Freaky Pocus', 5),
#  ('Soup Wisdom', 2),
#  ('Hate Handicap', 3),
#  ('Notting Speakeasy', 2),
#  ('Story Side', 5),
#  ('Ending Crowds', 5),
#  ('Mulholland Beast', 6),
#  ('Calendar Gunfight', 8),
#  ('Birds Perdition', 4),
#  ('Destination Jerk', 3),
#  ('Smile Earring', 8),
#  ('Maude Mod', 6),
#  ('Party Knock', 2),
#  ('Dying Maker', 2),
#  ('Fugitive Maguire', 11),
#  ('Tomorrow Hustler', 6),
#  ('Doubtfire Labyrinth', 5),
#  ('Park Citizen', 6),
#  ('Full Flatliners', 6),
#  ('Savannah Town', 6),
#  ('Dynamite Tarzan', 5),
#  ('Virginian Pluto', 8),
#  ('Expecations Natural', 3),
#  ('North Tequila', 5),
#  ('Oleander Clue', 10),
#  ('Anaconda Confessions', 5),
#  ('Chicago North', 8),
#  ('Circus Youth', 2),
#  ('Secret Groundhog', 3),
#  ('Murder Antitrust', 8),
#  ('Nemo Campus', 5),
#  ('Beauty Grease', 5),
#  ('Slipper Fidelity', 7),
#  ('Road Roxanne', 8),
#  ('Right Cranes', 7),
#  ('Intolerable Intentions', 6),
#  ('River Outlaw', 4),
#  ('Idaho Love', 6),
#  ('Detective Vision', 3),
#  ('Balloon Homeward', 6),
#  ('Christmas Moonshine', 3),
#  ('Mockingbird Hollywood', 3),
#  ('Lover Truman', 7),
#  ('Gathering Calendar', 3),
#  ('Drums Dynamite', 7),
#  ('Samurai Lion', 2),
#  ('Pond Seattle', 3),
#  ('Pearl Destiny', 4)]

# %% [markdown]
# # 5
#
# ### List each film title and the number of actors in that film, for films with more than 10 actors.

# %%
# %%sql
# EXPLAIN
# SELECT title, COUNT(*)
# FROM film
# INNER JOIN film_actor
#     ON film.film_id = film_actor.film_id
# GROUP BY title
# HAVING COUNT(*) > 10
# Out:
#  * postgres://dsa_ro_user:***@pgsql.dsa.lan/dvdrental
# 8 rows affected.
# [('HashAggregate  (cost=216.48..226.48 rows=1000 width=23)',),
#  ('  Group Key: film.title',),
#  ('  Filter: (count(*) > 10)',),
#  ('  ->  Hash Join  (cost=76.50..175.51 rows=5462 width=15)',),
#  ('        Hash Cond: (film_actor.film_id = film.film_id)',),
#  ('        ->  Seq Scan on film_actor  (cost=0.00..84.62 rows=5462 width=2)',),
#  ('        ->  Hash  (cost=64.00..64.00 rows=1000 width=19)',),
#  ('              ->  Seq Scan on film  (cost=0.00..64.00 rows=1000 width=19)',)]

# %%
# %%sql
# SELECT title, COUNT(*)
# FROM film
# INNER JOIN film_actor
#     ON film.film_id = film_actor.film_id
# GROUP BY title
# HAVING COUNT(*) > 10
# Out:
#  * postgres://dsa_ro_user:***@pgsql.dsa.lan/dvdrental
# 27 rows affected.
# [('Arabia Dogma', 12),
#  ('Lonely Elephant', 12),
#  ('Maker Gables', 11),
#  ('Lesson Cleopatra', 12),
#  ('Boondock Ballroom', 13),
#  ('Lambs Cincinatti', 15),
#  ('Crazy Home', 13),
#  ('Spice Sorority', 11),
#  ('Dracula Crystal', 13),
#  ('Chitty Lock', 13),
#  ('Telemark Heartbreakers', 11),
#  ('Mask Peach', 11),
#  ('Image Princess', 11),
#  ('Instinct Airport', 11),
#  ('Spirit Flintstones', 11),
#  ('Random Go', 13),
#  ('Rings Heartbreakers', 11),
#  ('Oz Liaisons', 11),
#  ('Submarine Bed', 11),
#  ('Hellfighters Sierra', 12),
#  ('Fiddler Lost', 11),
#  ('Holes Brannigan', 11),
#  ('Sky Miracle', 12),
#  ('Mummy Creatures', 13),
#  ('Pinocchio Simon', 11),
#  ('Titanic Boondock', 12),
#  ('Fugitive Maguire', 11)]

# %% [markdown]
# [Helpful Hints](https://youtu.be/4dZJoRfP7Kw)
#
#
# ---
#
# # 6
#
# ### List the average length of the movies in the database, per `language_id`

# %%
# %%sql
# EXPLAIN
# SELECT language_id, AVG(length)
# FROM film
# GROUP BY language_id
# Out:
#  * postgres://dsa_ro_user:***@pgsql.dsa.lan/dvdrental
# 3 rows affected.
# [('HashAggregate  (cost=69.00..69.01 rows=1 width=34)',),
#  ('  Group Key: language_id',),
#  ('  ->  Seq Scan on film  (cost=0.00..64.00 rows=1000 width=4)',)]

# %%
# %%sql
# SELECT language_id, AVG(length)
# FROM film
# GROUP BY language_id
# Out:
#  * postgres://dsa_ro_user:***@pgsql.dsa.lan/dvdrental
# 1 rows affected.
# [(1, Decimal('115.2720000000000000'))]

# %% [markdown]
# # 7
#
# ### List the average length of the movies in the database, per language name

# %%
# %%sql
# EXPLAIN
# SELECT name, AVG(length)
# FROM film
# INNER JOIN language
#     ON film.language_id = language.language_id
# GROUP BY name
# Out:
#  * postgres://dsa_ro_user:***@pgsql.dsa.lan/dvdrental
# 7 rows affected.
# [('HashAggregate  (cost=74.62..74.69 rows=6 width=116)',),
#  ('  Group Key: language.name',),
#  ('  ->  Hash Join  (cost=1.14..69.62 rows=1000 width=86)',),
#  ('        Hash Cond: (film.language_id = language.language_id)',),
#  ('        ->  Seq Scan on film  (cost=0.00..64.00 rows=1000 width=4)',),
#  ('        ->  Hash  (cost=1.06..1.06 rows=6 width=88)',),
#  ('              ->  Seq Scan on language  (cost=0.00..1.06 rows=6 width=88)',)]

# %%
# %%sql
# SELECT name, AVG(length)
# FROM film
# INNER JOIN language
#     ON film.language_id = language.language_id
# GROUP BY name
# Out:
#  * postgres://dsa_ro_user:***@pgsql.dsa.lan/dvdrental
# 1 rows affected.
# [('English             ', Decimal('115.2720000000000000'))]

# %% [markdown]
# # 8
#
# ### List each film title and its average rental duration in days.
#
# **HINT** `return_date::date` casts the return _timestamp_ to date.  PostgreSQL can do date math natively.

# %%
# %%sql
# EXPLAIN
# SELECT title, AVG(return_date::date - rental_date::date) AS average_duration
# FROM film
# INNER JOIN inventory
#     ON film.film_id = inventory.film_id
# INNER JOIN rental
#     ON inventory.inventory_id = rental.inventory_id
# GROUP BY title
# Out:
#  * postgres://dsa_ro_user:***@pgsql.dsa.lan/dvdrental
# 11 rows affected.
# [('HashAggregate  (cost=800.02..812.52 rows=1000 width=47)',),
#  ('  Group Key: film.title',),
#  ('  ->  Hash Join  (cost=204.57..599.47 rows=16044 width=31)',),
#  ('        Hash Cond: (inventory.film_id = film.film_id)',),
#  ('        ->  Hash Join  (cost=128.07..480.67 rows=16044 width=18)',),
#  ('              Hash Cond: (rental.inventory_id = inventory.inventory_id)',),
#  ('              ->  Seq Scan on rental  (cost=0.00..310.44 rows=16044 width=20)',),
#  ('              ->  Hash  (cost=70.81..70.81 rows=4581 width=6)',),
#  ('                    ->  Seq Scan on inventory  (cost=0.00..70.81 rows=4581 width=6)',),
#  ('        ->  Hash  (cost=64.00..64.00 rows=1000 width=19)',),
#  ('              ->  Seq Scan on film  (cost=0.00..64.00 rows=1000 width=19)',)]

# %%
# %%sql
# SELECT title, AVG(return_date::date - rental_date::date) AS average_duration
# FROM film
# INNER JOIN inventory
#     ON film.film_id = inventory.film_id
# INNER JOIN rental
#     ON inventory.inventory_id = rental.inventory_id
# GROUP BY title
# Out:
#  * postgres://dsa_ro_user:***@pgsql.dsa.lan/dvdrental
# 958 rows affected.
# [('Graceland Dynamite', Decimal('5.3333333333333333')),
#  ('Opus Ice', Decimal('5.0909090909090909')),
#  ('Braveheart Human', Decimal('4.0000000000000000')),
#  ('Wonderful Drop', Decimal('6.0000000000000000')),
#  ('Rush Goodfellas', Decimal('4.5483870967741935')),
#  ('Purple Movie', Decimal('4.0000000000000000')),
#  ('Minority Kiss', Decimal('4.9090909090909091')),
#  ('Luke Mummy', Decimal('5.0000000000000000')),
#  ('Fantasy Troopers', Decimal('5.2307692307692308')),
#  ('Grinch Massage', Decimal('5.2142857142857143')),
#  ('Gaslight Crusade', Decimal('4.0000000000000000')),
#  ('Microcosmos Paradise', Decimal('5.5384615384615385')),
#  ('Saturn Name', Decimal('5.3846153846153846')),
#  ('Memento Zoolander', Decimal('5.2307692307692308')),
#  ('Sunset Racer', Decimal('5.3750000000000000')),
#  ('Zoolander Fiction', Decimal('5.5882352941176471')),
#  ('Carol Texas', Decimal('5.1666666666666667')),
#  ('Stepmom Dream', Decimal('5.3500000000000000')),
#  ('Arabia Dogma', Decimal('4.6923076923076923')),
#  ('Minds Truman', Decimal('5.0000000000000000')),
#  ('Baked Cleopatra', Decimal('4.6000000000000000')),
#  ('Closer Bang', Decimal('4.9642857142857143')),
#  ('Enough Raging', Decimal('5.3529411764705882')),
#  ('Grosse Wonderful', Decimal('4.8750000000000000')),
#  ('Innocent Usual', Decimal('4.9615384615384615')),
#  ('Sleepless Monsoon', Decimal('5.0000000000000000')),
#  ('Suit Walls', Decimal('5.0526315789473684')),
#  ('Wizard Coldblooded', Decimal('4.0000000000000000')),
#  ('Lonely Elephant', Decimal('4.8000000000000000')),
#  ('Victory Academy', Decimal('3.8888888888888889')),
#  ('Bedazzled Married', Decimal('4.1538461538461538')),
#  ('Maker Gables', Decimal('5.3000000000000000')),
#  ('Private Drop', Decimal('5.0000000000000000')),
#  ('Worker Tarzan', Decimal('5.4000000000000000')),
#  ('Gosford Donnie', Decimal('4.5000000000000000')),
#  ('Drop Waterfront', Decimal('5.0000000000000000')),
#  ('Annie Identity', Decimal('4.2272727272727273')),
#  ('Lesson Cleopatra', Decimal('5.1428571428571429')),
#  ('Wanda Chamber', Decimal('5.4000000000000000')),
#  ('Dwarfs Alter', Decimal('5.2500000000000000')),
#  ('Garden Island', Decimal('5.0000000000000000')),
#  ('Graduate Lord', Decimal('5.2500000000000000')),
#  ('Patriot Roman', Decimal('5.5000000000000000')),
#  ('Novocaine Flight', Decimal('5.1578947368421053')),
#  ('Necklace Outbreak', Decimal('4.6666666666666667')),
#  ('Menagerie Rushmore', Decimal('5.4285714285714286')),
#  ('Sleeping Suspects', Decimal('4.9565217391304348')),
#  ('Uncut Suicides', Decimal('6.0714285714285714')),
#  ('Midnight Westward', Decimal('4.2500000000000000')),
#  ('Jersey Sassy', Decimal('6.0000000000000000')),
#  ('Rock Instinct', Decimal('5.0588235294117647')),
#  ('Magnificent Chitty', Decimal('6.3750000000000000')),
#  ('Clones Pinocchio', Decimal('4.8421052631578947')),
#  ('Insects Stone', Decimal('3.2941176470588235')),
#  ('Giant Troopers', Decimal('4.2142857142857143')),
#  ('Loser Hustler', Decimal('5.0666666666666667')),
#  ('Heavyweights Beast', Decimal('4.6521739130434783')),
#  ('Entrapment Satisfaction', Decimal('6.3333333333333333')),
#  ('Core Suit', Decimal('5.4444444444444444')),
#  ('Cyclone Family', Decimal('5.2857142857142857')),
#  ('Cabin Flash', Decimal('5.4000000000000000')),
#  ('Slacker Liaisons', Decimal('4.5882352941176471')),
#  ('Jaws Harry', Decimal('4.9285714285714286')),
#  ('Bowfinger Gables', Decimal('3.0909090909090909')),
#  ('Fellowship Autumn', Decimal('5.5769230769230769')),
#  ('Birdcage Casper', Decimal('5.2222222222222222')),
#  ('Forever Candidate', Decimal('4.6923076923076923')),
#  ('Dangerous Uptown', Decimal('6.1666666666666667')),
#  ('Guys Falcon', Decimal('4.5555555555555556')),
#  ('Warlock Werewolf', Decimal('4.5000000000000000')),
#  ('None Spiking', Decimal('5.1538461538461538')),
#  ('Bringing Hysterical', Decimal('5.8000000000000000')),
#  ('Haunting Pianist', Decimal('5.4090909090909091')),
#  ('Agent Truman', Decimal('5.9047619047619048')),
#  ('Motions Details', Decimal('4.7333333333333333')),
#  ('Tenenbaums Command', Decimal('3.1538461538461538')),
#  ('Tarzan Videotape', Decimal('4.5000000000000000')),
#  ('Secrets Paradise', Decimal('5.3500000000000000')),
#  ('Double Wrath', Decimal('5.3600000000000000')),
#  ('Birch Antitrust', Decimal('5.5454545454545455')),
#  ('Greatest North', Decimal('4.7931034482758621')),
#  ('Sense Greek', Decimal('4.5714285714285714')),
#  ('Secretary Rouge', Decimal('5.4444444444444444')),
#  ('Invasion Cyclone', Decimal('4.5185185185185185')),
#  ('Daughter Madigan', Decimal('5.5555555555555556')),
#  ('Congeniality Quest', Decimal('5.1818181818181818')),
#  ('Crossroads Casualties', Decimal('4.3809523809523810')),
#  ('Canyon Stock', Decimal('4.9444444444444444')),
#  ('Reef Salute', Decimal('5.5454545454545455')),
#  ('French Holiday', Decimal('5.1764705882352941')),
#  ('Rugrats Shakespeare', Decimal('4.5666666666666667')),
#  ('Highball Potter', Decimal('4.8571428571428571')),
#  ('Translation Summer', Decimal('4.6000000000000000')),
#  ('Papi Necklace', Decimal('5.2500000000000000')),
#  ('Tycoon Gathering', Decimal('6.5000000000000000')),
#  ('Peak Forever', Decimal('4.5500000000000000')),
#  ('Loverboy Attacks', Decimal('5.5000000000000000')),
#  ('Earring Instinct', Decimal('4.9473684210526316')),
#  ('Ship Wonderland', Decimal('3.0666666666666667')),
#  ('Rouge Squad', Decimal('4.6111111111111111')),
#  ('Clue Grail', Decimal('5.5714285714285714')),
#  ('Wonderland Christmas', Decimal('4.9090909090909091')),
#  ('Finding Anaconda', Decimal('4.9166666666666667')),
#  ('Thin Sagebrush', Decimal('5.5454545454545455')),
#  ('Nash Chocolat', Decimal('6.3333333333333333')),
#  ('Wrath Mile', Decimal('4.5000000000000000')),
#  ('Forrest Sons', Decimal('5.4444444444444444')),
#  ('Harold French', Decimal('3.1250000000000000')),
#  ('Pure Runner', Decimal('6.0000000000000000')),
#  ('Turn Star', Decimal('4.4285714285714286')),
#  ('Anthem Luke', Decimal('4.7333333333333333')),
#  ('Witches Panic', Decimal('5.5333333333333333')),
#  ('Duffel Apocalypse', Decimal('1.7142857142857143')),
#  ('Shrek License', Decimal('3.6428571428571429')),
#  ('Impossible Prejudice', Decimal('4.8571428571428571')),
#  ('Heaven Freedom', Decimal('5.0000000000000000')),
#  ('Peach Innocent', Decimal('5.7692307692307692')),
#  ('Frisco Forrest', Decimal('6.2500000000000000')),
#  ('Reds Pocus', Decimal('6.7777777777777778')),
#  ('Music Boondock', Decimal('5.0000000000000000')),
#  ('Chisum Behavior', Decimal('4.5384615384615385')),
#  ('Volcano Texas', Decimal('4.9047619047619048')),
#  ('Daisy Menagerie', Decimal('4.2500000000000000')),
#  ('Lost Bird', Decimal('6.1666666666666667')),
#  ('Conversation Downhill', Decimal('5.5625000000000000')),
#  ('Caribbean Liberty', Decimal('5.7777777777777778')),
#  ('Lambs Cincinatti', Decimal('5.0000000000000000')),
#  ('Escape Metropolis', Decimal('4.5600000000000000')),
#  ('Dumbo Lust', Decimal('5.0000000000000000')),
#  ('Pizza Jumanji', Decimal('4.4285714285714286')),
#  ('Hills Neighbors', Decimal('6.2800000000000000')),
#  ('Chance Resurrection', Decimal('5.1111111111111111')),
#  ('Truman Crazy', Decimal('4.6521739130434783')),
#  ('Candidate Perdition', Decimal('6.0000000000000000')),
#  ('Spiking Element', Decimal('4.5384615384615385')),
#  ('Fight Jawbreaker', Decimal('4.3333333333333333')),
#  ('Apache Divine', Decimal('4.1290322580645161')),
#  ('Shining Roses', Decimal('5.2500000000000000')),
#  ('Ishtar Rocketeer', Decimal('6.1428571428571429')),
#  ('Flying Hook', Decimal('6.0000000000000000')),
#  ('Desperate Trainspotting', Decimal('4.1666666666666667')),
#  ('Greedy Roots', Decimal('3.2857142857142857')),
#  ('Forrester Comancheros', Decimal('5.3461538461538462')),
#  ('Dirty Ace', Decimal('5.2666666666666667')),
#  ('Trading Pinocchio', Decimal('5.5000000000000000')),
#  ('Paths Control', Decimal('5.9000000000000000')),
#  ('Graffiti Love', Decimal('4.0333333333333333')),
#  ('Amelie Hellfighters', Decimal('4.8000000000000000')),
#  ('Pickup Driving', Decimal('6.0000000000000000')),
#  ('Panic Club', Decimal('5.4285714285714286')),
#  ('Crazy Home', Decimal('4.3333333333333333')),
#  ('Forward Temple', Decimal('5.6250000000000000')),
#  ('Vertigo Northwest', Decimal('5.0000000000000000')),
#  ('Jericho Mulan', Decimal('5.4117647058823529')),
#  ('Gunfighter Mussolini', Decimal('5.5833333333333333')),
#  ('Bilko Anonymous', Decimal('5.4615384615384615')),
#  ('Spice Sorority', Decimal('4.0500000000000000')),
#  ('Blade Polish', Decimal('4.0476190476190476')),
#  ('Massage Image', Decimal('5.2500000000000000')),
#  ('Home Pity', Decimal('6.2142857142857143')),
#  ('Boulevard Mob', Decimal('5.6470588235294118')),
#  ('Dalmations Sweden', Decimal('5.4000000000000000')),
#  ('Hunter Alter', Decimal('6.6000000000000000')),
#  ('Zorro Ark', Decimal('4.5161290322580645')),
#  ('Silence Kane', Decimal('5.1250000000000000')),
#  ('Taxi Kick', Decimal('4.4705882352941176')),
#  ('Resurrection Silverado', Decimal('4.4285714285714286')),
#  ('Suspects Quills', Decimal('5.1379310344827586')),
#  ('Dracula Crystal', Decimal('4.7142857142857143')),
#  ('Harper Dying', Decimal('5.7000000000000000')),
#  ('Simon North', Decimal('4.8333333333333333')),
#  ('Chitty Lock', Decimal('5.1428571428571429')),
#  ('Vacation Boondock', Decimal('4.9047619047619048')),
#  ('Ballroom Mockingbird', Decimal('4.5000000000000000')),
#  ('Legally Secretary', Decimal('4.2222222222222222')),
#  ('Barefoot Manchurian', Decimal('5.0555555555555556')),
#  ('Cruelty Unforgiven', Decimal('3.7142857142857143')),
#  ('Smoking Barbarella', Decimal('4.2941176470588235')),
#  ('Soldiers Evolution', Decimal('4.2500000000000000')),
#  ('Robbers Joon', Decimal('4.8387096774193548')),
#  ('Telemark Heartbreakers', Decimal('4.8000000000000000')),
#  ('Westward Seabiscuit', Decimal('5.8461538461538462')),
#  ('Million Ace', Decimal('4.7000000000000000')),
#  ('Notorious Reunion', Decimal('6.7142857142857143')),
#  ('Ali Forever', Decimal('4.6250000000000000')),
#  ('Coneheads Smoochy', Decimal('5.5200000000000000')),
#  ('Bird Independence', Decimal('5.5454545454545455')),
#  ('Intrigue Worst', Decimal('5.3684210526315789')),
#  ('Mask Peach', Decimal('5.2352941176470588')),
#  ('Scissorhands Slums', Decimal('3.4666666666666667')),
#  ('Boiled Dares', Decimal('4.7333333333333333')),
#  ('Majestic Floats', Decimal('6.1764705882352941')),
#  ('Past Suicides', Decimal('4.5384615384615385')),
#  ('Masked Bubble', Decimal('3.9000000000000000')),
#  ('Bull Shawshank', Decimal('4.7333333333333333')),
#  ('Reap Unfaithful', Decimal('5.3125000000000000')),
#  ('Gunfight Moon', Decimal('5.4545454545454545')),
#  ('Sagebrush Clueless', Decimal('6.4375000000000000')),
#  ('Beethoven Exorcist', Decimal('4.7272727272727273')),
#  ('Lock Rear', Decimal('4.0000000000000000')),
#  ('Vietnam Smoochy', Decimal('4.8666666666666667')),
#  ('Breaking Home', Decimal('4.2307692307692308')),
#  ('Runaway Tenenbaums', Decimal('4.8750000000000000')),
#  ('Head Stranger', Decimal('4.9545454545454545')),
#  ('Ace Goldfinger', Decimal('5.6666666666666667')),
#  ('Quest Mussolini', Decimal('4.4000000000000000')),
#  ('Dancing Fever', Decimal('6.2222222222222222')),
#  ('Image Princess', Decimal('4.9285714285714286')),
#  ('Fool Mockingbird', Decimal('5.4782608695652174')),
#  ('Panther Reds', Decimal('4.9333333333333333')),
#  ('Holocaust Highball', Decimal('4.9411764705882353')),
#  ('Bright Encounters', Decimal('5.3076923076923077')),
#  ('Adaptation Holes', Decimal('3.4166666666666667')),
#  ('Deceiver Betrayed', Decimal('3.9523809523809524')),
#  ('Antitrust Tomatoes', Decimal('4.7000000000000000')),
#  ('Fatal Haunted', Decimal('5.3928571428571429')),
#  ('Sons Interview', Decimal('5.1538461538461538')),
#  ('Yentl Idaho', Decimal('4.7826086956521739')),
#  ('Modern Dorado', Decimal('5.2000000000000000')),
#  ('Monsoon Cause', Decimal('5.7777777777777778')),
#  ('Rage Games', Decimal('4.2105263157894737')),
#  ('Uprising Uptown', Decimal('5.1875000000000000')),
#  ('Jason Trap', Decimal('5.2608695652173913')),
#  ('Sweet Brotherhood', Decimal('4.9333333333333333')),
#  ('Crusade Honey', Decimal('6.3750000000000000')),
#  ('Arachnophobia Rollercoaster', Decimal('5.5416666666666667')),
#  ('Stallion Sundance', Decimal('2.7142857142857143')),
#  ('Creatures Shakespeare', Decimal('5.9285714285714286')),
#  ('Easy Gladiator', Decimal('5.9565217391304348')),
#  ('Snatchers Montezuma', Decimal('3.6666666666666667')),
#  ('Shock Cabin', Decimal('5.4285714285714286')),
#  ('Island Exorcist', Decimal('4.8076923076923077')),
#  ('Liberty Magnificent', Decimal('6.0833333333333333')),
#  ('Seattle Expecations', Decimal('5.3478260869565217')),
#  ('Gun Bonnie', Decimal('5.8800000000000000')),
#  ('Alabama Devil', Decimal('5.6666666666666667')),
#  ('Train Bunch', Decimal('3.5000000000000000')),
#  ('Identity Lover', Decimal('4.8461538461538462')),
#  ('Clyde Theory', Decimal('5.5000000000000000')),
#  ('Troopers Metal', Decimal('5.0714285714285714')),
#  ('Primary Glass', Decimal('4.4814814814814815')),
#  ('Excitement Eve', Decimal('4.7619047619047619')),
#  ('Affair Prejudice', Decimal('4.7272727272727273')),
#  ('Fury Murder', Decimal('5.1052631578947368')),
#  ('Impact Aladdin', Decimal('7.0000000000000000')),
#  ('Deep Crusade', Decimal('5.5384615384615385')),
#  ('Sierra Divide', Decimal('5.7333333333333333')),
#  ('Dinosaur Secretary', Decimal('5.6000000000000000')),
#  ('Freedom Cleopatra', Decimal('2.8000000000000000')),
#  ('Mosquito Armageddon', Decimal('5.1428571428571429')),
#  ('Jungle Closer', Decimal('5.6666666666666667')),
#  ('Indian Love', Decimal('5.6250000000000000')),
#  ('Glass Dying', Decimal('5.6428571428571429')),
#  ('Born Spinal', Decimal('4.0000000000000000')),
#  ('Life Twisted', Decimal('5.1000000000000000')),
#  ('Greek Everyone', Decimal('4.8823529411764706')),
#  ('Massacre Usual', Decimal('5.7000000000000000')),
#  ('Kissing Dolls', Decimal('4.9000000000000000')),
#  ('Meet Chocolate', Decimal('5.2500000000000000')),
#  ('Dorado Notting', Decimal('5.9629629629629630')),
#  ('Titans Jerk', Decimal('5.5714285714285714')),
#  ('Hanging Deep', Decimal('4.6842105263157895')),
#  ('Streetcar Intentions', Decimal('4.2000000000000000')),
#  ('Hardly Robbers', Decimal('7.0000000000000000')),
#  ('War Notting', Decimal('5.4166666666666667')),
#  ('Diary Panic', Decimal('5.0000000000000000')),
#  ('Instinct Airport', Decimal('4.1111111111111111')),
#  ('Bikini Borrowers', Decimal('6.1176470588235294')),
#  ('Rebel Airport', Decimal('4.8750000000000000')),
#  ('Flamingos Connecticut', Decimal('4.3478260869565217')),
#  ('Cincinatti Whisperer', Decimal('6.5833333333333333')),
#  ('Trainspotting Strangers', Decimal('5.2727272727272727')),
#  ('Pelican Comforts', Decimal('5.8846153846153846')),
#  ('Madre Gables', Decimal('6.7857142857142857')),
#  ('Lord Arizona', Decimal('5.0000000000000000')),
#  ('Feathers Metal', Decimal('5.7272727272727273')),
#  ('Hook Chariots', Decimal('4.8461538461538462')),
#  ('Groove Fiction', Decimal('6.4444444444444444')),
#  ('Window Side', Decimal('4.6363636363636364')),
#  ('Silverado Goldfinger', Decimal('6.7272727272727273')),
#  ('Mannequin Worst', Decimal('4.4000000000000000')),
#  ('Willow Tracy', Decimal('5.3750000000000000')),
#  ('Natural Stock', Decimal('4.6923076923076923')),
#  ('Karate Moon', Decimal('4.8260869565217391')),
#  ('Roses Treasure', Decimal('4.7500000000000000')),
#  ('Jawbreaker Brooklyn', Decimal('2.7000000000000000')),
#  ('Racer Egg', Decimal('4.8333333333333333')),
#  ('Mixed Doors', Decimal('5.7500000000000000')),
#  ('Potter Connecticut', Decimal('5.1176470588235294')),
#  ('Mighty Luck', Decimal('5.5833333333333333')),
#  ('Sabrina Midnight', Decimal('4.6190476190476190')),
#  ('Roxanne Rebel', Decimal('4.3157894736842105')),
#  ('Fidelity Devil', Decimal('5.2380952380952381')),
#  ('Madness Attacks', Decimal('5.6000000000000000')),
#  ('Mussolini Spoilers', Decimal('4.2000000000000000')),
#  ('Star Operation', Decimal('5.4000000000000000')),
#  ('Vanilla Day', Decimal('5.7777777777777778')),
#  ('Bunch Minds', Decimal('5.4000000000000000')),
#  ('Sweethearts Suspects', Decimal('5.2500000000000000')),
#  ('Won Dares', Decimal('5.0000000000000000')),
#  ('Lola Agent', Decimal('5.2916666666666667')),
#  ('Reunion Witches', Decimal('3.9500000000000000')),
#  ('Encino Elf', Decimal('4.7222222222222222')),
#  ('Unfaithful Kill', Decimal('5.3750000000000000')),
#  ('Hustler Party', Decimal('6.5000000000000000')),
#  ('Spirit Flintstones', Decimal('4.2000000000000000')),
#  ('Rollercoaster Bringing', Decimal('5.9000000000000000')),
#  ('Details Packer', Decimal('5.5000000000000000')),
#  ('Pianist Outfield', Decimal('4.5000000000000000')),
#  ('Luck Opus', Decimal('4.9000000000000000')),
#  ('Butterfly Chocolat', Decimal('6.0333333333333333')),
#  ('Mallrats United', Decimal('5.5200000000000000')),
#  ('Desire Alien', Decimal('4.5000000000000000')),
#  ('Queen Luke', Decimal('5.3809523809523810')),
#  ('Glory Tracy', Decimal('3.8000000000000000')),
#  ('Bound Cheaper', Decimal('5.3043478260869565')),
#  ('Academy Dinosaur', Decimal('5.0909090909090909')),
#  ('Igby Maker', Decimal('5.4444444444444444')),
#  ('Gentlemen Stage', Decimal('5.1304347826086957')),
#  ('Pollock Deliverance', Decimal('4.6470588235294118')),
#  ('Sleuth Orient', Decimal('4.9523809523809524')),
#  ('Cowboy Doom', Decimal('3.4285714285714286')),
#  ('Prejudice Oleander', Decimal('5.6000000000000000')),
#  ('Odds Boogie', Decimal('5.3333333333333333')),
#  ('Freddy Storm', Decimal('5.3478260869565217')),
#  ('Valentine Vanishing', Decimal('5.7500000000000000')),
#  ('Show Lord', Decimal('4.3200000000000000')),
#  ('Confidential Interview', Decimal('5.2068965517241379')),
#  ('Armageddon Lost', Decimal('5.2000000000000000')),
#  ('Grail Frankenstein', Decimal('5.8888888888888889')),
#  ('Edge Kissing', Decimal('5.0000000000000000')),
#  ('Half Outfield', Decimal('4.7083333333333333')),
#  ('Love Suicides', Decimal('5.1000000000000000')),
#  ('Seven Swarm', Decimal('4.4000000000000000')),
#  ('Oscar Gold', Decimal('5.0000000000000000')),
#  ('Lies Treatment', Decimal('5.1851851851851852')),
#  ('Chocolat Harry', Decimal('5.7000000000000000')),
#  ('Wind Phantom', Decimal('4.8695652173913043')),
#  ('Casablanca Super', Decimal('4.1875000000000000')),
#  ('Random Go', Decimal('5.3333333333333333')),
#  ('Newsies Story', Decimal('5.4285714285714286')),
#  ('Leathernecks Dwarfs', Decimal('5.4285714285714286')),
#  ('Knock Warlock', Decimal('5.5833333333333333')),
#  ('Pajama Jawbreaker', Decimal('4.7142857142857143')),
#  ('Joon Northwest', Decimal('4.0588235294117647')),
#  ('Stage World', Decimal('5.3000000000000000')),
#  ('American Circus', Decimal('5.4285714285714286')),
#  ('Rear Trading', Decimal('5.5882352941176471')),
#  ('Siege Madre', Decimal('5.2666666666666667')),
#  ('Angels Life', Decimal('5.1363636363636364')),
#  ('Crooked Frogmen', Decimal('5.0909090909090909')),
#  ('Jingle Sagebrush', Decimal('4.1538461538461538')),
#  ('Tramp Others', Decimal('5.0500000000000000')),
#  ('Artist Coldblooded', Decimal('5.4375000000000000')),
#  ('Beverly Outlaw', Decimal('5.1904761904761905')),
#  ('Doom Dancing', Decimal('6.2380952380952381')),
#  ('Hunting Musketeers', Decimal('5.0000000000000000')),
#  ('Mine Titans', Decimal('5.7894736842105263')),
#  ('Rings Heartbreakers', Decimal('5.8000000000000000')),
#  ('Lights Deer', Decimal('5.7500000000000000')),
#  ('Mars Roman', Decimal('5.4210526315789474')),
#  ('Champion Flatliners', Decimal('4.8461538461538462')),
#  ('Temple Attraction', Decimal('4.5000000000000000')),
#  ('Dragon Squad', Decimal('4.8181818181818182')),
#  ('Roman Punk', Decimal('5.4583333333333333')),
#  ('Moulin Wake', Decimal('5.7500000000000000')),
#  ('Fiction Christmas', Decimal('5.7368421052631579')),
#  ('Princess Giant', Decimal('5.2307692307692308')),
#  ('Empire Malkovich', Decimal('5.8571428571428571')),
#  ('Fish Opus', Decimal('4.8800000000000000')),
#  ('Tequila Past', Decimal('3.3333333333333333')),
#  ('Theory Mermaid', Decimal('5.7000000000000000')),
#  ('Rocketeer Mother', Decimal('5.3636363636363636')),
#  ('Divine Resurrection', Decimal('4.8571428571428571')),
#  ('Manchurian Curtain', Decimal('5.6000000000000000')),
#  ('Casper Dragonfly', Decimal('4.2500000000000000')),
#  ('Mulan Moon', Decimal('5.3333333333333333')),
#  ('Newton Labyrinth', Decimal('5.4705882352941176')),
#  ('Bubble Grosse', Decimal('4.4000000000000000')),
#  ('Berets Agent', Decimal('4.4500000000000000')),
#  ('Lebowski Soldiers', Decimal('4.4761904761904762')),
#  ('Searchers Wait', Decimal('5.1428571428571429')),
#  ('Uptown Young', Decimal('3.5833333333333333')),
#  ('South Wait', Decimal('5.3333333333333333')),
#  ('Center Dinosaur', Decimal('4.1739130434782609')),
#  ('Spartacus Cheaper', Decimal('5.5555555555555556')),
#  ('Wedding Apollo', Decimal('5.3043478260869565')),
#  ('Perfect Groove', Decimal('6.4117647058823529')),
#  ('Dawn Pond', Decimal('5.5555555555555556')),
#  ('Ties Hunger', Decimal('5.0909090909090909')),
#  ('Satisfaction Confidential', Decimal('5.2941176470588235')),
#  ('Speed Suit', Decimal('5.3333333333333333')),
#  ('Halloween Nuts', Decimal('4.8000000000000000')),
#  ('Vision Torque', Decimal('5.1428571428571429')),
#  ('Blackout Private', Decimal('4.4444444444444444')),
#  ('Iron Moon', Decimal('4.0909090909090909')),
#  ('Bonnie Holocaust', Decimal('4.1875000000000000')),
#  ('Coma Head', Decimal('4.5384615384615385')),
#  ('Disciple Mother', Decimal('3.5555555555555556')),
#  ('Vanishing Rocky', Decimal('4.5882352941176471')),
#  ('Paris Weekend', Decimal('5.9285714285714286')),
#  ('Bill Others', Decimal('5.0000000000000000')),
#  ('Mob Duffel', Decimal('5.5000000000000000')),
#  ('Expendable Stallion', Decimal('5.1785714285714286')),
#  ('Patton Interview', Decimal('4.8695652173913043')),
#  ('Club Graffiti', Decimal('4.8235294117647059')),
#  ('Alien Center', Decimal('4.9090909090909091')),
#  ('Jade Bunch', Decimal('4.3888888888888889')),
#  ('Network Peak', Decimal('5.5483870967741935')),
#  ('Name Detective', Decimal('4.6818181818181818')),
#  ('Outfield Massacre', Decimal('5.5263157894736842')),
#  ('Watership Frontier', Decimal('6.1666666666666667')),
#  ('Trojan Tomorrow', Decimal('3.5000000000000000')),
#  ('Apocalypse Flamingos', Decimal('4.0000000000000000')),
#  ('Cat Coneheads', Decimal('5.1034482758620690')),
#  ('Varsity Trip', Decimal('4.1333333333333333')),
#  ('Strangelove Desire', Decimal('6.2916666666666667')),
#  ('Egypt Tenenbaums', Decimal('6.1176470588235294')),
#  ('Pirates Roxanne', Decimal('4.9500000000000000')),
#  ('Divorce Shining', Decimal('4.2857142857142857')),
#  ('Vampire Whale', Decimal('4.8333333333333333')),
#  ('Oz Liaisons', Decimal('4.0000000000000000')),
#  ('Ghostbusters Elf', Decimal('5.0000000000000000')),
#  ('Traffic Hobbit', Decimal('3.4000000000000000')),
#  ('Whale Bikini', Decimal('6.1111111111111111')),
#  ('Nuts Ties', Decimal('5.0000000000000000')),
#  ('Moonwalker Fool', Decimal('6.1666666666666667')),
#  ('Cheaper Clyde', Decimal('5.5500000000000000')),
#  ('Watch Tracy', Decimal('4.8750000000000000')),
#  ('Lust Lock', Decimal('3.6153846153846154')),
#  ('Citizen Shrek', Decimal('5.1538461538461538')),
#  ('Command Darling', Decimal('6.1875000000000000')),
#  ('Heartbreakers Bright', Decimal('4.4000000000000000')),
#  ('Patient Sister', Decimal('4.3157894736842105')),
#  ('Outbreak Divine', Decimal('5.0000000000000000')),
#  ('Bed Highball', Decimal('5.6666666666666667')),
#  ('Requiem Tycoon', Decimal('4.8421052631578947')),
#  ('National Story', Decimal('4.4736842105263158')),
#  ('Jeepers Wedding', Decimal('5.0625000000000000')),
#  ('Frida Slipper', Decimal('5.5000000000000000')),
#  ('Mourning Purple', Decimal('4.7619047619047619')),
#  ('Language Cowboy', Decimal('4.8181818181818182')),
#  ('Doors President', Decimal('4.4117647058823529')),
#  ('Barbarella Streetcar', Decimal('5.7200000000000000')),
#  ('Hoosiers Birdcage', Decimal('4.8750000000000000')),
#  ('Blindness Gun', Decimal('5.1428571428571429')),
#  ('Maltese Hope', Decimal('4.5454545454545455')),
#  ('Chamber Italian', Decimal('6.5833333333333333')),
#  ('Tomatoes Hellfighters', Decimal('4.2857142857142857')),
#  ('Army Flintstones', Decimal('4.8750000000000000')),
#  ('Moon Bunch', Decimal('4.9655172413793103')),
#  ('Wonka Sea', Decimal('4.6111111111111111')),
#  ('Hedwig Alter', Decimal('4.0833333333333333')),
#  ('Honey Ties', Decimal('5.4210526315789474')),
#  ('Hurricane Affair', Decimal('5.2500000000000000')),
#  ('Nightmare Chill', Decimal('4.6000000000000000')),
#  ('Matrix Snowman', Decimal('3.7777777777777778')),
#  ('Shootist Superfly', Decimal('5.0833333333333333')),
#  ('Hanky October', Decimal('5.8076923076923077')),
#  ('Orient Closer', Decimal('4.2941176470588235')),
#  ('Lawrence Love', Decimal('4.5384615384615385')),
#  ('Flight Lies', Decimal('7.0833333333333333')),
#  ('Usual Untouchables', Decimal('3.6153846153846154')),
#  ('Squad Fish', Decimal('3.4285714285714286')),
#  ('Shakespeare Saddle', Decimal('5.5000000000000000')),
#  ('Shepherd Midsummer', Decimal('4.6800000000000000')),
#  ('Wisdom Worker', Decimal('5.1111111111111111')),
#  ('African Egg', Decimal('7.0909090909090909')),
#  ('Family Sweet', Decimal('4.7407407407407407')),
#  ('Wait Cider', Decimal('5.8095238095238095')),
#  ('October Submarine', Decimal('5.5454545454545455')),
#  ('World Leathernecks', Decimal('5.0000000000000000')),
#  ('Encounters Curtain', Decimal('4.8421052631578947')),
#  ('California Birds', Decimal('5.2500000000000000')),
#  ('Brooklyn Desert', Decimal('5.4761904761904762')),
#  ('Dream Pickup', Decimal('5.2272727272727273')),
#  ('Phantom Glory', Decimal('4.1666666666666667')),
#  ('Arizona Bang', Decimal('4.5714285714285714')),
#  ('Midsummer Groundhog', Decimal('4.5909090909090909')),
#  ('Alaska Phantom', Decimal('5.2692307692307692')),
#  ('Stampede Disturbing', Decimal('5.0000000000000000')),
#  ('Attraction Newton', Decimal('4.3333333333333333')),
#  ('Earth Vision', Decimal('5.7272727272727273')),
#  ('Telegraph Voyage', Decimal('6.4814814814814815')),
#  ('Clueless Bucket', Decimal('4.7600000000000000')),
#  ('King Evolution', Decimal('5.1111111111111111')),
#  ('Hall Cassidy', Decimal('5.1250000000000000')),
#  ('Slums Duck', Decimal('5.2083333333333333')),
#  ('Desert Poseidon', Decimal('4.5263157894736842')),
#  ('Bride Intrigue', Decimal('4.5263157894736842')),
#  ('Wardrobe Phantom', Decimal('4.8518518518518519')),
#  ('Gangs Pride', Decimal('4.5185185185185185')),
#  ('Games Bowfinger', Decimal('3.9285714285714286')),
#  ('Sensibility Rear', Decimal('4.4000000000000000')),
#  ('Pluto Oleander', Decimal('4.1875000000000000')),
#  ('Homicide Peach', Decimal('4.2272727272727273')),
#  ('Kick Savannah', Decimal('4.7368421052631579')),
#  ('Ladybugs Armageddon', Decimal('5.6666666666666667')),
#  ('Darko Dorado', Decimal('5.3636363636363636')),
#  ('Lion Uncut', Decimal('5.2777777777777778')),
#  ('Creepers Kane', Decimal('4.0714285714285714')),
#  ('Superfly Trip', Decimal('3.9000000000000000')),
#  ('Song Hedwig', Decimal('5.0000000000000000')),
#  ('President Bang', Decimal('4.4285714285714286')),
#  ('Loathing Legally', Decimal('5.0000000000000000')),
#  ('Northwest Polish', Decimal('5.9000000000000000')),
#  ('Gilmore Boiled', Decimal('5.3214285714285714')),
#  ('Tracy Cider', Decimal('5.1153846153846154')),
#  ('Doctor Grail', Decimal('5.1428571428571429')),
#  ('Wars Pluto', Decimal('5.4000000000000000')),
#  ('Jumanji Blade', Decimal('4.3750000000000000')),
#  ('Noon Papi', Decimal('5.1764705882352941')),
#  ('Drumline Cyclone', Decimal('5.2727272727272727')),
#  ('Bang Kwai', Decimal('4.5000000000000000')),
#  ('Disturbing Scarface', Decimal('4.5384615384615385')),
#  ('Vanished Garden', Decimal('6.1666666666666667')),
#  ('Robbery Bright', Decimal('5.3846153846153846')),
#  ('Dolls Rage', Decimal('6.1111111111111111')),
#  ('Borrowers Bedazzled', Decimal('5.7272727272727273')),
#  ('Tootsie Pilot', Decimal('4.1333333333333333')),
#  ('Spy Mile', Decimal('5.1851851851851852')),
#  ('Destiny Saturday', Decimal('4.0000000000000000')),
#  ('Operation Operation', Decimal('4.5769230769230769')),
#  ('Homeward Cider', Decimal('3.5625000000000000')),
#  ('Galaxy Sweethearts', Decimal('4.3888888888888889')),
#  ('Sorority Queen', Decimal('3.9166666666666667')),
#  ('Groundhog Uncut', Decimal('5.2352941176470588')),
#  ('Santa Paris', Decimal('5.0909090909090909')),
#  ('Pittsburgh Hunchback', Decimal('6.3333333333333333')),
#  ('Hyde Doctor', Decimal('4.3600000000000000')),
#  ('Open African', Decimal('4.8571428571428571')),
#  ('Jacket Frisco', Decimal('5.0000000000000000')),
#  ('Untouchables Sunrise', Decimal('5.6250000000000000')),
#  ('Sugar Wonka', Decimal('3.7647058823529412')),
#  ('English Bulworth', Decimal('5.2000000000000000')),
#  ('Videotape Arsenic', Decimal('4.3793103448275862')),
#  ('Chill Luck', Decimal('4.9545454545454545')),
#  ('Packer Madigan', Decimal('4.4545454545454545')),
#  ('Metropolis Coma', Decimal('5.3461538461538462')),
#  ('Chainsaw Uptown', Decimal('4.7619047619047619')),
#  ('Divide Monster', Decimal('4.6190476190476190')),
#  ('Roots Remember', Decimal('5.0000000000000000')),
#  ('Autumn Crow', Decimal('5.2727272727272727')),
#  ('Frost Head', Decimal('5.5517241379310345')),
#  ('Saints Bride', Decimal('4.6250000000000000')),
#  ('Lucky Flying', Decimal('5.0769230769230769')),
#  ('Caddyshack Jedi', Decimal('4.7500000000000000')),
#  ('Airport Pollock', Decimal('5.0555555555555556')),
#  ('Happiness United', Decimal('5.0000000000000000')),
#  ('Express Lonely', Decimal('4.3076923076923077')),
#  ('Date Speed', Decimal('5.8461538461538462')),
#  ('Thief Pelican', Decimal('5.2631578947368421')),
#  ('Moonshine Cabin', Decimal('5.0476190476190476')),
#  ('Submarine Bed', Decimal('4.2666666666666667')),
#  ('Clerks Angels', Decimal('5.1428571428571429')),
#  ('Unforgiven Zoolander', Decimal('5.4444444444444444')),
#  ('Amadeus Holy', Decimal('4.8500000000000000')),
#  ('Musketeers Wait', Decimal('4.6470588235294118')),
#  ('Malkovich Pet', Decimal('4.3076923076923077')),
#  ('Heavenly Gun', Decimal('5.1428571428571429')),
#  ('Chaplin License', Decimal('4.2500000000000000')),
#  ('Anything Savannah', Decimal('5.5555555555555556')),
#  ('Elizabeth Shane', Decimal('4.8000000000000000')),
#  ('Outlaw Hanky', Decimal('4.8461538461538462')),
#  ('Blues Instinct', Decimal('4.5714285714285714')),
#  ('Maiden Home', Decimal('4.5416666666666667')),
#  ('Torque Bound', Decimal('5.0000000000000000')),
#  ('Airplane Sierra', Decimal('4.5333333333333333')),
#  ('Weekend Personal', Decimal('5.0000000000000000')),
#  ('Werewolf Lola', Decimal('5.1428571428571429')),
#  ('Hellfighters Sierra', Decimal('4.3000000000000000')),
#  ('Bucket Brotherhood', Decimal('4.9705882352941176')),
#  ('School Jacket', Decimal('5.0000000000000000')),
#  ('Bear Graceland', Decimal('5.4545454545454545')),
#  ('Strangers Graffiti', Decimal('5.7647058823529412')),
#  ('Zhivago Core', Decimal('5.8750000000000000')),
#  ('Inch Jet', Decimal('4.7222222222222222')),
#  ('Driver Annie', Decimal('3.9411764705882353')),
#  ('Tourist Pelican', Decimal('4.9545454545454545')),
#  ('Beneath Rush', Decimal('4.2000000000000000')),
#  ('Goodfellas Salute', Decimal('5.2580645161290323')),
#  ('Conquerer Nuts', Decimal('4.3125000000000000')),
#  ('Polish Brooklyn', Decimal('4.7222222222222222')),
#  ('Elf Murder', Decimal('3.4285714285714286')),
#  ('Japanese Run', Decimal('4.3333333333333333')),
#  ('Stagecoach Armageddon', Decimal('4.9615384615384615')),
#  ('Hanover Galaxy', Decimal('4.5294117647058824')),
#  ('Italian African', Decimal('4.3333333333333333')),
#  ('Amistad Midsummer', Decimal('4.4500000000000000')),
#  ('League Hellfighters', Decimal('5.1764705882352941')),
#  ('Fever Empire', Decimal('5.8000000000000000')),
#  ('Trip Newton', Decimal('4.2500000000000000')),
#  ('Reign Gentlemen', Decimal('5.3000000000000000')),
#  ('Flatliners Killer', Decimal('5.3181818181818182')),
#  ('Spinal Rocky', Decimal('5.6153846153846154')),
#  ('Early Home', Decimal('6.0000000000000000')),
#  ('Clockwork Paradise', Decimal('5.0000000000000000')),
#  ('Jet Neighbors', Decimal('6.0000000000000000')),
#  ('Breakfast Goldfinger', Decimal('5.5294117647058824')),
#  ('Sunrise League', Decimal('4.8333333333333333')),
#  ('Paradise Sabrina', Decimal('5.3333333333333333')),
#  ('Speakeasy Date', Decimal('5.2500000000000000')),
#  ('Wash Heavenly', Decimal('4.7826086956521739')),
#  ('Tights Dawn', Decimal('5.3461538461538462')),
#  ('Backlash Undefeated', Decimal('6.1578947368421053')),
#  ('Sea Virgin', Decimal('4.7727272727272727')),
#  ('Legend Jedi', Decimal('6.1111111111111111')),
#  ('Control Anthem', Decimal('5.2857142857142857')),
#  ('Cider Desire', Decimal('5.3684210526315789')),
#  ('Prix Undefeated', Decimal('3.6363636363636364')),
#  ('Behavior Runaway', Decimal('5.3076923076923077')),
#  ('Dances None', Decimal('4.1666666666666667')),
#  ('Downhill Enough', Decimal('5.2000000000000000')),
#  ('Fargo Gandhi', Decimal('4.0416666666666667')),
#  ('Gandhi Kwai', Decimal('5.2941176470588235')),
#  ('Fiddler Lost', Decimal('4.7000000000000000')),
#  ('Rules Human', Decimal('6.6875000000000000')),
#  ('Super Wyoming', Decimal('6.0000000000000000')),
#  ('Aladdin Calendar', Decimal('4.9130434782608696')),
#  ('Magic Mallrats', Decimal('4.1428571428571429')),
#  ('Exorcist Sting', Decimal('5.2307692307692308')),
#  ('Harry Idaho', Decimal('5.5172413793103448')),
#  ('Basic Easy', Decimal('4.6500000000000000')),
#  ('Cassidy Wyoming', Decimal('5.3333333333333333')),
#  ('Orange Grapes', Decimal('5.3333333333333333')),
#  ('Contact Anonymous', Decimal('5.0000000000000000')),
#  ('Kane Exorcist', Decimal('3.9285714285714286')),
#  ('Sweden Shining', Decimal('6.5882352941176471')),
#  ('Mission Zoolander', Decimal('4.6666666666666667')),
#  ('Alone Trip', Decimal('5.4705882352941176')),
#  ('Model Fish', Decimal('4.1333333333333333')),
#  ('Youth Kick', Decimal('5.6666666666666667')),
#  ('Town Ark', Decimal('4.1428571428571429')),
#  ('Darling Breaking', Decimal('5.4444444444444444')),
#  ('Crow Grease', Decimal('4.7500000000000000')),
#  ('Sun Confessions', Decimal('5.2400000000000000')),
#  ('Day Unfaithful', Decimal('6.0769230769230769')),
#  ('Pilot Hoosiers', Decimal('5.1875000000000000')),
#  ('Philadelphia Wife', Decimal('5.5454545454545455')),
#  ('Holes Brannigan', Decimal('5.2857142857142857')),
#  ('Wife Turn', Decimal('4.8387096774193548')),
#  ('Valley Packer', Decimal('5.4666666666666667')),
#  ('Coldblooded Darling', Decimal('5.7500000000000000')),
#  ('Horror Reign', Decimal('4.8888888888888889')),
#  ('Color Philadelphia', Decimal('5.5833333333333333')),
#  ('Banger Pinocchio', Decimal('4.5909090909090909')),
#  ('Streak Ridgemont', Decimal('6.0000000000000000')),
#  ('Steel Santa', Decimal('4.3913043478260870')),
#  ('Bulworth Commandments', Decimal('5.2857142857142857')),
#  ('Teen Apollo', Decimal('5.0588235294117647')),
#  ('Neighbors Charade', Decimal('5.5263157894736842')),
#  ('Trap Guys', Decimal('5.6875000000000000')),
#  ('Boogie Amelie', Decimal('4.6428571428571429')),
#  ('Grit Clockwork', Decimal('5.2812500000000000')),
#  ('Haunted Antitrust', Decimal('4.4000000000000000')),
#  ('Eagles Panky', Decimal('5.4285714285714286')),
#  ('Shane Darkness', Decimal('5.3571428571428571')),
#  ('Effect Gladiator', Decimal('5.9166666666666667')),
#  ('Stone Fire', Decimal('5.6363636363636364')),
#  ('Young Language', Decimal('4.5714285714285714')),
#  ('Candles Grapes', Decimal('4.6956521739130435')),
#  ('Darn Forrester', Decimal('5.7777777777777778')),
#  ('Hotel Happiness', Decimal('4.0000000000000000')),
#  ('Splendor Patton', Decimal('4.6666666666666667')),
#  ('Alamo Videotape', Decimal('5.0833333333333333')),
#  ('Hunger Roof', Decimal('6.3333333333333333')),
#  ('Independence Hotel', Decimal('5.0526315789473684')),
#  ('Hysterical Grail', Decimal('4.4000000000000000')),
#  ('Mermaid Insects', Decimal('4.9375000000000000')),
#  ('Unbreakable Karate', Decimal('5.6666666666666667')),
#  ('Brannigan Sunrise', Decimal('4.5000000000000000')),
#  ('High Encino', Decimal('5.3181818181818182')),
#  ('Hamlet Wisdom', Decimal('6.3571428571428571')),
#  ('Lose Inch', Decimal('4.5555555555555556')),
#  ('Devil Desire', Decimal('5.0000000000000000')),
#  ('Everyone Craft', Decimal('3.6923076923076923')),
#  ('Virtual Spoilers', Decimal('6.4285714285714286')),
#  ('Hunchback Impossible', Decimal('5.0000000000000000')),
#  ('Run Pacific', Decimal('6.5000000000000000')),
#  ('Connecticut Tramp', Decimal('5.5384615384615385')),
#  ('Ice Crossing', Decimal('4.9166666666666667')),
#  ('Daddy Pittsburgh', Decimal('5.0000000000000000')),
#  ('Betrayed Rear', Decimal('4.8666666666666667')),
#  ('Factory Dragon', Decimal('3.5882352941176471')),
#  ('Analyze Hoosiers', Decimal('5.7142857142857143')),
#  ('Working Microcosmos', Decimal('5.0000000000000000')),
#  ('Flintstones Happiness', Decimal('5.7058823529411765')),
#  ('Mod Secretary', Decimal('4.9090909090909091')),
#  ('Ferris Mother', Decimal('4.1764705882352941')),
#  ('Fire Wolves', Decimal('5.1428571428571429')),
#  ('Lawless Vision', Decimal('4.1875000000000000')),
#  ('Splash Gump', Decimal('5.7142857142857143')),
#  ('Comancheros Enemy', Decimal('3.0000000000000000')),
#  ('Jumping Wrath', Decimal('6.0833333333333333')),
#  ('Shawshank Bubble', Decimal('5.5000000000000000')),
#  ('Waterfront Deliverance', Decimal('5.7058823529411765')),
#  ('Voice Peach', Decimal('4.7894736842105263')),
#  ('Personal Ladybugs', Decimal('5.4285714285714286')),
#  ('Wrong Behavior', Decimal('4.4000000000000000')),
#  ('Cause Date', Decimal('5.8571428571428571')),
#  ('Bugsy Song', Decimal('5.6363636363636364')),
#  ('Montezuma Command', Decimal('4.0000000000000000')),
#  ('Curtain Videotape', Decimal('5.6538461538461538')),
#  ('Worst Banger', Decimal('4.9375000000000000')),
#  ('Holiday Games', Decimal('5.1333333333333333')),
#  ('Fireball Philadelphia', Decimal('5.5238095238095238')),
#  ('Eve Resurrection', Decimal('5.1428571428571429')),
#  ('Gables Metropolis', Decimal('4.8333333333333333')),
#  ('Talented Homicide', Decimal('4.6551724137931034')),
#  ('Words Hunter', Decimal('4.7500000000000000')),
#  ('Records Zorro', Decimal('5.1250000000000000')),
#  ('Element Freddy', Decimal('5.4000000000000000')),
#  ('Spirited Casualties', Decimal('5.0909090909090909')),
#  ('Egg Igby', Decimal('5.7619047619047619')),
#  ('Seabiscuit Punk', Decimal('5.4000000000000000')),
#  ('Magnolia Forrester', Decimal('5.7272727272727273')),
#  ('Cupboard Sinners', Decimal('5.0000000000000000')),
#  ('Tuxedo Mile', Decimal('5.9166666666666667')),
#  ('Beach Heartbreakers', Decimal('5.2352941176470588')),
#  ('Human Graffiti', Decimal('5.1333333333333333')),
#  ('Louisiana Harry', Decimal('4.2941176470588235')),
#  ('Donnie Alley', Decimal('4.8571428571428571')),
#  ('Pity Bound', Decimal('4.3846153846153846')),
#  ('Something Duck', Decimal('5.1578947368421053')),
#  ('Evolution Alter', Decimal('5.2500000000000000')),
#  ('Flash Wars', Decimal('5.0000000000000000')),
#  ('Treatment Jekyll', Decimal('3.5714285714285714')),
#  ('Hope Tootsie', Decimal('4.3333333333333333')),
#  ('Pocus Pulp', Decimal('5.0000000000000000')),
#  ('Trouble Date', Decimal('5.0909090909090909')),
#  ('Voyage Legally', Decimal('5.4642857142857143')),
#  ('Alley Evolution', Decimal('5.5714285714285714')),
#  ('Hollywood Anonymous', Decimal('4.3846153846153846')),
#  ('Coast Rainbow', Decimal('4.4285714285714286')),
#  ('Mummy Creatures', Decimal('5.6000000000000000')),
#  ('Room Roman', Decimal('4.9500000000000000')),
#  ('Frontier Cabin', Decimal('6.3333333333333333')),
#  ('Casualties Encino', Decimal('6.1111111111111111')),
#  ('Dozen Lion', Decimal('3.8571428571428571')),
#  ('Velvet Terminator', Decimal('4.4615384615384615')),
#  ('Money Harold', Decimal('5.1500000000000000')),
#  ('Sling Luke', Decimal('5.5000000000000000')),
#  ('Pacific Amistad', Decimal('3.9583333333333333')),
#  ('Eyes Driving', Decimal('4.8421052631578947')),
#  ('Wasteland Divine', Decimal('4.9333333333333333')),
#  ('Dares Pluto', Decimal('5.4444444444444444')),
#  ('Gleaming Jawbreaker', Decimal('6.3928571428571429')),
#  ('Fantasia Park', Decimal('4.8947368421052632')),
#  ('Beast Hunchback', Decimal('4.4545454545454545')),
#  ('Saturday Lambs', Decimal('5.1785714285714286')),
#  ('Kramer Chocolate', Decimal('4.7777777777777778')),
#  ('Pinocchio Simon', Decimal('5.1500000000000000')),
#  ('Maguire Apache', Decimal('5.4444444444444444')),
#  ('Wolves Desire', Decimal('4.0952380952380952')),
#  ('Wyoming Storm', Decimal('4.6153846153846154')),
#  ('Carrie Bunch', Decimal('4.9565217391304348')),
#  ('Jeopardy Encino', Decimal('4.5000000000000000')),
#  ('Labyrinth League', Decimal('4.2000000000000000')),
#  ('Juggler Hardly', Decimal('5.5483870967741935')),
#  ('Brotherhood Blanket', Decimal('5.6923076923076923')),
#  ('Poseidon Forever', Decimal('5.3529411764705882')),
#  ('Texas Watch', Decimal('3.1666666666666667')),
#  ('Women Dorado', Decimal('4.0454545454545455')),
#  ('Strictly Scarface', Decimal('4.6956521739130435')),
#  ('Charade Duffel', Decimal('5.0666666666666667')),
#  ('Summer Scarface', Decimal('5.0000000000000000')),
#  ('Lolita World', Decimal('5.3000000000000000')),
#  ('Mile Mulan', Decimal('5.8461538461538462')),
#  ('Cleopatra Devil', Decimal('6.0000000000000000')),
#  ('Rocky War', Decimal('4.8750000000000000')),
#  ('Kiss Glory', Decimal('5.0909090909090909')),
#  ('Pride Alamo', Decimal('3.4000000000000000')),
#  ('Jedi Beneath', Decimal('4.6842105263157895')),
#  ('Ridgemont Submarine', Decimal('6.0000000000000000')),
#  ('Redemption Comforts', Decimal('5.2000000000000000')),
#  ('Chariots Conspiracy', Decimal('3.9523809523809524')),
#  ('Informer Double', Decimal('3.4000000000000000')),
#  ('Scarface Bang', Decimal('4.4705882352941176')),
#  ('Titanic Boondock', Decimal('4.6666666666666667')),
#  ('Interview Liaisons', Decimal('4.5500000000000000')),
#  ('Smoochy Control', Decimal('5.0000000000000000')),
#  ('Runner Madigan', Decimal('4.0000000000000000')),
#  ('Steers Armageddon', Decimal('5.1333333333333333')),
#  ('Range Moonwalker', Decimal('4.0370370370370370')),
#  ('Remember Diary', Decimal('5.0555555555555556')),
#  ('Wild Apollo', Decimal('5.0000000000000000')),
#  ('Go Purple', Decimal('4.3000000000000000')),
#  ('Jekyll Frogmen', Decimal('5.1764705882352941')),
#  ('Pet Haunting', Decimal('5.2500000000000000')),
#  ('Opposite Necklace', Decimal('4.6666666666666667')),
#  ('Scalawag Duck', Decimal('4.0625000000000000')),
#  ('Enemy Odds', Decimal('4.9310344827586207')),
#  ('Camelot Vacation', Decimal('5.6153846153846154')),
#  ('Illusion Amelie', Decimal('4.9333333333333333')),
#  ('Bingo Talented', Decimal('5.7586206896551724')),
#  ('Twisted Pirates', Decimal('3.9090909090909091')),
#  ('Gold River', Decimal('5.2142857142857143')),
#  ('Miracle Virtual', Decimal('4.6666666666666667')),
#  ('Dude Blindness', Decimal('4.5000000000000000')),
#  ('Undefeated Dalmations', Decimal('4.6666666666666667')),
#  ('Kwai Homeward', Decimal('5.2608695652173913')),
#  ('Campus Remember', Decimal('6.2105263157894737')),
#  ('Insider Arizona', Decimal('4.1111111111111111')),
#  ('Baby Hall', Decimal('4.7500000000000000')),
#  ('Jerk Paycheck', Decimal('5.2500000000000000')),
#  ('Killer Innocent', Decimal('6.5000000000000000')),
#  ('Sassy Packer', Decimal('4.7692307692307692')),
#  ('Sleepy Japanese', Decimal('5.1500000000000000')),
#  ('Blanket Beverly', Decimal('6.0909090909090909')),
#  ('Platoon Instinct', Decimal('3.4444444444444444')),
#  ('Chicken Hellfighters', Decimal('4.6818181818181818')),
#  ('Pulp Beverly', Decimal('5.1034482758620690')),
#  ('Quills Bull', Decimal('4.3750000000000000')),
#  ('Shrunk Divine', Decimal('5.6428571428571429')),
#  ('Dragonfly Strangers', Decimal('4.8823529411764706')),
#  ('Lady Stage', Decimal('5.5000000000000000')),
#  ('Virgin Daisy', Decimal('5.0588235294117647')),
#  ('Gorgeous Bingo', Decimal('6.5555555555555556')),
#  ('Storm Happiness', Decimal('4.7931034482758621')),
#  ('Stock Glass', Decimal('3.7142857142857143')),
#  ('Sinners Atlantis', Decimal('5.3181818181818182')),
#  ('Monterey Labyrinth', Decimal('3.9230769230769231')),
#  ('Hours Rage', Decimal('4.8947368421052632')),
#  ('Driving Polish', Decimal('4.9047619047619048')),
#  ('Grease Youth', Decimal('4.1904761904761905')),
#  ('West Lion', Decimal('4.9375000000000000')),
#  ('Ghost Groundhog', Decimal('5.2500000000000000')),
#  ('Snatch Slipper', Decimal('5.7272727272727273')),
#  ('Horn Working', Decimal('4.5000000000000000')),
#  ('Lovely Jingle', Decimal('4.4615384615384615')),
#  ('Hawk Chill', Decimal('5.0000000000000000')),
#  ('Terminator Club', Decimal('6.1666666666666667')),
#  ('Rushmore Mermaid', Decimal('3.3333333333333333')),
#  ('Deer Virginian', Decimal('5.5000000000000000')),
#  ('Alter Victory', Decimal('4.6818181818181818')),
#  ('Darkness War', Decimal('5.6923076923076923')),
#  ('Mother Oleander', Decimal('6.8571428571428571')),
#  ('Falcon Volume', Decimal('4.6666666666666667')),
#  ('Shanghai Tycoon', Decimal('4.0000000000000000')),
#  ('Attacks Hate', Decimal('5.7500000000000000')),
#  ('Paycheck Wait', Decimal('4.6875000000000000')),
#  ('Rider Caddyshack', Decimal('5.5454545454545455')),
#  ('Drifter Commandments', Decimal('4.4347826086956522')),
#  ('Swarm Gold', Decimal('4.9615384615384615')),
#  ('Married Go', Decimal('4.6666666666666667')),
#  ('Badman Dawn', Decimal('4.6190476190476190')),
#  ('License Weekend', Decimal('3.5714285714285714')),
#  ('United Pilot', Decimal('5.0588235294117647')),
#  ('Scorpion Apollo', Decimal('4.9565217391304348')),
#  ('Atlantis Cause', Decimal('4.6666666666666667')),
#  ('Timberland Sky', Decimal('5.8064516129032258')),
#  ('Feud Frogmen', Decimal('4.5600000000000000')),
#  ('Reservoir Adaptation', Decimal('5.9000000000000000')),
#  ('Celebrity Horn', Decimal('5.2916666666666667')),
#  ('Mystic Truman', Decimal('5.0000000000000000')),
#  ('Holy Tadpole', Decimal('5.6666666666666667')),
#  ('Straight Hours', Decimal('4.3500000000000000')),
#  ('Goldmine Tycoon', Decimal('5.4074074074074074')),
#  ('Punk Divorce', Decimal('4.3750000000000000')),
#  ('Oklahoma Jumanji', Decimal('5.1666666666666667')),
#  ('Extraordinary Conquerer', Decimal('5.1666666666666667')),
#  ('Godfather Diary', Decimal('4.5000000000000000')),
#  ('Liaisons Sweet', Decimal('4.6818181818181818')),
#  ('Chasing Fight', Decimal('5.5789473684210526')),
#  ('Others Soup', Decimal('5.0434782608695652')),
#  ('Wagon Jaws', Decimal('6.9000000000000000')),
#  ('Hobbit Alien', Decimal('5.7419354838709677')),
#  ('Anonymous Human', Decimal('4.8461538461538462')),
#  ('Gone Trouble', Decimal('6.1000000000000000')),
#  ('Metal Armageddon', Decimal('6.1200000000000000')),
#  ('Grapes Fury', Decimal('4.2857142857142857')),
#  ('Goldfinger Sensibility', Decimal('5.1250000000000000')),
#  ('Sting Personal', Decimal('5.2380952380952381')),
#  ('Whisperer Giant', Decimal('5.5454545454545455')),
#  ('Craft Outfield', Decimal('4.1875000000000000')),
#  ('Dogma Family', Decimal('4.7000000000000000')),
#  ('Cranes Reservoir', Decimal('5.0000000000000000')),
#  ('Salute Apollo', Decimal('4.6521739130434783')),
#  ('Frogmen Breaking', Decimal('5.0000000000000000')),
#  ('Spoilers Hellfighters', Decimal('4.4000000000000000')),
#  ('Towers Hurricane', Decimal('4.0000000000000000')),
#  ('Potluck Mixed', Decimal('4.2727272727272727')),
#  ('Intentions Empire', Decimal('4.4666666666666667')),
#  ('Gilbert Pelican', Decimal('6.6666666666666667')),
#  ('Durham Panky', Decimal('4.7692307692307692')),
#  ('Blood Argonauts', Decimal('5.5000000000000000')),
#  ('Comforts Rush', Decimal('4.5294117647058824')),
#  ('Movie Shakespeare', Decimal('5.0384615384615385')),
#  ('House Dynamite', Decimal('4.7391304347826087')),
#  ('Saddle Antitrust', Decimal('5.0714285714285714')),
#  ('Madigan Dorado', Decimal('5.0000000000000000')),
#  ('Caper Motions', Decimal('4.5833333333333333')),
#  ('Panky Submarine', Decimal('6.4000000000000000')),
#  ('Side Ark', Decimal('6.0000000000000000')),
#  ('Stranger Strangers', Decimal('4.2727272727272727')),
#  ('Raging Airplane', Decimal('4.6923076923076923')),
#  ('Confessions Maguire', Decimal('5.2142857142857143')),
#  ('Monster Spartacus', Decimal('4.9285714285714286')),
#  ('Connection Microcosmos', Decimal('5.0000000000000000')),
#  ('Handicap Boondock', Decimal('4.6071428571428571')),
#  ('Duck Racer', Decimal('4.3333333333333333')),
#  ('Madison Trap', Decimal('6.0000000000000000')),
#  ('State Wasteland', Decimal('5.5000000000000000')),
#  ('Confused Candles', Decimal('5.8823529411764706')),
#  ('Muscle Bright', Decimal('4.2666666666666667')),
#  ('Hollow Jeopardy', Decimal('4.3000000000000000')),
#  ('Clash Freddy', Decimal('4.9600000000000000')),
#  ('Elephant Trojan', Decimal('4.5714285714285714')),
#  ('Sundance Invasion', Decimal('5.1111111111111111')),
#  ('Idols Snatchers', Decimal('4.7000000000000000')),
#  ('Snowman Rollercoaster', Decimal('4.8695652173913043')),
#  ('Conspiracy Spirit', Decimal('3.8000000000000000')),
#  ('Freaky Pocus', Decimal('3.8823529411764706')),
#  ('Soup Wisdom', Decimal('4.3750000000000000')),
#  ('Notting Speakeasy', Decimal('4.9000000000000000')),
#  ('Story Side', Decimal('4.4285714285714286')),
#  ('Ending Crowds', Decimal('4.6363636363636364')),
#  ('Mulholland Beast', Decimal('5.0000000000000000')),
#  ('Calendar Gunfight', Decimal('5.0952380952380952')),
#  ('Birds Perdition', Decimal('4.7222222222222222')),
#  ('Destination Jerk', Decimal('5.6250000000000000')),
#  ('Smile Earring', Decimal('6.7000000000000000')),
#  ('Maude Mod', Decimal('4.6250000000000000')),
#  ('Party Knock', Decimal('5.2307692307692308')),
#  ('Dying Maker', Decimal('3.9411764705882353')),
#  ('Fugitive Maguire', Decimal('4.0000000000000000')),
#  ('Tomorrow Hustler', Decimal('4.0400000000000000')),
#  ('Doubtfire Labyrinth', Decimal('4.2000000000000000')),
#  ('Full Flatliners', Decimal('3.6000000000000000')),
#  ('Park Citizen', Decimal('5.0000000000000000')),
#  ('Savannah Town', Decimal('5.3333333333333333')),
#  ('Dynamite Tarzan', Decimal('4.6800000000000000')),
#  ('Virginian Pluto', Decimal('4.3571428571428571')),
#  ('Expecations Natural', Decimal('5.2777777777777778')),
#  ('North Tequila', Decimal('4.0909090909090909')),
#  ('Oleander Clue', Decimal('6.6000000000000000')),
#  ('Anaconda Confessions', Decimal('4.3809523809523810')),
#  ('Chicago North', Decimal('5.6250000000000000')),
#  ('Circus Youth', Decimal('5.0666666666666667')),
#  ('Secret Groundhog', Decimal('4.8571428571428571')),
#  ('Murder Antitrust', Decimal('5.3913043478260870')),
#  ('Nemo Campus', Decimal('4.6428571428571429')),
#  ('Beauty Grease', Decimal('4.8181818181818182')),
#  ('Slipper Fidelity', Decimal('4.9375000000000000')),
#  ('Road Roxanne', Decimal('5.1578947368421053')),
#  ('Right Cranes', Decimal('4.9000000000000000')),
#  ('Intolerable Intentions', Decimal('4.6666666666666667')),
#  ('River Outlaw', Decimal('5.4210526315789474')),
#  ('Idaho Love', Decimal('3.9411764705882353')),
#  ('Detective Vision', Decimal('5.1923076923076923')),
#  ('Balloon Homeward', Decimal('5.6086956521739130')),
#  ('Christmas Moonshine', Decimal('5.2380952380952381')),
#  ('Lover Truman', Decimal('6.1000000000000000')),
#  ('Mockingbird Hollywood', Decimal('4.7826086956521739')),
#  ('Gathering Calendar', Decimal('4.3636363636363636')),
#  ('Drums Dynamite', Decimal('6.0000000000000000')),
#  ('Samurai Lion', Decimal('5.4400000000000000')),
#  ('Pond Seattle', Decimal('5.5789473684210526'))]

# %% [markdown]
# # 9
#
# ### List the film title and the number of times it has been rented in each city (name and country).

# %%
# %%sql
# EXPLAIN
# SELECT city, country, COUNT(title)
# FROM film
# INNER JOIN inventory
#     ON film.film_id = inventory.film_id
# INNER JOIN rental
#     ON inventory.inventory_id = rental.inventory_id
# INNER JOIN customer
#     ON rental.customer_id = customer.customer_id
# INNER JOIN address
#     ON customer.address_id = address.address_id
# INNER JOIN city
#     ON address.city_id = city.city_id
# INNER JOIN country
#     ON city.country_id = country.country_id
# GROUP BY city, country
# Out:
#  * postgres://dsa_ro_user:***@pgsql.dsa.lan/dvdrental
# 27 rows affected.
# [('HashAggregate  (cost=956.79..1117.23 rows=16044 width=26)',),
#  ('  Group Key: city.city, country.country',),
#  ('  ->  Hash Join  (cost=270.57..836.46 rows=16044 width=33)',),
#  ('        Hash Cond: (city.country_id = country.country_id)',),
#  ('        ->  Hash Join  (cost=267.12..789.26 rows=16044 width=26)',),
#  ('              Hash Cond: (address.city_id = city.city_id)',),
#  ('              ->  Hash Join  (cost=248.62..728.34 rows=16044 width=17)',),
#  ('                    Hash Cond: (customer.address_id = address.address_id)',),
#  ('                    ->  Hash Join  (cost=227.05..664.36 rows=16044 width=17)',),
#  ('                          Hash Cond: (rental.customer_id = customer.customer_id)',),
#  ('                          ->  Hash Join  (cost=204.57..599.47 rows=16044 width=17)',),
#  ('                                Hash Cond: (inventory.film_id = film.film_id)',),
#  ('                                ->  Hash Join  (cost=128.07..480.67 rows=16044 width=4)',),
#  ('                                      Hash Cond: (rental.inventory_id = inventory.inventory_id)',),
#  ('                                      ->  Seq Scan on rental  (cost=0.00..310.44 rows=16044 width=6)',),
#  ('                                      ->  Hash  (cost=70.81..70.81 rows=4581 width=6)',),
#  ('                                            ->  Seq Scan on inventory  (cost=0.00..70.81 rows=4581 width=6)',),
#  ('                                ->  Hash  (cost=64.00..64.00 rows=1000 width=19)',),
#  ('                                      ->  Seq Scan on film  (cost=0.00..64.00 rows=1000 width=19)',),
#  ('                          ->  Hash  (cost=14.99..14.99 rows=599 width=6)',),
#  ('                                ->  Seq Scan on customer  (cost=0.00..14.99 rows=599 width=6)',),
#  ('                    ->  Hash  (cost=14.03..14.03 rows=603 width=6)',),
#  ('                          ->  Seq Scan on address  (cost=0.00..14.03 rows=603 width=6)',),
#  ('              ->  Hash  (cost=11.00..11.00 rows=600 width=15)',),
#  ('                    ->  Seq Scan on city  (cost=0.00..11.00 rows=600 width=15)',),
#  ('        ->  Hash  (cost=2.09..2.09 rows=109 width=13)',),
#  ('              ->  Seq Scan on country  (cost=0.00..2.09 rows=109 width=13)',)]

# %%
# %%sql
# SELECT title, city, country, COUNT(*)
# FROM film
# INNER JOIN inventory
#     ON film.film_id = inventory.film_id
# INNER JOIN rental
#     ON inventory.inventory_id = rental.inventory_id
# INNER JOIN customer
#     ON rental.customer_id = customer.customer_id
# INNER JOIN address
#     ON customer.address_id = address.address_id
# INNER JOIN city
#     ON address.city_id = city.city_id
# INNER JOIN country
#     ON city.country_id = country.country_id
# GROUP BY city, country, title
# Out:
#  * postgres://dsa_ro_user:***@pgsql.dsa.lan/dvdrental
# 15827 rows affected.
# [('Cowboy Doom', 'Enshi', 'China', 1),
#  ('Vacation Boondock', 'Tama', 'Japan', 1),
#  ('Philadelphia Wife', 'Valencia', 'Venezuela', 1),
#  ('Pond Seattle', 'Apeldoorn', 'Netherlands', 1),
#  ('Rocky War', 'Ciomas', 'Indonesia', 1),
#  ('Bringing Hysterical', 'Nuuk', 'Greenland', 1),
#  ('Natural Stock', 'Santa Brbara dOeste', 'Brazil', 1),
#  ('Show Lord', 'Tychy', 'Poland', 1),
#  ('Bill Others', 'Lincoln', 'United States', 1),
#  ('Hunting Musketeers', 'Mwanza', 'Tanzania', 1),
#  ('West Lion', 'Esfahan', 'Iran', 1),
#  ('Closer Bang', 'Pathankot', 'India', 1),
#  ('California Birds', 'Lhokseumawe', 'Indonesia', 1),
#  ('Witches Panic', 'Santo Andr', 'Brazil', 1),
#  ('Strangelove Desire', 'Warren', 'United States', 1),
#  ('Samurai Lion', 'Jining', 'China', 1),
#  ('Badman Dawn', 'Beira', 'Mozambique', 1),
#  ('Worst Banger', 'Halisahar', 'India', 1),
#  ('Canyon Stock', 'Pereira', 'Colombia', 1),
#  ('Open African', 'Daugavpils', 'Latvia', 1),
#  ('Encounters Curtain', 'Uruapan', 'Mexico', 1),
#  ('Greatest North', 'Huixquilucan', 'Mexico', 1),
#  ('Heavyweights Beast', 'Batman', 'Turkey', 1),
#  ('Chance Resurrection', 'Halisahar', 'India', 1),
#  ('Empire Malkovich', 'Shimonoseki', 'Japan', 1),
#  ('Secrets Paradise', 'Jinzhou', 'China', 1),
#  ('Seattle Expecations', 'Tarlac', 'Philippines', 1),
#  ('Majestic Floats', 'Batman', 'Turkey', 1),
#  ('Whisperer Giant', 'Hoshiarpur', 'India', 1),
#  ('Bear Graceland', 'Pune', 'India', 1),
#  ('Gables Metropolis', 'Merlo', 'Argentina', 1),
#  ('Airport Pollock', 'Peoria', 'United States', 1),
#  ('Million Ace', 'Gaziantep', 'Turkey', 1),
#  ('Apache Divine', 'Bamenda', 'Cameroon', 1),
#  ('Gilmore Boiled', 'Huixquilucan', 'Mexico', 1),
#  ('Lights Deer', 'Gorontalo', 'Indonesia', 1),
#  ('Color Philadelphia', 'Akron', 'United States', 1),
#  ('Attraction Newton', 'Kimberley', 'South Africa', 1),
#  ('Arizona Bang', 'Szkesfehrvr', 'Hungary', 1),
#  ('Attraction Newton', 'Jakarta', 'Indonesia', 1),
#  ('Polish Brooklyn', 'Novoterkassk', 'Russian Federation', 1),
#  ('Forrester Comancheros', 'Denizli', 'Turkey', 1),
#  ('Kwai Homeward', 'Kuching', 'Malaysia', 1),
#  ('Falcon Volume', 'Toulon', 'France', 1),
#  ('Tights Dawn', 'Tartu', 'Estonia', 1),
#  ('Graffiti Love', 'Ozamis', 'Philippines', 1),
#  ('Flamingos Connecticut', 'Robamba', 'Ecuador', 1),
#  ('Dorado Notting', 'Johannesburg', 'South Africa', 1),
#  ('Trip Newton', 'Caracas', 'Venezuela', 1),
#  ('Rugrats Shakespeare', 'Atlixco', 'Mexico', 1),
#  ('Life Twisted', 'Southport', 'United Kingdom', 1),
#  ('Hamlet Wisdom', 'Toulouse', 'France', 1),
#  ('American Circus', 'Bydgoszcz', 'Poland', 1),
#  ('Lebowski Soldiers', 'Celaya', 'Mexico', 1),
#  ('Straight Hours', 'Coacalco de Berriozbal', 'Mexico', 1),
#  ('Gorgeous Bingo', 'Dundee', 'United Kingdom', 1),
#  ('Rush Goodfellas', 'Amroha', 'India', 1),
#  ('Idaho Love', 'Ciparay', 'Indonesia', 1),
#  ('Opus Ice', 'Rockford', 'United States', 1),
#  ('Fool Mockingbird', 'Sincelejo', 'Colombia', 1),
#  ('Flatliners Killer', 'Karnal', 'India', 1),
#  ('Gangs Pride', 'Salzburg', 'Austria', 1),
#  ('Shepherd Midsummer', 'Ogbomosho', 'Nigeria', 1),
#  ('Clueless Bucket', 'Datong', 'China', 1),
#  ('Seattle Expecations', 'Laredo', 'United States', 1),
#  ('Zoolander Fiction', 'Sharja', 'United Arab Emirates', 1),
#  ('Spy Mile', 'Almirante Brown', 'Argentina', 1),
#  ('Pure Runner', 'Ezeiza', 'Argentina', 1),
#  ('Clones Pinocchio', 'Pyongyang', 'North Korea', 1),
#  ('Sweden Shining', 'Mwene-Ditu', 'Congo, The Democratic Republic of the', 1),
#  ('Flamingos Connecticut', 'Lancaster', 'United States', 1),
#  ('Modern Dorado', 'Valle de Santiago', 'Mexico', 1),
#  ('Date Speed', 'Bhopal', 'India', 1),
#  ('Robbery Bright', 'Saint-Denis', 'Runion', 1),
#  ('Platoon Instinct', 'Ciudad del Este', 'Paraguay', 1),
#  ('Videotape Arsenic', 'Ashgabat', 'Turkmenistan', 1),
#  ('Wrong Behavior', 'Kansas City', 'United States', 1),
#  ('Wife Turn', 'Bern', 'Switzerland', 1),
#  ('Streak Ridgemont', 'Mexicali', 'Mexico', 1),
#  ('Boiled Dares', 'Okara', 'Pakistan', 1),
#  ('Saddle Antitrust', 'Sungai Petani', 'Malaysia', 1),
#  ('Thief Pelican', 'Halifax', 'Canada', 1),
#  ('Speed Suit', 'Stockport', 'United Kingdom', 1),
#  ('Cheaper Clyde', 'Iwatsuki', 'Japan', 1),
#  ('Mask Peach', 'Ruse', 'Bulgaria', 1),
#  ('Closer Bang', 'Tanshui', 'Taiwan', 1),
#  ('Yentl Idaho', 'Kitwe', 'Zambia', 1),
#  ('Head Stranger', 'Nantou', 'Taiwan', 1),
#  ('Gangs Pride', 'Tafuna', 'American Samoa', 1),
#  ('Beach Heartbreakers', 'Lungtan', 'Taiwan', 1),
#  ('Shawshank Bubble', 'Jurez', 'Mexico', 1),
#  ('Tuxedo Mile', 's-Hertogenbosch', 'Netherlands', 1),
#  ('Feud Frogmen', 'Buenaventura', 'Colombia', 1),
#  ('Sting Personal', 'Iwaki', 'Japan', 1),
#  ('Tomorrow Hustler', 'Gijn', 'Spain', 1),
#  ('Madre Gables', 'Cuernavaca', 'Mexico', 1),
#  ('Dude Blindness', 'Cuautla', 'Mexico', 1),
#  ('Notorious Reunion', 'Tegal', 'Indonesia', 1),
#  ('Grease Youth', 'Kansas City', 'United States', 1),
#  ('Spiking Element', 'Adoni', 'India', 1),
#  ('Fellowship Autumn', 'La Plata', 'Argentina', 1),
#  ('Hanky October', 'Citrus Heights', 'United States', 1),
#  ('Racer Egg', 'Kaliningrad', 'Russian Federation', 1),
#  ('Chicago North', 'Teboksary', 'Russian Federation', 1),
#  ('Harold French', 'Hamilton', 'New Zealand', 1),
#  ('Jade Bunch', 'Balaiha', 'Russian Federation', 1),
#  ('Samurai Lion', 'Balikesir', 'Turkey', 1),
#  ('Haunting Pianist', 'Kabul', 'Afghanistan', 1),
#  ('Rushmore Mermaid', 'Daugavpils', 'Latvia', 1),
#  ('Liberty Magnificent', 'Alessandria', 'Italy', 1),
#  ('Telegraph Voyage', 'Inegl', 'Turkey', 1),
#  ('Trojan Tomorrow', 'Mandaluyong', 'Philippines', 1),
#  ('Blues Instinct', 'Tabora', 'Tanzania', 1),
#  ('Beach Heartbreakers', 'Caracas', 'Venezuela', 1),
#  ('Holy Tadpole', 'Dhule (Dhulia)', 'India', 1),
#  ('Shrek License', 'Salala', 'Oman', 1),
#  ('Treatment Jekyll', 'Hiroshima', 'Japan', 1),
#  ('Wagon Jaws', 'Augusta-Richmond County', 'United States', 1),
#  ('Nemo Campus', 'Memphis', 'United States', 1),
#  ('Thin Sagebrush', 'Yantai', 'China', 1),
#  ('Earring Instinct', 'Zhoushan', 'China', 1),
#  ('Sleepless Monsoon', 'Fuyu', 'China', 2),
#  ('Durham Panky', 'Birgunj', 'Nepal', 1),
#  ('Lost Bird', 'Zhoushan', 'China', 1),
#  ('Alaska Phantom', 'Nantou', 'Taiwan', 1),
#  ('Bound Cheaper', 'Rizhao', 'China', 1),
#  ('Rules Human', 'Ibirit', 'Brazil', 1),
#  ('Remember Diary', 'Roanoke', 'United States', 1),
#  ('Hanging Deep', 'Salamanca', 'Mexico', 1),
#  ('Princess Giant', 'Kitwe', 'Zambia', 1),
#  ('Sling Luke', 'Datong', 'China', 1),
#  ('Falcon Volume', 'Balurghat', 'India', 1),
#  ('Pity Bound', 'Yuncheng', 'China', 1),
#  ('Sugar Wonka', 'Kimchon', 'South Korea', 1),
#  ('Hope Tootsie', 'Siegen', 'Germany', 1),
#  ('Island Exorcist', 'Sokoto', 'Nigeria', 1),
#  ('Juggler Hardly', 'Huixquilucan', 'Mexico', 1),
#  ('Reef Salute', 'Jakarta', 'Indonesia', 1),
#  ('Gangs Pride', 'Fukuyama', 'Japan', 1),
#  ('Highball Potter', 'Novi Sad', 'Yugoslavia', 1),
#  ('Apache Divine', 'Jaffna', 'Sri Lanka', 1),
#  ('Unbreakable Karate', 'Mysore', 'India', 1),
#  ('Hunchback Impossible', 'Naju', 'South Korea', 1),
#  ('Exorcist Sting', 'Belm', 'Brazil', 1),
#  ('Peak Forever', 'Augusta-Richmond County', 'United States', 1),
#  ('Blanket Beverly', 'Fuzhou', 'China', 1),
#  ('Scissorhands Slums', 'Elista', 'Russian Federation', 1),
#  ('Lust Lock', 'Mexicali', 'Mexico', 1),
#  ('Borrowers Bedazzled', 'Ranchi', 'India', 1),
#  ('Harper Dying', 'Qalyub', 'Egypt', 1),
#  ('Stepmom Dream', 'Beni-Mellal', 'Morocco', 1),
#  ('Fiction Christmas', 'Chapra', 'India', 1),
#  ('Chasing Fight', 'Sterling Heights', 'United States', 1),
#  ('Fantasia Park', 'Papeete', 'French Polynesia', 1),
#  ('Calendar Gunfight', 'Tete', 'Mozambique', 1),
#  ('Pond Seattle', 'Rajkot', 'India', 1),
#  ('Doors President', 'Zhoushan', 'China', 1),
#  ('Magnificent Chitty', 'Plock', 'Poland', 1),
#  ('Party Knock', 'Dadu', 'Pakistan', 1),
#  ('Forward Temple', 'Karnal', 'India', 1),
#  ('Lock Rear', 'Valle de Santiago', 'Mexico', 1),
#  ('Hustler Party', 'Blumenau', 'Brazil', 1),
#  ('Confused Candles', 'Tanza', 'Philippines', 1),
#  ('Jekyll Frogmen', 'Hanoi', 'Vietnam', 1),
#  ('Birch Antitrust', 'Poos de Caldas', 'Brazil', 1),
#  ('Bingo Talented', 'Manchester', 'United States', 1),
#  ('Inch Jet', 'South Hill', 'Anguilla', 1),
#  ('Westward Seabiscuit', 'Owo', 'Nigeria', 1),
#  ('Crossroads Casualties', 'Miyakonojo', 'Japan', 1),
#  ('Spinal Rocky', 'Yaound', 'Cameroon', 1),
#  ('Atlantis Cause', 'Sivas', 'Turkey', 1),
#  ('Canyon Stock', 'Atinsk', 'Russian Federation', 1),
#  ('Robbery Bright', 'Udine', 'Italy', 1),
#  ('Bingo Talented', 'Clarksville', 'United States', 1),
#  ('Masked Bubble', 'Coatzacoalcos', 'Mexico', 1),
#  ('Fargo Gandhi', 'Berhampore (Baharampur)', 'India', 1),
#  ('Mighty Luck', 'Santa F', 'Argentina', 1),
#  ('Mulan Moon', 'Juazeiro do Norte', 'Brazil', 1),
#  ('Prejudice Oleander', 'Johannesburg', 'South Africa', 1),
#  ('Telegraph Voyage', 'Datong', 'China', 1),
#  ('Loathing Legally', 'Bhopal', 'India', 1),
#  ('Prejudice Oleander', 'Emeishan', 'China', 1),
#  ('Shepherd Midsummer', 'Hagonoy', 'Philippines', 1),
#  ('Core Suit', 'Salzburg', 'Austria', 1),
#  ('Victory Academy', 'Akron', 'United States', 1),
#  ('Movie Shakespeare', 'Ashqelon', 'Israel', 1),
#  ('Eyes Driving', 'Mit Ghamr', 'Egypt', 1),
#  ('Pianist Outfield', 'Tel Aviv-Jaffa', 'Israel', 1),
#  ('Oscar Gold', 'Moscow', 'Russian Federation', 1),
#  ('Moonshine Cabin', 'Najafabad', 'Iran', 1),
#  ('Honey Ties', 'Bat Yam', 'Israel', 1),
#  ('Troopers Metal', 'Kimchon', 'South Korea', 1),
#  ('Darko Dorado', 'Buenaventura', 'Colombia', 1),
#  ('Park Citizen', 'Oulu', 'Finland', 1),
#  ('Million Ace', 'Hanoi', 'Vietnam', 1),
#  ('Stepmom Dream', 'Aurora', 'United States', 1),
#  ('Frogmen Breaking', 'Ede', 'Netherlands', 1),
#  ('Dracula Crystal', 'Nezahualcyotl', 'Mexico', 1),
#  ('Sleepless Monsoon', 'Robamba', 'Ecuador', 1),
#  ('Jungle Closer', 'Compton', 'United States', 1),
#  ('Encounters Curtain', 'Tandil', 'Argentina', 1),
#  ('Flatliners Killer', 'Plock', 'Poland', 1),
#  ('Personal Ladybugs', 'Vinh', 'Vietnam', 1),
#  ('Sinners Atlantis', 'Pak Kret', 'Thailand', 1),
#  ('Sinners Atlantis', 'Kolpino', 'Russian Federation', 1),
#  ('Wolves Desire', 'Salala', 'Oman', 1),
#  ('Movie Shakespeare', 'Salzburg', 'Austria', 1),
#  ('Arabia Dogma', 'Monclova', 'Mexico', 1),
#  ('Bride Intrigue', 'Qomsheh', 'Iran', 1),
#  ('Fool Mockingbird', 'Bradford', 'United Kingdom', 1),
#  ('Bride Intrigue', 'Sawhaj', 'Egypt', 1),
#  ('Antitrust Tomatoes', 'Sharja', 'United Arab Emirates', 1),
#  ('Kiss Glory', 'Satna', 'India', 1),
#  ('Flintstones Happiness', 'Alessandria', 'Italy', 1),
#  ('Musketeers Wait', 'Valparai', 'India', 1),
#  ('Samurai Lion', 'Aden', 'Yemen', 1),
#  ('Lose Inch', 'Iwatsuki', 'Japan', 1),
#  ('Divide Monster', 'Akishima', 'Japan', 1),
#  ('Juggler Hardly', 'Caracas', 'Venezuela', 1),
#  ('Opus Ice', 'Cuautla', 'Mexico', 1),
#  ('Oleander Clue', 'Ciparay', 'Indonesia', 1),
#  ('Gilbert Pelican', 'Addis Abeba', 'Ethiopia', 1),
#  ('Bikini Borrowers', 'Ahmadnagar', 'India', 1),
#  ('Metal Armageddon', 'Mandi Bahauddin', 'Pakistan', 1),
#  ('Maiden Home', 'Iwakuni', 'Japan', 1),
#  ('Open African', 'Sousse', 'Tunisia', 1),
#  ('Thief Pelican', 'Greensboro', 'United States', 1),
#  ('Details Packer', 'Nabereznyje Telny', 'Russian Federation', 1),
#  ('Christmas Moonshine', 'Arak', 'Iran', 1),
#  ('Strangelove Desire', 'Adoni', 'India', 1),
#  ('Steel Santa', 'Livorno', 'Italy', 1),
#  ('Papi Necklace', 'Dzerzinsk', 'Russian Federation', 1),
#  ('Dawn Pond', 'Imus', 'Philippines', 1),
#  ('Sunset Racer', 'Tabriz', 'Iran', 1),
#  ('Craft Outfield', 'Gingoog', 'Philippines', 1),
#  ('Spice Sorority', 'Junan', 'China', 1),
#  ('Robbers Joon', 'Hodeida', 'Yemen', 1),
#  ('Mixed Doors', 'Torren', 'Mexico', 1),
#  ('Core Suit', 'Hiroshima', 'Japan', 1),
#  ('Metal Armageddon', 'Pereira', 'Colombia', 1),
#  ('Silverado Goldfinger', 'Monywa', 'Myanmar', 1),
#  ('Human Graffiti', 'Vitria de Santo Anto', 'Brazil', 1),
#  ('Heavyweights Beast', 'Simferopol', 'Ukraine', 1),
#  ('Image Princess', 'Yerevan', 'Armenia', 1),
#  ('Jacket Frisco', 'Botshabelo', 'South Africa', 1),
#  ('Flying Hook', 'Mannheim', 'Germany', 2),
#  ('Ghost Groundhog', 'Miraj', 'India', 1),
#  ('Personal Ladybugs', 'Baybay', 'Philippines', 1),
#  ('Spoilers Hellfighters', 'Kanazawa', 'Japan', 1),
#  ('Louisiana Harry', 'Datong', 'China', 1),
#  ('Odds Boogie', 'Faaa', 'French Polynesia', 1),
#  ('Apache Divine', 'Cavite', 'Philippines', 1),
#  ('Mockingbird Hollywood', 'Haldia', 'India', 1),
#  ('Texas Watch', 'Arlington', 'United States', 1),
#  ('Confidential Interview', 'Shubra al-Khayma', 'Egypt', 1),
#  ('Bird Independence', 'Adana', 'Turkey', 1),
#  ('Talented Homicide', 'Eskisehir', 'Turkey', 1),
#  ('Graffiti Love', 'Balikesir', 'Turkey', 1),
#  ('Wasteland Divine', 'Ogbomosho', 'Nigeria', 1),
#  ('Sinners Atlantis', 'Leshan', 'China', 1),
#  ('Maltese Hope', 'Rockford', 'United States', 1),
#  ('Goldfinger Sensibility', 'Athenai', 'Greece', 1),
#  ('Trip Newton', 'Uluberia', 'India', 1),
#  ('Maiden Home', 'Zhoushan', 'China', 1),
#  ('Comancheros Enemy', 'Otsu', 'Japan', 1),
#  ('Pickup Driving', 'Hubli-Dharwad', 'India', 1),
#  ('Ghost Groundhog', 'Palghat (Palakkad)', 'India', 1),
#  ('Sabrina Midnight', 'Saarbrcken', 'Germany', 1),
#  ('Notting Speakeasy', 'Basel', 'Switzerland', 1),
#  ('Wardrobe Phantom', 'Tonghae', 'South Korea', 1),
#  ('Garden Island', 'Abha', 'Saudi Arabia', 1),
#  ('South Wait', 'Isesaki', 'Japan', 1),
#  ('Casualties Encino', 'Warren', 'United States', 1),
#  ('Vampire Whale', 'Ciomas', 'Indonesia', 1),
#  ('Saturday Lambs', 'Acua', 'Mexico', 1),
#  ('Shane Darkness', 'Ahmadnagar', 'India', 1),
#  ('House Dynamite', 'Baku', 'Azerbaijan', 1),
#  ('Meet Chocolate', 'Paarl', 'South Africa', 1),
#  ('Darkness War', 'Dhaka', 'Bangladesh', 1),
#  ('Gables Metropolis', 'Qalyub', 'Egypt', 1),
#  ('Sun Confessions', 'Salzburg', 'Austria', 1),
#  ('Groundhog Uncut', 'Pathankot', 'India', 1),
#  ('Wash Heavenly', 'Boa Vista', 'Brazil', 1),
#  ('Aladdin Calendar', 'Gulbarga', 'India', 1),
#  ('Fury Murder', 'Callao', 'Peru', 1),
#  ('Sinners Atlantis', 'Shenzhen', 'China', 1),
#  ('Ice Crossing', 'Valparai', 'India', 1),
#  ('Seven Swarm', 'Tonghae', 'South Korea', 1),
#  ('Superfly Trip', 'Bratislava', 'Slovakia', 1),
#  ('Lawless Vision', 'Balaiha', 'Russian Federation', 1),
#  ('Dawn Pond', 'Uruapan', 'Mexico', 1),
#  ('Shock Cabin', 'Saarbrcken', 'Germany', 1),
#  ('Independence Hotel', 'Bandar Seri Begawan', 'Brunei', 1),
#  ('Garden Island', 'Kolpino', 'Russian Federation', 1),
#  ('Peak Forever', 'Nagareyama', 'Japan', 1),
#  ('Pocus Pulp', 'Probolinggo', 'Indonesia', 1),
#  ('Undefeated Dalmations', 'Pudukkottai', 'India', 1),
#  ('Watch Tracy', 'Changzhou', 'China', 1),
#  ('Goldfinger Sensibility', 'Gingoog', 'Philippines', 1),
#  ('Alabama Devil', 'Probolinggo', 'Indonesia', 1),
#  ('Spy Mile', 'Jaffna', 'Sri Lanka', 1),
#  ('Everyone Craft', 'Kisumu', 'Kenya', 1),
#  ('Potter Connecticut', 'Pontianak', 'Indonesia', 1),
#  ('Deep Crusade', 'Ezeiza', 'Argentina', 1),
#  ('Queen Luke', 'Ocumare del Tuy', 'Venezuela', 1),
#  ('Salute Apollo', 'Lublin', 'Poland', 1),
#  ('Open African', 'Ruse', 'Bulgaria', 1),
#  ('Sierra Divide', 'Bandar Seri Begawan', 'Brunei', 1),
#  ('Vertigo Northwest', 'Kansas City', 'United States', 1),
#  ('Pond Seattle', 'San Bernardino', 'United States', 1),
#  ('Mosquito Armageddon', 'Tandil', 'Argentina', 1),
#  ('Fool Mockingbird', 'Gijn', 'Spain', 1),
#  ('Insects Stone', 'Teboksary', 'Russian Federation', 1),
#  ('Handicap Boondock', 'Palghat (Palakkad)', 'India', 1),
#  ('Massage Image', 'Junan', 'China', 1),
#  ('National Story', 'Torren', 'Mexico', 1),
#  ('Lola Agent', 'Pudukkottai', 'India', 1),
#  ('Dancing Fever', 'Varanasi (Benares)', 'India', 1),
#  ('Hellfighters Sierra', 'Katihar', 'India', 1),
#  ('Chicago North', 'Peoria', 'United States', 1),
#  ('Evolution Alter', 'Valencia', 'Venezuela', 1),
#  ('Caddyshack Jedi', 'Ktahya', 'Turkey', 1),
#  ('Network Peak', 'Tanza', 'Philippines', 1),
#  ('Shawshank Bubble', 'Kakamigahara', 'Japan', 1),
#  ('Trading Pinocchio', 'A Corua (La Corua)', 'Spain', 1),
#  ('Sea Virgin', 'Daugavpils', 'Latvia', 1),
#  ('Hollow Jeopardy', 'Kimchon', 'South Korea', 1),
#  ('Primary Glass', 'Po', 'Brazil', 1),
#  ('Salute Apollo', 'Trshavn', 'Faroe Islands', 1),
#  ('Princess Giant', 'Bern', 'Switzerland', 1),
#  ('Menagerie Rushmore', 'Berhampore (Baharampur)', 'India', 1),
#  ('Edge Kissing', 'London', 'United Kingdom', 1),
#  ('Platoon Instinct', 'Lima', 'Peru', 1),
#  ('Grit Clockwork', 'Portoviejo', 'Ecuador', 1),
#  ('Amistad Midsummer', 'Nantou', 'Taiwan', 1),
#  ('Apache Divine', 'Taizz', 'Yemen', 1),
#  ('Dracula Crystal', 'Salinas', 'United States', 1),
#  ('Remember Diary', 'Yangor', 'Nauru', 1),
#  ('Tracy Cider', 'Bergamo', 'Italy', 1),
#  ('Cupboard Sinners', 'Vilnius', 'Lithuania', 1),
#  ('Requiem Tycoon', 'Balaiha', 'Russian Federation', 1),
#  ('Terminator Club', 'Niznekamsk', 'Russian Federation', 1),
#  ('Expendable Stallion', 'al-Hawiya', 'Saudi Arabia', 1),
#  ('Story Side', 'Zaoyang', 'China', 1),
#  ('Gilmore Boiled', 'Nador', 'Morocco', 1),
#  ('Bilko Anonymous', 'Angra dos Reis', 'Brazil', 1),
#  ('Patient Sister', 'Sullana', 'Peru', 1),
#  ('Town Ark', 'Serpuhov', 'Russian Federation', 1),
#  ('Coast Rainbow', 'El Alto', 'Bolivia', 1),
#  ('Pelican Comforts', 'Tambaram', 'India', 1),
#  ('Anonymous Human', 'Basel', 'Switzerland', 1),
#  ('Telemark Heartbreakers', 'Higashiosaka', 'Japan', 1),
#  ('Tomorrow Hustler', 'San Felipe del Progreso', 'Mexico', 1),
#  ('Hunchback Impossible', 'La Plata', 'Argentina', 1),
#  ('Metal Armageddon', 'Plock', 'Poland', 1),
#  ('Rush Goodfellas', 'Florencia', 'Colombia', 2),
#  ('Quest Mussolini', 'Sambhal', 'India', 1),
#  ('Park Citizen', 'Molodetno', 'Belarus', 1),
#  ('Philadelphia Wife', 'al-Manama', 'Bahrain', 1),
#  ('Torque Bound', 'Balaiha', 'Russian Federation', 1),
#  ('Roses Treasure', 'Ivanovo', 'Russian Federation', 1),
#  ('Freddy Storm', 'Baku', 'Azerbaijan', 1),
#  ('Double Wrath', 'Birgunj', 'Nepal', 1),
#  ('Coldblooded Darling', 'London', 'United Kingdom', 1),
#  ('Arabia Dogma', 'La Plata', 'Argentina', 1),
#  ('Roses Treasure', 'Pyongyang', 'North Korea', 1),
#  ('Fool Mockingbird', 'Sterling Heights', 'United States', 1),
#  ('Spinal Rocky', 'Ranchi', 'India', 1),
#  ('Contact Anonymous', 'Pudukkottai', 'India', 1),
#  ('Durham Panky', 'Patiala', 'India', 1),
#  ('Stock Glass', 'Tongliao', 'China', 1),
#  ('Beast Hunchback', 'Faaa', 'French Polynesia', 1),
#  ('Hanover Galaxy', 'Naju', 'South Korea', 1),
#  ('Hook Chariots', 'Baybay', 'Philippines', 1),
#  ('Monster Spartacus', 'Fuyu', 'China', 1),
#  ('Untouchables Sunrise', 'Ranchi', 'India', 2),
#  ('Banger Pinocchio', 'Siliguri (Shiliguri)', 'India', 1),
#  ('Beauty Grease', 'Acua', 'Mexico', 1),
#  ('Women Dorado', 'Monywa', 'Myanmar', 1),
#  ('Shepherd Midsummer', 'Greensboro', 'United States', 1),
#  ('Confidential Interview', 'Kaduna', 'Nigeria', 1),
#  ('Berets Agent', 'Rampur', 'India', 1),
#  ('Scalawag Duck', 'Merlo', 'Argentina', 1),
#  ('Contact Anonymous', 'Imus', 'Philippines', 1),
#  ('Mission Zoolander', 'Uttarpara-Kotrung', 'India', 1),
#  ('Image Princess', 'Fuyu', 'China', 1),
#  ('Whale Bikini', 'Portoviejo', 'Ecuador', 1),
#  ('Graffiti Love', 'Kilis', 'Turkey', 1),
#  ('Jeopardy Encino', 'Garland', 'United States', 1),
#  ('Lady Stage', 'Ponce', 'Puerto Rico', 1),
#  ('Homeward Cider', 'Boksburg', 'South Africa', 1),
#  ('Grapes Fury', 'Laohekou', 'China', 1),
#  ('Rebel Airport', 'Patras', 'Greece', 1),
#  ('Butterfly Chocolat', 'Hanoi', 'Vietnam', 1),
#  ('Beneath Rush', 'Wroclaw', 'Poland', 1),
#  ('Exorcist Sting', 'Arlington', 'United States', 1),
#  ('Roxanne Rebel', 'Apeldoorn', 'Netherlands', 1),
#  ('Dude Blindness', 'Mandi Bahauddin', 'Pakistan', 1),
#  ('Clash Freddy', 'El Fuerte', 'Mexico', 1),
#  ('Forward Temple', 'Santa Rosa', 'Philippines', 1),
#  ('South Wait', 'Haldia', 'India', 1),
#  ('Majestic Floats', 'Yaound', 'Cameroon', 1),
#  ('Range Moonwalker', 'Baiyin', 'China', 1),
#  ('Mine Titans', 'Arecibo', 'Puerto Rico', 1),
#  ('Minds Truman', 'Gorontalo', 'Indonesia', 1),
#  ('Atlantis Cause', 'Fuzhou', 'China', 1),
#  ('Airport Pollock', 'Palghat (Palakkad)', 'India', 1),
#  ('Driving Polish', 'Lhokseumawe', 'Indonesia', 1),
#  ('Scarface Bang', 'Aurora', 'United States', 1),
#  ('Dancing Fever', 'Joliet', 'United States', 1),
#  ('Willow Tracy', 'Nha Trang', 'Vietnam', 1),
#  ('Mystic Truman', 'Santiago de Compostela', 'Spain', 1),
#  ('Cyclone Family', 'Phnom Penh', 'Cambodia', 1),
#  ('Hours Rage', 'Baku', 'Azerbaijan', 1),
#  ('Massacre Usual', 'Merlo', 'Argentina', 1),
#  ('Center Dinosaur', 'Le Mans', 'France', 1),
#  ('River Outlaw', 'Loja', 'Ecuador', 1),
#  ('English Bulworth', 'Portoviejo', 'Ecuador', 1),
#  ('Kiss Glory', 'Boa Vista', 'Brazil', 1),
#  ('Outlaw Hanky', 'Tarlac', 'Philippines', 1),
#  ('Pulp Beverly', 'Richmond Hill', 'Canada', 1),
#  ('Music Boondock', 'Kanazawa', 'Japan', 1),
#  ('Dragon Squad', 'Eskisehir', 'Turkey', 1),
#  ('Torque Bound', 'Sambhal', 'India', 1),
#  ('Rugrats Shakespeare', 'ostka', 'Ukraine', 1),
#  ('Armageddon Lost', 'Surakarta', 'Indonesia', 1),
#  ('Shrunk Divine', 'Kamyin', 'Russian Federation', 1),
#  ('Party Knock', 'Kamakura', 'Japan', 1),
#  ('Mummy Creatures', 'Ede', 'Netherlands', 1),
#  ('Butterfly Chocolat', 'Dos Quebradas', 'Colombia', 1),
#  ('Necklace Outbreak', 'Songkhla', 'Thailand', 1),
#  ('Impossible Prejudice', 'Angra dos Reis', 'Brazil', 1),
#  ('Jade Bunch', 'Ranchi', 'India', 1),
#  ('Details Packer', 'Southampton', 'United Kingdom', 1),
#  ('Effect Gladiator', 'Szkesfehrvr', 'Hungary', 1),
#  ('Torque Bound', 'Oshawa', 'Canada', 1),
#  ('Fireball Philadelphia', 'NDjamna', 'Chad', 1),
#  ('Innocent Usual', 'Niznekamsk', 'Russian Federation', 1),
#  ('Tenenbaums Command', 'Adana', 'Turkey', 1),
#  ('Entrapment Satisfaction', 'Roanoke', 'United States', 1),
#  ('Breaking Home', 'Paarl', 'South Africa', 1),
#  ('Sassy Packer', 'Pereira', 'Colombia', 1),
#  ('Sweethearts Suspects', 'Bhopal', 'India', 1),
#  ('Feathers Metal', 'Bandar Seri Begawan', 'Brunei', 1),
#  ('Vision Torque', 'Lengshuijiang', 'China', 1),
#  ('Bugsy Song', 'Yangor', 'Nauru', 1),
#  ('Pajama Jawbreaker', 'Araatuba', 'Brazil', 1),
#  ('Yentl Idaho', 'Vitria de Santo Anto', 'Brazil', 1),
#  ('Ishtar Rocketeer', 'Nantou', 'Taiwan', 1),
#  ('Impact Aladdin', 'Etawah', 'India', 1),
#  ('Go Purple', 'Ede', 'Netherlands', 1),
#  ('Grease Youth', 'Hagonoy', 'Philippines', 1),
#  ('Airplane Sierra', 'Ibirit', 'Brazil', 1),
#  ('Color Philadelphia', 'Rampur', 'India', 1),
#  ('Alley Evolution', 'Tonghae', 'South Korea', 1),
#  ('Operation Operation', 'Haiphong', 'Vietnam', 1),
#  ('Witches Panic', 'Richmond Hill', 'Canada', 1),
#  ('Maguire Apache', 'Tabriz', 'Iran', 1),
#  ('Scalawag Duck', 'Dos Quebradas', 'Colombia', 1),
#  ('Gun Bonnie', 'Tangail', 'Bangladesh', 1),
#  ('Flamingos Connecticut', 'Kansas City', 'United States', 1),
#  ('Haunting Pianist', 'Okayama', 'Japan', 1),
#  ('Gandhi Kwai', 'Yaound', 'Cameroon', 1),
#  ('Dalmations Sweden', 'Botosani', 'Romania', 1),
#  ('Gleaming Jawbreaker', 'Coatzacoalcos', 'Mexico', 1),
#  ('Confessions Maguire', 'Syrakusa', 'Italy', 1),
#  ('Heaven Freedom', 'Sunnyvale', 'United States', 1),
#  ('Beach Heartbreakers', 'Quilmes', 'Argentina', 1),
#  ('Charade Duffel', 'Emeishan', 'China', 1),
#  ('Stagecoach Armageddon', 'Kirovo-Tepetsk', 'Russian Federation', 1),
#  ('Noon Papi', 'Alvorada', 'Brazil', 1),
#  ('Encounters Curtain', 'Czestochowa', 'Poland', 1),
#  ('Wonderland Christmas', 'Laohekou', 'China', 2),
#  ('Working Microcosmos', 'Baybay', 'Philippines', 1),
#  ('Pirates Roxanne', 'Nezahualcyotl', 'Mexico', 1),
#  ('Grinch Massage', 'Batman', 'Turkey', 1),
#  ('Beach Heartbreakers', 'Xiangtan', 'China', 1),
#  ('Remember Diary', 'Maikop', 'Russian Federation', 1),
#  ('Pickup Driving', 'Witten', 'Germany', 1),
#  ('Gun Bonnie', 'Naala-Porto', 'Mozambique', 1),
#  ('Enemy Odds', 'Jos Azueta', 'Mexico', 1),
#  ('Orient Closer', 'Palghat (Palakkad)', 'India', 1),
#  ('Dracula Crystal', 'Czestochowa', 'Poland', 1),
#  ('Barefoot Manchurian', 'Jastrzebie-Zdrj', 'Poland', 1),
#  ('Lights Deer', 'Eskisehir', 'Turkey', 1),
#  ('Requiem Tycoon', 'Molodetno', 'Belarus', 1),
#  ('Goldfinger Sensibility', 'Abu Dhabi', 'United Arab Emirates', 1),
#  ('Holiday Games', 'Zanzibar', 'Tanzania', 1),
#  ('Nightmare Chill', 'Shimoga', 'India', 1),
#  ('Reds Pocus', 'Rockford', 'United States', 1),
#  ('Bucket Brotherhood', 'Alvorada', 'Brazil', 1),
#  ('Doom Dancing', 'London', 'United Kingdom', 1),
#  ('Speakeasy Date', 'Touliu', 'Taiwan', 1),
#  ('Hanging Deep', 'Bag', 'Brazil', 1),
#  ('Musketeers Wait', 'Sharja', 'United Arab Emirates', 1),
#  ('Road Roxanne', 'Kamyin', 'Russian Federation', 1),
#  ('Unforgiven Zoolander', 'Balikesir', 'Turkey', 1),
#  ('Hyde Doctor', 'Mardan', 'Pakistan', 1),
#  ('Velvet Terminator', 'Rancagua', 'Chile', 1),
#  ('Spirit Flintstones', 'Munger (Monghyr)', 'India', 1),
#  ('Rush Goodfellas', 'Leshan', 'China', 2),
#  ('Texas Watch', 'Greensboro', 'United States', 1),
#  ('Shawshank Bubble', 'Szkesfehrvr', 'Hungary', 1),
#  ('Panther Reds', 'Palghat (Palakkad)', 'India', 1),
#  ('Kane Exorcist', 'Jaipur', 'India', 1),
#  ('Jedi Beneath', 'Richmond Hill', 'Canada', 1),
#  ('Casablanca Super', 'Jaipur', 'India', 1),
#  ('Hustler Party', 'Apeldoorn', 'Netherlands', 1),
#  ('Pianist Outfield', 'La Romana', 'Dominican Republic', 1),
#  ('Rocketeer Mother', 'Siliguri (Shiliguri)', 'India', 1),
#  ('Lonely Elephant', 'Kabul', 'Afghanistan', 1),
#  ('Hunting Musketeers', 'Southport', 'United Kingdom', 1),
#  ('Timberland Sky', 'Palghat (Palakkad)', 'India', 1),
#  ('Eagles Panky', 'El Alto', 'Bolivia', 1),
#  ('Gathering Calendar', 'Jining', 'China', 1),
#  ('Rush Goodfellas', 'Augusta-Richmond County', 'United States', 1),
#  ('Daisy Menagerie', 'Mandi Bahauddin', 'Pakistan', 1),
#  ('Chicago North', 'Kisumu', 'Kenya', 1),
#  ('Double Wrath', 'Uruapan', 'Mexico', 1),
#  ('Suspects Quills', 'Tanza', 'Philippines', 1),
#  ('Horn Working', 'Bhimavaram', 'India', 1),
#  ('Clueless Bucket', 'Daxian', 'China', 1),
#  ('Translation Summer', 'al-Ayn', 'United Arab Emirates', 1),
#  ('English Bulworth', 'Xintai', 'China', 1),
#  ('Pluto Oleander', 'Toulouse', 'France', 1),
#  ('Armageddon Lost', 'Dzerzinsk', 'Russian Federation', 1),
#  ('Reign Gentlemen', 'Basel', 'Switzerland', 1),
#  ('Family Sweet', 'Berhampore (Baharampur)', 'India', 1),
#  ('Berets Agent', 'Sorocaba', 'Brazil', 1),
#  ('Human Graffiti', 'Zaoyang', 'China', 1),
#  ('Kick Savannah', 'Liepaja', 'Latvia', 1),
#  ('Story Side', 'Nam Dinh', 'Vietnam', 1),
#  ('Cyclone Family', 'Cape Coral', 'United States', 1),
#  ('Identity Lover', 'Fuyu', 'China', 1),
#  ('Goldfinger Sensibility', 'Torren', 'Mexico', 1),
#  ('Sundance Invasion', 'Tarlac', 'Philippines', 1),
#  ('Ridgemont Submarine', 'Kilis', 'Turkey', 1),
#  ('Arachnophobia Rollercoaster', 'Mwene-Ditu', 'Congo, The Democratic Republic of the', 1),
#  ('Princess Giant', 'San Miguel de Tucumn', 'Argentina', 1),
#  ('Doors President', 'Iwaki', 'Japan', 1),
#  ('Backlash Undefeated', 'Cuauhtmoc', 'Mexico', 1),
#  ('Married Go', 'Maring', 'Brazil', 1),
#  ('Nightmare Chill', 'Jhansi', 'India', 1),
#  ('Panic Club', 'Boksburg', 'South Africa', 1),
#  ('Uptown Young', 'Adana', 'Turkey', 1),
#  ('Trouble Date', 'Brescia', 'Italy', 1),
#  ('Saturday Lambs', 'Brockton', 'United States', 1),
#  ('Sting Personal', 'Ourense (Orense)', 'Spain', 1),
#  ('Ferris Mother', 'San Felipe de Puerto Plata', 'Dominican Republic', 1),
#  ('Pelican Comforts', 'Miyakonojo', 'Japan', 1),
#  ('Towers Hurricane', 'Tabriz', 'Iran', 1),
#  ('Chisum Behavior', 'Bamenda', 'Cameroon', 1),
#  ('Full Flatliners', 'Songkhla', 'Thailand', 1),
#  ('Hurricane Affair', 'Laiwu', 'China', 1),
#  ('Grapes Fury', 'Uijongbu', 'South Korea', 1),
#  ('Circus Youth', 'Tanauan', 'Philippines', 1),
#  ('Innocent Usual', 'Yingkou', 'China', 1),
#  ('Freddy Storm', 'Hunuco', 'Peru', 1),
#  ('Home Pity', 'Taguig', 'Philippines', 1),
#  ('Cat Coneheads', 'Tafuna', 'American Samoa', 1),
#  ('Maguire Apache', 'Udine', 'Italy', 1),
#  ('Bikini Borrowers', 'Papeete', 'French Polynesia', 1),
#  ('Poseidon Forever', 'Jamalpur', 'Bangladesh', 1),
#  ('Mourning Purple', 'El Monte', 'United States', 1),
#  ('Blues Instinct', 'Kowloon and New Kowloon', 'Hong Kong', 1),
#  ('Spiking Element', 'Binzhou', 'China', 1),
#  ('Lebowski Soldiers', 'Ambattur', 'India', 1),
#  ('Peach Innocent', 'Daugavpils', 'Latvia', 1),
#  ('Married Go', 'Pudukkottai', 'India', 1),
#  ('Roses Treasure', 'Dhule (Dhulia)', 'India', 1),
#  ('Flight Lies', 'Bislig', 'Philippines', 1),
#  ('Bang Kwai', 'Shikarpur', 'Pakistan', 1),
#  ('Wait Cider', 'al-Qatif', 'Saudi Arabia', 2),
#  ('Nightmare Chill', 'Talavera', 'Philippines', 1),
#  ('Alamo Videotape', 'Papeete', 'French Polynesia', 1),
#  ('Feud Frogmen', 'Trshavn', 'Faroe Islands', 1),
#  ('Feathers Metal', 'Tama', 'Japan', 1),
#  ('Model Fish', 'Bellevue', 'United States', 1),
#  ('Ship Wonderland', 'Jalib al-Shuyukh', 'Kuwait', 1),
#  ('Telegraph Voyage', 'Sumy', 'Ukraine', 1),
#  ('Patton Interview', 'Sanya', 'China', 1),
#  ('Mermaid Insects', 'Baha Blanca', 'Argentina', 1),
#  ('Sweet Brotherhood', 'Ashgabat', 'Turkmenistan', 1),
#  ('Enough Raging', 'Xiangtan', 'China', 1),
#  ('Ace Goldfinger', 'Touliu', 'Taiwan', 1),
#  ('Expecations Natural', 'Batman', 'Turkey', 1),
#  ('Fish Opus', 'Escobar', 'Argentina', 1),
#  ('Rear Trading', 'Liaocheng', 'China', 1),
#  ('Clyde Theory', 'Saarbrcken', 'Germany', 1),
#  ('Clerks Angels', 'Songkhla', 'Thailand', 1),
#  ('Frida Slipper', 'Vaduz', 'Liechtenstein', 1),
#  ('Modern Dorado', 'Uijongbu', 'South Korea', 1),
#  ('Freddy Storm', 'Naju', 'South Korea', 1),
#  ('Candidate Perdition', 'Hagonoy', 'Philippines', 1),
#  ('Masked Bubble', 'Hubli-Dharwad', 'India', 1),
#  ('Monterey Labyrinth', 'Rio Claro', 'Brazil', 1),
#  ('Feud Frogmen', 'Pune', 'India', 1),
#  ('Labyrinth League', 'Shimoga', 'India', 1),
#  ('Wagon Jaws', 'al-Qatif', 'Saudi Arabia', 1),
#  ('Story Side', 'Taguig', 'Philippines', 1),
#  ('Pizza Jumanji', 'Kaliningrad', 'Russian Federation', 1),
#  ('Confidential Interview', 'Sasebo', 'Japan', 1),
#  ('Past Suicides', 'Chapra', 'India', 1),
#  ('Cabin Flash', 'Ashdod', 'Israel', 1),
#  ('Excitement Eve', 'Dos Quebradas', 'Colombia', 1),
#  ('Satisfaction Confidential', 'Callao', 'Peru', 1),
#  ('Summer Scarface', 'Iwatsuki', 'Japan', 1),
#  ('Dawn Pond', 'Apeldoorn', 'Netherlands', 2),
#  ('Trap Guys', 'Naala-Porto', 'Mozambique', 1),
#  ('Harry Idaho', 'Parbhani', 'India', 1),
#  ('Ice Crossing', 'Sambhal', 'India', 1),
#  ('Trainspotting Strangers', 'Sousse', 'Tunisia', 1),
#  ('Punk Divorce', 'Nakhon Sawan', 'Thailand', 1),
#  ('Racer Egg', 'Toulon', 'France', 1),
#  ('Life Twisted', 'Dadu', 'Pakistan', 1),
#  ('Gandhi Kwai', 'Botshabelo', 'South Africa', 1),
#  ('Scarface Bang', 'Peoria', 'United States', 1),
#  ('Clyde Theory', 'Vilnius', 'Lithuania', 1),
#  ('Monster Spartacus', 'Benin City', 'Nigeria', 1),
#  ('Greatest North', 'Stara Zagora', 'Bulgaria', 1),
#  ('Stampede Disturbing', 'Pontianak', 'Indonesia', 1),
#  ('Sleepy Japanese', 'Changhwa', 'Taiwan', 1),
#  ('Lebowski Soldiers', 'Munger (Monghyr)', 'India', 1),
#  ('Caribbean Liberty', 'Urawa', 'Japan', 1),
#  ('Virgin Daisy', 'Nagareyama', 'Japan', 1),
#  ('Jericho Mulan', 'Jaipur', 'India', 1),
#  ('Destiny Saturday', 'Braslia', 'Brazil', 1),
#  ('Confidential Interview', 'Kurashiki', 'Japan', 1),
#  ('Valentine Vanishing', 'Salzburg', 'Austria', 1),
#  ('Airplane Sierra', 'Iwakuni', 'Japan', 1),
#  ('Wrong Behavior', 'Almirante Brown', 'Argentina', 1),
#  ('Guys Falcon', 'Bhimavaram', 'India', 1),
#  ('Boogie Amelie', 'Halifax', 'Canada', 1),
#  ('Fireball Philadelphia', 'Namibe', 'Angola', 1),
#  ('Casualties Encino', 'Sanya', 'China', 1),
#  ('Barefoot Manchurian', 'Juazeiro do Norte', 'Brazil', 1),
#  ('Curtain Videotape', 'Haiphong', 'Vietnam', 1),
#  ('Rider Caddyshack', 'Hodeida', 'Yemen', 1),
#  ('Splash Gump', 'Sumy', 'Ukraine', 1),
#  ('Affair Prejudice', 'Aparecida de Goinia', 'Brazil', 1),
#  ('Titans Jerk', 'Poos de Caldas', 'Brazil', 1),
#  ('Core Suit', 'Chatsworth', 'South Africa', 1),
#  ('Snowman Rollercoaster', 'South Hill', 'Anguilla', 1),
#  ('Idols Snatchers', 'Syrakusa', 'Italy', 1),
#  ('Camelot Vacation', 'Urawa', 'Japan', 1),
#  ('Alaska Phantom', 'Sterling Heights', 'United States', 1),
#  ('Juggler Hardly', 'Enshi', 'China', 1),
#  ('Werewolf Lola', 'Lipetsk', 'Russian Federation', 1),
#  ('Mars Roman', 'Shaoguan', 'China', 1),
#  ('Quills Bull', 'Sawhaj', 'Egypt', 1),
#  ('Beach Heartbreakers', 'Pathankot', 'India', 1),
#  ('Gunfight Moon', 'Tanauan', 'Philippines', 1),
#  ('Samurai Lion', 'Hanoi', 'Vietnam', 1),
#  ('Clash Freddy', 'Batman', 'Turkey', 1),
#  ('Virginian Pluto', 'Nuuk', 'Greenland', 1),
#  ('Contact Anonymous', 'Buenaventura', 'Colombia', 1),
#  ('Summer Scarface', 'Coquimbo', 'Chile', 1),
#  ('Holocaust Highball', 'Emeishan', 'China', 1),
#  ('Philadelphia Wife', 'Sincelejo', 'Colombia', 1),
#  ('Tramp Others', 'Maikop', 'Russian Federation', 1),
#  ('Varsity Trip', 'Torren', 'Mexico', 1),
#  ('Sunrise League', 'Deba Habe', 'Nigeria', 1),
#  ('Brooklyn Desert', 'Kowloon and New Kowloon', 'Hong Kong', 1),
#  ('Beach Heartbreakers', 'Kilis', 'Turkey', 1),
#  ('Lover Truman', 'Pemalang', 'Indonesia', 1),
#  ('Drums Dynamite', 'Berhampore (Baharampur)', 'India', 1),
#  ('Jason Trap', 'ostka', 'Ukraine', 1),
#  ('Armageddon Lost', 'Cianjur', 'Indonesia', 1),
#  ('Anonymous Human', 'Liepaja', 'Latvia', 1),
#  ('Pride Alamo', 'Ede', 'Netherlands', 1),
#  ('Splendor Patton', 'Nezahualcyotl', 'Mexico', 1),
#  ('Heartbreakers Bright', 'Pereira', 'Colombia', 1),
#  ('National Story', 'Beira', 'Mozambique', 1),
#  ('Army Flintstones', 'Pune', 'India', 1),
#  ('Story Side', 'Liepaja', 'Latvia', 1),
#  ('Goldmine Tycoon', 'Batman', 'Turkey', 1),
#  ('Vampire Whale', 'Yuncheng', 'China', 1),
#  ('Inch Jet', 'Soshanguve', 'South Africa', 1),
#  ('Harry Idaho', 'Daxian', 'China', 1),
#  ('Smoking Barbarella', 'Kingstown', 'Saint Vincent and the Grenadines', 1),
#  ('Mod Secretary', 'Beira', 'Mozambique', 1),
#  ('Basic Easy', 'Batman', 'Turkey', 1),
#  ('Insider Arizona', 'Florencia', 'Colombia', 1),
#  ('Matrix Snowman', 'Baybay', 'Philippines', 1),
#  ('Easy Gladiator', 'Kuching', 'Malaysia', 1),
#  ('Sweethearts Suspects', 'Deba Habe', 'Nigeria', 1),
#  ('Musketeers Wait', 'Po', 'Brazil', 1),
#  ('Hellfighters Sierra', 'Nezahualcyotl', 'Mexico', 1),
#  ('Mallrats United', 'Saint Louis', 'United States', 1),
#  ('Snatch Slipper', 'Effon-Alaiye', 'Nigeria', 1),
#  ('Halloween Nuts', 'Southend-on-Sea', 'United Kingdom', 1),
#  ('Patton Interview', 'Kamakura', 'Japan', 1),
#  ('Mars Roman', 'Addis Abeba', 'Ethiopia', 1),
#  ('Divine Resurrection', 'Tanauan', 'Philippines', 1),
#  ('Dalmations Sweden', 'Dadu', 'Pakistan', 1),
#  ('Glass Dying', 'Batman', 'Turkey', 1),
#  ('Town Ark', 'Braslia', 'Brazil', 1),
#  ('Haunting Pianist', 'Valencia', 'Venezuela', 1),
#  ('Song Hedwig', 'Dongying', 'China', 1),
#  ('Treatment Jekyll', 'Arak', 'Iran', 1),
#  ('Fatal Haunted', 'Ueda', 'Japan', 1),
#  ('Camelot Vacation', 'Poos de Caldas', 'Brazil', 1),
#  ('Drop Waterfront', 'Lungtan', 'Taiwan', 1),
#  ('Panther Reds', 'Changzhou', 'China', 1),
#  ('Hyde Doctor', 'Gorontalo', 'Indonesia', 1),
#  ('Wind Phantom', 'Ciudad del Este', 'Paraguay', 1),
#  ('Heavyweights Beast', 'Banjul', 'Gambia', 1),
#  ('Hours Rage', 'Chiayi', 'Taiwan', 1),
#  ('Pulp Beverly', 'Vancouver', 'Canada', 1),
#  ('Egypt Tenenbaums', 'Toulouse', 'France', 1),
#  ('Grit Clockwork', 'Kitwe', 'Zambia', 1),
#  ('Earring Instinct', 'Teboksary', 'Russian Federation', 1),
#  ('Expendable Stallion', 'Tabuk', 'Saudi Arabia', 1),
#  ('Fellowship Autumn', 'Dzerzinsk', 'Russian Federation', 1),
#  ('Moon Bunch', 'Yuzhou', 'China', 1),
#  ('Juggler Hardly', 'Lubumbashi', 'Congo, The Democratic Republic of the', 1),
#  ('Bill Others', 'Nabereznyje Telny', 'Russian Federation', 1),
#  ('Gaslight Crusade', 'Kalisz', 'Poland', 1),
#  ('Tracy Cider', 'Hidalgo', 'Mexico', 1),
#  ('Pocus Pulp', 'ostka', 'Ukraine', 1),
#  ('Brannigan Sunrise', 'Mannheim', 'Germany', 1),
#  ('Blindness Gun', 'Valencia', 'Venezuela', 1),
#  ('Encino Elf', 'Pachuca de Soto', 'Mexico', 1),
#  ('Sunrise League', 'Rampur', 'India', 1),
#  ('Horn Working', 'Gandhinagar', 'India', 1),
#  ('Poseidon Forever', 'Masqat', 'Oman', 1),
#  ('Alone Trip', 'Cabuyao', 'Philippines', 1),
#  ('Dragonfly Strangers', 'Duisburg', 'Germany', 1),
#  ('Agent Truman', 'Citrus Heights', 'United States', 1),
#  ('Boogie Amelie', 'Miraj', 'India', 1),
#  ('Telegraph Voyage', 'Donostia-San Sebastin', 'Spain', 1),
#  ('Doubtfire Labyrinth', 'Allende', 'Mexico', 1),
#  ('Hedwig Alter', 'Junan', 'China', 1),
#  ('Blanket Beverly', 'Cavite', 'Philippines', 1),
#  ('Basic Easy', 'Escobar', 'Argentina', 1),
#  ('Independence Hotel', 'Ife', 'Nigeria', 1),
#  ('Hook Chariots', 'Erlangen', 'Germany', 1),
#  ('Interview Liaisons', 'Iwatsuki', 'Japan', 1),
#  ('Stock Glass', 'Syrakusa', 'Italy', 1),
#  ('Gunfight Moon', 'Sal', 'Morocco', 1),
#  ('Juggler Hardly', 'Monclova', 'Mexico', 1),
#  ('Hook Chariots', 'Simferopol', 'Ukraine', 1),
#  ('Clueless Bucket', 'Aurora', 'United States', 1),
#  ('Mine Titans', 'Plock', 'Poland', 1),
#  ('Opposite Necklace', 'Santiago de Compostela', 'Spain', 1),
#  ('Fiddler Lost', 'Coatzacoalcos', 'Mexico', 1),
#  ('Muscle Bright', 'Kingstown', 'Saint Vincent and the Grenadines', 1),
#  ('Blindness Gun', 'Clarksville', 'United States', 1),
#  ('Closer Bang', 'San Lorenzo', 'Paraguay', 1),
#  ('California Birds', 'Tangail', 'Bangladesh', 1),
#  ('Vision Torque', 'Shahr-e Kord', 'Iran', 1),
#  ('Telemark Heartbreakers', 'London', 'United Kingdom', 1),
#  ('Club Graffiti', 'Fukuyama', 'Japan', 1),
#  ('Haunting Pianist', 'Belm', 'Brazil', 1),
#  ('Behavior Runaway', 'Akron', 'United States', 1),
#  ('Wonka Sea', 'Lipetsk', 'Russian Federation', 1),
#  ('Brannigan Sunrise', 'Amersfoort', 'Netherlands', 1),
#  ('Paycheck Wait', 'Yuncheng', 'China', 1),
#  ('Midsummer Groundhog', 'Braslia', 'Brazil', 2),
#  ('Maker Gables', 'Balurghat', 'India', 1),
#  ('Dragonfly Strangers', 'La Romana', 'Dominican Republic', 1),
#  ('Roxanne Rebel', 'Tsaotun', 'Taiwan', 1),
#  ('Intrigue Worst', 'Toulon', 'France', 1),
#  ('Earring Instinct', 'Datong', 'China', 1),
#  ('Horror Reign', 'Kamjanets-Podilskyi', 'Ukraine', 1),
#  ('Calendar Gunfight', 'Quilmes', 'Argentina', 1),
#  ('Family Sweet', 'Pingxiang', 'China', 1),
#  ('Clueless Bucket', 'Kolpino', 'Russian Federation', 1),
#  ('Sassy Packer', 'Dhule (Dhulia)', 'India', 1),
#  ('Gleaming Jawbreaker', 'Valle de la Pascua', 'Venezuela', 1),
#  ('Zorro Ark', 'Tieli', 'China', 1),
#  ('Metropolis Coma', 'Valencia', 'Venezuela', 1),
#  ('Women Dorado', 'Songkhla', 'Thailand', 1),
#  ('Titans Jerk', 'Celaya', 'Mexico', 1),
#  ('Pilot Hoosiers', 'al-Ayn', 'United Arab Emirates', 1),
#  ('Mourning Purple', 'Tangail', 'Bangladesh', 1),
#  ('Soup Wisdom', 'Tabora', 'Tanzania', 1),
#  ('Maiden Home', 'Isesaki', 'Japan', 1),
#  ('Island Exorcist', 'Lima', 'Peru', 1),
#  ('Amadeus Holy', 'Nabereznyje Telny', 'Russian Federation', 1),
#  ('Anaconda Confessions', 'Kermanshah', 'Iran', 1),
#  ('Madison Trap', 'Gaziantep', 'Turkey', 1),
#  ('License Weekend', 'Hami', 'China', 1),
#  ('Jawbreaker Brooklyn', 'Bucuresti', 'Romania', 1),
#  ('Shock Cabin', 'Barcelona', 'Venezuela', 1),
#  ('Halloween Nuts', 'Goinia', 'Brazil', 1),
#  ('Patriot Roman', 'Kamakura', 'Japan', 1),
#  ('Legally Secretary', 'Suihua', 'China', 1),
#  ('Congeniality Quest', 'Kursk', 'Russian Federation', 1),
#  ('Fatal Haunted', 'Bern', 'Switzerland', 1),
#  ('Mine Titans', 'Kirovo-Tepetsk', 'Russian Federation', 1),
#  ('Whisperer Giant', 'Kamyin', 'Russian Federation', 1),
#  ('Wardrobe Phantom', 'Sousse', 'Tunisia', 1),
#  ('Gilbert Pelican', 'Botshabelo', 'South Africa', 1),
#  ('Element Freddy', 'San Lorenzo', 'Paraguay', 1),
#  ('Details Packer', 'Kowloon and New Kowloon', 'Hong Kong', 1),
#  ('Apache Divine', 'Carmen', 'Mexico', 1),
#  ('Mulan Moon', 'Mukateve', 'Ukraine', 1),
#  ('Giant Troopers', 'Kaduna', 'Nigeria', 1),
#  ('Fargo Gandhi', 'Liaocheng', 'China', 1),
#  ('Eyes Driving', 'Maikop', 'Russian Federation', 1),
#  ('Lawless Vision', 'Bern', 'Switzerland', 1),
#  ('Lebowski Soldiers', 'Kermanshah', 'Iran', 1),
#  ('Lies Treatment', 'Hiroshima', 'Japan', 1),
#  ('Earth Vision', 'Aden', 'Yemen', 1),
#  ('Insider Arizona', 'Lengshuijiang', 'China', 1),
#  ('Birch Antitrust', 'Sokoto', 'Nigeria', 1),
#  ('Confidential Interview', 'Bijapur', 'India', 1),
#  ('Mallrats United', 'Coquimbo', 'Chile', 1),
#  ('Racer Egg', 'San Felipe del Progreso', 'Mexico', 1),
#  ('Chaplin License', 'Phnom Penh', 'Cambodia', 1),
#  ('Town Ark', 'Richmond Hill', 'Canada', 1),
#  ('West Lion', 'Tanauan', 'Philippines', 1),
#  ('Innocent Usual', 'Valparai', 'India', 2),
#  ('Virgin Daisy', 'Ife', 'Nigeria', 1),
#  ('Egg Igby', 'Tel Aviv-Jaffa', 'Israel', 1),
#  ('Duck Racer', 'Korla', 'China', 1),
#  ('Blindness Gun', 'Udaipur', 'India', 1),
#  ('Connecticut Tramp', 'Citt del Vaticano', 'Holy See (Vatican City State)', 1),
#  ('Day Unfaithful', 'Najafabad', 'Iran', 1),
#  ('Greedy Roots', 'Manchester', 'United States', 1),
#  ('Shrek License', 'Sokoto', 'Nigeria', 1),
#  ('Fireball Philadelphia', 'Sasebo', 'Japan', 2),
#  ('National Story', 'Xiangfan', 'China', 1),
#  ('Spice Sorority', 'Kamakura', 'Japan', 1),
#  ('Strangelove Desire', 'Simferopol', 'Ukraine', 1),
#  ('Inch Jet', 'Juiz de Fora', 'Brazil', 1),
#  ('Impact Aladdin', 'Uttarpara-Kotrung', 'India', 1),
#  ('Wife Turn', 'Kuching', 'Malaysia', 1),
#  ('Labyrinth League', 'London', 'United Kingdom', 1),
#  ('Queen Luke', 'Ruse', 'Bulgaria', 1),
#  ('Factory Dragon', 'Stara Zagora', 'Bulgaria', 1),
#  ('Center Dinosaur', 'El Alto', 'Bolivia', 1),
#  ('Hanging Deep', 'Skikda', 'Algeria', 1),
#  ('Jason Trap', 'Lengshuijiang', 'China', 1),
#  ('Mummy Creatures', 'Compton', 'United States', 1),
#  ('Perfect Groove', 'Haining', 'China', 1),
#  ('English Bulworth', 'Maring', 'Brazil', 1),
#  ('Ballroom Mockingbird', 'Cam Ranh', 'Vietnam', 1),
#  ('Pianist Outfield', 'Tangail', 'Bangladesh', 1),
#  ('Dangerous Uptown', 'Ikerre', 'Nigeria', 1),
#  ('Alaska Phantom', 'Laohekou', 'China', 1),
#  ('Jekyll Frogmen', 'Bratislava', 'Slovakia', 1),
#  ('Holocaust Highball', 'Santa Rosa', 'Philippines', 1),
#  ('Majestic Floats', 'Shubra al-Khayma', 'Egypt', 1),
#  ('Tracy Cider', 'Lausanne', 'Switzerland', 1),
#  ('Samurai Lion', 'Huixquilucan', 'Mexico', 1),
#  ('Saturday Lambs', 'Tartu', 'Estonia', 1),
#  ('Miracle Virtual', 'Huixquilucan', 'Mexico', 1),
#  ('Jedi Beneath', 'Qinhuangdao', 'China', 1),
#  ('Sweden Shining', 'Aparecida de Goinia', 'Brazil', 1),
#  ('Tights Dawn', 'Joliet', 'United States', 1),
#  ('Wonderland Christmas', 'Salamanca', 'Mexico', 1),
#  ('Comforts Rush', 'Dundee', 'United Kingdom', 1),
#  ('Rock Instinct', 'Haldia', 'India', 1),
#  ('Cleopatra Devil', 'Daxian', 'China', 1),
#  ('Candidate Perdition', 'Benin City', 'Nigeria', 1),
#  ('Tootsie Pilot', 'Kowloon and New Kowloon', 'Hong Kong', 1),
#  ('Gone Trouble', 'Kamjanets-Podilskyi', 'Ukraine', 1),
#  ('Torque Bound', 'Hiroshima', 'Japan', 1),
#  ('Wonka Sea', 'Hsichuh', 'Taiwan', 1),
#  ('Insider Arizona', 'Sucre', 'Bolivia', 1),
#  ('Graduate Lord', 'Daugavpils', 'Latvia', 1),
#  ('Ship Wonderland', 'Soshanguve', 'South Africa', 1),
#  ('Enemy Odds', 'Sirjan', 'Iran', 1),
#  ('Cause Date', 'Sagamihara', 'Japan', 1),
#  ('Home Pity', 'Bamenda', 'Cameroon', 1),
#  ('Hope Tootsie', 'Kisumu', 'Kenya', 1),
#  ('Graffiti Love', 'Liepaja', 'Latvia', 1),
#  ('Hotel Happiness', 'Phnom Penh', 'Cambodia', 1),
#  ('Sabrina Midnight', 'Novi Sad', 'Yugoslavia', 1),
#  ('Tootsie Pilot', 'Bag', 'Brazil', 1),
#  ('English Bulworth', 'Laredo', 'United States', 2),
#  ('Operation Operation', 'Garland', 'United States', 1),
#  ('Paradise Sabrina', 'Grand Prairie', 'United States', 1),
#  ('Hope Tootsie', 'Ivanovo', 'Russian Federation', 1),
#  ('Vietnam Smoochy', 'Esfahan', 'Iran', 1),
#  ('Craft Outfield', 'Poos de Caldas', 'Brazil', 1),
#  ('Fiddler Lost', 'Monclova', 'Mexico', 1),
#  ('Day Unfaithful', 'Baybay', 'Philippines', 1),
#  ('Igby Maker', 'Tangail', 'Bangladesh', 1),
#  ('Roxanne Rebel', 'York', 'United Kingdom', 1),
#  ('Graduate Lord', 'Citt del Vaticano', 'Holy See (Vatican City State)', 1),
#  ('Gleaming Jawbreaker', 'Sincelejo', 'Colombia', 1),
#  ('Rock Instinct', 'Tabora', 'Tanzania', 1),
#  ('Santa Paris', 'Santo Andr', 'Brazil', 1),
#  ('Gangs Pride', 'Nyeri', 'Kenya', 1),
#  ('Jacket Frisco', 'Atlixco', 'Mexico', 1),
#  ('Darn Forrester', 'Sunnyvale', 'United States', 1),
#  ('Truman Crazy', 'Balaiha', 'Russian Federation', 1),
#  ('Mask Peach', 'Bag', 'Brazil', 1),
#  ('Star Operation', 'Mardan', 'Pakistan', 1),
#  ('Scarface Bang', 'Cuauhtmoc', 'Mexico', 1),
#  ('Sleuth Orient', 'Ozamis', 'Philippines', 1),
#  ('Deceiver Betrayed', 'Mardan', 'Pakistan', 1),
#  ('Sunrise League', 'Davao', 'Philippines', 1),
#  ('Flamingos Connecticut', 'Naala-Porto', 'Mozambique', 1),
#  ('Goldfinger Sensibility', 'Haldia', 'India', 1),
#  ('Brotherhood Blanket', 'Pachuca de Soto', 'Mexico', 1),
#  ('Saturn Name', 'Denizli', 'Turkey', 1),
#  ('Horror Reign', 'Merlo', 'Argentina', 1),
#  ('Bright Encounters', 'Jastrzebie-Zdrj', 'Poland', 1),
#  ('Contact Anonymous', 'Funafuti', 'Tuvalu', 1),
#  ('Pilot Hoosiers', 'Guaruj', 'Brazil', 1),
#  ('Drifter Commandments', 'Jining', 'China', 1),
#  ('Hall Cassidy', 'Ogbomosho', 'Nigeria', 1),
#  ('Inch Jet', 'Portoviejo', 'Ecuador', 1),
#  ('Bowfinger Gables', 'San Lorenzo', 'Paraguay', 1),
#  ('Chaplin License', 'Konotop', 'Ukraine', 1),
#  ('English Bulworth', 'Cape Coral', 'United States', 1),
#  ('Operation Operation', 'Jhansi', 'India', 1),
#  ('Evolution Alter', 'Bellevue', 'United States', 1),
#  ('Groove Fiction', 'Monywa', 'Myanmar', 1),
#  ('Trading Pinocchio', 'Munger (Monghyr)', 'India', 1),
#  ('Strangers Graffiti', 'Kragujevac', 'Yugoslavia', 1),
#  ('Jacket Frisco', 'Rampur', 'India', 1),
#  ('Instinct Airport', 'Balaiha', 'Russian Federation', 1),
#  ('Kick Savannah', 'Oyo', 'Nigeria', 1),
#  ('Robbers Joon', 'Cuauhtmoc', 'Mexico', 1),
#  ('Taxi Kick', 'Rockford', 'United States', 1),
#  ('Exorcist Sting', 'Mwanza', 'Tanzania', 1),
#  ('Enough Raging', 'Zhoushan', 'China', 1),
#  ('Madre Gables', 'Mwanza', 'Tanzania', 1),
#  ('Cheaper Clyde', 'Halifax', 'Canada', 2),
#  ('Forever Candidate', 'Probolinggo', 'Indonesia', 1),
#  ('Intrigue Worst', 'Korla', 'China', 1),
#  ('Records Zorro', 'Citrus Heights', 'United States', 1),
#  ('Madison Trap', 'La Paz', 'Mexico', 1),
#  ('World Leathernecks', 'Tabuk', 'Saudi Arabia', 1),
#  ('Minds Truman', 'al-Ayn', 'United Arab Emirates', 1),
#  ('Fool Mockingbird', 'Chandrapur', 'India', 1),
#  ('Boiled Dares', 'Fukuyama', 'Japan', 1),
#  ('Barbarella Streetcar', 'Qomsheh', 'Iran', 1),
#  ('Requiem Tycoon', 'Dallas', 'United States', 1),
#  ('Berets Agent', 'Ashgabat', 'Turkmenistan', 1),
#  ('Oscar Gold', 'Uijongbu', 'South Korea', 1),
#  ('Crooked Frogmen', 'Tanauan', 'Philippines', 1),
#  ('Newton Labyrinth', 'Ciomas', 'Indonesia', 1),
#  ('License Weekend', 'Jedda', 'Saudi Arabia', 1),
#  ('Doubtfire Labyrinth', 'Lhokseumawe', 'Indonesia', 1),
#  ('Wife Turn', 'Mahajanga', 'Madagascar', 1),
#  ('Dynamite Tarzan', 'Emeishan', 'China', 1),
#  ('Conversation Downhill', 'Saarbrcken', 'Germany', 1),
#  ('Others Soup', 'Esfahan', 'Iran', 1),
#  ('Malkovich Pet', 'Guadalajara', 'Mexico', 1),
#  ('Talented Homicide', 'Oshawa', 'Canada', 1),
#  ('Swarm Gold', 'Halle/Saale', 'Germany', 1),
#  ('Park Citizen', 'Nyeri', 'Kenya', 1),
#  ('Cause Date', 'Deba Habe', 'Nigeria', 1),
#  ('Seabiscuit Punk', 'Kolpino', 'Russian Federation', 1),
#  ('Dawn Pond', 'Bradford', 'United Kingdom', 1),
#  ('Pulp Beverly', 'Vila Velha', 'Brazil', 1),
#  ('Forrester Comancheros', 'Kragujevac', 'Yugoslavia', 1),
#  ('Muscle Bright', 'Davao', 'Philippines', 1),
#  ('Loser Hustler', 'Angra dos Reis', 'Brazil', 1),
#  ('Malkovich Pet', 'Erlangen', 'Germany', 1),
#  ('Juggler Hardly', 'Effon-Alaiye', 'Nigeria', 1),
#  ('Fish Opus', 'Sambhal', 'India', 1),
#  ('Coldblooded Darling', 'Baku', 'Azerbaijan', 1),
#  ('Philadelphia Wife', 'Okayama', 'Japan', 1),
#  ('Hanover Galaxy', 'Addis Abeba', 'Ethiopia', 1),
#  ('Uprising Uptown', 'Tanza', 'Philippines', 1),
#  ('Requiem Tycoon', 'Laiwu', 'China', 1),
#  ('Wash Heavenly', 'Arak', 'Iran', 1),
#  ('Horn Working', 'Jinchang', 'China', 1),
#  ('Creepers Kane', 'Roanoke', 'United States', 1),
#  ('Rage Games', 'Bchar', 'Algeria', 1),
#  ('Horror Reign', 'Kuching', 'Malaysia', 1),
#  ('Ties Hunger', 'Xintai', 'China', 1),
#  ('Interview Liaisons', 'Buenaventura', 'Colombia', 1),
#  ('Blues Instinct', 'Rampur', 'India', 1),
#  ('Million Ace', 'Baybay', 'Philippines', 1),
#  ('October Submarine', 'Coquimbo', 'Chile', 1),
#  ('Oleander Clue', 'Tokat', 'Turkey', 1),
#  ('Desperate Trainspotting', 'Fukuyama', 'Japan', 1),
#  ('Vanishing Rocky', 'Datong', 'China', 1),
#  ('Greedy Roots', 'Po', 'Brazil', 1),
#  ('Cat Coneheads', 'Sousse', 'Tunisia', 1),
#  ('Gaslight Crusade', 'Dadu', 'Pakistan', 1),
#  ('Fatal Haunted', 'Patiala', 'India', 1),
#  ('Flying Hook', 'Higashiosaka', 'Japan', 1),
#  ('Usual Untouchables', 'Nyeri', 'Kenya', 1),
#  ('Angels Life', 'Sharja', 'United Arab Emirates', 1),
#  ('Open African', 'Funafuti', 'Tuvalu', 1),
#  ('Camelot Vacation', 'Bat Yam', 'Israel', 1),
#  ('Tomorrow Hustler', 'Guaruj', 'Brazil', 1),
#  ('Baked Cleopatra', 'Phnom Penh', 'Cambodia', 1),
#  ('Streak Ridgemont', 'Dundee', 'United Kingdom', 1),
#  ('Velvet Terminator', 'Halisahar', 'India', 1),
#  ('Million Ace', 'Moscow', 'Russian Federation', 1),
#  ('Games Bowfinger', 'Aparecida de Goinia', 'Brazil', 1),
#  ('Ferris Mother', 'Baku', 'Azerbaijan', 1),
#  ('Island Exorcist', 'Peoria', 'United States', 1),
#  ('Conversation Downhill', 'Fukuyama', 'Japan', 1),
#  ('Beauty Grease', 'Dhule (Dhulia)', 'India', 1),
#  ('Bilko Anonymous', 'Shivapuri', 'India', 1),
#  ('Wash Heavenly', 'Etawah', 'India', 1),
#  ('Frida Slipper', 'Benin City', 'Nigeria', 1),
#  ('Redemption Comforts', 'Lapu-Lapu', 'Philippines', 1),
#  ('Story Side', 'Belm', 'Brazil', 1),
#  ...]

# %% [markdown]
# # 10
#
# ### List the film title, number of times it has been rented, and the most recent rental date, in order of least recently rented, then most rentals.

# %%
# %%sql
# EXPLAIN
# SELECT title, COUNT(title), MAX(rental_date::date)
# FROM film
# INNER JOIN inventory
#     ON film.film_id = inventory.film_id
# INNER JOIN rental
#     ON inventory.inventory_id = rental.inventory_id
# GROUP BY title
# ORDER BY MAX(rental_date::date), COUNT(*) DESC
# Out:
#  * postgres://dsa_ro_user:***@pgsql.dsa.lan/dvdrental
# 13 rows affected.
# [('Sort  (cost=859.84..862.34 rows=1000 width=35)',),
#  ('  Sort Key: (max((rental.rental_date)::date)), (count(*)) DESC',),
#  ('  ->  HashAggregate  (cost=800.02..810.02 rows=1000 width=35)',),
#  ('        Group Key: film.title',),
#  ('        ->  Hash Join  (cost=204.57..599.47 rows=16044 width=23)',),
#  ('              Hash Cond: (inventory.film_id = film.film_id)',),
#  ('              ->  Hash Join  (cost=128.07..480.67 rows=16044 width=10)',),
#  ('                    Hash Cond: (rental.inventory_id = inventory.inventory_id)',),
#  ('                    ->  Seq Scan on rental  (cost=0.00..310.44 rows=16044 width=12)',),
#  ('                    ->  Hash  (cost=70.81..70.81 rows=4581 width=6)',),
#  ('                          ->  Seq Scan on inventory  (cost=0.00..70.81 rows=4581 width=6)',),
#  ('              ->  Hash  (cost=64.00..64.00 rows=1000 width=19)',),
#  ('                    ->  Seq Scan on film  (cost=0.00..64.00 rows=1000 width=19)',)]

# %%
# %%sql
# SELECT title, COUNT(title), MAX(rental_date::date)
# FROM film
# INNER JOIN inventory
#     ON film.film_id = inventory.film_id
# INNER JOIN rental
#     ON inventory.inventory_id = rental.inventory_id
# GROUP BY title
# ORDER BY MAX(rental_date::date), COUNT(*) DESC
# Out:
#  * postgres://dsa_ro_user:***@pgsql.dsa.lan/dvdrental
# 958 rows affected.
# [('Papi Necklace', 8, datetime.date(2005, 8, 17)),
#  ('Graceland Dynamite', 6, datetime.date(2005, 8, 17)),
#  ('Towers Hurricane', 11, datetime.date(2005, 8, 18)),
#  ('Superfly Trip', 10, datetime.date(2005, 8, 18)),
#  ('Dares Pluto', 9, datetime.date(2005, 8, 18)),
#  ('Miracle Virtual', 9, datetime.date(2005, 8, 18)),
#  ('Impact Aladdin', 9, datetime.date(2005, 8, 18)),
#  ('Hoosiers Birdcage', 8, datetime.date(2005, 8, 18)),
#  ('Lights Deer', 8, datetime.date(2005, 8, 18)),
#  ('Eve Resurrection', 7, datetime.date(2005, 8, 18)),
#  ('Leathernecks Dwarfs', 7, datetime.date(2005, 8, 18)),
#  ('Clue Grail', 7, datetime.date(2005, 8, 18)),
#  ('Bed Highball', 6, datetime.date(2005, 8, 18)),
#  ('Sling Luke', 6, datetime.date(2005, 8, 18)),
#  ('Youth Kick', 6, datetime.date(2005, 8, 18)),
#  ('Jersey Sassy', 6, datetime.date(2005, 8, 18)),
#  ('Conspiracy Spirit', 5, datetime.date(2005, 8, 18)),
#  ('Fever Empire', 5, datetime.date(2005, 8, 18)),
#  ('Atlantis Cause', 24, datetime.date(2005, 8, 19)),
#  ('Factory Dragon', 17, datetime.date(2005, 8, 19)),
#  ('Comforts Rush', 17, datetime.date(2005, 8, 19)),
#  ('Greek Everyone', 17, datetime.date(2005, 8, 19)),
#  ('Panky Submarine', 15, datetime.date(2005, 8, 19)),
#  ('Breaking Home', 13, datetime.date(2005, 8, 19)),
#  ('Valentine Vanishing', 12, datetime.date(2005, 8, 19)),
#  ('Bowfinger Gables', 11, datetime.date(2005, 8, 19)),
#  ('Language Cowboy', 11, datetime.date(2005, 8, 19)),
#  ('Luck Opus', 10, datetime.date(2005, 8, 19)),
#  ('Smile Earring', 10, datetime.date(2005, 8, 19)),
#  ('Frogmen Breaking', 10, datetime.date(2005, 8, 19)),
#  ('Intolerable Intentions', 9, datetime.date(2005, 8, 19)),
#  ('Monsoon Cause', 9, datetime.date(2005, 8, 19)),
#  ('Jungle Closer', 9, datetime.date(2005, 8, 19)),
#  ('Magnificent Chitty', 8, datetime.date(2005, 8, 19)),
#  ('Runner Madigan', 8, datetime.date(2005, 8, 19)),
#  ('Maude Mod', 8, datetime.date(2005, 8, 19)),
#  ('Jumanji Blade', 8, datetime.date(2005, 8, 19)),
#  ('Heavenly Gun', 7, datetime.date(2005, 8, 19)),
#  ('Killer Innocent', 6, datetime.date(2005, 8, 19)),
#  ('Warlock Werewolf', 6, datetime.date(2005, 8, 19)),
#  ('Phantom Glory', 6, datetime.date(2005, 8, 19)),
#  ('Private Drop', 5, datetime.date(2005, 8, 19)),
#  ('Mussolini Spoilers', 5, datetime.date(2005, 8, 19)),
#  ('Lies Treatment', 27, datetime.date(2005, 8, 20)),
#  ('Empire Malkovich', 21, datetime.date(2005, 8, 20)),
#  ('Divide Monster', 21, datetime.date(2005, 8, 20)),
#  ('Anaconda Confessions', 21, datetime.date(2005, 8, 20)),
#  ('Chocolat Harry', 20, datetime.date(2005, 8, 20)),
#  ('Something Duck', 19, datetime.date(2005, 8, 20)),
#  ('Hanging Deep', 19, datetime.date(2005, 8, 20)),
#  ('Hanover Galaxy', 17, datetime.date(2005, 8, 20)),
#  ('Confused Candles', 17, datetime.date(2005, 8, 20)),
#  ('Idaho Love', 17, datetime.date(2005, 8, 20)),
#  ('Noon Papi', 17, datetime.date(2005, 8, 20)),
#  ('Pickup Driving', 16, datetime.date(2005, 8, 20)),
#  ('Pilot Hoosiers', 16, datetime.date(2005, 8, 20)),
#  ('Slipper Fidelity', 16, datetime.date(2005, 8, 20)),
#  ('Spirit Flintstones', 15, datetime.date(2005, 8, 20)),
#  ('Translation Summer', 15, datetime.date(2005, 8, 20)),
#  ('Hamlet Wisdom', 14, datetime.date(2005, 8, 20)),
#  ('Searchers Wait', 14, datetime.date(2005, 8, 20)),
#  ('Chisum Behavior', 13, datetime.date(2005, 8, 20)),
#  ('Super Wyoming', 13, datetime.date(2005, 8, 20)),
#  ('Arabia Dogma', 13, datetime.date(2005, 8, 20)),
#  ('Anonymous Human', 13, datetime.date(2005, 8, 20)),
#  ('Past Suicides', 13, datetime.date(2005, 8, 20)),
#  ('Evolution Alter', 12, datetime.date(2005, 8, 20)),
#  ('Beethoven Exorcist', 11, datetime.date(2005, 8, 20)),
#  ('Stranger Strangers', 11, datetime.date(2005, 8, 20)),
#  ('Prix Undefeated', 11, datetime.date(2005, 8, 20)),
#  ('Beneath Rush', 10, datetime.date(2005, 8, 20)),
#  ('Jeopardy Encino', 10, datetime.date(2005, 8, 20)),
#  ('Holy Tadpole', 9, datetime.date(2005, 8, 20)),
#  ('Birdcage Casper', 9, datetime.date(2005, 8, 20)),
#  ('Random Go', 9, datetime.date(2005, 8, 20)),
#  ('Speed Suit', 9, datetime.date(2005, 8, 20)),
#  ('Diary Panic', 9, datetime.date(2005, 8, 20)),
#  ('Untouchables Sunrise', 8, datetime.date(2005, 8, 20)),
#  ('Chaplin License', 8, datetime.date(2005, 8, 20)),
#  ('Punk Divorce', 8, datetime.date(2005, 8, 20)),
#  ('Park Citizen', 8, datetime.date(2005, 8, 20)),
#  ('Soup Wisdom', 8, datetime.date(2005, 8, 20)),
#  ('Soldiers Evolution', 8, datetime.date(2005, 8, 20)),
#  ('License Weekend', 7, datetime.date(2005, 8, 20)),
#  ('Hawk Chill', 7, datetime.date(2005, 8, 20)),
#  ('Fire Wolves', 7, datetime.date(2005, 8, 20)),
#  ('Doctor Grail', 7, datetime.date(2005, 8, 20)),
#  ('Braveheart Human', 5, datetime.date(2005, 8, 20)),
#  ('Enemy Odds', 29, datetime.date(2005, 8, 21)),
#  ('Primary Glass', 27, datetime.date(2005, 8, 21)),
#  ('Contact Anonymous', 26, datetime.date(2005, 8, 21)),
#  ('Attraction Newton', 24, datetime.date(2005, 8, 21)),
#  ('Strangelove Desire', 24, datetime.date(2005, 8, 21)),
#  ('Hurricane Affair', 24, datetime.date(2005, 8, 21)),
#  ('Wash Heavenly', 23, datetime.date(2005, 8, 21)),
#  ('Aladdin Calendar', 23, datetime.date(2005, 8, 21)),
#  ('Easy Gladiator', 23, datetime.date(2005, 8, 21)),
#  ('Midsummer Groundhog', 22, datetime.date(2005, 8, 21)),
#  ('Tourist Pelican', 22, datetime.date(2005, 8, 21)),
#  ('Sabrina Midnight', 21, datetime.date(2005, 8, 21)),
#  ('Wolves Desire', 21, datetime.date(2005, 8, 21)),
#  ('Agent Truman', 21, datetime.date(2005, 8, 21)),
#  ('Dalmations Sweden', 20, datetime.date(2005, 8, 21)),
#  ('Prejudice Oleander', 20, datetime.date(2005, 8, 21)),
#  ('Eyes Driving', 19, datetime.date(2005, 8, 21)),
#  ('Jedi Beneath', 19, datetime.date(2005, 8, 21)),
#  ('Neighbors Charade', 19, datetime.date(2005, 8, 21)),
#  ('Jacket Frisco', 18, datetime.date(2005, 8, 21)),
#  ('Groove Fiction', 18, datetime.date(2005, 8, 21)),
#  ('Unforgiven Zoolander', 18, datetime.date(2005, 8, 21)),
#  ('Waterfront Deliverance', 17, datetime.date(2005, 8, 21)),
#  ('Musketeers Wait', 17, datetime.date(2005, 8, 21)),
#  ('United Pilot', 17, datetime.date(2005, 8, 21)),
#  ('Teen Apollo', 17, datetime.date(2005, 8, 21)),
#  ('League Hellfighters', 17, datetime.date(2005, 8, 21)),
#  ('Dying Maker', 17, datetime.date(2005, 8, 21)),
#  ('Chicago North', 16, datetime.date(2005, 8, 21)),
#  ('Craft Outfield', 16, datetime.date(2005, 8, 21)),
#  ('Pluto Oleander', 16, datetime.date(2005, 8, 21)),
#  ('Bonnie Holocaust', 16, datetime.date(2005, 8, 21)),
#  ('Destiny Saturday', 16, datetime.date(2005, 8, 21)),
#  ('Homeward Cider', 16, datetime.date(2005, 8, 21)),
#  ('Wasteland Divine', 15, datetime.date(2005, 8, 21)),
#  ('Hysterical Grail', 15, datetime.date(2005, 8, 21)),
#  ('Model Fish', 15, datetime.date(2005, 8, 21)),
#  ('Betrayed Rear', 15, datetime.date(2005, 8, 21)),
#  ('Cabin Flash', 15, datetime.date(2005, 8, 21)),
#  ('Submarine Bed', 15, datetime.date(2005, 8, 21)),
#  ('Lonely Elephant', 15, datetime.date(2005, 8, 21)),
#  ('Dirty Ace', 15, datetime.date(2005, 8, 21)),
#  ('Vietnam Smoochy', 15, datetime.date(2005, 8, 21)),
#  ('Boiled Dares', 15, datetime.date(2005, 8, 21)),
#  ('Jaws Harry', 14, datetime.date(2005, 8, 21)),
#  ('Kane Exorcist', 14, datetime.date(2005, 8, 21)),
#  ('Home Pity', 14, datetime.date(2005, 8, 21)),
#  ('Pajama Jawbreaker', 14, datetime.date(2005, 8, 21)),
#  ('Tomatoes Hellfighters', 14, datetime.date(2005, 8, 21)),
#  ('Shanghai Tycoon', 14, datetime.date(2005, 8, 21)),
#  ('Exorcist Sting', 13, datetime.date(2005, 8, 21)),
#  ('Identity Lover', 13, datetime.date(2005, 8, 21)),
#  ('Date Speed', 13, datetime.date(2005, 8, 21)),
#  ('Hollywood Anonymous', 13, datetime.date(2005, 8, 21)),
#  ('Robbery Bright', 13, datetime.date(2005, 8, 21)),
#  ('Mile Mulan', 13, datetime.date(2005, 8, 21)),
#  ('Uptown Young', 12, datetime.date(2005, 8, 21)),
#  ('Lost Bird', 12, datetime.date(2005, 8, 21)),
#  ('Speakeasy Date', 12, datetime.date(2005, 8, 21)),
#  ('Loverboy Attacks', 12, datetime.date(2005, 8, 21)),
#  ('Massage Image', 12, datetime.date(2005, 8, 21)),
#  ('Finding Anaconda', 12, datetime.date(2005, 8, 21)),
#  ('Flight Lies', 12, datetime.date(2005, 8, 21)),
#  ('Sorority Queen', 12, datetime.date(2005, 8, 21)),
#  ('Thin Sagebrush', 11, datetime.date(2005, 8, 21)),
#  ('Feathers Metal', 11, datetime.date(2005, 8, 21)),
#  ('Drumline Cyclone', 11, datetime.date(2005, 8, 21)),
#  ('Mod Secretary', 11, datetime.date(2005, 8, 21)),
#  ('Autumn Crow', 11, datetime.date(2005, 8, 21)),
#  ('Ending Crowds', 11, datetime.date(2005, 8, 21)),
#  ('Bugsy Song', 11, datetime.date(2005, 8, 21)),
#  ('Jawbreaker Brooklyn', 10, datetime.date(2005, 8, 21)),
#  ('Lover Truman', 10, datetime.date(2005, 8, 21)),
#  ('Right Cranes', 10, datetime.date(2005, 8, 21)),
#  ('Doubtfire Labyrinth', 10, datetime.date(2005, 8, 21)),
#  ('Wagon Jaws', 10, datetime.date(2005, 8, 21)),
#  ('Antitrust Tomatoes', 10, datetime.date(2005, 8, 21)),
#  ('Stage World', 10, datetime.date(2005, 8, 21)),
#  ('Elizabeth Shane', 10, datetime.date(2005, 8, 21)),
#  ('Sensibility Rear', 10, datetime.date(2005, 8, 21)),
#  ('Spartacus Cheaper', 9, datetime.date(2005, 8, 21)),
#  ('Matrix Snowman', 9, datetime.date(2005, 8, 21)),
#  ('Legend Jedi', 9, datetime.date(2005, 8, 21)),
#  ('King Evolution', 9, datetime.date(2005, 8, 21)),
#  ('Casualties Encino', 9, datetime.date(2005, 8, 21)),
#  ('Wisdom Worker', 9, datetime.date(2005, 8, 21)),
#  ('Vanilla Day', 9, datetime.date(2005, 8, 21)),
#  ('Darling Breaking', 9, datetime.date(2005, 8, 21)),
#  ('Platoon Instinct', 9, datetime.date(2005, 8, 21)),
#  ('Runaway Tenenbaums', 8, datetime.date(2005, 8, 21)),
#  ('Harold French', 8, datetime.date(2005, 8, 21)),
#  ('Casper Dragonfly', 8, datetime.date(2005, 8, 21)),
#  ('Destination Jerk', 8, datetime.date(2005, 8, 21)),
#  ('Grosse Wonderful', 8, datetime.date(2005, 8, 21)),
#  ('President Bang', 7, datetime.date(2005, 8, 21)),
#  ('Pizza Jumanji', 7, datetime.date(2005, 8, 21)),
#  ('Clerks Angels', 7, datetime.date(2005, 8, 21)),
#  ('Elf Murder', 7, datetime.date(2005, 8, 21)),
#  ('Treatment Jekyll', 7, datetime.date(2005, 8, 21)),
#  ('Luke Mummy', 7, datetime.date(2005, 8, 21)),
#  ('Duffel Apocalypse', 7, datetime.date(2005, 8, 21)),
#  ('Early Home', 7, datetime.date(2005, 8, 21)),
#  ('Texas Watch', 6, datetime.date(2005, 8, 21)),
#  ('Frontier Cabin', 6, datetime.date(2005, 8, 21)),
#  ('School Jacket', 6, datetime.date(2005, 8, 21)),
#  ('Freedom Cleopatra', 5, datetime.date(2005, 8, 21)),
#  ('Bunch Minds', 5, datetime.date(2005, 8, 21)),
#  ('Full Flatliners', 5, datetime.date(2005, 8, 21)),
#  ('Traffic Hobbit', 5, datetime.date(2005, 8, 21)),
#  ('Mixed Doors', 4, datetime.date(2005, 8, 21)),
#  ('Robbers Joon', 31, datetime.date(2005, 8, 22)),
#  ('Rush Goodfellas', 31, datetime.date(2005, 8, 22)),
#  ('Hobbit Alien', 31, datetime.date(2005, 8, 22)),
#  ('Butterfly Chocolat', 30, datetime.date(2005, 8, 22)),
#  ('Married Go', 30, datetime.date(2005, 8, 22)),
#  ('Storm Happiness', 29, datetime.date(2005, 8, 22)),
#  ('Bingo Talented', 29, datetime.date(2005, 8, 22)),
#  ('Videotape Arsenic', 29, datetime.date(2005, 8, 22)),
#  ('Moon Bunch', 29, datetime.date(2005, 8, 22)),
#  ('Fatal Haunted', 28, datetime.date(2005, 8, 22)),
#  ('Giant Troopers', 28, datetime.date(2005, 8, 22)),
#  ('Handicap Boondock', 28, datetime.date(2005, 8, 22)),
#  ('Closer Bang', 28, datetime.date(2005, 8, 22)),
#  ('Gilmore Boiled', 28, datetime.date(2005, 8, 22)),
#  ('Dancing Fever', 27, datetime.date(2005, 8, 22)),
#  ('Lose Inch', 27, datetime.date(2005, 8, 22)),
#  ('Goldmine Tycoon', 27, datetime.date(2005, 8, 22)),
#  ('Spy Mile', 27, datetime.date(2005, 8, 22)),
#  ('Durham Panky', 26, datetime.date(2005, 8, 22)),
#  ('Disturbing Scarface', 26, datetime.date(2005, 8, 22)),
#  ('Metropolis Coma', 26, datetime.date(2005, 8, 22)),
#  ('Fantasy Troopers', 26, datetime.date(2005, 8, 22)),
#  ('Brotherhood Blanket', 26, datetime.date(2005, 8, 22)),
#  ('Innocent Usual', 26, datetime.date(2005, 8, 22)),
#  ('Fellowship Autumn', 26, datetime.date(2005, 8, 22)),
#  ('Feud Frogmen', 25, datetime.date(2005, 8, 22)),
#  ('Gun Bonnie', 25, datetime.date(2005, 8, 22)),
#  ('Sun Confessions', 25, datetime.date(2005, 8, 22)),
#  ('Metal Armageddon', 25, datetime.date(2005, 8, 22)),
#  ('Madness Attacks', 25, datetime.date(2005, 8, 22)),
#  ('Fargo Gandhi', 24, datetime.date(2005, 8, 22)),
#  ('Goldfinger Sensibility', 24, datetime.date(2005, 8, 22)),
#  ('Sunrise League', 24, datetime.date(2005, 8, 22)),
#  ('Slums Duck', 24, datetime.date(2005, 8, 22)),
#  ('Arachnophobia Rollercoaster', 24, datetime.date(2005, 8, 22)),
#  ('Alamo Videotape', 24, datetime.date(2005, 8, 22)),
#  ('Knock Warlock', 24, datetime.date(2005, 8, 22)),
#  ('Lola Agent', 24, datetime.date(2005, 8, 22)),
#  ('Fool Mockingbird', 23, datetime.date(2005, 8, 22)),
#  ('Cupboard Sinners', 23, datetime.date(2005, 8, 22)),
#  ('Truman Crazy', 23, datetime.date(2005, 8, 22)),
#  ('Gentlemen Stage', 23, datetime.date(2005, 8, 22)),
#  ('Candles Grapes', 23, datetime.date(2005, 8, 22)),
#  ('Kwai Homeward', 23, datetime.date(2005, 8, 22)),
#  ('Flamingos Connecticut', 23, datetime.date(2005, 8, 22)),
#  ('Salute Apollo', 23, datetime.date(2005, 8, 22)),
#  ('Sinners Atlantis', 22, datetime.date(2005, 8, 22)),
#  ('Liaisons Sweet', 22, datetime.date(2005, 8, 22)),
#  ('Shakespeare Saddle', 22, datetime.date(2005, 8, 22)),
#  ('Congeniality Quest', 22, datetime.date(2005, 8, 22)),
#  ('Kiss Glory', 22, datetime.date(2005, 8, 22)),
#  ('Dream Pickup', 22, datetime.date(2005, 8, 22)),
#  ('Flatliners Killer', 22, datetime.date(2005, 8, 22)),
#  ('High Encino', 22, datetime.date(2005, 8, 22)),
#  ('Moonshine Cabin', 21, datetime.date(2005, 8, 22)),
#  ('Fireball Philadelphia', 21, datetime.date(2005, 8, 22)),
#  ('Excitement Eve', 21, datetime.date(2005, 8, 22)),
#  ('Secret Groundhog', 21, datetime.date(2005, 8, 22)),
#  ('Resurrection Silverado', 21, datetime.date(2005, 8, 22)),
#  ('Doom Dancing', 21, datetime.date(2005, 8, 22)),
#  ('Driving Polish', 21, datetime.date(2005, 8, 22)),
#  ('Deceiver Betrayed', 21, datetime.date(2005, 8, 22)),
#  ('Christmas Moonshine', 21, datetime.date(2005, 8, 22)),
#  ('Mourning Purple', 21, datetime.date(2005, 8, 22)),
#  ('Sleuth Orient', 21, datetime.date(2005, 8, 22)),
#  ('Brooklyn Desert', 21, datetime.date(2005, 8, 22)),
#  ('Unbreakable Karate', 21, datetime.date(2005, 8, 22)),
#  ('Chariots Conspiracy', 21, datetime.date(2005, 8, 22)),
#  ('Egg Igby', 21, datetime.date(2005, 8, 22)),
#  ('Tramp Others', 20, datetime.date(2005, 8, 22)),
#  ('Interview Liaisons', 20, datetime.date(2005, 8, 22)),
#  ('Stepmom Dream', 20, datetime.date(2005, 8, 22)),
#  ('Money Harold', 20, datetime.date(2005, 8, 22)),
#  ('Cheaper Clyde', 20, datetime.date(2005, 8, 22)),
#  ('Room Roman', 20, datetime.date(2005, 8, 22)),
#  ('Minds Truman', 20, datetime.date(2005, 8, 22)),
#  ('Straight Hours', 20, datetime.date(2005, 8, 22)),
#  ('Secrets Paradise', 20, datetime.date(2005, 8, 22)),
#  ('Thief Pelican', 19, datetime.date(2005, 8, 22)),
#  ('Clones Pinocchio', 19, datetime.date(2005, 8, 22)),
#  ('Novocaine Flight', 19, datetime.date(2005, 8, 22)),
#  ('Hours Rage', 19, datetime.date(2005, 8, 22)),
#  ('Fury Murder', 19, datetime.date(2005, 8, 22)),
#  ('Mars Roman', 19, datetime.date(2005, 8, 22)),
#  ('Independence Hotel', 19, datetime.date(2005, 8, 22)),
#  ('Campus Remember', 19, datetime.date(2005, 8, 22)),
#  ('Pond Seattle', 19, datetime.date(2005, 8, 22)),
#  ('Expecations Natural', 18, datetime.date(2005, 8, 22)),
#  ('Mission Zoolander', 18, datetime.date(2005, 8, 22)),
#  ('Hope Tootsie', 18, datetime.date(2005, 8, 22)),
#  ('Secretary Rouge', 18, datetime.date(2005, 8, 22)),
#  ('Paradise Sabrina', 18, datetime.date(2005, 8, 22)),
#  ('Weekend Personal', 18, datetime.date(2005, 8, 22)),
#  ('Galaxy Sweethearts', 18, datetime.date(2005, 8, 22)),
#  ('Virgin Daisy', 17, datetime.date(2005, 8, 22)),
#  ('Newton Labyrinth', 17, datetime.date(2005, 8, 22)),
#  ('Majestic Floats', 17, datetime.date(2005, 8, 22)),
#  ('Mask Peach', 17, datetime.date(2005, 8, 22)),
#  ('Rear Trading', 17, datetime.date(2005, 8, 22)),
#  ('Potter Connecticut', 17, datetime.date(2005, 8, 22)),
#  ('Bikini Borrowers', 17, datetime.date(2005, 8, 22)),
#  ('Egypt Tenenbaums', 17, datetime.date(2005, 8, 22)),
#  ('Satisfaction Confidential', 17, datetime.date(2005, 8, 22)),
#  ('Taxi Kick', 17, datetime.date(2005, 8, 22)),
#  ('Flintstones Happiness', 17, datetime.date(2005, 8, 22)),
#  ('Holocaust Highball', 17, datetime.date(2005, 8, 22)),
#  ('Ferris Mother', 17, datetime.date(2005, 8, 22)),
#  ('Gandhi Kwai', 17, datetime.date(2005, 8, 22)),
#  ('Freaky Pocus', 17, datetime.date(2005, 8, 22)),
#  ('French Holiday', 17, datetime.date(2005, 8, 22)),
#  ('Graduate Lord', 16, datetime.date(2005, 8, 22)),
#  ('Daisy Menagerie', 16, datetime.date(2005, 8, 22)),
#  ('Rules Human', 16, datetime.date(2005, 8, 22)),
#  ('Watch Tracy', 16, datetime.date(2005, 8, 22)),
#  ('Command Darling', 16, datetime.date(2005, 8, 22)),
#  ('Rocky War', 16, datetime.date(2005, 8, 22)),
#  ('Mermaid Insects', 16, datetime.date(2005, 8, 22)),
#  ('West Lion', 16, datetime.date(2005, 8, 22)),
#  ('Army Flintstones', 16, datetime.date(2005, 8, 22)),
#  ('Moulin Wake', 16, datetime.date(2005, 8, 22)),
#  ('Patriot Roman', 16, datetime.date(2005, 8, 22)),
#  ('Conquerer Nuts', 16, datetime.date(2005, 8, 22)),
#  ('Trap Guys', 16, datetime.date(2005, 8, 22)),
#  ('Silence Kane', 16, datetime.date(2005, 8, 22)),
#  ('Words Hunter', 16, datetime.date(2005, 8, 22)),
#  ('Artist Coldblooded', 16, datetime.date(2005, 8, 22)),
#  ('Nash Chocolat', 15, datetime.date(2005, 8, 22)),
#  ('Anthem Luke', 15, datetime.date(2005, 8, 22)),
#  ('Worker Tarzan', 15, datetime.date(2005, 8, 22)),
#  ('Tootsie Pilot', 15, datetime.date(2005, 8, 22)),
#  ('Human Graffiti', 15, datetime.date(2005, 8, 22)),
#  ('Ship Wonderland', 15, datetime.date(2005, 8, 22)),
#  ('Valley Packer', 15, datetime.date(2005, 8, 22)),
#  ('Panther Reds', 15, datetime.date(2005, 8, 22)),
#  ('Labyrinth League', 15, datetime.date(2005, 8, 22)),
#  ('Airplane Sierra', 15, datetime.date(2005, 8, 22)),
#  ('Scissorhands Slums', 15, datetime.date(2005, 8, 22)),
#  ('Steers Armageddon', 15, datetime.date(2005, 8, 22)),
#  ('Madison Trap', 15, datetime.date(2005, 8, 22)),
#  ('Grinch Massage', 14, datetime.date(2005, 8, 22)),
#  ('Notorious Reunion', 14, datetime.date(2005, 8, 22)),
#  ('Town Ark', 14, datetime.date(2005, 8, 22)),
#  ('Turn Star', 14, datetime.date(2005, 8, 22)),
#  ('Alley Evolution', 14, datetime.date(2005, 8, 22)),
#  ('Analyze Hoosiers', 14, datetime.date(2005, 8, 22)),
#  ('Shane Darkness', 14, datetime.date(2005, 8, 22)),
#  ('Donnie Alley', 14, datetime.date(2005, 8, 22)),
#  ('Wrath Mile', 14, datetime.date(2005, 8, 22)),
#  ('Personal Ladybugs', 14, datetime.date(2005, 8, 22)),
#  ('Splash Gump', 14, datetime.date(2005, 8, 22)),
#  ('Impossible Prejudice', 14, datetime.date(2005, 8, 22)),
#  ('Confessions Maguire', 14, datetime.date(2005, 8, 22)),
#  ('Elephant Trojan', 14, datetime.date(2005, 8, 22)),
#  ('Gold River', 14, datetime.date(2005, 8, 22)),
#  ('Connecticut Tramp', 13, datetime.date(2005, 8, 22)),
#  ('Sassy Packer', 13, datetime.date(2005, 8, 22)),
#  ('Monterey Labyrinth', 13, datetime.date(2005, 8, 22)),
#  ('Bright Encounters', 13, datetime.date(2005, 8, 22)),
#  ('Darkness War', 13, datetime.date(2005, 8, 22)),
#  ('Spiking Element', 13, datetime.date(2005, 8, 22)),
#  ('Daddy Pittsburgh', 13, datetime.date(2005, 8, 22)),
#  ('Behavior Runaway', 13, datetime.date(2005, 8, 22)),
#  ('Tenenbaums Command', 13, datetime.date(2005, 8, 22)),
#  ('Memento Zoolander', 13, datetime.date(2005, 8, 22)),
#  ('Drums Dynamite', 13, datetime.date(2005, 8, 22)),
#  ('Pittsburgh Hunchback', 12, datetime.date(2005, 8, 22)),
#  ('Savannah Town', 12, datetime.date(2005, 8, 22)),
#  ('Vampire Whale', 12, datetime.date(2005, 8, 22)),
#  ('Reef Salute', 11, datetime.date(2005, 8, 22)),
#  ('Gathering Calendar', 11, datetime.date(2005, 8, 22)),
#  ('Beast Hunchback', 11, datetime.date(2005, 8, 22)),
#  ('Stone Fire', 11, datetime.date(2005, 8, 22)),
#  ('Rider Caddyshack', 11, datetime.date(2005, 8, 22)),
#  ('Opus Ice', 11, datetime.date(2005, 8, 22)),
#  ('Magnolia Forrester', 11, datetime.date(2005, 8, 22)),
#  ('Cranes Reservoir', 11, datetime.date(2005, 8, 22)),
#  ('Wars Pluto', 10, datetime.date(2005, 8, 22)),
#  ('Notting Speakeasy', 10, datetime.date(2005, 8, 22)),
#  ('Lambs Cincinatti', 10, datetime.date(2005, 8, 22)),
#  ('Run Pacific', 10, datetime.date(2005, 8, 22)),
#  ('Hollow Jeopardy', 10, datetime.date(2005, 8, 22)),
#  ('Gone Trouble', 10, datetime.date(2005, 8, 22)),
#  ('Blood Argonauts', 10, datetime.date(2005, 8, 22)),
#  ('Oleander Clue', 10, datetime.date(2005, 8, 22)),
#  ('Guys Falcon', 9, datetime.date(2005, 8, 22)),
#  ('Wonderful Drop', 9, datetime.date(2005, 8, 22)),
#  ('Victory Academy', 9, datetime.date(2005, 8, 22)),
#  ('Dolls Rage', 9, datetime.date(2005, 8, 22)),
#  ('Legally Secretary', 9, datetime.date(2005, 8, 22)),
#  ('Crazy Home', 9, datetime.date(2005, 8, 22)),
#  ('Anything Savannah', 9, datetime.date(2005, 8, 22)),
#  ('Maguire Apache', 9, datetime.date(2005, 8, 22)),
#  ('Kramer Chocolate', 9, datetime.date(2005, 8, 22)),
#  ('Hotel Happiness', 9, datetime.date(2005, 8, 22)),
#  ('Drop Waterfront', 9, datetime.date(2005, 8, 22)),
#  ('Ballroom Mockingbird', 8, datetime.date(2005, 8, 22)),
#  ('Desire Alien', 8, datetime.date(2005, 8, 22)),
#  ('Gosford Donnie', 8, datetime.date(2005, 8, 22)),
#  ('Tarzan Videotape', 8, datetime.date(2005, 8, 22)),
#  ('Pet Haunting', 8, datetime.date(2005, 8, 22)),
#  ('Godfather Diary', 8, datetime.date(2005, 8, 22)),
#  ('Baby Hall', 8, datetime.date(2005, 8, 22)),
#  ('Unfaithful Kill', 8, datetime.date(2005, 8, 22)),
#  ('Divorce Shining', 7, datetime.date(2005, 8, 22)),
#  ('Control Anthem', 7, datetime.date(2005, 8, 22)),
#  ('Magic Mallrats', 7, datetime.date(2005, 8, 22)),
#  ('Panic Club', 7, datetime.date(2005, 8, 22)),
#  ('Cowboy Doom', 7, datetime.date(2005, 8, 22)),
#  ('Bulworth Commandments', 7, datetime.date(2005, 8, 22)),
#  ('Vision Torque', 7, datetime.date(2005, 8, 22)),
#  ('Dozen Lion', 7, datetime.date(2005, 8, 22)),
#  ('Ishtar Rocketeer', 7, datetime.date(2005, 8, 22)),
#  ('Ladybugs Armageddon', 6, datetime.date(2005, 8, 22)),
#  ('Watership Frontier', 6, datetime.date(2005, 8, 22)),
#  ('Rushmore Mermaid', 6, datetime.date(2005, 8, 22)),
#  ('Desperate Trainspotting', 6, datetime.date(2005, 8, 22)),
#  ('Tequila Past', 6, datetime.date(2005, 8, 22)),
#  ('Terminator Club', 6, datetime.date(2005, 8, 22)),
#  ('Mannequin Worst', 5, datetime.date(2005, 8, 22)),
#  ('Informer Double', 5, datetime.date(2005, 8, 22)),
#  ('Hardly Robbers', 4, datetime.date(2005, 8, 22)),
#  ('Bucket Brotherhood', 34, datetime.date(2005, 8, 23)),
#  ('Rocketeer Mother', 33, datetime.date(2005, 8, 23)),
#  ('Grit Clockwork', 32, datetime.date(2005, 8, 23)),
#  ('Scalawag Duck', 32, datetime.date(2005, 8, 23)),
#  ('Forward Temple', 32, datetime.date(2005, 8, 23)),
#  ('Goodfellas Salute', 31, datetime.date(2005, 8, 23)),
#  ('Timberland Sky', 31, datetime.date(2005, 8, 23)),
#  ('Zorro Ark', 31, datetime.date(2005, 8, 23)),
#  ('Wife Turn', 31, datetime.date(2005, 8, 23)),
#  ('Apache Divine', 31, datetime.date(2005, 8, 23)),
#  ('Network Peak', 31, datetime.date(2005, 8, 23)),
#  ('Dogma Family', 30, datetime.date(2005, 8, 23)),
#  ('Massacre Usual', 30, datetime.date(2005, 8, 23)),
#  ('English Bulworth', 30, datetime.date(2005, 8, 23)),
#  ('Witches Panic', 30, datetime.date(2005, 8, 23)),
#  ('Graffiti Love', 30, datetime.date(2005, 8, 23)),
#  ('Rugrats Shakespeare', 30, datetime.date(2005, 8, 23)),
#  ('Muscle Bright', 30, datetime.date(2005, 8, 23)),
#  ('Idols Snatchers', 30, datetime.date(2005, 8, 23)),
#  ('Confidential Interview', 29, datetime.date(2005, 8, 23)),
#  ('Greatest North', 29, datetime.date(2005, 8, 23)),
#  ('Talented Homicide', 29, datetime.date(2005, 8, 23)),
#  ('Trip Newton', 28, datetime.date(2005, 8, 23)),
#  ('Voyage Legally', 28, datetime.date(2005, 8, 23)),
#  ('Saturday Lambs', 28, datetime.date(2005, 8, 23)),
#  ('Story Side', 28, datetime.date(2005, 8, 23)),
#  ('Expendable Stallion', 28, datetime.date(2005, 8, 23)),
#  ('Roses Treasure', 28, datetime.date(2005, 8, 23)),
#  ('Blackout Private', 27, datetime.date(2005, 8, 23)),
#  ('Gangs Pride', 27, datetime.date(2005, 8, 23)),
#  ('Chance Resurrection', 27, datetime.date(2005, 8, 23)),
#  ('Wardrobe Phantom', 27, datetime.date(2005, 8, 23)),
#  ('Telegraph Voyage', 27, datetime.date(2005, 8, 23)),
#  ('Invasion Cyclone', 27, datetime.date(2005, 8, 23)),
#  ('Range Moonwalker', 27, datetime.date(2005, 8, 23)),
#  ('Dorado Notting', 27, datetime.date(2005, 8, 23)),
#  ('Horror Reign', 27, datetime.date(2005, 8, 23)),
#  ('Alaska Phantom', 26, datetime.date(2005, 8, 23)),
#  ('Westward Seabiscuit', 26, datetime.date(2005, 8, 23)),
#  ('Island Exorcist', 26, datetime.date(2005, 8, 23)),
#  ('Pelican Comforts', 26, datetime.date(2005, 8, 23)),
#  ('Coma Head', 26, datetime.date(2005, 8, 23)),
#  ('Hanky October', 26, datetime.date(2005, 8, 23)),
#  ('Tracy Cider', 26, datetime.date(2005, 8, 23)),
#  ('Malkovich Pet', 26, datetime.date(2005, 8, 23)),
#  ('Stagecoach Armageddon', 26, datetime.date(2005, 8, 23)),
#  ('Tights Dawn', 26, datetime.date(2005, 8, 23)),
#  ('Pity Bound', 26, datetime.date(2005, 8, 23)),
#  ('Pocus Pulp', 26, datetime.date(2005, 8, 23)),
#  ('Velvet Terminator', 26, datetime.date(2005, 8, 23)),
#  ('Barbarella Streetcar', 25, datetime.date(2005, 8, 23)),
#  ('Downhill Enough', 25, datetime.date(2005, 8, 23)),
#  ('Clueless Bucket', 25, datetime.date(2005, 8, 23)),
#  ('Working Microcosmos', 25, datetime.date(2005, 8, 23)),
#  ('Fish Opus', 25, datetime.date(2005, 8, 23)),
#  ('Streetcar Intentions', 25, datetime.date(2005, 8, 23)),
#  ('Double Wrath', 25, datetime.date(2005, 8, 23)),
#  ('Nightmare Chill', 25, datetime.date(2005, 8, 23)),
#  ('Dynamite Tarzan', 25, datetime.date(2005, 8, 23)),
#  ('Samurai Lion', 25, datetime.date(2005, 8, 23)),
#  ('Mallrats United', 25, datetime.date(2005, 8, 23)),
#  ('Clash Freddy', 25, datetime.date(2005, 8, 23)),
#  ('Escape Metropolis', 25, datetime.date(2005, 8, 23)),
#  ('Hills Neighbors', 25, datetime.date(2005, 8, 23)),
#  ('Shepherd Midsummer', 25, datetime.date(2005, 8, 23)),
#  ('Show Lord', 25, datetime.date(2005, 8, 23)),
#  ('Coneheads Smoochy', 25, datetime.date(2005, 8, 23)),
#  ('Telemark Heartbreakers', 25, datetime.date(2005, 8, 23)),
#  ('Tomorrow Hustler', 25, datetime.date(2005, 8, 23)),
#  ('Oscar Gold', 25, datetime.date(2005, 8, 23)),
#  ('Pacific Amistad', 24, datetime.date(2005, 8, 23)),
#  ('Color Philadelphia', 24, datetime.date(2005, 8, 23)),
#  ('Oz Liaisons', 24, datetime.date(2005, 8, 23)),
#  ('Maiden Home', 24, datetime.date(2005, 8, 23)),
#  ('Shootist Superfly', 24, datetime.date(2005, 8, 23)),
#  ('Horn Working', 24, datetime.date(2005, 8, 23)),
#  ('Caper Motions', 24, datetime.date(2005, 8, 23)),
#  ('Roman Punk', 24, datetime.date(2005, 8, 23)),
#  ('Celebrity Horn', 24, datetime.date(2005, 8, 23)),
#  ('Orange Grapes', 24, datetime.date(2005, 8, 23)),
#  ('Jumping Wrath', 24, datetime.date(2005, 8, 23)),
#  ('Ice Crossing', 24, datetime.date(2005, 8, 23)),
#  ('Carrie Bunch', 23, datetime.date(2005, 8, 23)),
#  ('Steel Santa', 23, datetime.date(2005, 8, 23)),
#  ('Academy Dinosaur', 23, datetime.date(2005, 8, 23)),
#  ('Freddy Storm', 23, datetime.date(2005, 8, 23)),
#  ('Wind Phantom', 23, datetime.date(2005, 8, 23)),
#  ('House Dynamite', 23, datetime.date(2005, 8, 23)),
#  ('Others Soup', 23, datetime.date(2005, 8, 23)),
#  ('Scorpion Apollo', 23, datetime.date(2005, 8, 23)),
#  ('Outbreak Divine', 23, datetime.date(2005, 8, 23)),
#  ('Balloon Homeward', 23, datetime.date(2005, 8, 23)),
#  ('Murder Antitrust', 23, datetime.date(2005, 8, 23)),
#  ('Snowman Rollercoaster', 23, datetime.date(2005, 8, 23)),
#  ('Heavyweights Beast', 23, datetime.date(2005, 8, 23)),
#  ('Strictly Scarface', 23, datetime.date(2005, 8, 23)),
#  ('Yentl Idaho', 23, datetime.date(2005, 8, 23)),
#  ('Karate Moon', 23, datetime.date(2005, 8, 23)),
#  ('Patton Interview', 23, datetime.date(2005, 8, 23)),
#  ('Borrowers Bedazzled', 22, datetime.date(2005, 8, 23)),
#  ('Packer Madigan', 22, datetime.date(2005, 8, 23)),
#  ('Head Stranger', 22, datetime.date(2005, 8, 23)),
#  ('Haunting Pianist', 22, datetime.date(2005, 8, 23)),
#  ('Hustler Party', 22, datetime.date(2005, 8, 23)),
#  ('Beauty Grease', 22, datetime.date(2005, 8, 23)),
#  ('Wonderland Christmas', 22, datetime.date(2005, 8, 23)),
#  ('Homicide Peach', 22, datetime.date(2005, 8, 23)),
#  ('Maltese Hope', 22, datetime.date(2005, 8, 23)),
#  ('Whisperer Giant', 22, datetime.date(2005, 8, 23)),
#  ('Bear Graceland', 22, datetime.date(2005, 8, 23)),
#  ('Angels Life', 22, datetime.date(2005, 8, 23)),
#  ('Sea Virgin', 22, datetime.date(2005, 8, 23)),
#  ('Chicken Hellfighters', 22, datetime.date(2005, 8, 23)),
#  ('Alien Center', 22, datetime.date(2005, 8, 23)),
#  ('Banger Pinocchio', 22, datetime.date(2005, 8, 23)),
#  ('Annie Identity', 22, datetime.date(2005, 8, 23)),
#  ('Snatch Slipper', 22, datetime.date(2005, 8, 23)),
#  ('Alter Victory', 22, datetime.date(2005, 8, 23)),
#  ('Chill Luck', 22, datetime.date(2005, 8, 23)),
#  ('Coast Rainbow', 21, datetime.date(2005, 8, 23)),
#  ('Blues Instinct', 21, datetime.date(2005, 8, 23)),
#  ('Lebowski Soldiers', 21, datetime.date(2005, 8, 23)),
#  ('Arizona Bang', 21, datetime.date(2005, 8, 23)),
#  ('Calendar Gunfight', 21, datetime.date(2005, 8, 23)),
#  ('Crossroads Casualties', 21, datetime.date(2005, 8, 23)),
#  ('Highball Potter', 21, datetime.date(2005, 8, 23)),
#  ('Sting Personal', 21, datetime.date(2005, 8, 23)),
#  ('Badman Dawn', 21, datetime.date(2005, 8, 23)),
#  ('Grease Youth', 21, datetime.date(2005, 8, 23)),
#  ('Dracula Crystal', 21, datetime.date(2005, 8, 23)),
#  ('Undefeated Dalmations', 21, datetime.date(2005, 8, 23)),
#  ('Vacation Boondock', 21, datetime.date(2005, 8, 23)),
#  ('Wait Cider', 21, datetime.date(2005, 8, 23)),
#  ('Cause Date', 21, datetime.date(2005, 8, 23)),
#  ('Open African', 21, datetime.date(2005, 8, 23)),
#  ('Fidelity Devil', 21, datetime.date(2005, 8, 23)),
#  ('Splendor Patton', 21, datetime.date(2005, 8, 23)),
#  ('Chainsaw Uptown', 21, datetime.date(2005, 8, 23)),
#  ('Beverly Outlaw', 21, datetime.date(2005, 8, 23)),
#  ('Redemption Comforts', 20, datetime.date(2005, 8, 23)),
#  ('Northwest Polish', 20, datetime.date(2005, 8, 23)),
#  ('Heartbreakers Bright', 20, datetime.date(2005, 8, 23)),
#  ('Hellfighters Sierra', 20, datetime.date(2005, 8, 23)),
#  ('Reign Gentlemen', 20, datetime.date(2005, 8, 23)),
#  ('Jet Neighbors', 20, datetime.date(2005, 8, 23)),
#  ('Love Suicides', 20, datetime.date(2005, 8, 23)),
#  ('Reunion Witches', 20, datetime.date(2005, 8, 23)),
#  ('Kissing Dolls', 20, datetime.date(2005, 8, 23)),
#  ('Wrong Behavior', 20, datetime.date(2005, 8, 23)),
#  ('Dinosaur Secretary', 20, datetime.date(2005, 8, 23)),
#  ('Pinocchio Simon', 20, datetime.date(2005, 8, 23)),
#  ('Quest Mussolini', 20, datetime.date(2005, 8, 23)),
#  ('Masked Bubble', 20, datetime.date(2005, 8, 23)),
#  ('Million Ace', 20, datetime.date(2005, 8, 23)),
#  ('Go Purple', 20, datetime.date(2005, 8, 23)),
#  ('Harper Dying', 20, datetime.date(2005, 8, 23)),
#  ('Jerk Paycheck', 20, datetime.date(2005, 8, 23)),
#  ('Spice Sorority', 20, datetime.date(2005, 8, 23)),
#  ('Peak Forever', 20, datetime.date(2005, 8, 23)),
#  ('Bringing Hysterical', 20, datetime.date(2005, 8, 23)),
#  ('Garden Island', 20, datetime.date(2005, 8, 23)),
#  ('Patient Sister', 19, datetime.date(2005, 8, 23)),
#  ('Honey Ties', 19, datetime.date(2005, 8, 23)),
#  ('Rage Games', 19, datetime.date(2005, 8, 23)),
#  ('Bill Others', 19, datetime.date(2005, 8, 23)),
#  ('Cider Desire', 19, datetime.date(2005, 8, 23)),
#  ('Backlash Undefeated', 19, datetime.date(2005, 8, 23)),
#  ('Voice Peach', 19, datetime.date(2005, 8, 23)),
#  ('Road Roxanne', 19, datetime.date(2005, 8, 23)),
#  ('Fiction Christmas', 19, datetime.date(2005, 8, 23)),
#  ('Bride Intrigue', 19, datetime.date(2005, 8, 23)),
#  ('Requiem Tycoon', 19, datetime.date(2005, 8, 23)),
#  ('Music Boondock', 19, datetime.date(2005, 8, 23)),
#  ('Earring Instinct', 19, datetime.date(2005, 8, 23)),
#  ('Mine Titans', 19, datetime.date(2005, 8, 23)),
#  ('Desert Poseidon', 19, datetime.date(2005, 8, 23)),
#  ('Encounters Curtain', 19, datetime.date(2005, 8, 23)),
#  ('Roxanne Rebel', 19, datetime.date(2005, 8, 23)),
#  ('Fantasia Park', 19, datetime.date(2005, 8, 23)),
#  ('National Story', 19, datetime.date(2005, 8, 23)),
#  ('Wonka Sea', 18, datetime.date(2005, 8, 23)),
#  ('Lion Uncut', 18, datetime.date(2005, 8, 23)),
#  ('Darn Forrester', 18, datetime.date(2005, 8, 23)),
#  ('Remember Diary', 18, datetime.date(2005, 8, 23)),
#  ('Dawn Pond', 18, datetime.date(2005, 8, 23)),
#  ('Whale Bikini', 18, datetime.date(2005, 8, 23)),
#  ('Birds Perdition', 18, datetime.date(2005, 8, 23)),
#  ('Rouge Squad', 18, datetime.date(2005, 8, 23)),
#  ('Forrest Sons', 18, datetime.date(2005, 8, 23)),
#  ('Inch Jet', 18, datetime.date(2005, 8, 23)),
#  ('Airport Pollock', 18, datetime.date(2005, 8, 23)),
#  ('Polish Brooklyn', 18, datetime.date(2005, 8, 23)),
#  ('Carol Texas', 18, datetime.date(2005, 8, 23)),
#  ('Heaven Freedom', 18, datetime.date(2005, 8, 23)),
#  ('Barefoot Manchurian', 18, datetime.date(2005, 8, 23)),
#  ('Jade Bunch', 18, datetime.date(2005, 8, 23)),
#  ('Instinct Airport', 18, datetime.date(2005, 8, 23)),
#  ('Core Suit', 18, datetime.date(2005, 8, 23)),
#  ('Racer Egg', 18, datetime.date(2005, 8, 23)),
#  ('Orient Closer', 17, datetime.date(2005, 8, 23)),
#  ('Slacker Liaisons', 17, datetime.date(2005, 8, 23)),
#  ('Roots Remember', 17, datetime.date(2005, 8, 23)),
#  ('Strangers Graffiti', 17, datetime.date(2005, 8, 23)),
#  ('Rock Instinct', 17, datetime.date(2005, 8, 23)),
#  ('Jericho Mulan', 17, datetime.date(2005, 8, 23)),
#  ('Sugar Wonka', 17, datetime.date(2005, 8, 23)),
#  ('Poseidon Forever', 17, datetime.date(2005, 8, 23)),
#  ('Perfect Groove', 17, datetime.date(2005, 8, 23)),
#  ('Joon Northwest', 17, datetime.date(2005, 8, 23)),
#  ('Louisiana Harry', 17, datetime.date(2005, 8, 23)),
#  ('Breakfast Goldfinger', 17, datetime.date(2005, 8, 23)),
#  ('Beach Heartbreakers', 17, datetime.date(2005, 8, 23)),
#  ('Zoolander Fiction', 17, datetime.date(2005, 8, 23)),
#  ('Jekyll Frogmen', 17, datetime.date(2005, 8, 23)),
#  ('Gaslight Crusade', 16, datetime.date(2005, 8, 23)),
#  ('Casablanca Super', 16, datetime.date(2005, 8, 23)),
#  ('Dude Blindness', 16, datetime.date(2005, 8, 23)),
#  ('Jeepers Wedding', 16, datetime.date(2005, 8, 23)),
#  ('Lock Rear', 16, datetime.date(2005, 8, 23)),
#  ('Reap Unfaithful', 16, datetime.date(2005, 8, 23)),
#  ('Paycheck Wait', 16, datetime.date(2005, 8, 23)),
#  ('Attacks Hate', 16, datetime.date(2005, 8, 23)),
#  ('Indian Love', 16, datetime.date(2005, 8, 23)),
#  ('Uprising Uptown', 16, datetime.date(2005, 8, 23)),
#  ('Wizard Coldblooded', 16, datetime.date(2005, 8, 23)),
#  ('Worst Banger', 16, datetime.date(2005, 8, 23)),
#  ('Sagebrush Clueless', 16, datetime.date(2005, 8, 23)),
#  ('Coldblooded Darling', 16, datetime.date(2005, 8, 23)),
#  ('Hall Cassidy', 16, datetime.date(2005, 8, 23)),
#  ('Caddyshack Jedi', 16, datetime.date(2005, 8, 23)),
#  ('Quills Bull', 16, datetime.date(2005, 8, 23)),
#  ('Willow Tracy', 16, datetime.date(2005, 8, 23)),
#  ('Circus Youth', 15, datetime.date(2005, 8, 23)),
#  ('Rings Heartbreakers', 15, datetime.date(2005, 8, 23)),
#  ('Hunting Musketeers', 15, datetime.date(2005, 8, 23)),
#  ('Siege Madre', 15, datetime.date(2005, 8, 23)),
#  ('Edge Kissing', 15, datetime.date(2005, 8, 23)),
#  ('Odds Boogie', 15, datetime.date(2005, 8, 23)),
#  ('Manchurian Curtain', 15, datetime.date(2005, 8, 23)),
#  ('Holiday Games', 15, datetime.date(2005, 8, 23)),
#  ('Sierra Divide', 15, datetime.date(2005, 8, 23)),
#  ('Entrapment Satisfaction', 15, datetime.date(2005, 8, 23)),
#  ('Sweet Brotherhood', 15, datetime.date(2005, 8, 23)),
#  ('Modern Dorado', 15, datetime.date(2005, 8, 23)),
#  ('Illusion Amelie', 15, datetime.date(2005, 8, 23)),
#  ('Loser Hustler', 15, datetime.date(2005, 8, 23)),
#  ('Charade Duffel', 15, datetime.date(2005, 8, 23)),
#  ('Necklace Outbreak', 15, datetime.date(2005, 8, 23)),
#  ('Greedy Roots', 14, datetime.date(2005, 8, 23)),
#  ('Stock Glass', 14, datetime.date(2005, 8, 23)),
#  ('Troopers Metal', 14, datetime.date(2005, 8, 23)),
#  ('Blindness Gun', 14, datetime.date(2005, 8, 23)),
#  ('Virtual Spoilers', 14, datetime.date(2005, 8, 23)),
#  ('Werewolf Lola', 14, datetime.date(2005, 8, 23)),
#  ('Madre Gables', 14, datetime.date(2005, 8, 23)),
#  ('Saddle Antitrust', 14, datetime.date(2005, 8, 23)),
#  ('Uncut Suicides', 14, datetime.date(2005, 8, 23)),
#  ('Mother Oleander', 14, datetime.date(2005, 8, 23)),
#  ('Image Princess', 14, datetime.date(2005, 8, 23)),
#  ('Nemo Campus', 14, datetime.date(2005, 8, 23)),
#  ('Games Bowfinger', 14, datetime.date(2005, 8, 23)),
#  ('Paris Weekend', 14, datetime.date(2005, 8, 23)),
#  ('Creepers Kane', 14, datetime.date(2005, 8, 23)),
#  ('Stampede Disturbing', 14, datetime.date(2005, 8, 23)),
#  ('Shrunk Divine', 14, datetime.date(2005, 8, 23)),
#  ('Glass Dying', 14, datetime.date(2005, 8, 23)),
#  ('Forever Candidate', 13, datetime.date(2005, 8, 23)),
#  ('Natural Stock', 13, datetime.date(2005, 8, 23)),
#  ('Spinal Rocky', 13, datetime.date(2005, 8, 23)),
#  ('Lucky Flying', 13, datetime.date(2005, 8, 23)),
#  ('Wyoming Storm', 13, datetime.date(2005, 8, 23)),
#  ('Flash Wars', 13, datetime.date(2005, 8, 23)),
#  ('Raging Airplane', 13, datetime.date(2005, 8, 23)),
#  ('Usual Untouchables', 13, datetime.date(2005, 8, 23)),
#  ('Bilko Anonymous', 13, datetime.date(2005, 8, 23)),
#  ('Bedazzled Married', 13, datetime.date(2005, 8, 23)),
#  ('Express Lonely', 13, datetime.date(2005, 8, 23)),
#  ('Everyone Craft', 13, datetime.date(2005, 8, 23)),
#  ('Jingle Sagebrush', 13, datetime.date(2005, 8, 23)),
#  ('Lawrence Love', 13, datetime.date(2005, 8, 23)),
#  ('Microcosmos Paradise', 13, datetime.date(2005, 8, 23)),
#  ('Hook Chariots', 13, datetime.date(2005, 8, 23)),
#  ('Saturn Name', 13, datetime.date(2005, 8, 23)),
#  ('Citizen Shrek', 13, datetime.date(2005, 8, 23)),
#  ('Purple Movie', 13, datetime.date(2005, 8, 23)),
#  ('Champion Flatliners', 13, datetime.date(2005, 8, 23)),
#  ('Party Knock', 13, datetime.date(2005, 8, 23)),
#  ('Mighty Luck', 12, datetime.date(2005, 8, 23)),
#  ('Brannigan Sunrise', 12, datetime.date(2005, 8, 23)),
#  ('War Notting', 12, datetime.date(2005, 8, 23)),
#  ('Meet Chocolate', 12, datetime.date(2005, 8, 23)),
#  ('Dangerous Uptown', 12, datetime.date(2005, 8, 23)),
#  ('Crow Grease', 12, datetime.date(2005, 8, 23)),
#  ('Side Ark', 12, datetime.date(2005, 8, 23)),
#  ('Born Spinal', 12, datetime.date(2005, 8, 23)),
#  ('Gunfighter Mussolini', 12, datetime.date(2005, 8, 23)),
#  ('Temple Attraction', 12, datetime.date(2005, 8, 23)),
#  ('Alabama Devil', 12, datetime.date(2005, 8, 23)),
#  ('Tycoon Gathering', 12, datetime.date(2005, 8, 23)),
#  ('Liberty Magnificent', 12, datetime.date(2005, 8, 23)),
#  ('Hedwig Alter', 12, datetime.date(2005, 8, 23)),
#  ('Adaptation Holes', 12, datetime.date(2005, 8, 23)),
#  ('California Birds', 12, datetime.date(2005, 8, 23)),
#  ('Mob Duffel', 12, datetime.date(2005, 8, 23)),
#  ('Bird Independence', 11, datetime.date(2005, 8, 23)),
#  ('Potluck Mixed', 11, datetime.date(2005, 8, 23)),
#  ('Santa Paris', 11, datetime.date(2005, 8, 23)),
#  ('Ties Hunger', 11, datetime.date(2005, 8, 23)),
#  ('Spirited Casualties', 11, datetime.date(2005, 8, 23)),
#  ('Darko Dorado', 11, datetime.date(2005, 8, 23)),
#  ('Fugitive Maguire', 11, datetime.date(2005, 8, 23)),
#  ('Birch Antitrust', 11, datetime.date(2005, 8, 23)),
#  ('October Submarine', 11, datetime.date(2005, 8, 23)),
#  ('Dragon Squad', 11, datetime.date(2005, 8, 23)),
#  ('North Tequila', 11, datetime.date(2005, 8, 23)),
#  ('Iron Moon', 11, datetime.date(2005, 8, 23)),
#  ('Trainspotting Strangers', 11, datetime.date(2005, 8, 23)),
#  ('Twisted Pirates', 11, datetime.date(2005, 8, 23)),
#  ('Rollercoaster Bringing', 10, datetime.date(2005, 8, 23)),
#  ('Life Twisted', 10, datetime.date(2005, 8, 23)),
#  ('Maker Gables', 10, datetime.date(2005, 8, 23)),
#  ('Reservoir Adaptation', 10, datetime.date(2005, 8, 23)),
#  ('Halloween Nuts', 10, datetime.date(2005, 8, 23)),
#  ('Spoilers Hellfighters', 10, datetime.date(2005, 8, 23)),
#  ('Amelie Hellfighters', 10, datetime.date(2005, 8, 23)),
#  ('Clockwork Paradise', 10, datetime.date(2005, 8, 23)),
#  ('Mystic Truman', 10, datetime.date(2005, 8, 23)),
#  ('Paths Control', 10, datetime.date(2005, 8, 23)),
#  ('Madigan Dorado', 10, datetime.date(2005, 8, 23)),
#  ('Lolita World', 10, datetime.date(2005, 8, 23)),
#  ('Element Freddy', 10, datetime.date(2005, 8, 23)),
#  ('Fiddler Lost', 10, datetime.date(2005, 8, 23)),
#  ('Reds Pocus', 9, datetime.date(2005, 8, 23)),
#  ('Gilbert Pelican', 9, datetime.date(2005, 8, 23)),
#  ('Caribbean Liberty', 9, datetime.date(2005, 8, 23)),
#  ('Snatchers Montezuma', 9, datetime.date(2005, 8, 23)),
#  ('Daughter Madigan', 9, datetime.date(2005, 8, 23)),
#  ('Montezuma Command', 9, datetime.date(2005, 8, 23)),
#  ('Ghostbusters Elf', 9, datetime.date(2005, 8, 23)),
#  ('Nuts Ties', 9, datetime.date(2005, 8, 23)),
#  ('Won Dares', 9, datetime.date(2005, 8, 23)),
#  ('Records Zorro', 8, datetime.date(2005, 8, 23)),
#  ('Shining Roses', 8, datetime.date(2005, 8, 23)),
#  ('Clyde Theory', 8, datetime.date(2005, 8, 23)),
#  ('Sunset Racer', 8, datetime.date(2005, 8, 23)),
#  ('Vertigo Northwest', 8, datetime.date(2005, 8, 23)),
#  ('Saints Bride', 8, datetime.date(2005, 8, 23)),
#  ('Rebel Airport', 8, datetime.date(2005, 8, 23)),
#  ('Crusade Honey', 8, datetime.date(2005, 8, 23)),
#  ('Newsies Story', 7, datetime.date(2005, 8, 23)),
#  ('Squad Fish', 7, datetime.date(2005, 8, 23)),
#  ('Stallion Sundance', 7, datetime.date(2005, 8, 23)),
#  ('Cruelty Unforgiven', 7, datetime.date(2005, 8, 23)),
#  ('Lesson Cleopatra', 7, datetime.date(2005, 8, 23)),
#  ('Menagerie Rushmore', 7, datetime.date(2005, 8, 23)),
#  ('Sense Greek', 7, datetime.date(2005, 8, 23)),
#  ('Young Language', 7, datetime.date(2005, 8, 23)),
#  ('Comancheros Enemy', 6, datetime.date(2005, 8, 23)),
#  ('Cassidy Wyoming', 6, datetime.date(2005, 8, 23)),
#  ('Japanese Run', 6, datetime.date(2005, 8, 23)),
#  ('Apocalypse Flamingos', 6, datetime.date(2005, 8, 23)),
#  ('Italian African', 6, datetime.date(2005, 8, 23)),
#  ('Simon North', 6, datetime.date(2005, 8, 23)),
#  ('Dumbo Lust', 6, datetime.date(2005, 8, 23)),
#  ('Duck Racer', 6, datetime.date(2005, 8, 23)),
#  ('Oklahoma Jumanji', 6, datetime.date(2005, 8, 23)),
#  ('Extraordinary Conquerer', 6, datetime.date(2005, 8, 23)),
#  ('Glory Tracy', 5, datetime.date(2005, 8, 23)),
#  ('Seven Swarm', 5, datetime.date(2005, 8, 23)),
#  ('Hunter Alter', 5, datetime.date(2005, 8, 23)),
#  ('Train Bunch', 4, datetime.date(2005, 8, 23)),
#  ('Ridgemont Submarine', 32, datetime.date(2006, 2, 14)),
#  ('Juggler Hardly', 32, datetime.date(2006, 2, 14)),
#  ('Cat Coneheads', 30, datetime.date(2006, 2, 14)),
#  ('Frost Head', 30, datetime.date(2006, 2, 14)),
#  ('Harry Idaho', 30, datetime.date(2006, 2, 14)),
#  ('Suspects Quills', 30, datetime.date(2006, 2, 14)),
#  ('Shock Cabin', 30, datetime.date(2006, 2, 14)),
#  ('Pulp Beverly', 30, datetime.date(2006, 2, 14)),
#  ('Family Sweet', 29, datetime.date(2006, 2, 14)),
#  ('Virginian Pluto', 29, datetime.date(2006, 2, 14)),
#  ('Boogie Amelie', 29, datetime.date(2006, 2, 14)),
#  ('Titans Jerk', 29, datetime.date(2006, 2, 14)),
#  ('Gleaming Jawbreaker', 29, datetime.date(2006, 2, 14)),
#  ('Sweethearts Suspects', 29, datetime.date(2006, 2, 14)),
#  ('Deer Virginian', 29, datetime.date(2006, 2, 14)),
#  ('Curtain Videotape', 27, datetime.date(2006, 2, 14)),
#  ('None Spiking', 27, datetime.date(2006, 2, 14)),
#  ('Camelot Vacation', 27, datetime.date(2006, 2, 14)),
#  ('Detective Vision', 27, datetime.date(2006, 2, 14)),
#  ('Movie Shakespeare', 27, datetime.date(2006, 2, 14)),
#  ('Forrester Comancheros', 27, datetime.date(2006, 2, 14)),
#  ('Torque Bound', 27, datetime.date(2006, 2, 14)),
#  ('Swarm Gold', 27, datetime.date(2006, 2, 14)),
#  ('Operation Operation', 27, datetime.date(2006, 2, 14)),
#  ('Loathing Legally', 27, datetime.date(2006, 2, 14)),
#  ('Princess Giant', 27, datetime.date(2006, 2, 14)),
#  ('Seabiscuit Punk', 26, datetime.date(2006, 2, 14)),
#  ('Hyde Doctor', 26, datetime.date(2006, 2, 14)),
#  ('Half Outfield', 26, datetime.date(2006, 2, 14)),
#  ('Trading Pinocchio', 25, datetime.date(2006, 2, 14)),
#  ('Effect Gladiator', 25, datetime.date(2006, 2, 14)),
#  ('Bound Cheaper', 24, datetime.date(2006, 2, 14)),
#  ('Wedding Apollo', 24, datetime.date(2006, 2, 14)),
#  ('Jason Trap', 24, datetime.date(2006, 2, 14)),
#  ('Mockingbird Hollywood', 24, datetime.date(2006, 2, 14)),
#  ('Seattle Expecations', 24, datetime.date(2006, 2, 14)),
#  ('Sleeping Suspects', 24, datetime.date(2006, 2, 14)),
#  ('Gunfight Moon', 24, datetime.date(2006, 2, 14)),
#  ('Center Dinosaur', 24, datetime.date(2006, 2, 14)),
#  ('Drifter Commandments', 24, datetime.date(2006, 2, 14)),
#  ('Crooked Frogmen', 23, datetime.date(2006, 2, 14)),
#  ('Women Dorado', 23, datetime.date(2006, 2, 14)),
#  ('Earth Vision', 23, datetime.date(2006, 2, 14)),
#  ('Affair Prejudice', 23, datetime.date(2006, 2, 14)),
#  ('Titanic Boondock', 23, datetime.date(2006, 2, 14)),
#  ('Name Detective', 23, datetime.date(2006, 2, 14)),
#  ('Trouble Date', 23, datetime.date(2006, 2, 14)),
#  ('Philadelphia Wife', 23, datetime.date(2006, 2, 14)),
#  ('South Wait', 22, datetime.date(2006, 2, 14)),
#  ('Falcon Volume', 22, datetime.date(2006, 2, 14)),
#  ('Eagles Panky', 22, datetime.date(2006, 2, 14)),
#  ('Grapes Fury', 22, datetime.date(2006, 2, 14)),
#  ('American Circus', 22, datetime.date(2006, 2, 14)),
#  ('Volcano Texas', 22, datetime.date(2006, 2, 14)),
#  ('Fight Jawbreaker', 22, datetime.date(2006, 2, 14)),
#  ('Blade Polish', 22, datetime.date(2006, 2, 14)),
#  ('Queen Luke', 22, datetime.date(2006, 2, 14)),
#  ('Ghost Groundhog', 21, datetime.date(2006, 2, 14)),
#  ('Pirates Roxanne', 21, datetime.date(2006, 2, 14)),
#  ('Amadeus Holy', 21, datetime.date(2006, 2, 14)),
#  ('Berets Agent', 21, datetime.date(2006, 2, 14)),
#  ('Star Operation', 21, datetime.date(2006, 2, 14)),
#  ('Basic Easy', 21, datetime.date(2006, 2, 14)),
#  ('Sleepy Japanese', 21, datetime.date(2006, 2, 14)),
#  ('Amistad Midsummer', 21, datetime.date(2006, 2, 14)),
#  ('Pianist Outfield', 21, datetime.date(2006, 2, 14)),
#  ('Armageddon Lost', 21, datetime.date(2006, 2, 14)),
#  ('Suit Walls', 21, datetime.date(2006, 2, 14)),
#  ('Intrigue Worst', 20, datetime.date(2006, 2, 14)),
#  ('River Outlaw', 20, datetime.date(2006, 2, 14)),
#  ('Insider Arizona', 20, datetime.date(2006, 2, 14)),
#  ('Outfield Massacre', 20, datetime.date(2006, 2, 14)),
#  ('Sleepless Monsoon', 20, datetime.date(2006, 2, 14)),
#  ('Hunchback Impossible', 20, datetime.date(2006, 2, 14)),
#  ('Flying Hook', 20, datetime.date(2006, 2, 14)),
#  ('Chasing Fight', 20, datetime.date(2006, 2, 14)),
#  ('Kick Savannah', 20, datetime.date(2006, 2, 14)),
#  ('Trojan Tomorrow', 19, datetime.date(2006, 2, 14)),
#  ('Doors President', 19, datetime.date(2006, 2, 14)),
#  ('Canyon Stock', 19, datetime.date(2006, 2, 14)),
#  ('Details Packer', 19, datetime.date(2006, 2, 14)),
#  ('Encino Elf', 19, datetime.date(2006, 2, 14)),
#  ('Disciple Mother', 19, datetime.date(2006, 2, 14)),
#  ('Club Graffiti', 19, datetime.date(2006, 2, 14)),
#  ('Shawshank Bubble', 19, datetime.date(2006, 2, 14)),
#  ('Gables Metropolis', 19, datetime.date(2006, 2, 14)),
#  ('Gorgeous Bingo', 19, datetime.date(2006, 2, 14)),
#  ('Sundance Invasion', 19, datetime.date(2006, 2, 14)),
#  ('Igby Maker', 19, datetime.date(2006, 2, 14)),
#  ('Sweden Shining', 18, datetime.date(2006, 2, 14)),
#  ('Alone Trip', 18, datetime.date(2006, 2, 14)),
#  ('Pollock Deliverance', 18, datetime.date(2006, 2, 14)),
#  ('Vanishing Rocky', 18, datetime.date(2006, 2, 14)),
#  ('Groundhog Uncut', 18, datetime.date(2006, 2, 14)),
#  ('Cleopatra Devil', 18, datetime.date(2006, 2, 14)),
#  ('Scarface Bang', 18, datetime.date(2006, 2, 14)),
#  ('Smoking Barbarella', 18, datetime.date(2006, 2, 14)),
#  ('Boulevard Mob', 18, datetime.date(2006, 2, 14)),
#  ('Dragonfly Strangers', 18, datetime.date(2006, 2, 14)),
#  ('Candidate Perdition', 18, datetime.date(2006, 2, 14)),
#  ('Insects Stone', 18, datetime.date(2006, 2, 14)),
#  ('Enough Raging', 18, datetime.date(2006, 2, 14)),
#  ('Driver Annie', 18, datetime.date(2006, 2, 14)),
#  ('Intentions Empire', 17, datetime.date(2006, 2, 14)),
#  ('Conversation Downhill', 17, datetime.date(2006, 2, 14)),
#  ('Lawless Vision', 17, datetime.date(2006, 2, 14)),
#  ('Midnight Westward', 17, datetime.date(2006, 2, 14)),
#  ('Lady Stage', 17, datetime.date(2006, 2, 14)),
#  ('Streak Ridgemont', 16, datetime.date(2006, 2, 14)),
#  ('Varsity Trip', 16, datetime.date(2006, 2, 14)),
#  ('Summer Scarface', 16, datetime.date(2006, 2, 14)),
#  ('Bull Shawshank', 16, datetime.date(2006, 2, 14)),
#  ('Pride Alamo', 16, datetime.date(2006, 2, 14)),
#  ('Motions Details', 16, datetime.date(2006, 2, 14)),
#  ('Baked Cleopatra', 16, datetime.date(2006, 2, 14)),
#  ('Pure Runner', 16, datetime.date(2006, 2, 14)),
#  ('Mummy Creatures', 16, datetime.date(2006, 2, 14)),
#  ('Creatures Shakespeare', 16, datetime.date(2006, 2, 14)),
#  ('Wanda Chamber', 16, datetime.date(2006, 2, 14)),
#  ('Devil Desire', 15, datetime.date(2006, 2, 14)),
#  ('Holes Brannigan', 15, datetime.date(2006, 2, 14)),
#  ('Mosquito Armageddon', 15, datetime.date(2006, 2, 14)),
#  ('Divine Resurrection', 15, datetime.date(2006, 2, 14)),
#  ('Cyclone Family', 15, datetime.date(2006, 2, 14)),
#  ('Lust Lock', 15, datetime.date(2006, 2, 14)),
#  ('Shrek License', 15, datetime.date(2006, 2, 14)),
#  ('Sons Interview', 15, datetime.date(2006, 2, 14)),
#  ('Monster Spartacus', 15, datetime.date(2006, 2, 14)),
#  ('Outlaw Hanky', 14, datetime.date(2006, 2, 14)),
#  ('Peach Innocent', 14, datetime.date(2006, 2, 14)),
#  ('Lovely Jingle', 14, datetime.date(2006, 2, 14)),
#  ('Dances None', 14, datetime.date(2006, 2, 14)),
#  ('Deep Crusade', 14, datetime.date(2006, 2, 14)),
#  ('Day Unfaithful', 14, datetime.date(2006, 2, 14)),
#  ('Moonwalker Fool', 13, datetime.date(2006, 2, 14)),
#  ('Opposite Necklace', 13, datetime.date(2006, 2, 14)),
#  ('Tuxedo Mile', 13, datetime.date(2006, 2, 14)),
#  ('State Wasteland', 13, datetime.date(2006, 2, 14)),
#  ('Chamber Italian', 13, datetime.date(2006, 2, 14)),
#  ('Cincinatti Whisperer', 13, datetime.date(2006, 2, 14)),
#  ('Mulan Moon', 13, datetime.date(2006, 2, 14)),
#  ('Hunger Roof', 13, datetime.date(2006, 2, 14)),
#  ('African Egg', 12, datetime.date(2006, 2, 14)),
#  ('Window Side', 12, datetime.date(2006, 2, 14)),
#  ('Blanket Beverly', 12, datetime.date(2006, 2, 14)),
#  ('Silverado Goldfinger', 12, datetime.date(2006, 2, 14)),
#  ('Smoochy Control', 12, datetime.date(2006, 2, 14)),
#  ('Minority Kiss', 12, datetime.date(2006, 2, 14)),
#  ('Lord Arizona', 11, datetime.date(2006, 2, 14)),
#  ('Frida Slipper', 11, datetime.date(2006, 2, 14)),
#  ('Song Hedwig', 11, datetime.date(2006, 2, 14)),
#  ('Theory Mermaid', 11, datetime.date(2006, 2, 14)),
#  ('Grail Frankenstein', 10, datetime.date(2006, 2, 14)),
#  ('Ali Forever', 9, datetime.date(2006, 2, 14)),
#  ('Frisco Forrest', 9, datetime.date(2006, 2, 14)),
#  ('Zhivago Core', 9, datetime.date(2006, 2, 14)),
#  ('Dwarfs Alter', 9, datetime.date(2006, 2, 14)),
#  ('Chitty Lock', 8, datetime.date(2006, 2, 14)),
#  ('World Leathernecks', 8, datetime.date(2006, 2, 14)),
#  ('Mulholland Beast', 7, datetime.date(2006, 2, 14)),
#  ('Bang Kwai', 7, datetime.date(2006, 2, 14)),
#  ('Vanished Garden', 7, datetime.date(2006, 2, 14)),
#  ('Ace Goldfinger', 7, datetime.date(2006, 2, 14)),
#  ('Connection Microcosmos', 7, datetime.date(2006, 2, 14)),
#  ('Happiness United', 6, datetime.date(2006, 2, 14)),
#  ('Haunted Antitrust', 6, datetime.date(2006, 2, 14)),
#  ('Bubble Grosse', 6, datetime.date(2006, 2, 14)),
#  ('Wild Apollo', 6, datetime.date(2006, 2, 14))]

# %% [markdown]
# # Save your Notebook, then `File > Close and Halt`

# %% [markdown]
# ---
