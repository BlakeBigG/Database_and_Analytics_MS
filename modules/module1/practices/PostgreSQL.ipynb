# %% [markdown]
# # PostgreSQL and Query Practice

# %% [markdown]
# This practice uses the DVD Rental database.
#
# Below is the schema (tables and relationships).
# We will address database design and _Entity-Relationship Diagrams_ (ERD) later in the course.
# For now, know that the table names are in the blue heading of the bubbles and the attributes (columns) are listed below.
# After Module 2, we will begin to exploit the relationships among the tables.
#
# ![ERD MISSING](../images/PostgreSQL-Sample-Database.png)

# %%
# %load_ext sql
# %sql postgres://dsa_ro_user:readonly@pgsql.dsa.lan/dvdrental
# Out:
# 'Connected: dsa_ro_user@dvdrental'

# %% [markdown]
# <span style="background:yellow">The above cell should be run when you (re-)start working on the lab.</span>
#
# **NOTE:** After questions 2-8 are links to helpful hint videos in case you struggle on a question.
# Ultimately, you should be sure to look at the solutions that are posted in the `answers` folder for a particular day with the next course day's content release.
#
# # 1
#
# ### Select all the data from the language table.
#
# **HINT** use `SELECT` and the `%sql` or `%%sql` notebook extension.

# %%
# %%sql SELECT *
# FROM language
# Out:
#  * postgres://dsa_ro_user:***@pgsql.dsa.lan/dvdrental
# 6 rows affected.
# [(1, 'English             ', datetime.datetime(2006, 2, 15, 10, 2, 19)),
#  (2, 'Italian             ', datetime.datetime(2006, 2, 15, 10, 2, 19)),
#  (3, 'Japanese            ', datetime.datetime(2006, 2, 15, 10, 2, 19)),
#  (4, 'Mandarin            ', datetime.datetime(2006, 2, 15, 10, 2, 19)),
#  (5, 'French              ', datetime.datetime(2006, 2, 15, 10, 2, 19)),
#  (6, 'German              ', datetime.datetime(2006, 2, 15, 10, 2, 19))]

# %% [markdown]
# [Helpful Hints](https://youtu.be/UR15jpl5EK8)
#
# ---
#
# # 2
#
# ### List all the actors who are named a variation of the name John.

# %%
# %%sql SELECT first_name, last_name
# FROM actor
# WHERE first_name LIKE 'John%';
# Out:
#  * postgres://dsa_ro_user:***@pgsql.dsa.lan/dvdrental
# 3 rows affected.
# [('Johnny', 'Lollobrigida'), ('Johnny', 'Cage'), ('John', 'Suvari')]

# %% [markdown]
# [Helpful Hints](https://youtu.be/3NeWY8WHSGU)
#
# ---
#
# # 3
#
#
# ### In a single query, list the `film_id` and `title` of films with a rental duration less than four days and the films with duration greater than six days.

# %%
# %%sql SELECT film_id, title
# FROM film
# WHERE rental_duration < 4
#     OR rental_duration > 6;
# Out:
#  * postgres://dsa_ro_user:***@pgsql.dsa.lan/dvdrental
# 394 rows affected.
# [(133, 'Chamber Italian'),
#  (2, 'Ace Goldfinger'),
#  (3, 'Adaptation Holes'),
#  (6, 'Agent Truman'),
#  (9, 'Alabama Devil'),
#  (17, 'Alone Trip'),
#  (21, 'American Circus'),
#  (23, 'Anaconda Confessions'),
#  (25, 'Angels Life'),
#  (26, 'Annie Identity'),
#  (27, 'Anonymous Human'),
#  (36, 'Argonauts Town'),
#  (37, 'Arizona Bang'),
#  (46, 'Autumn Crow'),
#  (48, 'Backlash Undefeated'),
#  (50, 'Baked Cleopatra'),
#  (126, 'Casualties Encino'),
#  (60, 'Beast Hunchback'),
#  (65, 'Behavior Runaway'),
#  (69, 'Beverly Outlaw'),
#  (70, 'Bikini Borrowers'),
#  (71, 'Bilko Anonymous'),
#  (78, 'Blackout Private'),
#  (80, 'Blanket Beverly'),
#  (82, 'Blood Argonauts'),
#  (84, 'Boiled Dares'),
#  (87, 'Boondock Ballroom'),
#  (88, 'Born Spinal'),
#  (89, 'Borrowers Bedazzled'),
#  (90, 'Boulevard Mob'),
#  (92, 'Bowfinger Gables'),
#  (94, 'Braveheart Human'),
#  (97, 'Bride Intrigue'),
#  (99, 'Bringing Hysterical'),
#  (100, 'Brooklyn Desert'),
#  (101, 'Brotherhood Blanket'),
#  (103, 'Bucket Brotherhood'),
#  (109, 'Butterfly Chocolat'),
#  (111, 'Caddyshack Jedi'),
#  (114, 'Camelot Vacation'),
#  (118, 'Canyon Stock'),
#  (120, 'Caribbean Liberty'),
#  (122, 'Carrie Bunch'),
#  (124, 'Casper Dragonfly'),
#  (128, 'Catch Amistad'),
#  (129, 'Cause Date'),
#  (130, 'Celebrity Horn'),
#  (135, 'Chance Resurrection'),
#  (136, 'Chaplin License'),
#  (137, 'Charade Duffel'),
#  (139, 'Chasing Fight'),
#  (142, 'Chicken Hellfighters'),
#  (144, 'Chinatown Gladiator'),
#  (148, 'Chocolate Duck'),
#  (149, 'Christmas Moonshine'),
#  (150, 'Cider Desire'),
#  (153, 'Citizen Shrek'),
#  (156, 'Clerks Angels'),
#  (157, 'Clockwork Paradise'),
#  (184, 'Core Suit'),
#  (165, 'Coldblooded Darling'),
#  (169, 'Comforts Rush'),
#  (172, 'Coneheads Smoochy'),
#  (173, 'Confessions Maguire'),
#  (175, 'Confused Candles'),
#  (181, 'Contact Anonymous'),
#  (182, 'Control Anthem'),
#  (185, 'Cowboy Doom'),
#  (188, 'Crazy Home'),
#  (189, 'Creatures Shakespeare'),
#  (195, 'Crowds Telemark'),
#  (196, 'Cruelty Unforgiven'),
#  (200, 'Curtain Videotape'),
#  (201, 'Cyclone Family'),
#  (205, 'Dances None'),
#  (207, 'Dangerous Uptown'),
#  (208, 'Dares Pluto'),
#  (210, 'Darko Dorado'),
#  (211, 'Darling Breaking'),
#  (212, 'Darn Forrester'),
#  (214, 'Daughter Madigan'),
#  (216, 'Day Unfaithful'),
#  (218, 'Deceiver Betrayed'),
#  (220, 'Deer Virginian'),
#  (223, 'Desire Alien'),
#  (224, 'Desperate Trainspotting'),
#  (225, 'Destination Jerk'),
#  (230, 'Diary Panic'),
#  (231, 'Dinosaur Secretary'),
#  (232, 'Dirty Ace'),
#  (233, 'Disciple Mother'),
#  (237, 'Divorce Shining'),
#  (240, 'Dolls Rage'),
#  (243, 'Doors President'),
#  (247, 'Downhill Enough'),
#  (249, 'Dracula Crystal'),
#  (257, 'Drumline Cyclone'),
#  (260, 'Dude Blindness'),
#  (269, 'Earring Instinct'),
#  (270, 'Earth Vision'),
#  (275, 'Egypt Tenenbaums'),
#  (279, 'Elizabeth Shane'),
#  (280, 'Empire Malkovich'),
#  (285, 'English Bulworth'),
#  (286, 'Enough Raging'),
#  (288, 'Escape Metropolis'),
#  (292, 'Excitement Eve'),
#  (295, 'Expendable Stallion'),
#  (304, 'Fargo Gandhi'),
#  (306, 'Feathers Metal'),
#  (308, 'Ferris Mother'),
#  (314, 'Fight Jawbreaker'),
#  (318, 'Firehouse Vietnam'),
#  (321, 'Flash Wars'),
#  (323, 'Flight Lies'),
#  (324, 'Flintstones Happiness'),
#  (327, 'Fool Mockingbird'),
#  (328, 'Forever Candidate'),
#  (330, 'Forrester Comancheros'),
#  (332, 'Frankenstein Stranger'),
#  (333, 'Freaky Pocus'),
#  (342, 'Fugitive Maguire'),
#  (344, 'Fury Murder'),
#  (345, 'Gables Metropolis'),
#  (347, 'Games Bowfinger'),
#  (348, 'Gandhi Kwai'),
#  (350, 'Garden Island'),
#  (355, 'Ghostbusters Elf'),
#  (357, 'Gilbert Pelican'),
#  (362, 'Glory Tracy'),
#  (363, 'Go Purple'),
#  (364, 'Godfather Diary'),
#  (366, 'Goldfinger Sensibility'),
#  (368, 'Gone Trouble'),
#  (373, 'Graduate Lord'),
#  (374, 'Graffiti Love'),
#  (377, 'Grease Youth'),
#  (379, 'Greedy Roots'),
#  (380, 'Greek Everyone'),
#  (381, 'Grinch Massage'),
#  (382, 'Grit Clockwork'),
#  (386, 'Gump Date'),
#  (387, 'Gun Bonnie'),
#  (389, 'Gunfighter Mussolini'),
#  (394, 'Hamlet Wisdom'),
#  (400, 'Hardly Robbers'),
#  (402, 'Harper Dying'),
#  (409, 'Heartbreakers Bright'),
#  (410, 'Heaven Freedom'),
#  (413, 'Hedwig Alter'),
#  (414, 'Hellfighters Sierra'),
#  (415, 'High Encino'),
#  (420, 'Holes Brannigan'),
#  (421, 'Holiday Games'),
#  (422, 'Hollow Jeopardy'),
#  (423, 'Hollywood Anonymous'),
#  (426, 'Home Pity'),
#  (429, 'Honey Ties'),
#  (430, 'Hook Chariots'),
#  (431, 'Hoosiers Birdcage'),
#  (434, 'Horror Reign'),
#  (437, 'House Dynamite'),
#  (438, 'Human Graffiti'),
#  (444, 'Hustler Party'),
#  (448, 'Idaho Love'),
#  (451, 'Igby Maker'),
#  (453, 'Image Princess'),
#  (455, 'Impossible Prejudice'),
#  (460, 'Innocent Usual'),
#  (461, 'Insects Stone'),
#  (464, 'Intentions Empire'),
#  (469, 'Iron Moon'),
#  (471, 'Island Exorcist'),
#  (472, 'Italian African'),
#  (479, 'Jedi Beneath'),
#  (480, 'Jeepers Wedding'),
#  (482, 'Jeopardy Encino'),
#  (483, 'Jericho Mulan'),
#  (484, 'Jerk Paycheck'),
#  (486, 'Jet Neighbors'),
#  (488, 'Joon Northwest'),
#  (496, 'Kick Savannah'),
#  (498, 'Killer Innocent'),
#  (499, 'King Evolution'),
#  (501, 'Kissing Dolls'),
#  (503, 'Kramer Chocolate'),
#  (753, 'Rush Goodfellas'),
#  (511, 'Lawrence Love'),
#  (515, 'Legally Secretary'),
#  (516, 'Legend Jedi'),
#  (517, 'Lesson Cleopatra'),
#  (519, 'Liberty Magnificent'),
#  (520, 'License Weekend'),
#  (521, 'Lies Treatment'),
#  (523, 'Lights Deer'),
#  (526, 'Lock Rear'),
#  (529, 'Lonely Elephant'),
#  (531, 'Lose Inch'),
#  (536, 'Lovely Jingle'),
#  (537, 'Lover Truman'),
#  (538, 'Loverboy Attacks'),
#  (539, 'Luck Opus'),
#  (540, 'Lucky Flying'),
#  (542, 'Lust Lock'),
#  (546, 'Madre Gables'),
#  (547, 'Magic Mallrats'),
#  (548, 'Magnificent Chitty'),
#  (551, 'Maiden Home'),
#  (558, 'Mannequin Worst'),
#  (559, 'Married Go'),
#  (567, 'Meet Chocolate'),
#  (569, 'Menagerie Rushmore'),
#  (574, 'Midnight Westward'),
#  (575, 'Midsummer Groundhog'),
#  (576, 'Mighty Luck'),
#  (579, 'Minds Truman'),
#  (580, 'Mine Titans'),
#  (582, 'Miracle Virtual'),
#  (583, 'Mission Zoolander'),
#  (589, 'Modern Dorado'),
#  (590, 'Money Harold'),
#  (595, 'Moon Bunch'),
#  (599, 'Mother Oleander'),
#  (605, 'Mulholland Beast'),
#  (606, 'Mummy Creatures'),
#  (609, 'Muscle Bright'),
#  (610, 'Music Boondock'),
#  (611, 'Musketeers Wait'),
#  (618, 'Necklace Outbreak'),
#  (619, 'Neighbors Charade'),
#  (624, 'Nightmare Chill'),
#  (625, 'None Spiking'),
#  (629, 'Notorious Reunion'),
#  (630, 'Notting Speakeasy'),
#  (635, 'Oklahoma Jumanji'),
#  (637, 'Open African'),
#  (638, 'Operation Operation'),
#  (639, 'Opposite Necklace'),
#  (642, 'Order Betrayed'),
#  (643, 'Orient Closer'),
#  (644, 'Oscar Gold'),
#  (645, 'Others Soup'),
#  (648, 'Outlaw Hanky'),
#  (650, 'Pacific Amistad'),
#  (651, 'Packer Madigan'),
#  (652, 'Pajama Jawbreaker'),
#  (653, 'Panic Club'),
#  (656, 'Papi Necklace'),
#  (658, 'Paris Weekend'),
#  (659, 'Park Citizen'),
#  (660, 'Party Knock'),
#  (662, 'Paths Control'),
#  (663, 'Patient Sister'),
#  (667, 'Peach Innocent'),
#  (668, 'Peak Forever'),
#  (669, 'Pearl Destiny'),
#  (671, 'Perdition Fargo'),
#  (672, 'Perfect Groove'),
#  (673, 'Personal Ladybugs'),
#  (674, 'Pet Haunting'),
#  (676, 'Philadelphia Wife'),
#  (678, 'Pickup Driving'),
#  (690, 'Pond Seattle'),
#  (692, 'Potluck Mixed'),
#  (697, 'Primary Glass'),
#  (698, 'Princess Giant'),
#  (699, 'Private Drop'),
#  (704, 'Pure Runner'),
#  (709, 'Racer Egg'),
#  (713, 'Rainbow Shock'),
#  (715, 'Range Moonwalker'),
#  (718, 'Rebel Airport'),
#  (719, 'Records Zorro'),
#  (720, 'Redemption Comforts'),
#  (721, 'Reds Pocus'),
#  (723, 'Reign Gentlemen'),
#  (726, 'Reservoir Adaptation'),
#  (728, 'Reunion Witches'),
#  (730, 'Ridgemont Submarine'),
#  (731, 'Right Cranes'),
#  (735, 'Robbers Joon'),
#  (738, 'Rocketeer Mother'),
#  (741, 'Roman Punk'),
#  (742, 'Roof Champion'),
#  (743, 'Room Roman'),
#  (746, 'Rouge Squad'),
#  (750, 'Run Pacific'),
#  (756, 'Saddle Antitrust'),
#  (761, 'Santa Paris'),
#  (763, 'Satisfaction Confidential'),
#  (764, 'Saturday Lambs'),
#  (765, 'Saturn Name'),
#  (768, 'Scarface Bang'),
#  (771, 'Scorpion Apollo'),
#  (774, 'Searchers Wait'),
#  (778, 'Secrets Paradise'),
#  (780, 'Sensibility Rear'),
#  (784, 'Shanghai Tycoon'),
#  (786, 'Shepherd Midsummer'),
#  (789, 'Shock Cabin'),
#  (791, 'Show Lord'),
#  (792, 'Shrek License'),
#  (795, 'Siege Madre'),
#  (796, 'Sierra Divide'),
#  (797, 'Silence Kane'),
#  (799, 'Simon North'),
#  (800, 'Sinners Atlantis'),
#  (802, 'Sky Miracle'),
#  (803, 'Slacker Liaisons'),
#  (804, 'Sleeping Suspects'),
#  (812, 'Smoking Barbarella'),
#  (813, 'Smoochy Control'),
#  (816, 'Snowman Rollercoaster'),
#  (817, 'Soldiers Evolution'),
#  (819, 'Song Hedwig'),
#  (820, 'Sons Interview'),
#  (826, 'Speed Suit'),
#  (828, 'Spiking Element'),
#  (829, 'Spinal Rocky'),
#  (830, 'Spirit Flintstones'),
#  (836, 'Squad Fish'),
#  (845, 'Stepmom Dream'),
#  (846, 'Sting Personal'),
#  (847, 'Stock Glass'),
#  (848, 'Stone Fire'),
#  (850, 'Story Side'),
#  (851, 'Straight Hours'),
#  (853, 'Stranger Strangers'),
#  (855, 'Streak Ridgemont'),
#  (857, 'Strictly Scarface'),
#  (859, 'Sugar Wonka'),
#  (861, 'Suit Walls'),
#  (865, 'Sunrise League'),
#  (891, 'Timberland Sky'),
#  (872, 'Sweet Brotherhood'),
#  (873, 'Sweethearts Suspects'),
#  (876, 'Tarzan Videotape'),
#  (878, 'Teen Apollo'),
#  (879, 'Telegraph Voyage'),
#  (885, 'Texas Watch'),
#  (889, 'Ties Hunger'),
#  (892, 'Titanic Boondock'),
#  (895, 'Tomorrow Hustler'),
#  (896, 'Tootsie Pilot'),
#  (897, 'Torque Bound'),
#  (899, 'Towers Hurricane'),
#  (901, 'Tracy Cider'),
#  (904, 'Train Bunch'),
#  (905, 'Trainspotting Strangers'),
#  (908, 'Trap Guys'),
#  (909, 'Treasure Command'),
#  (910, 'Treatment Jekyll'),
#  (911, 'Trip Newton'),
#  (912, 'Trojan Tomorrow'),
#  (913, 'Troopers Metal'),
#  (915, 'Truman Crazy'),
#  (916, 'Turn Star'),
#  (917, 'Tuxedo Mile'),
#  (919, 'Tycoon Gathering'),
#  (920, 'Unbreakable Karate'),
#  (921, 'Uncut Suicides'),
#  (922, 'Undefeated Dalmations'),
#  (923, 'Unfaithful Kill'),
#  (924, 'Unforgiven Zoolander'),
#  (925, 'United Pilot'),
#  (931, 'Valentine Vanishing'),
#  (932, 'Valley Packer'),
#  (934, 'Vanilla Day'),
#  (936, 'Vanishing Rocky'),
#  (937, 'Varsity Trip'),
#  (938, 'Velvet Terminator'),
#  (942, 'Vietnam Smoochy'),
#  (946, 'Virtual Spoilers'),
#  (950, 'Volume House'),
#  (952, 'Wagon Jaws'),
#  (953, 'Wait Cider'),
#  (954, 'Wake Jaws'),
#  (955, 'Walls Artist'),
#  (956, 'Wanda Chamber'),
#  (957, 'War Notting'),
#  (961, 'Wash Heavenly'),
#  (962, 'Wasteland Divine'),
#  (966, 'Wedding Apollo'),
#  (970, 'Westward Seabiscuit'),
#  (973, 'Wife Turn'),
#  (977, 'Window Side'),
#  (978, 'Wisdom Worker'),
#  (981, 'Wolves Desire'),
#  (983, 'Won Dares'),
#  (984, 'Wonderful Drop'),
#  (987, 'Words Hunter'),
#  (988, 'Worker Tarzan'),
#  (990, 'World Leathernecks'),
#  (1000, 'Zorro Ark')]

# %% [markdown]
#
# [Helpful Hints](https://youtu.be/qhKW-DrI6FE)
#
# ---
#
# # 4
#
#
# ### Modify the query in Q3 to constrain the films less than 4 days to 0.99 `rental_rate` and the greater than 6 days to 2.99 `rental_rate`.

# %%
# %%sql SELECT film_id, title
# FROM film
# WHERE (rental_duration < 4
#        AND rental_rate = 0.99)
#     OR (rental_duration > 6
#         AND rental_rate = 2.99);
# Out:
#  * postgres://dsa_ro_user:***@pgsql.dsa.lan/dvdrental
# 148 rows affected.
# [(3, 'Adaptation Holes'),
#  (17, 'Alone Trip'),
#  (23, 'Anaconda Confessions'),
#  (26, 'Annie Identity'),
#  (78, 'Blackout Private'),
#  (80, 'Blanket Beverly'),
#  (82, 'Blood Argonauts'),
#  (90, 'Boulevard Mob'),
#  (94, 'Braveheart Human'),
#  (99, 'Bringing Hysterical'),
#  (101, 'Brotherhood Blanket'),
#  (109, 'Butterfly Chocolat'),
#  (111, 'Caddyshack Jedi'),
#  (114, 'Camelot Vacation'),
#  (136, 'Chaplin License'),
#  (142, 'Chicken Hellfighters'),
#  (150, 'Cider Desire'),
#  (181, 'Contact Anonymous'),
#  (188, 'Crazy Home'),
#  (189, 'Creatures Shakespeare'),
#  (201, 'Cyclone Family'),
#  (205, 'Dances None'),
#  (208, 'Dares Pluto'),
#  (220, 'Deer Virginian'),
#  (223, 'Desire Alien'),
#  (225, 'Destination Jerk'),
#  (230, 'Diary Panic'),
#  (231, 'Dinosaur Secretary'),
#  (232, 'Dirty Ace'),
#  (233, 'Disciple Mother'),
#  (240, 'Dolls Rage'),
#  (247, 'Downhill Enough'),
#  (257, 'Drumline Cyclone'),
#  (269, 'Earring Instinct'),
#  (275, 'Egypt Tenenbaums'),
#  (285, 'English Bulworth'),
#  (286, 'Enough Raging'),
#  (288, 'Escape Metropolis'),
#  (292, 'Excitement Eve'),
#  (295, 'Expendable Stallion'),
#  (306, 'Feathers Metal'),
#  (314, 'Fight Jawbreaker'),
#  (328, 'Forever Candidate'),
#  (333, 'Freaky Pocus'),
#  (344, 'Fury Murder'),
#  (345, 'Gables Metropolis'),
#  (362, 'Glory Tracy'),
#  (363, 'Go Purple'),
#  (366, 'Goldfinger Sensibility'),
#  (368, 'Gone Trouble'),
#  (373, 'Graduate Lord'),
#  (374, 'Graffiti Love'),
#  (380, 'Greek Everyone'),
#  (382, 'Grit Clockwork'),
#  (394, 'Hamlet Wisdom'),
#  (400, 'Hardly Robbers'),
#  (402, 'Harper Dying'),
#  (410, 'Heaven Freedom'),
#  (413, 'Hedwig Alter'),
#  (429, 'Honey Ties'),
#  (434, 'Horror Reign'),
#  (437, 'House Dynamite'),
#  (461, 'Insects Stone'),
#  (471, 'Island Exorcist'),
#  (482, 'Jeopardy Encino'),
#  (488, 'Joon Northwest'),
#  (496, 'Kick Savannah'),
#  (498, 'Killer Innocent'),
#  (753, 'Rush Goodfellas'),
#  (517, 'Lesson Cleopatra'),
#  (520, 'License Weekend'),
#  (526, 'Lock Rear'),
#  (531, 'Lose Inch'),
#  (539, 'Luck Opus'),
#  (540, 'Lucky Flying'),
#  (546, 'Madre Gables'),
#  (547, 'Magic Mallrats'),
#  (559, 'Married Go'),
#  (569, 'Menagerie Rushmore'),
#  (574, 'Midnight Westward'),
#  (576, 'Mighty Luck'),
#  (589, 'Modern Dorado'),
#  (599, 'Mother Oleander'),
#  (605, 'Mulholland Beast'),
#  (606, 'Mummy Creatures'),
#  (609, 'Muscle Bright'),
#  (618, 'Necklace Outbreak'),
#  (619, 'Neighbors Charade'),
#  (625, 'None Spiking'),
#  (638, 'Operation Operation'),
#  (642, 'Order Betrayed'),
#  (644, 'Oscar Gold'),
#  (645, 'Others Soup'),
#  (650, 'Pacific Amistad'),
#  (651, 'Packer Madigan'),
#  (652, 'Pajama Jawbreaker'),
#  (656, 'Papi Necklace'),
#  (658, 'Paris Weekend'),
#  (660, 'Party Knock'),
#  (672, 'Perfect Groove'),
#  (673, 'Personal Ladybugs'),
#  (674, 'Pet Haunting'),
#  (690, 'Pond Seattle'),
#  (709, 'Racer Egg'),
#  (726, 'Reservoir Adaptation'),
#  (728, 'Reunion Witches'),
#  (730, 'Ridgemont Submarine'),
#  (735, 'Robbers Joon'),
#  (738, 'Rocketeer Mother'),
#  (746, 'Rouge Squad'),
#  (750, 'Run Pacific'),
#  (756, 'Saddle Antitrust'),
#  (761, 'Santa Paris'),
#  (784, 'Shanghai Tycoon'),
#  (789, 'Shock Cabin'),
#  (792, 'Shrek License'),
#  (796, 'Sierra Divide'),
#  (799, 'Simon North'),
#  (800, 'Sinners Atlantis'),
#  (802, 'Sky Miracle'),
#  (816, 'Snowman Rollercoaster'),
#  (819, 'Song Hedwig'),
#  (828, 'Spiking Element'),
#  (829, 'Spinal Rocky'),
#  (847, 'Stock Glass'),
#  (848, 'Stone Fire'),
#  (851, 'Straight Hours'),
#  (891, 'Timberland Sky'),
#  (873, 'Sweethearts Suspects'),
#  (896, 'Tootsie Pilot'),
#  (901, 'Tracy Cider'),
#  (909, 'Treasure Command'),
#  (910, 'Treatment Jekyll'),
#  (913, 'Troopers Metal'),
#  (920, 'Unbreakable Karate'),
#  (921, 'Uncut Suicides'),
#  (923, 'Unfaithful Kill'),
#  (925, 'United Pilot'),
#  (932, 'Valley Packer'),
#  (937, 'Varsity Trip'),
#  (952, 'Wagon Jaws'),
#  (953, 'Wait Cider'),
#  (962, 'Wasteland Divine'),
#  (966, 'Wedding Apollo'),
#  (978, 'Wisdom Worker'),
#  (983, 'Won Dares'),
#  (988, 'Worker Tarzan'),
#  (990, 'World Leathernecks')]

# %% [markdown]
# [Helpful Hints](https://youtu.be/C-2ASERLE_Q)
#
# ---
#
# # 5
#
# ###  List the unique values for `rental_rate` from the `film` table.

# %%
# %%sql SELECT DISTINCT rental_rate
# FROM film;
# Out:
#  * postgres://dsa_ro_user:***@pgsql.dsa.lan/dvdrental
# 3 rows affected.
# [(Decimal('2.99'),), (Decimal('4.99'),), (Decimal('0.99'),)]

# %% [markdown]
# [Helpful Hints](https://youtu.be/xurTFkJ5S0g)
#
# ---
#
# # 6
#
#
# ###  List the `first_name` and `last_name` of actors whose last name start with the letter N, listed in reverse alphabetical order by last name

# %%
# %%sql SELECT first_name, last_name
# FROM actor
# WHERE last_name LIKE 'N%'
# ORDER BY last_name DESC;
# Out:
#  * postgres://dsa_ro_user:***@pgsql.dsa.lan/dvdrental
# 7 rows affected.
# [('Warren', 'Nolte'),
#  ('Salma', 'Nolte'),
#  ('Albert', 'Nolte'),
#  ('Jayne', 'Nolte'),
#  ('Bette', 'Nicholson'),
#  ('Christian', 'Neeson'),
#  ('Jayne', 'Neeson')]

# %% [markdown]
# [Helpful Hints](https://youtu.be/uK2I4mrnJQ8)
#
#
# ---
#
# # 7
#
# ### List the top 8 `payment`s that have been made, along with the payment dates.

# %%
# %%sql SELECT amount, payment_date
# FROM payment
# ORDER BY amount DESC
# LIMIT 8;
# Out:
#  * postgres://dsa_ro_user:***@pgsql.dsa.lan/dvdrental
# 8 rows affected.
# [(Decimal('11.99'), datetime.datetime(2007, 3, 23, 20, 47, 59, 996577)),
#  (Decimal('11.99'), datetime.datetime(2007, 4, 6, 21, 26, 57, 996577)),
#  (Decimal('11.99'), datetime.datetime(2007, 3, 22, 22, 17, 22, 996577)),
#  (Decimal('11.99'), datetime.datetime(2007, 3, 21, 22, 2, 26, 996577)),
#  (Decimal('11.99'), datetime.datetime(2007, 3, 2, 20, 46, 39, 996577)),
#  (Decimal('11.99'), datetime.datetime(2007, 4, 7, 19, 14, 17, 996577)),
#  (Decimal('11.99'), datetime.datetime(2007, 3, 21, 21, 57, 24, 996577)),
#  (Decimal('11.99'), datetime.datetime(2007, 4, 29, 21, 6, 7, 996577))]

# %% [markdown]
# [Helpful Hints](https://youtu.be/nV5P5h2x1SA)
#
# ---
#
# # 8
#
# ### List the top 20 `return_date`, `rental_date`, `rental_id`  from the rentals where a value exists for the return date; showing these in order of latest return date, then rental_date.

# %%
# %%sql SELECT return_date, rental_date, rental_id
# FROM rental
# ORDER BY return_date DESC, rental_date DESC
# LIMIT 20;
# Out:
#  * postgres://dsa_ro_user:***@pgsql.dsa.lan/dvdrental
# 20 rows affected.
# [(None, datetime.datetime(2006, 2, 14, 15, 16, 3), 11757),
#  (None, datetime.datetime(2006, 2, 14, 15, 16, 3), 11847),
#  (None, datetime.datetime(2006, 2, 14, 15, 16, 3), 11754),
#  (None, datetime.datetime(2006, 2, 14, 15, 16, 3), 11739),
#  (None, datetime.datetime(2006, 2, 14, 15, 16, 3), 11709),
#  (None, datetime.datetime(2006, 2, 14, 15, 16, 3), 11782),
#  (None, datetime.datetime(2006, 2, 14, 15, 16, 3), 11672),
#  (None, datetime.datetime(2006, 2, 14, 15, 16, 3), 11676),
#  (None, datetime.datetime(2006, 2, 14, 15, 16, 3), 11646),
#  (None, datetime.datetime(2006, 2, 14, 15, 16, 3), 11657),
#  (None, datetime.datetime(2006, 2, 14, 15, 16, 3), 11563),
#  (None, datetime.datetime(2006, 2, 14, 15, 16, 3), 11593),
#  (None, datetime.datetime(2006, 2, 14, 15, 16, 3), 11541),
#  (None, datetime.datetime(2006, 2, 14, 15, 16, 3), 12101),
#  (None, datetime.datetime(2006, 2, 14, 15, 16, 3), 11496),
#  (None, datetime.datetime(2006, 2, 14, 15, 16, 3), 13719),
#  (None, datetime.datetime(2006, 2, 14, 15, 16, 3), 11577),
#  (None, datetime.datetime(2006, 2, 14, 15, 16, 3), 11652),
#  (None, datetime.datetime(2006, 2, 14, 15, 16, 3), 11611),
#  (None, datetime.datetime(2006, 2, 14, 15, 16, 3), 11848)]

# %% [markdown]
# [Helpful Hints](https://youtu.be/H_biSct9Imw)
#
# ---

# %% [markdown]
# # SAVE YOUR NOTEBOOK, then `File > Close and Halt`

# %% [markdown]
# ---
