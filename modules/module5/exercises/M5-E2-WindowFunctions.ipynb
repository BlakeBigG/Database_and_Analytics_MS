# %% [markdown]
# # Window Functions
#
# Please remember to use the `EXPLAIN` before you execute a query to help avoid unnecessary load on the DBMS and indefinite waits by you for results.
#
# Therefore, for each question, we are providing a cell for the `EXPLAIN` as well as the final SQL.
#
#
# ## Our practice schema:
#
# We will use the same database as in the Day 1 practice.
#
# A PDF of the _Entity-Relationship Diagrams_ (ERD) is available [here](https://web.dsa.missouri.edu/static/PDF/DVD_Rental_ERD2.pdf).
# Printing it out is recommended.
#
#
# **NOTE**: These queries are more complex that the previous day's.
# If you get stuck on one, skip and come back to it later.
#
#
# **NOTE**: For this notebook, it is desired taht you construct solutions using Window Functions.

# %%
# %load_ext sql
# %sql postgres://dsa_ro_user:readonly@pgsql.dsa.lan/dvdrental
# Out:
# 'Connected: dsa_ro_user@dvdrental'

# %% [markdown]
# # 1
#
# ### For the following customers: list each movie they have rented, its `film.rental_duration`, and the comparison of the  `film.rental_duration` versus their average `rental` duration `(return_date  - rental_date)` as a column named `cmp`.
#
# Customer IDs:
#   * 318
#   * 110
#   * 281
#   * 61

# %%
# %%sql
# EXPLAIN
#
# SELECT r.customer_id, f.title, f.rental_duration,
# (f.rental_duration - AVG(r.return_date::date - r.rental_date::date) OVER (PARTITION BY r.customer_id)) AS cmp
# FROM rental r
# JOIN inventory USING (inventory_id)
# JOIN film f USING (film_id)
# WHERE r.customer_id IN (318, 110, 281, 61)
# AND r.return_date IS NOT NULL
# Out:
#  * postgres://dsa_ro_user:***@pgsql.dsa.lan/dvdrental
# 12 rows affected.
# [('WindowAgg  (cost=542.34..545.40 rows=102 width=51)',),
#  ('  ->  Sort  (cost=542.34..542.60 rows=102 width=35)',),
#  ('        Sort Key: r.customer_id',),
#  ('        ->  Nested Loop  (cost=392.21..538.94 rows=102 width=35)',),
#  ('              ->  Hash Join  (cost=391.93..503.85 rows=102 width=20)',),
#  ('                    Hash Cond: (inventory.inventory_id = r.inventory_id)',),
#  ('                    ->  Seq Scan on inventory  (cost=0.00..70.81 rows=4581 width=6)',),
#  ('                    ->  Hash  (cost=390.66..390.66 rows=102 width=22)',),
#  ('                          ->  Seq Scan on rental r  (cost=0.00..390.66 rows=102 width=22)',),
#  ("                                Filter: ((return_date IS NOT NULL) AND (customer_id = ANY ('{318,110,281,61}'::integer[])))",),
#  ('              ->  Index Scan using film_pkey on film f  (cost=0.28..0.34 rows=1 width=21)',),
#  ('                    Index Cond: (film_id = inventory.film_id)',)]

# %%
# %%sql
#
# SELECT r.customer_id, f.title, f.rental_duration,
# (f.rental_duration - AVG(r.return_date::date - r.rental_date::date) OVER (PARTITION BY r.customer_id)) AS cmp
# FROM rental r
# JOIN inventory USING (inventory_id)
# JOIN film f USING (film_id)
# WHERE r.customer_id IN (318, 110, 281, 61)
# AND r.return_date IS NOT NULL
# Out:
#  * postgres://dsa_ro_user:***@pgsql.dsa.lan/dvdrental
# 54 rows affected.
# [(61, 'Necklace Outbreak', 3, Decimal('-3.0000000000000000')),
#  (61, 'Iron Moon', 7, Decimal('1.0000000000000000')),
#  (61, 'Fireball Philadelphia', 4, Decimal('-2.0000000000000000')),
#  (61, 'Impact Aladdin', 6, Decimal('0E-16')),
#  (61, 'Autumn Crow', 3, Decimal('-3.0000000000000000')),
#  (61, 'Smoochy Control', 7, Decimal('1.0000000000000000')),
#  (61, 'Barefoot Manchurian', 6, Decimal('0E-16')),
#  (61, 'Ridgemont Submarine', 3, Decimal('-3.0000000000000000')),
#  (61, 'Voyage Legally', 6, Decimal('0E-16')),
#  (61, 'Reign Gentlemen', 3, Decimal('-3.0000000000000000')),
#  (61, 'Vacation Boondock', 4, Decimal('-2.0000000000000000')),
#  (61, 'Anonymous Human', 7, Decimal('1.0000000000000000')),
#  (61, 'Remember Diary', 5, Decimal('-1.0000000000000000')),
#  (61, 'Notting Speakeasy', 7, Decimal('1.0000000000000000')),
#  (110, 'Packer Madigan', 3, Decimal('-1.3571428571428571')),
#  (110, 'Brotherhood Blanket', 3, Decimal('-1.3571428571428571')),
#  (110, 'Comforts Rush', 3, Decimal('-1.3571428571428571')),
#  (110, 'Vanishing Rocky', 3, Decimal('-1.3571428571428571')),
#  (110, 'Wife Turn', 3, Decimal('-1.3571428571428571')),
#  (110, 'Cowboy Doom', 3, Decimal('-1.3571428571428571')),
#  (110, 'Highball Potter', 6, Decimal('1.6428571428571429')),
#  (110, 'Jericho Mulan', 3, Decimal('-1.3571428571428571')),
#  (110, 'Juggler Hardly', 4, Decimal('-0.3571428571428571')),
#  (110, 'Moonshine Cabin', 4, Decimal('-0.3571428571428571')),
#  (110, 'Paths Control', 3, Decimal('-1.3571428571428571')),
#  (110, 'Prix Undefeated', 4, Decimal('-0.3571428571428571')),
#  (110, 'Rocky War', 4, Decimal('-0.3571428571428571')),
#  (110, 'Bound Cheaper', 5, Decimal('0.6428571428571429')),
#  (281, 'Wardrobe Phantom', 6, Decimal('0.5000000000000000')),
#  (281, 'Atlantis Cause', 6, Decimal('0.5000000000000000')),
#  (281, 'Doom Dancing', 4, Decimal('-1.5000000000000000')),
#  (281, 'Bride Intrigue', 7, Decimal('1.5000000000000000')),
#  (281, 'Packer Madigan', 3, Decimal('-2.5000000000000000')),
#  (281, 'Club Graffiti', 4, Decimal('-1.5000000000000000')),
#  (281, 'Wisdom Worker', 3, Decimal('-2.5000000000000000')),
#  (281, 'Graduate Lord', 7, Decimal('1.5000000000000000')),
#  (281, 'Dynamite Tarzan', 4, Decimal('-1.5000000000000000')),
#  (281, 'Tights Dawn', 5, Decimal('-0.5000000000000000')),
#  (281, 'Juggler Hardly', 4, Decimal('-1.5000000000000000')),
#  (281, 'Rage Games', 4, Decimal('-1.5000000000000000')),
#  (281, 'Language Cowboy', 5, Decimal('-0.5000000000000000')),
#  (281, 'Blanket Beverly', 7, Decimal('1.5000000000000000')),
#  (318, 'Valley Packer', 3, Decimal('-1.8333333333333333')),
#  (318, 'Bonnie Holocaust', 4, Decimal('-0.8333333333333333')),
#  (318, 'Duffel Apocalypse', 5, Decimal('0.1666666666666667')),
#  (318, 'High Encino', 3, Decimal('-1.8333333333333333')),
#  (318, 'Hobbit Alien', 5, Decimal('0.1666666666666667')),
#  (318, 'Montezuma Command', 6, Decimal('1.1666666666666667')),
#  (318, 'Pelican Comforts', 4, Decimal('-0.8333333333333333')),
#  (318, 'Side Ark', 5, Decimal('0.1666666666666667')),
#  (318, 'Sleepy Japanese', 4, Decimal('-0.8333333333333333')),
#  (318, 'Tenenbaums Command', 4, Decimal('-0.8333333333333333')),
#  (318, 'American Circus', 3, Decimal('-1.8333333333333333')),
#  (318, 'Vampire Whale', 4, Decimal('-0.8333333333333333'))]

# %% [markdown]
# [Helpful Hints Video](https://youtu.be/cm1_d1qWLhg)
#
#
# ---
#
# # 2
#
# ### For each store (inventory.store_id), list the top three films that have been rented based on accumulated rental durations.
#
# Hint: Use the `rank()` function and a derived table

# %%
# %%sql
# EXPLAIN
#
# SELECT store_id, film_id, duration, rank
# FROM (
#     SELECT i.store_id, i.film_id,
#     SUM(r.return_date - r.rental_date) AS duration,
#         RANK() OVER (PARTITION BY i.store_id
#         ORDER BY SUM(r.return_date - r.rental_date) DESC)
#     FROM inventory i
#     JOIN rental r USING (inventory_id)
#     WHERE r.return_date IS NOT NULL
#     GROUP BY i.store_id, i.film_id
# ) AS a
# WHERE RANK <= 3
# Out:
#  * postgres://dsa_ro_user:***@pgsql.dsa.lan/dvdrental
# 13 rows affected.
# [('Subquery Scan on a  (cost=695.81..726.95 rows=319 width=28)',),
#  ('  Filter: (a.rank <= 3)',),
#  ('  ->  WindowAgg  (cost=695.81..714.97 rows=958 width=28)',),
#  ('        ->  Sort  (cost=695.81..698.21 rows=958 width=20)',),
#  ('              Sort Key: i.store_id, (sum((r.return_date - r.rental_date))) DESC',),
#  ('              ->  HashAggregate  (cost=638.79..648.37 rows=958 width=20)',),
#  ('                    Group Key: i.store_id, i.film_id',),
#  ('                    ->  Hash Join  (cost=128.07..480.18 rows=15861 width=20)',),
#  ('                          Hash Cond: (r.inventory_id = i.inventory_id)',),
#  ('                          ->  Seq Scan on rental r  (cost=0.00..310.44 rows=15861 width=20)',),
#  ('                                Filter: (return_date IS NOT NULL)',),
#  ('                          ->  Hash  (cost=70.81..70.81 rows=4581 width=8)',),
#  ('                                ->  Seq Scan on inventory i  (cost=0.00..70.81 rows=4581 width=8)',)]

# %%
# %%sql
#
# SELECT store_id, film_id, duration, rank
# FROM (
#     SELECT i.store_id, i.film_id,
#     SUM(r.return_date - r.rental_date) AS duration,
#         RANK() OVER (PARTITION BY i.store_id
#         ORDER BY SUM(r.return_date - r.rental_date) DESC)
#     FROM inventory i
#     JOIN rental r USING (inventory_id)
#     WHERE r.return_date IS NOT NULL
#     GROUP BY i.store_id, i.film_id
# ) AS a
# WHERE RANK <= 3
# Out:
#  * postgres://dsa_ro_user:***@pgsql.dsa.lan/dvdrental
# 6 rows affected.
# [(1, 971, datetime.timedelta(days=111, seconds=37260), 1),
#  (1, 109, datetime.timedelta(days=105, seconds=51420), 2),
#  (1, 852, datetime.timedelta(days=104, seconds=33540), 3),
#  (2, 552, datetime.timedelta(days=104, seconds=62700), 1),
#  (2, 891, datetime.timedelta(days=100, seconds=68700), 2),
#  (2, 491, datetime.timedelta(days=100, seconds=29640), 3)]

# %% [markdown]
# [Helpful Hints Video](https://youtu.be/COQem8x3kR4)
#
#
# ---
#
# # 3
#
# ### For each category, list the three longest movies

# %%
# %%sql
# EXPLAIN
#
# SELECT name, title, length, RANK
# FROM (
#     SELECT name, title, length,
#     RANK() OVER (PARTITION BY name ORDER BY length DESC)
#     FROM category
#     JOIN film_category USING (category_id)
#     JOIN film USING (film_id)
# ) AS a
# WHERE RANK <= 3
# Out:
#  * postgres://dsa_ro_user:***@pgsql.dsa.lan/dvdrental
# 14 rows affected.
# [('Subquery Scan on a  (cost=149.64..182.14 rows=333 width=93)',),
#  ('  Filter: (a.rank <= 3)',),
#  ('  ->  WindowAgg  (cost=149.64..169.64 rows=1000 width=93)',),
#  ('        ->  Sort  (cost=149.64..152.14 rows=1000 width=85)',),
#  ('              Sort Key: category.name, film.length DESC',),
#  ('              ->  Hash Join  (cost=77.86..99.81 rows=1000 width=85)',),
#  ('                    Hash Cond: (film_category.film_id = film.film_id)',),
#  ('                    ->  Hash Join  (cost=1.36..20.67 rows=1000 width=70)',),
#  ('                          Hash Cond: (film_category.category_id = category.category_id)',),
#  ('                          ->  Seq Scan on film_category  (cost=0.00..16.00 rows=1000 width=4)',),
#  ('                          ->  Hash  (cost=1.16..1.16 rows=16 width=72)',),
#  ('                                ->  Seq Scan on category  (cost=0.00..1.16 rows=16 width=72)',),
#  ('                    ->  Hash  (cost=64.00..64.00 rows=1000 width=21)',),
#  ('                          ->  Seq Scan on film  (cost=0.00..64.00 rows=1000 width=21)',)]

# %%
# %%sql
#
# SELECT name, title, length, RANK
# FROM (
#     SELECT name, title, length,
#     RANK() OVER (PARTITION BY name ORDER BY length DESC)
#     FROM category
#     JOIN film_category USING (category_id)
#     JOIN film USING (film_id)
# ) AS a
# WHERE RANK <= 3
# Out:
#  * postgres://dsa_ro_user:***@pgsql.dsa.lan/dvdrental
# 53 rows affected.
# [('Action', 'Worst Banger', 185, 1),
#  ('Action', 'Darn Forrester', 185, 1),
#  ('Action', 'Casualties Encino', 179, 3),
#  ('Animation', 'Pond Seattle', 185, 1),
#  ('Animation', 'Gangs Pride', 185, 1),
#  ('Animation', 'Theory Mermaid', 184, 3),
#  ('Animation', 'Sons Interview', 184, 3),
#  ('Children', 'Wrong Behavior', 178, 1),
#  ('Children', 'Fury Murder', 178, 1),
#  ('Children', 'Empire Malkovich', 177, 3),
#  ('Classics', 'Conspiracy Spirit', 184, 1),
#  ('Classics', 'Dracula Crystal', 176, 2),
#  ('Classics', 'Lights Deer', 174, 3),
#  ('Comedy', 'Control Anthem', 185, 1),
#  ('Comedy', 'Saturn Name', 182, 2),
#  ('Comedy', 'Searchers Wait', 182, 2),
#  ('Documentary', 'Young Language', 183, 1),
#  ('Documentary', 'Wife Turn', 183, 1),
#  ('Documentary', 'Cause Date', 179, 3),
#  ('Drama', 'Jacket Frisco', 181, 1),
#  ('Drama', 'Something Duck', 180, 2),
#  ('Drama', 'Slacker Liaisons', 179, 3),
#  ('Drama', 'Torque Bound', 179, 3),
#  ('Drama', 'Virgin Daisy', 179, 3),
#  ('Family', 'King Evolution', 184, 1),
#  ('Family', 'Baked Cleopatra', 182, 2),
#  ('Family', 'Manchurian Curtain', 177, 3),
#  ('Foreign', 'Crystal Breaking', 184, 1),
#  ('Foreign', 'Sorority Queen', 184, 1),
#  ('Foreign', 'Catch Amistad', 183, 3),
#  ('Games', 'Chicago North', 185, 1),
#  ('Games', 'Moonwalker Fool', 184, 2),
#  ('Games', 'Monsoon Cause', 182, 3),
#  ('Horror', 'Love Suicides', 181, 1),
#  ('Horror', 'Analyze Hoosiers', 181, 1),
#  ('Horror', 'Texas Watch', 179, 3),
#  ('Music', 'Home Pity', 185, 1),
#  ('Music', 'Scalawag Duck', 183, 2),
#  ('Music', 'Reds Pocus', 182, 3),
#  ('New', 'Frontier Cabin', 183, 1),
#  ('New', 'Wild Apollo', 181, 2),
#  ('New', 'Runaway Tenenbaums', 181, 2),
#  ('Sci-Fi', 'Soldiers Evolution', 185, 1),
#  ('Sci-Fi', 'Express Lonely', 178, 2),
#  ('Sci-Fi', 'Eyes Driving', 172, 3),
#  ('Sci-Fi', 'Connecticut Tramp', 172, 3),
#  ('Sports', 'Smoochy Control', 184, 1),
#  ('Sports', 'Records Zorro', 182, 2),
#  ('Sports', 'Star Operation', 181, 3),
#  ('Travel', 'Sweet Brotherhood', 185, 1),
#  ('Travel', 'Muscle Bright', 185, 1),
#  ('Travel', 'Kick Savannah', 179, 3),
#  ('Travel', 'Born Spinal', 179, 3)]

# %% [markdown]
# # 4
#
# ### For each customer, list their two shortest movie rentals.

# %%
# %%sql
# EXPLAIN
#
# SELECT customer_id, first_name, last_name, duration, rank
# FROM (
#     SELECT c.customer_id, c.first_name, c.last_name, (r.return_date - r.rental_date) AS duration,
#     RANK() OVER (PARTITION BY c.customer_id ORDER BY (r.return_date - r.rental_date))
#     FROM customer c
#     JOIN rental r USING (customer_id)
# ) AS a
# WHERE RANK <=2
# Out:
#  * postgres://dsa_ro_user:***@pgsql.dsa.lan/dvdrental
# 10 rows affected.
# [('Subquery Scan on a  (cost=1536.10..2097.64 rows=5348 width=41)',),
#  ('  Filter: (a.rank <= 2)',),
#  ('  ->  WindowAgg  (cost=1536.10..1897.09 rows=16044 width=41)',),
#  ('        ->  Sort  (cost=1536.10..1576.21 rows=16044 width=33)',),
#  ('              Sort Key: c.customer_id, ((r.return_date - r.rental_date))',),
#  ('              ->  Hash Join  (cost=22.48..415.44 rows=16044 width=33)',),
#  ('                    Hash Cond: (r.customer_id = c.customer_id)',),
#  ('                    ->  Seq Scan on rental r  (cost=0.00..310.44 rows=16044 width=18)',),
#  ('                    ->  Hash  (cost=14.99..14.99 rows=599 width=17)',),
#  ('                          ->  Seq Scan on customer c  (cost=0.00..14.99 rows=599 width=17)',)]

# %%
# %%sql
#
# SELECT customer_id, first_name, last_name, duration, rank
# FROM (
#     SELECT c.customer_id, c.first_name, c.last_name, (r.return_date - r.rental_date) AS duration,
#     RANK() OVER (PARTITION BY c.customer_id ORDER BY (r.return_date - r.rental_date))
#     FROM customer c
#     JOIN rental r USING (customer_id)
# ) AS a
# WHERE RANK <=2
# Out:
#  * postgres://dsa_ro_user:***@pgsql.dsa.lan/dvdrental
# 1198 rows affected.
# [(1, 'Mary', 'Smith', datetime.timedelta(days=1, seconds=7020), 1),
#  (1, 'Mary', 'Smith', datetime.timedelta(days=1, seconds=9840), 2),
#  (2, 'Patricia', 'Johnson', datetime.timedelta(seconds=69180), 1),
#  (2, 'Patricia', 'Johnson', datetime.timedelta(days=1, seconds=15660), 2),
#  (3, 'Linda', 'Williams', datetime.timedelta(seconds=70380), 1),
#  (3, 'Linda', 'Williams', datetime.timedelta(days=1, seconds=18120), 2),
#  (4, 'Barbara', 'Jones', datetime.timedelta(seconds=85080), 1),
#  (4, 'Barbara', 'Jones', datetime.timedelta(days=1, seconds=11040), 2),
#  (5, 'Elizabeth', 'Brown', datetime.timedelta(seconds=72600), 1),
#  (5, 'Elizabeth', 'Brown', datetime.timedelta(seconds=78540), 2),
#  (6, 'Jennifer', 'Davis', datetime.timedelta(seconds=78060), 1),
#  (6, 'Jennifer', 'Davis', datetime.timedelta(days=1, seconds=20280), 2),
#  (7, 'Maria', 'Miller', datetime.timedelta(days=1, seconds=72840), 1),
#  (7, 'Maria', 'Miller', datetime.timedelta(days=2, seconds=11700), 2),
#  (8, 'Susan', 'Wilson', datetime.timedelta(days=1, seconds=4860), 1),
#  (8, 'Susan', 'Wilson', datetime.timedelta(days=1, seconds=15480), 2),
#  (9, 'Margaret', 'Moore', datetime.timedelta(days=1, seconds=73320), 1),
#  (9, 'Margaret', 'Moore', datetime.timedelta(days=1, seconds=81000), 2),
#  (10, 'Dorothy', 'Taylor', datetime.timedelta(days=1, seconds=8400), 1),
#  (10, 'Dorothy', 'Taylor', datetime.timedelta(days=1, seconds=18660), 2),
#  (11, 'Lisa', 'Anderson', datetime.timedelta(seconds=76920), 1),
#  (11, 'Lisa', 'Anderson', datetime.timedelta(days=1, seconds=5940), 2),
#  (12, 'Nancy', 'Thomas', datetime.timedelta(seconds=65280), 1),
#  (12, 'Nancy', 'Thomas', datetime.timedelta(seconds=84300), 2),
#  (13, 'Karen', 'Jackson', datetime.timedelta(days=1, seconds=11520), 1),
#  (13, 'Karen', 'Jackson', datetime.timedelta(days=1, seconds=67440), 2),
#  (14, 'Betty', 'White', datetime.timedelta(seconds=76500), 1),
#  (14, 'Betty', 'White', datetime.timedelta(seconds=82020), 2),
#  (15, 'Helen', 'Harris', datetime.timedelta(seconds=79680), 1),
#  (15, 'Helen', 'Harris', datetime.timedelta(days=1, seconds=2040), 2),
#  (16, 'Sandra', 'Martin', datetime.timedelta(seconds=84600), 1),
#  (16, 'Sandra', 'Martin', datetime.timedelta(days=1, seconds=1260), 2),
#  (17, 'Donna', 'Thompson', datetime.timedelta(seconds=75240), 1),
#  (17, 'Donna', 'Thompson', datetime.timedelta(seconds=75720), 2),
#  (18, 'Carol', 'Garcia', datetime.timedelta(seconds=68640), 1),
#  (18, 'Carol', 'Garcia', datetime.timedelta(seconds=75360), 2),
#  (19, 'Ruth', 'Martinez', datetime.timedelta(seconds=69360), 1),
#  (19, 'Ruth', 'Martinez', datetime.timedelta(seconds=76380), 2),
#  (20, 'Sharon', 'Robinson', datetime.timedelta(seconds=67200), 1),
#  (20, 'Sharon', 'Robinson', datetime.timedelta(days=1, seconds=5520), 2),
#  (21, 'Michelle', 'Clark', datetime.timedelta(days=1, seconds=5940), 1),
#  (21, 'Michelle', 'Clark', datetime.timedelta(days=1, seconds=7500), 2),
#  (22, 'Laura', 'Rodriguez', datetime.timedelta(seconds=78600), 1),
#  (22, 'Laura', 'Rodriguez', datetime.timedelta(seconds=83940), 2),
#  (23, 'Sarah', 'Lewis', datetime.timedelta(seconds=79440), 1),
#  (23, 'Sarah', 'Lewis', datetime.timedelta(seconds=80460), 2),
#  (24, 'Kimberly', 'Lee', datetime.timedelta(seconds=74820), 1),
#  (24, 'Kimberly', 'Lee', datetime.timedelta(days=1, seconds=12120), 2),
#  (25, 'Deborah', 'Walker', datetime.timedelta(seconds=75900), 1),
#  (25, 'Deborah', 'Walker', datetime.timedelta(days=1, seconds=75780), 2),
#  (26, 'Jessica', 'Hall', datetime.timedelta(seconds=70560), 1),
#  (26, 'Jessica', 'Hall', datetime.timedelta(days=1, seconds=2880), 2),
#  (27, 'Shirley', 'Allen', datetime.timedelta(seconds=74880), 1),
#  (27, 'Shirley', 'Allen', datetime.timedelta(days=1, seconds=17340), 2),
#  (28, 'Cynthia', 'Young', datetime.timedelta(seconds=65700), 1),
#  (28, 'Cynthia', 'Young', datetime.timedelta(seconds=67320), 2),
#  (29, 'Angela', 'Hernandez', datetime.timedelta(seconds=65520), 1),
#  (29, 'Angela', 'Hernandez', datetime.timedelta(days=1, seconds=2880), 2),
#  (30, 'Melissa', 'King', datetime.timedelta(seconds=86280), 1),
#  (30, 'Melissa', 'King', datetime.timedelta(days=1, seconds=900), 2),
#  (31, 'Brenda', 'Wright', datetime.timedelta(seconds=79860), 1),
#  (31, 'Brenda', 'Wright', datetime.timedelta(seconds=80160), 2),
#  (32, 'Amy', 'Lopez', datetime.timedelta(seconds=74580), 1),
#  (32, 'Amy', 'Lopez', datetime.timedelta(seconds=75780), 2),
#  (33, 'Anna', 'Hill', datetime.timedelta(seconds=70380), 1),
#  (33, 'Anna', 'Hill', datetime.timedelta(seconds=70860), 2),
#  (34, 'Rebecca', 'Scott', datetime.timedelta(seconds=66180), 1),
#  (34, 'Rebecca', 'Scott', datetime.timedelta(seconds=81600), 2),
#  (35, 'Virginia', 'Green', datetime.timedelta(seconds=66120), 1),
#  (35, 'Virginia', 'Green', datetime.timedelta(seconds=70080), 2),
#  (36, 'Kathleen', 'Adams', datetime.timedelta(seconds=66420), 1),
#  (36, 'Kathleen', 'Adams', datetime.timedelta(days=1, seconds=6000), 2),
#  (37, 'Pamela', 'Baker', datetime.timedelta(seconds=79740), 1),
#  (37, 'Pamela', 'Baker', datetime.timedelta(days=1, seconds=12780), 2),
#  (38, 'Martha', 'Gonzalez', datetime.timedelta(seconds=65880), 1),
#  (38, 'Martha', 'Gonzalez', datetime.timedelta(seconds=80160), 2),
#  (39, 'Debra', 'Nelson', datetime.timedelta(seconds=75120), 1),
#  (39, 'Debra', 'Nelson', datetime.timedelta(days=1, seconds=13500), 2),
#  (40, 'Amanda', 'Carter', datetime.timedelta(seconds=85440), 1),
#  (40, 'Amanda', 'Carter', datetime.timedelta(days=2, seconds=8640), 2),
#  (41, 'Stephanie', 'Mitchell', datetime.timedelta(days=1, seconds=9660), 1),
#  (41, 'Stephanie', 'Mitchell', datetime.timedelta(days=1, seconds=12480), 2),
#  (42, 'Carolyn', 'Perez', datetime.timedelta(seconds=66600), 1),
#  (42, 'Carolyn', 'Perez', datetime.timedelta(seconds=66960), 2),
#  (43, 'Christine', 'Roberts', datetime.timedelta(seconds=67740), 1),
#  (43, 'Christine', 'Roberts', datetime.timedelta(seconds=78780), 2),
#  (44, 'Marie', 'Turner', datetime.timedelta(seconds=73380), 1),
#  (44, 'Marie', 'Turner', datetime.timedelta(seconds=77880), 2),
#  (45, 'Janet', 'Phillips', datetime.timedelta(seconds=77460), 1),
#  (45, 'Janet', 'Phillips', datetime.timedelta(days=1, seconds=6060), 2),
#  (46, 'Catherine', 'Campbell', datetime.timedelta(seconds=73140), 1),
#  (46, 'Catherine', 'Campbell', datetime.timedelta(seconds=74940), 2),
#  (47, 'Frances', 'Parker', datetime.timedelta(days=1, seconds=5280), 1),
#  (47, 'Frances', 'Parker', datetime.timedelta(days=1, seconds=14160), 2),
#  (48, 'Ann', 'Evans', datetime.timedelta(seconds=83040), 1),
#  (48, 'Ann', 'Evans', datetime.timedelta(days=2, seconds=16620), 2),
#  (49, 'Joyce', 'Edwards', datetime.timedelta(days=1, seconds=8160), 1),
#  (49, 'Joyce', 'Edwards', datetime.timedelta(days=1, seconds=11880), 2),
#  (50, 'Diane', 'Collins', datetime.timedelta(seconds=68220), 1),
#  (50, 'Diane', 'Collins', datetime.timedelta(seconds=81600), 2),
#  (51, 'Alice', 'Stewart', datetime.timedelta(days=1, seconds=180), 1),
#  (51, 'Alice', 'Stewart', datetime.timedelta(days=1, seconds=78000), 2),
#  (52, 'Julie', 'Sanchez', datetime.timedelta(seconds=66900), 1),
#  (52, 'Julie', 'Sanchez', datetime.timedelta(days=1, seconds=66360), 2),
#  (53, 'Heather', 'Morris', datetime.timedelta(seconds=85200), 1),
#  (53, 'Heather', 'Morris', datetime.timedelta(days=1, seconds=11820), 2),
#  (54, 'Teresa', 'Rogers', datetime.timedelta(seconds=73020), 1),
#  (54, 'Teresa', 'Rogers', datetime.timedelta(seconds=85080), 2),
#  (55, 'Doris', 'Reed', datetime.timedelta(seconds=66840), 1),
#  (55, 'Doris', 'Reed', datetime.timedelta(seconds=74520), 2),
#  (56, 'Gloria', 'Cook', datetime.timedelta(seconds=79260), 1),
#  (56, 'Gloria', 'Cook', datetime.timedelta(days=1, seconds=10920), 2),
#  (57, 'Evelyn', 'Morgan', datetime.timedelta(seconds=69840), 1),
#  (57, 'Evelyn', 'Morgan', datetime.timedelta(seconds=79980), 2),
#  (58, 'Jean', 'Bell', datetime.timedelta(seconds=70740), 1),
#  (58, 'Jean', 'Bell', datetime.timedelta(seconds=75300), 2),
#  (59, 'Cheryl', 'Murphy', datetime.timedelta(days=1, seconds=1200), 1),
#  (59, 'Cheryl', 'Murphy', datetime.timedelta(days=1, seconds=10260), 2),
#  (60, 'Mildred', 'Bailey', datetime.timedelta(seconds=67020), 1),
#  (60, 'Mildred', 'Bailey', datetime.timedelta(seconds=71340), 2),
#  (61, 'Katherine', 'Rivera', datetime.timedelta(seconds=65940), 1),
#  (61, 'Katherine', 'Rivera', datetime.timedelta(days=1, seconds=69240), 2),
#  (62, 'Joan', 'Cooper', datetime.timedelta(seconds=69060), 1),
#  (62, 'Joan', 'Cooper', datetime.timedelta(days=1, seconds=6840), 2),
#  (63, 'Ashley', 'Richardson', datetime.timedelta(seconds=74580), 1),
#  (63, 'Ashley', 'Richardson', datetime.timedelta(days=2, seconds=20280), 2),
#  (64, 'Judith', 'Cox', datetime.timedelta(days=1, seconds=17460), 1),
#  (64, 'Judith', 'Cox', datetime.timedelta(days=1, seconds=19140), 2),
#  (65, 'Rose', 'Howard', datetime.timedelta(seconds=72600), 1),
#  (65, 'Rose', 'Howard', datetime.timedelta(seconds=78600), 2),
#  (66, 'Janice', 'Ward', datetime.timedelta(days=1, seconds=14760), 1),
#  (66, 'Janice', 'Ward', datetime.timedelta(days=1, seconds=68760), 2),
#  (67, 'Kelly', 'Torres', datetime.timedelta(seconds=65760), 1),
#  (67, 'Kelly', 'Torres', datetime.timedelta(seconds=81480), 2),
#  (68, 'Nicole', 'Peterson', datetime.timedelta(seconds=69420), 1),
#  (68, 'Nicole', 'Peterson', datetime.timedelta(seconds=82980), 2),
#  (69, 'Judy', 'Gray', datetime.timedelta(days=1, seconds=1860), 1),
#  (69, 'Judy', 'Gray', datetime.timedelta(days=2, seconds=73920), 2),
#  (70, 'Christina', 'Ramirez', datetime.timedelta(seconds=75240), 1),
#  (70, 'Christina', 'Ramirez', datetime.timedelta(days=1, seconds=13980), 2),
#  (71, 'Kathy', 'James', datetime.timedelta(seconds=70680), 1),
#  (71, 'Kathy', 'James', datetime.timedelta(seconds=82740), 2),
#  (72, 'Theresa', 'Watson', datetime.timedelta(seconds=79500), 1),
#  (72, 'Theresa', 'Watson', datetime.timedelta(days=1, seconds=2580), 2),
#  (73, 'Beverly', 'Brooks', datetime.timedelta(seconds=72300), 1),
#  (73, 'Beverly', 'Brooks', datetime.timedelta(seconds=73740), 2),
#  (74, 'Denise', 'Kelly', datetime.timedelta(seconds=68220), 1),
#  (74, 'Denise', 'Kelly', datetime.timedelta(days=1, seconds=75000), 2),
#  (75, 'Tammy', 'Sanders', datetime.timedelta(seconds=80160), 1),
#  (75, 'Tammy', 'Sanders', datetime.timedelta(seconds=81540), 2),
#  (76, 'Irene', 'Price', datetime.timedelta(seconds=70320), 1),
#  (76, 'Irene', 'Price', datetime.timedelta(seconds=80460), 2),
#  (77, 'Jane', 'Bennett', datetime.timedelta(days=1, seconds=3840), 1),
#  (77, 'Jane', 'Bennett', datetime.timedelta(days=1, seconds=4380), 2),
#  (78, 'Lori', 'Wood', datetime.timedelta(seconds=76140), 1),
#  (78, 'Lori', 'Wood', datetime.timedelta(days=1, seconds=75900), 2),
#  (79, 'Rachel', 'Barnes', datetime.timedelta(seconds=80880), 1),
#  (79, 'Rachel', 'Barnes', datetime.timedelta(days=1, seconds=5580), 2),
#  (80, 'Marilyn', 'Ross', datetime.timedelta(seconds=86040), 1),
#  (80, 'Marilyn', 'Ross', datetime.timedelta(days=1, seconds=7020), 2),
#  (81, 'Andrea', 'Henderson', datetime.timedelta(seconds=71280), 1),
#  (81, 'Andrea', 'Henderson', datetime.timedelta(days=1, seconds=2100), 2),
#  (82, 'Kathryn', 'Coleman', datetime.timedelta(days=1, seconds=81360), 1),
#  (82, 'Kathryn', 'Coleman', datetime.timedelta(days=2, seconds=1020), 2),
#  (83, 'Louise', 'Jenkins', datetime.timedelta(seconds=71820), 1),
#  (83, 'Louise', 'Jenkins', datetime.timedelta(seconds=72360), 2),
#  (84, 'Sara', 'Perry', datetime.timedelta(seconds=69660), 1),
#  (84, 'Sara', 'Perry', datetime.timedelta(seconds=75840), 2),
#  (85, 'Anne', 'Powell', datetime.timedelta(seconds=66360), 1),
#  (85, 'Anne', 'Powell', datetime.timedelta(seconds=68220), 2),
#  (86, 'Jacqueline', 'Long', datetime.timedelta(seconds=70680), 1),
#  (86, 'Jacqueline', 'Long', datetime.timedelta(seconds=75720), 2),
#  (87, 'Wanda', 'Patterson', datetime.timedelta(seconds=69060), 1),
#  (87, 'Wanda', 'Patterson', datetime.timedelta(seconds=69900), 2),
#  (88, 'Bonnie', 'Hughes', datetime.timedelta(seconds=74640), 1),
#  (88, 'Bonnie', 'Hughes', datetime.timedelta(days=1, seconds=73860), 2),
#  (89, 'Julia', 'Flores', datetime.timedelta(days=1, seconds=15420), 1),
#  (89, 'Julia', 'Flores', datetime.timedelta(days=1, seconds=66480), 2),
#  (90, 'Ruby', 'Washington', datetime.timedelta(seconds=66480), 1),
#  (90, 'Ruby', 'Washington', datetime.timedelta(seconds=72660), 2),
#  (91, 'Lois', 'Butler', datetime.timedelta(days=1, seconds=12300), 1),
#  (91, 'Lois', 'Butler', datetime.timedelta(days=1, seconds=66420), 2),
#  (92, 'Tina', 'Simmons', datetime.timedelta(days=1, seconds=68340), 1),
#  (92, 'Tina', 'Simmons', datetime.timedelta(days=1, seconds=69300), 2),
#  (93, 'Phyllis', 'Foster', datetime.timedelta(seconds=72960), 1),
#  (93, 'Phyllis', 'Foster', datetime.timedelta(seconds=85980), 2),
#  (94, 'Norma', 'Gonzales', datetime.timedelta(seconds=66420), 1),
#  (94, 'Norma', 'Gonzales', datetime.timedelta(days=1, seconds=3900), 2),
#  (95, 'Paula', 'Bryant', datetime.timedelta(days=1, seconds=78300), 1),
#  (95, 'Paula', 'Bryant', datetime.timedelta(days=2, seconds=600), 2),
#  (96, 'Diana', 'Alexander', datetime.timedelta(seconds=76920), 1),
#  (96, 'Diana', 'Alexander', datetime.timedelta(days=1, seconds=20280), 2),
#  (97, 'Annie', 'Russell', datetime.timedelta(seconds=68760), 1),
#  (97, 'Annie', 'Russell', datetime.timedelta(days=1, seconds=4620), 2),
#  (98, 'Lillian', 'Griffin', datetime.timedelta(seconds=84180), 1),
#  (98, 'Lillian', 'Griffin', datetime.timedelta(days=1, seconds=6840), 2),
#  (99, 'Emily', 'Diaz', datetime.timedelta(seconds=74460), 1),
#  (99, 'Emily', 'Diaz', datetime.timedelta(seconds=82080), 2),
#  (100, 'Robin', 'Hayes', datetime.timedelta(seconds=65760), 1),
#  (100, 'Robin', 'Hayes', datetime.timedelta(seconds=77400), 2),
#  (101, 'Peggy', 'Myers', datetime.timedelta(seconds=79200), 1),
#  (101, 'Peggy', 'Myers', datetime.timedelta(days=1, seconds=14700), 2),
#  (102, 'Crystal', 'Ford', datetime.timedelta(days=1, seconds=66480), 1),
#  (102, 'Crystal', 'Ford', datetime.timedelta(days=1, seconds=77040), 2),
#  (103, 'Gladys', 'Hamilton', datetime.timedelta(seconds=79620), 1),
#  (103, 'Gladys', 'Hamilton', datetime.timedelta(seconds=85260), 2),
#  (104, 'Rita', 'Graham', datetime.timedelta(seconds=64920), 1),
#  (104, 'Rita', 'Graham', datetime.timedelta(seconds=70440), 2),
#  (105, 'Dawn', 'Sullivan', datetime.timedelta(seconds=82800), 1),
#  (105, 'Dawn', 'Sullivan', datetime.timedelta(days=1, seconds=13800), 2),
#  (106, 'Connie', 'Wallace', datetime.timedelta(seconds=78180), 1),
#  (106, 'Connie', 'Wallace', datetime.timedelta(days=1, seconds=1500), 2),
#  (107, 'Florence', 'Woods', datetime.timedelta(days=1, seconds=17580), 1),
#  (107, 'Florence', 'Woods', datetime.timedelta(days=1, seconds=20340), 2),
#  (108, 'Tracy', 'Cole', datetime.timedelta(seconds=65280), 1),
#  (108, 'Tracy', 'Cole', datetime.timedelta(days=2, seconds=2220), 2),
#  (109, 'Edna', 'West', datetime.timedelta(seconds=85620), 1),
#  (109, 'Edna', 'West', datetime.timedelta(seconds=86220), 2),
#  (110, 'Tiffany', 'Jordan', datetime.timedelta(days=1, seconds=2040), 1),
#  (110, 'Tiffany', 'Jordan', datetime.timedelta(days=1, seconds=14640), 2),
#  (111, 'Carmen', 'Owens', datetime.timedelta(seconds=66960), 1),
#  (111, 'Carmen', 'Owens', datetime.timedelta(seconds=70140), 2),
#  (112, 'Rosa', 'Reynolds', datetime.timedelta(seconds=83580), 1),
#  (112, 'Rosa', 'Reynolds', datetime.timedelta(days=1, seconds=64860), 2),
#  (113, 'Cindy', 'Fisher', datetime.timedelta(seconds=76320), 1),
#  (113, 'Cindy', 'Fisher', datetime.timedelta(days=1, seconds=10500), 2),
#  (114, 'Grace', 'Ellis', datetime.timedelta(seconds=66240), 1),
#  (114, 'Grace', 'Ellis', datetime.timedelta(seconds=78780), 2),
#  (115, 'Wendy', 'Harrison', datetime.timedelta(seconds=77280), 1),
#  (115, 'Wendy', 'Harrison', datetime.timedelta(days=1, seconds=85080), 2),
#  (116, 'Victoria', 'Gibson', datetime.timedelta(seconds=66360), 1),
#  (116, 'Victoria', 'Gibson', datetime.timedelta(seconds=79260), 2),
#  (117, 'Edith', 'Mcdonald', datetime.timedelta(seconds=77580), 1),
#  (117, 'Edith', 'Mcdonald', datetime.timedelta(seconds=79080), 2),
#  (118, 'Kim', 'Cruz', datetime.timedelta(seconds=71160), 1),
#  (118, 'Kim', 'Cruz', datetime.timedelta(days=1, seconds=17760), 2),
#  (119, 'Sherry', 'Marshall', datetime.timedelta(seconds=76680), 1),
#  (119, 'Sherry', 'Marshall', datetime.timedelta(seconds=78360), 2),
#  (120, 'Sylvia', 'Ortiz', datetime.timedelta(days=1, seconds=73020), 1),
#  (120, 'Sylvia', 'Ortiz', datetime.timedelta(days=1, seconds=77820), 2),
#  (121, 'Josephine', 'Gomez', datetime.timedelta(seconds=73980), 1),
#  (121, 'Josephine', 'Gomez', datetime.timedelta(days=1, seconds=5880), 2),
#  (122, 'Thelma', 'Murray', datetime.timedelta(seconds=70140), 1),
#  (122, 'Thelma', 'Murray', datetime.timedelta(seconds=76920), 2),
#  (123, 'Shannon', 'Freeman', datetime.timedelta(seconds=69120), 1),
#  (123, 'Shannon', 'Freeman', datetime.timedelta(seconds=69300), 2),
#  (124, 'Sheila', 'Wells', datetime.timedelta(seconds=66600), 1),
#  (124, 'Sheila', 'Wells', datetime.timedelta(seconds=82620), 2),
#  (125, 'Ethel', 'Webb', datetime.timedelta(days=1, seconds=68760), 1),
#  (125, 'Ethel', 'Webb', datetime.timedelta(days=1, seconds=70560), 2),
#  (126, 'Ellen', 'Simpson', datetime.timedelta(seconds=69960), 1),
#  (126, 'Ellen', 'Simpson', datetime.timedelta(seconds=74640), 2),
#  (127, 'Elaine', 'Stevens', datetime.timedelta(seconds=65040), 1),
#  (127, 'Elaine', 'Stevens', datetime.timedelta(days=1, seconds=4440), 2),
#  (128, 'Marjorie', 'Tucker', datetime.timedelta(seconds=80520), 1),
#  (128, 'Marjorie', 'Tucker', datetime.timedelta(days=1, seconds=5340), 2),
#  (129, 'Carrie', 'Porter', datetime.timedelta(seconds=79080), 1),
#  (129, 'Carrie', 'Porter', datetime.timedelta(days=1, seconds=5040), 2),
#  (130, 'Charlotte', 'Hunter', datetime.timedelta(seconds=65940), 1),
#  (130, 'Charlotte', 'Hunter', datetime.timedelta(seconds=68100), 2),
#  (131, 'Monica', 'Hicks', datetime.timedelta(seconds=65880), 1),
#  (131, 'Monica', 'Hicks', datetime.timedelta(seconds=70440), 2),
#  (132, 'Esther', 'Crawford', datetime.timedelta(seconds=75180), 1),
#  (132, 'Esther', 'Crawford', datetime.timedelta(days=1, seconds=780), 2),
#  (133, 'Pauline', 'Henry', datetime.timedelta(days=1, seconds=7080), 1),
#  (133, 'Pauline', 'Henry', datetime.timedelta(days=1, seconds=13140), 2),
#  (134, 'Emma', 'Boyd', datetime.timedelta(seconds=75960), 1),
#  (134, 'Emma', 'Boyd', datetime.timedelta(seconds=81600), 2),
#  (135, 'Juanita', 'Mason', datetime.timedelta(seconds=71100), 1),
#  (135, 'Juanita', 'Mason', datetime.timedelta(days=1, seconds=3240), 2),
#  (136, 'Anita', 'Morales', datetime.timedelta(days=1, seconds=20040), 1),
#  (136, 'Anita', 'Morales', datetime.timedelta(days=1, seconds=76320), 2),
#  (137, 'Rhonda', 'Kennedy', datetime.timedelta(seconds=78300), 1),
#  (137, 'Rhonda', 'Kennedy', datetime.timedelta(seconds=86160), 2),
#  (138, 'Hazel', 'Warren', datetime.timedelta(seconds=72300), 1),
#  (138, 'Hazel', 'Warren', datetime.timedelta(seconds=74160), 2),
#  (139, 'Amber', 'Dixon', datetime.timedelta(days=1, seconds=15600), 1),
#  (139, 'Amber', 'Dixon', datetime.timedelta(days=2, seconds=780), 2),
#  (140, 'Eva', 'Ramos', datetime.timedelta(seconds=66720), 1),
#  (140, 'Eva', 'Ramos', datetime.timedelta(days=1, seconds=65340), 2),
#  (141, 'Debbie', 'Reyes', datetime.timedelta(seconds=80100), 1),
#  (141, 'Debbie', 'Reyes', datetime.timedelta(days=1, seconds=3300), 2),
#  (142, 'April', 'Burns', datetime.timedelta(days=1, seconds=7320), 1),
#  (142, 'April', 'Burns', datetime.timedelta(days=1, seconds=70800), 2),
#  (143, 'Leslie', 'Gordon', datetime.timedelta(seconds=68700), 1),
#  (143, 'Leslie', 'Gordon', datetime.timedelta(days=1, seconds=3660), 2),
#  (144, 'Clara', 'Shaw', datetime.timedelta(seconds=64800), 1),
#  (144, 'Clara', 'Shaw', datetime.timedelta(seconds=79800), 2),
#  (145, 'Lucille', 'Holmes', datetime.timedelta(seconds=84600), 1),
#  (145, 'Lucille', 'Holmes', datetime.timedelta(days=1, seconds=780), 2),
#  (146, 'Jamie', 'Rice', datetime.timedelta(days=1, seconds=7620), 1),
#  (146, 'Jamie', 'Rice', datetime.timedelta(days=1, seconds=16860), 2),
#  (147, 'Joanne', 'Robertson', datetime.timedelta(seconds=84000), 1),
#  (147, 'Joanne', 'Robertson', datetime.timedelta(seconds=84120), 2),
#  (148, 'Eleanor', 'Hunt', datetime.timedelta(seconds=69660), 1),
#  (148, 'Eleanor', 'Hunt', datetime.timedelta(seconds=78180), 2),
#  (149, 'Valerie', 'Black', datetime.timedelta(seconds=75420), 1),
#  (149, 'Valerie', 'Black', datetime.timedelta(days=1, seconds=6180), 2),
#  (150, 'Danielle', 'Daniels', datetime.timedelta(seconds=69960), 1),
#  (150, 'Danielle', 'Daniels', datetime.timedelta(seconds=74520), 2),
#  (151, 'Megan', 'Palmer', datetime.timedelta(seconds=73980), 1),
#  (151, 'Megan', 'Palmer', datetime.timedelta(seconds=76260), 2),
#  (152, 'Alicia', 'Mills', datetime.timedelta(seconds=81420), 1),
#  (152, 'Alicia', 'Mills', datetime.timedelta(seconds=85140), 2),
#  (153, 'Suzanne', 'Nichols', datetime.timedelta(seconds=67020), 1),
#  (153, 'Suzanne', 'Nichols', datetime.timedelta(days=1, seconds=20700), 2),
#  (154, 'Michele', 'Grant', datetime.timedelta(seconds=73380), 1),
#  (154, 'Michele', 'Grant', datetime.timedelta(days=1, seconds=18600), 2),
#  (155, 'Gail', 'Knight', datetime.timedelta(seconds=83640), 1),
#  (155, 'Gail', 'Knight', datetime.timedelta(days=1, seconds=5280), 2),
#  (156, 'Bertha', 'Ferguson', datetime.timedelta(days=1, seconds=4020), 1),
#  (156, 'Bertha', 'Ferguson', datetime.timedelta(days=1, seconds=8100), 2),
#  (157, 'Darlene', 'Rose', datetime.timedelta(seconds=72780), 1),
#  (157, 'Darlene', 'Rose', datetime.timedelta(days=1, seconds=540), 2),
#  (158, 'Veronica', 'Stone', datetime.timedelta(seconds=72720), 1),
#  (158, 'Veronica', 'Stone', datetime.timedelta(seconds=84780), 2),
#  (159, 'Jill', 'Hawkins', datetime.timedelta(seconds=78120), 1),
#  (159, 'Jill', 'Hawkins', datetime.timedelta(days=1, seconds=18720), 2),
#  (160, 'Erin', 'Dunn', datetime.timedelta(seconds=82620), 1),
#  (160, 'Erin', 'Dunn', datetime.timedelta(days=1, seconds=11460), 2),
#  (161, 'Geraldine', 'Perkins', datetime.timedelta(seconds=85620), 1),
#  (161, 'Geraldine', 'Perkins', datetime.timedelta(days=1, seconds=13260), 2),
#  (162, 'Lauren', 'Hudson', datetime.timedelta(seconds=81420), 1),
#  (162, 'Lauren', 'Hudson', datetime.timedelta(seconds=82620), 2),
#  (163, 'Cathy', 'Spencer', datetime.timedelta(seconds=72420), 1),
#  (163, 'Cathy', 'Spencer', datetime.timedelta(seconds=79980), 2),
#  (164, 'Joann', 'Gardner', datetime.timedelta(seconds=83220), 1),
#  (164, 'Joann', 'Gardner', datetime.timedelta(days=1, seconds=960), 2),
#  (165, 'Lorraine', 'Stephens', datetime.timedelta(seconds=70020), 1),
#  (165, 'Lorraine', 'Stephens', datetime.timedelta(seconds=76920), 2),
#  (166, 'Lynn', 'Payne', datetime.timedelta(days=1, seconds=4140), 1),
#  (166, 'Lynn', 'Payne', datetime.timedelta(days=1, seconds=6660), 2),
#  (167, 'Sally', 'Pierce', datetime.timedelta(seconds=65100), 1),
#  (167, 'Sally', 'Pierce', datetime.timedelta(seconds=67080), 2),
#  (168, 'Regina', 'Berry', datetime.timedelta(days=1, seconds=77280), 1),
#  (168, 'Regina', 'Berry', datetime.timedelta(days=2, seconds=9660), 2),
#  (169, 'Erica', 'Matthews', datetime.timedelta(seconds=86340), 1),
#  (169, 'Erica', 'Matthews', datetime.timedelta(days=1, seconds=9360), 2),
#  (170, 'Beatrice', 'Arnold', datetime.timedelta(seconds=70200), 1),
#  (170, 'Beatrice', 'Arnold', datetime.timedelta(days=1, seconds=71940), 2),
#  (171, 'Dolores', 'Wagner', datetime.timedelta(days=1, seconds=9960), 1),
#  (171, 'Dolores', 'Wagner', datetime.timedelta(days=1, seconds=67440), 2),
#  (172, 'Bernice', 'Willis', datetime.timedelta(seconds=69660), 1),
#  (172, 'Bernice', 'Willis', datetime.timedelta(seconds=73620), 2),
#  (173, 'Audrey', 'Ray', datetime.timedelta(seconds=83700), 1),
#  (173, 'Audrey', 'Ray', datetime.timedelta(days=1, seconds=10200), 2),
#  (174, 'Yvonne', 'Watkins', datetime.timedelta(seconds=71460), 1),
#  (174, 'Yvonne', 'Watkins', datetime.timedelta(days=1, seconds=7620), 2),
#  (175, 'Annette', 'Olson', datetime.timedelta(days=1, seconds=77820), 1),
#  (175, 'Annette', 'Olson', datetime.timedelta(days=1, seconds=82380), 2),
#  (176, 'June', 'Carroll', datetime.timedelta(seconds=64980), 1),
#  (176, 'June', 'Carroll', datetime.timedelta(seconds=69360), 2),
#  (177, 'Samantha', 'Duncan', datetime.timedelta(seconds=74820), 1),
#  (177, 'Samantha', 'Duncan', datetime.timedelta(days=1, seconds=4680), 2),
#  (178, 'Marion', 'Snyder', datetime.timedelta(seconds=71100), 1),
#  (178, 'Marion', 'Snyder', datetime.timedelta(seconds=77820), 2),
#  (179, 'Dana', 'Hart', datetime.timedelta(seconds=69180), 1),
#  (179, 'Dana', 'Hart', datetime.timedelta(seconds=75720), 2),
#  (180, 'Stacy', 'Cunningham', datetime.timedelta(seconds=83820), 1),
#  (180, 'Stacy', 'Cunningham', datetime.timedelta(days=2, seconds=66780), 2),
#  (181, 'Ana', 'Bradley', datetime.timedelta(days=1, seconds=5040), 1),
#  (181, 'Ana', 'Bradley', datetime.timedelta(days=1, seconds=76920), 2),
#  (182, 'Renee', 'Lane', datetime.timedelta(seconds=65700), 1),
#  (182, 'Renee', 'Lane', datetime.timedelta(days=1, seconds=13860), 2),
#  (183, 'Ida', 'Andrews', datetime.timedelta(days=1, seconds=3060), 1),
#  (183, 'Ida', 'Andrews', datetime.timedelta(days=1, seconds=5340), 2),
#  (184, 'Vivian', 'Ruiz', datetime.timedelta(seconds=85080), 1),
#  (184, 'Vivian', 'Ruiz', datetime.timedelta(days=1, seconds=2460), 2),
#  (185, 'Roberta', 'Harper', datetime.timedelta(seconds=69900), 1),
#  (185, 'Roberta', 'Harper', datetime.timedelta(seconds=78180), 2),
#  (186, 'Holly', 'Fox', datetime.timedelta(seconds=68700), 1),
#  (186, 'Holly', 'Fox', datetime.timedelta(seconds=68760), 2),
#  (187, 'Brittany', 'Riley', datetime.timedelta(seconds=70440), 1),
#  (187, 'Brittany', 'Riley', datetime.timedelta(days=2, seconds=64860), 2),
#  (188, 'Melanie', 'Armstrong', datetime.timedelta(seconds=72420), 1),
#  (188, 'Melanie', 'Armstrong', datetime.timedelta(seconds=72540), 2),
#  (189, 'Loretta', 'Carpenter', datetime.timedelta(days=1, seconds=15180), 1),
#  (189, 'Loretta', 'Carpenter', datetime.timedelta(days=1, seconds=70620), 2),
#  (190, 'Yolanda', 'Weaver', datetime.timedelta(seconds=76320), 1),
#  (190, 'Yolanda', 'Weaver', datetime.timedelta(days=1, seconds=69360), 2),
#  (191, 'Jeanette', 'Greene', datetime.timedelta(seconds=74400), 1),
#  (191, 'Jeanette', 'Greene', datetime.timedelta(seconds=76560), 2),
#  (192, 'Laurie', 'Lawrence', datetime.timedelta(seconds=85440), 1),
#  (192, 'Laurie', 'Lawrence', datetime.timedelta(days=1, seconds=2100), 2),
#  (193, 'Katie', 'Elliott', datetime.timedelta(seconds=72000), 1),
#  (193, 'Katie', 'Elliott', datetime.timedelta(days=1, seconds=180), 2),
#  (194, 'Kristen', 'Chavez', datetime.timedelta(seconds=64920), 1),
#  (194, 'Kristen', 'Chavez', datetime.timedelta(days=1, seconds=15000), 2),
#  (195, 'Vanessa', 'Sims', datetime.timedelta(seconds=65100), 1),
#  (195, 'Vanessa', 'Sims', datetime.timedelta(seconds=82260), 2),
#  (196, 'Alma', 'Austin', datetime.timedelta(seconds=70140), 1),
#  (196, 'Alma', 'Austin', datetime.timedelta(seconds=72300), 2),
#  (197, 'Sue', 'Peters', datetime.timedelta(seconds=73380), 1),
#  (197, 'Sue', 'Peters', datetime.timedelta(seconds=76680), 2),
#  (198, 'Elsie', 'Kelley', datetime.timedelta(seconds=75600), 1),
#  (198, 'Elsie', 'Kelley', datetime.timedelta(seconds=77700), 2),
#  (199, 'Beth', 'Franklin', datetime.timedelta(seconds=65100), 1),
#  (199, 'Beth', 'Franklin', datetime.timedelta(days=1, seconds=68520), 2),
#  (200, 'Jeanne', 'Lawson', datetime.timedelta(days=1, seconds=7920), 1),
#  (200, 'Jeanne', 'Lawson', datetime.timedelta(days=1, seconds=9240), 2),
#  (201, 'Vicki', 'Fields', datetime.timedelta(seconds=81120), 1),
#  (201, 'Vicki', 'Fields', datetime.timedelta(days=1, seconds=11520), 2),
#  (202, 'Carla', 'Gutierrez', datetime.timedelta(seconds=72840), 1),
#  (202, 'Carla', 'Gutierrez', datetime.timedelta(seconds=79860), 2),
#  (203, 'Tara', 'Ryan', datetime.timedelta(days=1, seconds=80040), 1),
#  (203, 'Tara', 'Ryan', datetime.timedelta(days=1, seconds=85200), 2),
#  (204, 'Rosemary', 'Schmidt', datetime.timedelta(seconds=65220), 1),
#  (204, 'Rosemary', 'Schmidt', datetime.timedelta(seconds=70980), 2),
#  (205, 'Eileen', 'Carr', datetime.timedelta(days=1, seconds=67080), 1),
#  (205, 'Eileen', 'Carr', datetime.timedelta(days=1, seconds=74640), 2),
#  (206, 'Terri', 'Vasquez', datetime.timedelta(seconds=65820), 1),
#  (206, 'Terri', 'Vasquez', datetime.timedelta(seconds=74820), 2),
#  (207, 'Gertrude', 'Castillo', datetime.timedelta(days=1, seconds=960), 1),
#  (207, 'Gertrude', 'Castillo', datetime.timedelta(days=2, seconds=7500), 2),
#  (208, 'Lucy', 'Wheeler', datetime.timedelta(seconds=67260), 1),
#  (208, 'Lucy', 'Wheeler', datetime.timedelta(seconds=71460), 2),
#  (209, 'Tonya', 'Chapman', datetime.timedelta(seconds=74220), 1),
#  (209, 'Tonya', 'Chapman', datetime.timedelta(days=1, seconds=11460), 2),
#  (210, 'Ella', 'Oliver', datetime.timedelta(seconds=78420), 1),
#  (210, 'Ella', 'Oliver', datetime.timedelta(days=1, seconds=8160), 2),
#  (211, 'Stacey', 'Montgomery', datetime.timedelta(seconds=65940), 1),
#  (211, 'Stacey', 'Montgomery', datetime.timedelta(seconds=76440), 2),
#  (212, 'Wilma', 'Richards', datetime.timedelta(days=1, seconds=6780), 1),
#  (212, 'Wilma', 'Richards', datetime.timedelta(days=2, seconds=20520), 2),
#  (213, 'Gina', 'Williamson', datetime.timedelta(seconds=67920), 1),
#  (213, 'Gina', 'Williamson', datetime.timedelta(seconds=70620), 2),
#  (214, 'Kristin', 'Johnston', datetime.timedelta(days=1, seconds=8280), 1),
#  (214, 'Kristin', 'Johnston', datetime.timedelta(days=1, seconds=9000), 2),
#  (215, 'Jessie', 'Banks', datetime.timedelta(days=1, seconds=2460), 1),
#  (215, 'Jessie', 'Banks', datetime.timedelta(days=1, seconds=10080), 2),
#  (216, 'Natalie', 'Meyer', datetime.timedelta(seconds=68520), 1),
#  (216, 'Natalie', 'Meyer', datetime.timedelta(seconds=72480), 2),
#  (217, 'Agnes', 'Bishop', datetime.timedelta(seconds=68880), 1),
#  (217, 'Agnes', 'Bishop', datetime.timedelta(days=1, seconds=14880), 2),
#  (218, 'Vera', 'Mccoy', datetime.timedelta(seconds=84360), 1),
#  (218, 'Vera', 'Mccoy', datetime.timedelta(days=1, seconds=66540), 2),
#  (219, 'Willie', 'Howell', datetime.timedelta(seconds=66360), 1),
#  (219, 'Willie', 'Howell', datetime.timedelta(days=1, seconds=74280), 2),
#  (220, 'Charlene', 'Alvarez', datetime.timedelta(seconds=73860), 1),
#  (220, 'Charlene', 'Alvarez', datetime.timedelta(days=1, seconds=6480), 2),
#  (221, 'Bessie', 'Morrison', datetime.timedelta(seconds=73200), 1),
#  (221, 'Bessie', 'Morrison', datetime.timedelta(seconds=81120), 2),
#  (222, 'Delores', 'Hansen', datetime.timedelta(seconds=70920), 1),
#  (222, 'Delores', 'Hansen', datetime.timedelta(seconds=85080), 2),
#  (223, 'Melinda', 'Fernandez', datetime.timedelta(seconds=83760), 1),
#  (223, 'Melinda', 'Fernandez', datetime.timedelta(days=1, seconds=6900), 2),
#  (224, 'Pearl', 'Garza', datetime.timedelta(seconds=67860), 1),
#  (224, 'Pearl', 'Garza', datetime.timedelta(days=1, seconds=8220), 2),
#  (225, 'Arlene', 'Harvey', datetime.timedelta(seconds=83760), 1),
#  (225, 'Arlene', 'Harvey', datetime.timedelta(seconds=85380), 2),
#  (226, 'Maureen', 'Little', datetime.timedelta(seconds=76320), 1),
#  (226, 'Maureen', 'Little', datetime.timedelta(days=2, seconds=9540), 2),
#  (227, 'Colleen', 'Burton', datetime.timedelta(days=1, seconds=20400), 1),
#  (227, 'Colleen', 'Burton', datetime.timedelta(days=1, seconds=85080), 2),
#  (228, 'Allison', 'Stanley', datetime.timedelta(seconds=72960), 1),
#  (228, 'Allison', 'Stanley', datetime.timedelta(seconds=73020), 2),
#  (229, 'Tamara', 'Nguyen', datetime.timedelta(days=1, seconds=4320), 1),
#  (229, 'Tamara', 'Nguyen', datetime.timedelta(days=1, seconds=4560), 2),
#  (230, 'Joy', 'George', datetime.timedelta(seconds=70020), 1),
#  (230, 'Joy', 'George', datetime.timedelta(seconds=71340), 2),
#  (231, 'Georgia', 'Jacobs', datetime.timedelta(seconds=64980), 1),
#  (231, 'Georgia', 'Jacobs', datetime.timedelta(days=1, seconds=19980), 2),
#  (232, 'Constance', 'Reid', datetime.timedelta(seconds=77640), 1),
#  (232, 'Constance', 'Reid', datetime.timedelta(seconds=78900), 2),
#  (233, 'Lillie', 'Kim', datetime.timedelta(seconds=73680), 1),
#  (233, 'Lillie', 'Kim', datetime.timedelta(seconds=74160), 2),
#  (234, 'Claudia', 'Fuller', datetime.timedelta(seconds=70680), 1),
#  (234, 'Claudia', 'Fuller', datetime.timedelta(seconds=77940), 2),
#  (235, 'Jackie', 'Lynch', datetime.timedelta(seconds=71940), 1),
#  (235, 'Jackie', 'Lynch', datetime.timedelta(days=1, seconds=11520), 2),
#  (236, 'Marcia', 'Dean', datetime.timedelta(seconds=71100), 1),
#  (236, 'Marcia', 'Dean', datetime.timedelta(seconds=73260), 2),
#  (237, 'Tanya', 'Gilbert', datetime.timedelta(seconds=67680), 1),
#  (237, 'Tanya', 'Gilbert', datetime.timedelta(seconds=75000), 2),
#  (238, 'Nellie', 'Garrett', datetime.timedelta(seconds=78780), 1),
#  (238, 'Nellie', 'Garrett', datetime.timedelta(days=1, seconds=66720), 2),
#  (239, 'Minnie', 'Romero', datetime.timedelta(seconds=70980), 1),
#  (239, 'Minnie', 'Romero', datetime.timedelta(days=1, seconds=6780), 2),
#  (240, 'Marlene', 'Welch', datetime.timedelta(seconds=68340), 1),
#  (240, 'Marlene', 'Welch', datetime.timedelta(seconds=72720), 2),
#  (241, 'Heidi', 'Larson', datetime.timedelta(seconds=72120), 1),
#  (241, 'Heidi', 'Larson', datetime.timedelta(seconds=75120), 2),
#  (242, 'Glenda', 'Frazier', datetime.timedelta(seconds=66720), 1),
#  (242, 'Glenda', 'Frazier', datetime.timedelta(seconds=84600), 2),
#  (243, 'Lydia', 'Burke', datetime.timedelta(seconds=64860), 1),
#  (243, 'Lydia', 'Burke', datetime.timedelta(seconds=65580), 2),
#  (244, 'Viola', 'Hanson', datetime.timedelta(seconds=68880), 1),
#  (244, 'Viola', 'Hanson', datetime.timedelta(seconds=73260), 2),
#  (245, 'Courtney', 'Day', datetime.timedelta(seconds=80640), 1),
#  (245, 'Courtney', 'Day', datetime.timedelta(days=1, seconds=10500), 2),
#  (246, 'Marian', 'Mendoza', datetime.timedelta(seconds=72480), 1),
#  (246, 'Marian', 'Mendoza', datetime.timedelta(days=1, seconds=6360), 2),
#  (247, 'Stella', 'Moreno', datetime.timedelta(days=1, seconds=600), 1),
#  (247, 'Stella', 'Moreno', datetime.timedelta(days=1, seconds=19740), 2),
#  (248, 'Caroline', 'Bowman', datetime.timedelta(seconds=69180), 1),
#  (248, 'Caroline', 'Bowman', datetime.timedelta(days=2, seconds=3180), 2),
#  (249, 'Dora', 'Medina', datetime.timedelta(days=1, seconds=83640), 1),
#  (249, 'Dora', 'Medina', datetime.timedelta(days=2, seconds=9420), 2),
#  (250, 'Jo', 'Fowler', datetime.timedelta(seconds=85320), 1),
#  (250, 'Jo', 'Fowler', datetime.timedelta(days=1, seconds=16140), 2),
#  (251, 'Vickie', 'Brewer', datetime.timedelta(seconds=65520), 1),
#  (251, 'Vickie', 'Brewer', datetime.timedelta(seconds=66780), 2),
#  (252, 'Mattie', 'Hoffman', datetime.timedelta(seconds=65280), 1),
#  (252, 'Mattie', 'Hoffman', datetime.timedelta(seconds=84420), 2),
#  (253, 'Terry', 'Carlson', datetime.timedelta(seconds=72360), 1),
#  (253, 'Terry', 'Carlson', datetime.timedelta(days=1, seconds=5940), 2),
#  (254, 'Maxine', 'Silva', datetime.timedelta(seconds=74460), 1),
#  (254, 'Maxine', 'Silva', datetime.timedelta(seconds=75660), 2),
#  (255, 'Irma', 'Pearson', datetime.timedelta(seconds=72480), 1),
#  (255, 'Irma', 'Pearson', datetime.timedelta(seconds=75060), 2),
#  (256, 'Mabel', 'Holland', datetime.timedelta(seconds=75840), 1),
#  (256, 'Mabel', 'Holland', datetime.timedelta(seconds=84060), 2),
#  (257, 'Marsha', 'Douglas', datetime.timedelta(seconds=65100), 1),
#  (257, 'Marsha', 'Douglas', datetime.timedelta(seconds=69360), 2),
#  (258, 'Myrtle', 'Fleming', datetime.timedelta(seconds=74100), 1),
#  (258, 'Myrtle', 'Fleming', datetime.timedelta(seconds=75060), 2),
#  (259, 'Lena', 'Jensen', datetime.timedelta(seconds=84600), 1),
#  (259, 'Lena', 'Jensen', datetime.timedelta(days=1, seconds=720), 2),
#  (260, 'Christy', 'Vargas', datetime.timedelta(seconds=77400), 1),
#  (260, 'Christy', 'Vargas', datetime.timedelta(days=1, seconds=960), 2),
#  (261, 'Deanna', 'Byrd', datetime.timedelta(seconds=81840), 1),
#  (261, 'Deanna', 'Byrd', datetime.timedelta(days=1, seconds=2880), 2),
#  (262, 'Patsy', 'Davidson', datetime.timedelta(seconds=81240), 1),
#  (262, 'Patsy', 'Davidson', datetime.timedelta(days=1, seconds=78120), 2),
#  (263, 'Hilda', 'Hopkins', datetime.timedelta(seconds=67620), 1),
#  (263, 'Hilda', 'Hopkins', datetime.timedelta(seconds=73380), 2),
#  (264, 'Gwendolyn', 'May', datetime.timedelta(seconds=79440), 1),
#  (264, 'Gwendolyn', 'May', datetime.timedelta(seconds=83700), 2),
#  (265, 'Jennie', 'Terry', datetime.timedelta(seconds=68520), 1),
#  (265, 'Jennie', 'Terry', datetime.timedelta(days=1, seconds=4440), 2),
#  (266, 'Nora', 'Herrera', datetime.timedelta(seconds=74100), 1),
#  (266, 'Nora', 'Herrera', datetime.timedelta(seconds=82500), 2),
#  (267, 'Margie', 'Wade', datetime.timedelta(seconds=84780), 1),
#  (267, 'Margie', 'Wade', datetime.timedelta(days=1, seconds=69180), 2),
#  (268, 'Nina', 'Soto', datetime.timedelta(seconds=81060), 1),
#  (268, 'Nina', 'Soto', datetime.timedelta(seconds=81900), 2),
#  (269, 'Cassandra', 'Walters', datetime.timedelta(days=1, seconds=13800), 1),
#  (269, 'Cassandra', 'Walters', datetime.timedelta(days=1, seconds=16020), 2),
#  (270, 'Leah', 'Curtis', datetime.timedelta(seconds=83880), 1),
#  (270, 'Leah', 'Curtis', datetime.timedelta(days=1, seconds=17040), 2),
#  (271, 'Penny', 'Neal', datetime.timedelta(days=1, seconds=13080), 1),
#  (271, 'Penny', 'Neal', datetime.timedelta(days=1, seconds=14400), 2),
#  (272, 'Kay', 'Caldwell', datetime.timedelta(seconds=74940), 1),
#  (272, 'Kay', 'Caldwell', datetime.timedelta(seconds=77940), 2),
#  (273, 'Priscilla', 'Lowe', datetime.timedelta(seconds=68520), 1),
#  (273, 'Priscilla', 'Lowe', datetime.timedelta(seconds=69720), 2),
#  (274, 'Naomi', 'Jennings', datetime.timedelta(seconds=71100), 1),
#  (274, 'Naomi', 'Jennings', datetime.timedelta(seconds=71880), 2),
#  (275, 'Carole', 'Barnett', datetime.timedelta(seconds=79380), 1),
#  (275, 'Carole', 'Barnett', datetime.timedelta(days=1, seconds=65940), 2),
#  (276, 'Brandy', 'Graves', datetime.timedelta(seconds=81540), 1),
#  (276, 'Brandy', 'Graves', datetime.timedelta(days=1, seconds=71760), 2),
#  (277, 'Olga', 'Jimenez', datetime.timedelta(seconds=84780), 1),
#  (277, 'Olga', 'Jimenez', datetime.timedelta(days=1, seconds=480), 2),
#  (278, 'Billie', 'Horton', datetime.timedelta(seconds=74700), 1),
#  (278, 'Billie', 'Horton', datetime.timedelta(seconds=80700), 2),
#  (279, 'Dianne', 'Shelton', datetime.timedelta(seconds=78540), 1),
#  (279, 'Dianne', 'Shelton', datetime.timedelta(seconds=80460), 2),
#  (280, 'Tracey', 'Barrett', datetime.timedelta(seconds=81360), 1),
#  (280, 'Tracey', 'Barrett', datetime.timedelta(days=1, seconds=1140), 2),
#  (281, 'Leona', 'Obrien', datetime.timedelta(days=1, seconds=4620), 1),
#  (281, 'Leona', 'Obrien', datetime.timedelta(days=1, seconds=72900), 2),
#  (282, 'Jenny', 'Castro', datetime.timedelta(seconds=70080), 1),
#  (282, 'Jenny', 'Castro', datetime.timedelta(seconds=71700), 2),
#  (283, 'Felicia', 'Sutton', datetime.timedelta(seconds=73500), 1),
#  (283, 'Felicia', 'Sutton', datetime.timedelta(seconds=78060), 2),
#  (284, 'Sonia', 'Gregory', datetime.timedelta(days=2, seconds=6540), 1),
#  (284, 'Sonia', 'Gregory', datetime.timedelta(days=2, seconds=15660), 2),
#  (285, 'Miriam', 'Mckinney', datetime.timedelta(seconds=73860), 1),
#  (285, 'Miriam', 'Mckinney', datetime.timedelta(days=1, seconds=10380), 2),
#  (286, 'Velma', 'Lucas', datetime.timedelta(seconds=80760), 1),
#  (286, 'Velma', 'Lucas', datetime.timedelta(seconds=85560), 2),
#  (287, 'Becky', 'Miles', datetime.timedelta(seconds=67980), 1),
#  (287, 'Becky', 'Miles', datetime.timedelta(seconds=79560), 2),
#  (288, 'Bobbie', 'Craig', datetime.timedelta(seconds=74220), 1),
#  (288, 'Bobbie', 'Craig', datetime.timedelta(days=1, seconds=7380), 2),
#  (289, 'Violet', 'Rodriquez', datetime.timedelta(days=1, seconds=2100), 1),
#  (289, 'Violet', 'Rodriquez', datetime.timedelta(days=1, seconds=69600), 2),
#  (290, 'Kristina', 'Chambers', datetime.timedelta(seconds=66840), 1),
#  (290, 'Kristina', 'Chambers', datetime.timedelta(days=1, seconds=16380), 2),
#  (291, 'Toni', 'Holt', datetime.timedelta(days=1, seconds=85800), 1),
#  (291, 'Toni', 'Holt', datetime.timedelta(days=2, seconds=2340), 2),
#  (292, 'Misty', 'Lambert', datetime.timedelta(days=1, seconds=1800), 1),
#  (292, 'Misty', 'Lambert', datetime.timedelta(days=2, seconds=1440), 2),
#  (293, 'Mae', 'Fletcher', datetime.timedelta(days=1, seconds=75420), 1),
#  (293, 'Mae', 'Fletcher', datetime.timedelta(days=1, seconds=80520), 2),
#  (294, 'Shelly', 'Watts', datetime.timedelta(days=1, seconds=16080), 1),
#  (294, 'Shelly', 'Watts', datetime.timedelta(days=1, seconds=73620), 2),
#  (295, 'Daisy', 'Bates', datetime.timedelta(seconds=71640), 1),
#  (295, 'Daisy', 'Bates', datetime.timedelta(seconds=84480), 2),
#  (296, 'Ramona', 'Hale', datetime.timedelta(seconds=67860), 1),
#  (296, 'Ramona', 'Hale', datetime.timedelta(seconds=67980), 2),
#  (297, 'Sherri', 'Rhodes', datetime.timedelta(seconds=70500), 1),
#  (297, 'Sherri', 'Rhodes', datetime.timedelta(seconds=79620), 2),
#  (298, 'Erika', 'Pena', datetime.timedelta(days=1, seconds=1980), 1),
#  (298, 'Erika', 'Pena', datetime.timedelta(days=1, seconds=6060), 2),
#  (299, 'James', 'Gannon', datetime.timedelta(seconds=84000), 1),
#  (299, 'James', 'Gannon', datetime.timedelta(days=1, seconds=4500), 2),
#  (300, 'John', 'Farnsworth', datetime.timedelta(seconds=79020), 1),
#  (300, 'John', 'Farnsworth', datetime.timedelta(days=1, seconds=9480), 2),
#  (301, 'Robert', 'Baughman', datetime.timedelta(seconds=68340), 1),
#  (301, 'Robert', 'Baughman', datetime.timedelta(seconds=81960), 2),
#  (302, 'Michael', 'Silverman', datetime.timedelta(days=1, seconds=21240), 1),
#  (302, 'Michael', 'Silverman', datetime.timedelta(days=1, seconds=68040), 2),
#  (303, 'William', 'Satterfield', datetime.timedelta(seconds=79980), 1),
#  (303, 'William', 'Satterfield', datetime.timedelta(days=1, seconds=82800), 2),
#  (304, 'David', 'Royal', datetime.timedelta(seconds=76680), 1),
#  (304, 'David', 'Royal', datetime.timedelta(days=1, seconds=15360), 2),
#  (305, 'Richard', 'Mccrary', datetime.timedelta(days=1, seconds=2880), 1),
#  (305, 'Richard', 'Mccrary', datetime.timedelta(days=1, seconds=18960), 2),
#  (306, 'Charles', 'Kowalski', datetime.timedelta(seconds=85140), 1),
#  (306, 'Charles', 'Kowalski', datetime.timedelta(days=1, seconds=9120), 2),
#  (307, 'Joseph', 'Joy', datetime.timedelta(days=1, seconds=75480), 1),
#  (307, 'Joseph', 'Joy', datetime.timedelta(days=1, seconds=77040), 2),
#  (308, 'Thomas', 'Grigsby', datetime.timedelta(seconds=83040), 1),
#  (308, 'Thomas', 'Grigsby', datetime.timedelta(days=1, seconds=4260), 2),
#  (309, 'Christopher', 'Greco', datetime.timedelta(days=1, seconds=960), 1),
#  (309, 'Christopher', 'Greco', datetime.timedelta(days=1, seconds=3420), 2),
#  (310, 'Daniel', 'Cabral', datetime.timedelta(seconds=81360), 1),
#  (310, 'Daniel', 'Cabral', datetime.timedelta(days=1, seconds=6540), 2),
#  (311, 'Paul', 'Trout', datetime.timedelta(days=1, seconds=2760), 1),
#  (311, 'Paul', 'Trout', datetime.timedelta(days=1, seconds=13620), 2),
#  (312, 'Mark', 'Rinehart', datetime.timedelta(seconds=75720), 1),
#  (312, 'Mark', 'Rinehart', datetime.timedelta(days=1, seconds=9720), 2),
#  (313, 'Donald', 'Mahon', datetime.timedelta(seconds=83220), 1),
#  (313, 'Donald', 'Mahon', datetime.timedelta(days=1, seconds=840), 2),
#  (314, 'George', 'Linton', datetime.timedelta(seconds=70200), 1),
#  (314, 'George', 'Linton', datetime.timedelta(seconds=72000), 2),
#  (315, 'Kenneth', 'Gooden', datetime.timedelta(seconds=67680), 1),
#  (315, 'Kenneth', 'Gooden', datetime.timedelta(days=3, seconds=75420), 2),
#  (316, 'Steven', 'Curley', datetime.timedelta(seconds=72600), 1),
#  (316, 'Steven', 'Curley', datetime.timedelta(days=1, seconds=4800), 2),
#  (317, 'Edward', 'Baugh', datetime.timedelta(seconds=86040), 1),
#  (317, 'Edward', 'Baugh', datetime.timedelta(days=1, seconds=83700), 2),
#  (318, 'Brian', 'Wyman', datetime.timedelta(seconds=70860), 1),
#  (318, 'Brian', 'Wyman', datetime.timedelta(days=1, seconds=10140), 2),
#  (319, 'Ronald', 'Weiner', datetime.timedelta(seconds=70620), 1),
#  (319, 'Ronald', 'Weiner', datetime.timedelta(seconds=82380), 2),
#  (320, 'Anthony', 'Schwab', datetime.timedelta(days=1, seconds=11340), 1),
#  (320, 'Anthony', 'Schwab', datetime.timedelta(days=1, seconds=11760), 2),
#  (321, 'Kevin', 'Schuler', datetime.timedelta(seconds=73500), 1),
#  (321, 'Kevin', 'Schuler', datetime.timedelta(days=1, seconds=20280), 2),
#  (322, 'Jason', 'Morrissey', datetime.timedelta(seconds=71760), 1),
#  (322, 'Jason', 'Morrissey', datetime.timedelta(seconds=85200), 2),
#  (323, 'Matthew', 'Mahan', datetime.timedelta(seconds=66360), 1),
#  (323, 'Matthew', 'Mahan', datetime.timedelta(seconds=74340), 2),
#  (324, 'Gary', 'Coy', datetime.timedelta(seconds=74160), 1),
#  (324, 'Gary', 'Coy', datetime.timedelta(days=1, seconds=8820), 2),
#  (325, 'Timothy', 'Bunn', datetime.timedelta(seconds=69780), 1),
#  (325, 'Timothy', 'Bunn', datetime.timedelta(seconds=70860), 2),
#  (326, 'Jose', 'Andrew', datetime.timedelta(seconds=77160), 1),
#  (326, 'Jose', 'Andrew', datetime.timedelta(days=1, seconds=19380), 2),
#  (327, 'Larry', 'Thrasher', datetime.timedelta(days=1, seconds=75180), 1),
#  (327, 'Larry', 'Thrasher', datetime.timedelta(days=2, seconds=2220), 2),
#  (328, 'Jeffrey', 'Spear', datetime.timedelta(seconds=82560), 1),
#  (328, 'Jeffrey', 'Spear', datetime.timedelta(days=1, seconds=60), 2),
#  (329, 'Frank', 'Waggoner', datetime.timedelta(seconds=82260), 1),
#  (329, 'Frank', 'Waggoner', datetime.timedelta(days=1, seconds=1920), 2),
#  (330, 'Scott', 'Shelley', datetime.timedelta(days=1, seconds=4860), 1),
#  (330, 'Scott', 'Shelley', datetime.timedelta(days=1, seconds=67260), 2),
#  (331, 'Eric', 'Robert', datetime.timedelta(seconds=75120), 1),
#  (331, 'Eric', 'Robert', datetime.timedelta(seconds=76980), 2),
#  (332, 'Stephen', 'Qualls', datetime.timedelta(seconds=78060), 1),
#  (332, 'Stephen', 'Qualls', datetime.timedelta(days=1, seconds=79740), 2),
#  (333, 'Andrew', 'Purdy', datetime.timedelta(seconds=71640), 1),
#  (333, 'Andrew', 'Purdy', datetime.timedelta(days=1), 2),
#  (334, 'Raymond', 'Mcwhorter', datetime.timedelta(seconds=70200), 1),
#  (334, 'Raymond', 'Mcwhorter', datetime.timedelta(seconds=73380), 2),
#  (335, 'Gregory', 'Mauldin', datetime.timedelta(seconds=67320), 1),
#  (335, 'Gregory', 'Mauldin', datetime.timedelta(days=1, seconds=2400), 2),
#  (336, 'Joshua', 'Mark', datetime.timedelta(seconds=65880), 1),
#  (336, 'Joshua', 'Mark', datetime.timedelta(seconds=85380), 2),
#  (337, 'Jerry', 'Jordon', datetime.timedelta(seconds=80940), 1),
#  (337, 'Jerry', 'Jordon', datetime.timedelta(days=2, seconds=12480), 2),
#  (338, 'Dennis', 'Gilman', datetime.timedelta(days=1, seconds=5760), 1),
#  (338, 'Dennis', 'Gilman', datetime.timedelta(days=1, seconds=70200), 2),
#  (339, 'Walter', 'Perryman', datetime.timedelta(seconds=72720), 1),
#  (339, 'Walter', 'Perryman', datetime.timedelta(seconds=76560), 2),
#  (340, 'Patrick', 'Newsom', datetime.timedelta(seconds=71640), 1),
#  (340, 'Patrick', 'Newsom', datetime.timedelta(days=1, seconds=5880), 2),
#  (341, 'Peter', 'Menard', datetime.timedelta(seconds=74520), 1),
#  (341, 'Peter', 'Menard', datetime.timedelta(seconds=78180), 2),
#  (342, 'Harold', 'Martino', datetime.timedelta(seconds=78540), 1),
#  (342, 'Harold', 'Martino', datetime.timedelta(seconds=82740), 2),
#  (343, 'Douglas', 'Graf', datetime.timedelta(seconds=66300), 1),
#  (343, 'Douglas', 'Graf', datetime.timedelta(seconds=78360), 2),
#  (344, 'Henry', 'Billingsley', datetime.timedelta(seconds=71520), 1),
#  (344, 'Henry', 'Billingsley', datetime.timedelta(days=1, seconds=71940), 2),
#  (345, 'Carl', 'Artis', datetime.timedelta(seconds=72660), 1),
#  (345, 'Carl', 'Artis', datetime.timedelta(seconds=80700), 2),
#  (346, 'Arthur', 'Simpkins', datetime.timedelta(seconds=70500), 1),
#  (346, 'Arthur', 'Simpkins', datetime.timedelta(seconds=73500), 2),
#  (347, 'Ryan', 'Salisbury', datetime.timedelta(seconds=72600), 1),
#  (347, 'Ryan', 'Salisbury', datetime.timedelta(days=1, seconds=3780), 2),
#  (348, 'Roger', 'Quintanilla', datetime.timedelta(seconds=85080), 1),
#  (348, 'Roger', 'Quintanilla', datetime.timedelta(days=1, seconds=72660), 2),
#  (349, 'Joe', 'Gilliland', datetime.timedelta(seconds=77280), 1),
#  (349, 'Joe', 'Gilliland', datetime.timedelta(seconds=86160), 2),
# ...
#  (385, 'Phillip', 'Holm', datetime.timedelta(seconds=83940), 2),
#  (386, 'Todd', 'Tan', datetime.timedelta(days=1, seconds=17820), 1),
#  (386, 'Todd', 'Tan', datetime.timedelta(days=1, seconds=70800), 2),
#  (387, 'Jesse', 'Schilling', datetime.timedelta(seconds=82500), 1),
#  (387, 'Jesse', 'Schilling', datetime.timedelta(seconds=86280), 2),
#  (388, 'Craig', 'Morrell', datetime.timedelta(seconds=82620), 1),
#  (388, 'Craig', 'Morrell', datetime.timedelta(seconds=82920), 2),
#  (389, 'Alan', 'Kahn', datetime.timedelta(days=1, seconds=80700), 1),
#  (389, 'Alan', 'Kahn', datetime.timedelta(days=1, seconds=84120), 2),
#  (390, 'Shawn', 'Heaton', datetime.timedelta(seconds=69240), 1),
#  (390, 'Shawn', 'Heaton', datetime.timedelta(seconds=70860), 2),
#  (391, 'Clarence', 'Gamez', datetime.timedelta(seconds=70920), 1),
#  (391, 'Clarence', 'Gamez', datetime.timedelta(seconds=81240), 2),
#  (392, 'Sean', 'Douglass', datetime.timedelta(seconds=68700), 1),
#  (392, 'Sean', 'Douglass', datetime.timedelta(days=1, seconds=71700), 2),
#  (393, 'Philip', 'Causey', datetime.timedelta(seconds=66480), 1),
#  (393, 'Philip', 'Causey', datetime.timedelta(days=1, seconds=7800), 2),
#  (394, 'Chris', 'Brothers', datetime.timedelta(days=1, seconds=4380), 1),
#  (394, 'Chris', 'Brothers', datetime.timedelta(days=1, seconds=72720), 2),
#  (395, 'Johnny', 'Turpin', datetime.timedelta(seconds=72960), 1),
#  (395, 'Johnny', 'Turpin', datetime.timedelta(seconds=74460), 2),
#  (396, 'Earl', 'Shanks', datetime.timedelta(seconds=67560), 1),
#  (396, 'Earl', 'Shanks', datetime.timedelta(days=1, seconds=73980), 2),
#  (397, 'Jimmy', 'Schrader', datetime.timedelta(seconds=71880), 1),
#  (397, 'Jimmy', 'Schrader', datetime.timedelta(seconds=76200), 2),
#  (398, 'Antonio', 'Meek', datetime.timedelta(seconds=74100), 1),
#  (398, 'Antonio', 'Meek', datetime.timedelta(days=2, seconds=67860), 2),
#  (399, 'Danny', 'Isom', datetime.timedelta(seconds=67500), 1),
#  (399, 'Danny', 'Isom', datetime.timedelta(seconds=86100), 2),
#  (400, 'Bryan', 'Hardison', datetime.timedelta(seconds=65640), 1),
#  (400, 'Bryan', 'Hardison', datetime.timedelta(seconds=74820), 2),
#  (401, 'Tony', 'Carranza', datetime.timedelta(seconds=74760), 1),
#  (401, 'Tony', 'Carranza', datetime.timedelta(seconds=77700), 2),
#  (402, 'Luis', 'Yanez', datetime.timedelta(days=1, seconds=6300), 1),
#  (402, 'Luis', 'Yanez', datetime.timedelta(days=1, seconds=8640), 2),
#  (403, 'Mike', 'Way', datetime.timedelta(seconds=70920), 1),
#  (403, 'Mike', 'Way', datetime.timedelta(seconds=74940), 2),
#  (404, 'Stanley', 'Scroggins', datetime.timedelta(days=1, seconds=68340), 1),
#  (404, 'Stanley', 'Scroggins', datetime.timedelta(days=1, seconds=68340), 1),
#  (405, 'Leonard', 'Schofield', datetime.timedelta(seconds=74820), 1),
#  (405, 'Leonard', 'Schofield', datetime.timedelta(seconds=79140), 2),
#  (406, 'Nathan', 'Runyon', datetime.timedelta(seconds=66240), 1),
#  (406, 'Nathan', 'Runyon', datetime.timedelta(seconds=74340), 2),
#  (407, 'Dale', 'Ratcliff', datetime.timedelta(seconds=64920), 1),
#  (407, 'Dale', 'Ratcliff', datetime.timedelta(seconds=75000), 2),
#  (408, 'Manuel', 'Murrell', datetime.timedelta(days=1, seconds=5520), 1),
#  (408, 'Manuel', 'Murrell', datetime.timedelta(days=1, seconds=19080), 2),
#  (409, 'Rodney', 'Moeller', datetime.timedelta(seconds=64800), 1),
#  (409, 'Rodney', 'Moeller', datetime.timedelta(seconds=69300), 2),
#  (410, 'Curtis', 'Irby', datetime.timedelta(seconds=69960), 1),
#  (410, 'Curtis', 'Irby', datetime.timedelta(seconds=82020), 2),
#  (411, 'Norman', 'Currier', datetime.timedelta(days=1, seconds=7320), 1),
#  (411, 'Norman', 'Currier', datetime.timedelta(days=1, seconds=12000), 2),
#  (412, 'Allen', 'Butterfield', datetime.timedelta(days=1, seconds=4260), 1),
#  (412, 'Allen', 'Butterfield', datetime.timedelta(days=1, seconds=73260), 2),
#  (413, 'Marvin', 'Yee', datetime.timedelta(seconds=76860), 1),
#  (413, 'Marvin', 'Yee', datetime.timedelta(days=1, seconds=3240), 2),
#  (414, 'Vincent', 'Ralston', datetime.timedelta(days=1, seconds=10200), 1),
#  (414, 'Vincent', 'Ralston', datetime.timedelta(days=1, seconds=14700), 2),
#  (415, 'Glenn', 'Pullen', datetime.timedelta(seconds=71820), 1),
#  (415, 'Glenn', 'Pullen', datetime.timedelta(seconds=76320), 2),
#  (416, 'Jeffery', 'Pinson', datetime.timedelta(seconds=68040), 1),
#  (416, 'Jeffery', 'Pinson', datetime.timedelta(seconds=68160), 2),
#  (417, 'Travis', 'Estep', datetime.timedelta(seconds=85680), 1),
#  (417, 'Travis', 'Estep', datetime.timedelta(days=1, seconds=2280), 2),
#  (418, 'Jeff', 'East', datetime.timedelta(seconds=64920), 1),
#  (418, 'Jeff', 'East', datetime.timedelta(seconds=78420), 2),
#  (419, 'Chad', 'Carbone', datetime.timedelta(seconds=82320), 1),
#  (419, 'Chad', 'Carbone', datetime.timedelta(seconds=84720), 2),
#  (420, 'Jacob', 'Lance', datetime.timedelta(seconds=64920), 1),
#  (420, 'Jacob', 'Lance', datetime.timedelta(days=1, seconds=5040), 2),
#  (421, 'Lee', 'Hawks', datetime.timedelta(days=1, seconds=5700), 1),
#  (421, 'Lee', 'Hawks', datetime.timedelta(days=1, seconds=15840), 2),
#  (422, 'Melvin', 'Ellington', datetime.timedelta(days=1, seconds=85500), 1),
#  (422, 'Melvin', 'Ellington', datetime.timedelta(days=2, seconds=14580), 2),
#  (423, 'Alfred', 'Casillas', datetime.timedelta(days=1, seconds=2280), 1),
#  (423, 'Alfred', 'Casillas', datetime.timedelta(days=1, seconds=69360), 2),
#  (424, 'Kyle', 'Spurlock', datetime.timedelta(seconds=66120), 1),
#  (424, 'Kyle', 'Spurlock', datetime.timedelta(seconds=84360), 2),
#  (425, 'Francis', 'Sikes', datetime.timedelta(seconds=67860), 1),
#  (425, 'Francis', 'Sikes', datetime.timedelta(seconds=84900), 2),
#  (426, 'Bradley', 'Motley', datetime.timedelta(days=1, seconds=7620), 1),
#  (426, 'Bradley', 'Motley', datetime.timedelta(days=1, seconds=8400), 2),
#  (427, 'Jesus', 'Mccartney', datetime.timedelta(seconds=70320), 1),
#  (427, 'Jesus', 'Mccartney', datetime.timedelta(days=1, seconds=11700), 2),
#  (428, 'Herbert', 'Kruger', datetime.timedelta(seconds=78360), 1),
#  (428, 'Herbert', 'Kruger', datetime.timedelta(days=1, seconds=8100), 2),
#  (429, 'Frederick', 'Isbell', datetime.timedelta(seconds=65760), 1),
#  (429, 'Frederick', 'Isbell', datetime.timedelta(seconds=79140), 2),
#  (430, 'Ray', 'Houle', datetime.timedelta(days=1, seconds=2640), 1),
#  (430, 'Ray', 'Houle', datetime.timedelta(days=1, seconds=9120), 2),
#  (431, 'Joel', 'Francisco', datetime.timedelta(seconds=82440), 1),
#  (431, 'Joel', 'Francisco', datetime.timedelta(days=1, seconds=10680), 2),
#  (432, 'Edwin', 'Burk', datetime.timedelta(seconds=75000), 1),
#  (432, 'Edwin', 'Burk', datetime.timedelta(days=1, seconds=13920), 2),
#  (433, 'Don', 'Bone', datetime.timedelta(seconds=75900), 1),
#  (433, 'Don', 'Bone', datetime.timedelta(days=1, seconds=10980), 2),
#  (434, 'Eddie', 'Tomlin', datetime.timedelta(seconds=71580), 1),
#  (434, 'Eddie', 'Tomlin', datetime.timedelta(days=1, seconds=4740), 2),
#  (435, 'Ricky', 'Shelby', datetime.timedelta(seconds=67800), 1),
#  (435, 'Ricky', 'Shelby', datetime.timedelta(seconds=68160), 2),
#  (436, 'Troy', 'Quigley', datetime.timedelta(days=2, seconds=7920), 1),
#  (436, 'Troy', 'Quigley', datetime.timedelta(days=2, seconds=9840), 2),
#  (437, 'Randall', 'Neumann', datetime.timedelta(days=1, seconds=16920), 1),
#  (437, 'Randall', 'Neumann', datetime.timedelta(days=1, seconds=72060), 2),
#  (438, 'Barry', 'Lovelace', datetime.timedelta(days=1, seconds=4560), 1),
#  (438, 'Barry', 'Lovelace', datetime.timedelta(days=1, seconds=6900), 2),
#  (439, 'Alexander', 'Fennell', datetime.timedelta(seconds=69240), 1),
#  (439, 'Alexander', 'Fennell', datetime.timedelta(seconds=69240), 1),
#  (440, 'Bernard', 'Colby', datetime.timedelta(days=1, seconds=14220), 1),
#  (440, 'Bernard', 'Colby', datetime.timedelta(days=1, seconds=65040), 2),
#  (441, 'Mario', 'Cheatham', datetime.timedelta(days=1, seconds=1620), 1),
#  (441, 'Mario', 'Cheatham', datetime.timedelta(days=1, seconds=16560), 2),
#  (442, 'Leroy', 'Bustamante', datetime.timedelta(seconds=77460), 1),
#  (442, 'Leroy', 'Bustamante', datetime.timedelta(days=1, seconds=8160), 2),
#  (443, 'Francisco', 'Skidmore', datetime.timedelta(days=1, seconds=6480), 1),
#  (443, 'Francisco', 'Skidmore', datetime.timedelta(days=1, seconds=64800), 2),
#  (444, 'Marcus', 'Hidalgo', datetime.timedelta(seconds=69240), 1),
#  (444, 'Marcus', 'Hidalgo', datetime.timedelta(seconds=78120), 2),
#  (445, 'Micheal', 'Forman', datetime.timedelta(days=1, seconds=74160), 1),
#  (445, 'Micheal', 'Forman', datetime.timedelta(days=2, seconds=6120), 2),
#  (446, 'Theodore', 'Culp', datetime.timedelta(days=1, seconds=2580), 1),
#  (446, 'Theodore', 'Culp', datetime.timedelta(days=1, seconds=8700), 2),
#  (447, 'Clifford', 'Bowens', datetime.timedelta(seconds=80220), 1),
#  (447, 'Clifford', 'Bowens', datetime.timedelta(days=1, seconds=7800), 2),
#  (448, 'Miguel', 'Betancourt', datetime.timedelta(days=1, seconds=12600), 1),
#  (448, 'Miguel', 'Betancourt', datetime.timedelta(days=1, seconds=21480), 2),
#  (449, 'Oscar', 'Aquino', datetime.timedelta(days=1, seconds=21180), 1),
#  (449, 'Oscar', 'Aquino', datetime.timedelta(days=1, seconds=68280), 2),
#  (450, 'Jay', 'Robb', datetime.timedelta(days=1, seconds=6120), 1),
#  (450, 'Jay', 'Robb', datetime.timedelta(days=1, seconds=16860), 2),
#  (451, 'Jim', 'Rea', datetime.timedelta(seconds=67680), 1),
#  (451, 'Jim', 'Rea', datetime.timedelta(days=1, seconds=15540), 2),
#  (452, 'Tom', 'Milner', datetime.timedelta(seconds=74280), 1),
#  (452, 'Tom', 'Milner', datetime.timedelta(seconds=78840), 2),
#  (453, 'Calvin', 'Martel', datetime.timedelta(seconds=66480), 1),
#  (453, 'Calvin', 'Martel', datetime.timedelta(seconds=79380), 2),
#  (454, 'Alex', 'Gresham', datetime.timedelta(seconds=78060), 1),
#  (454, 'Alex', 'Gresham', datetime.timedelta(seconds=81060), 2),
#  (455, 'Jon', 'Wiles', datetime.timedelta(seconds=69180), 1),
#  (455, 'Jon', 'Wiles', datetime.timedelta(seconds=81180), 2),
#  (456, 'Ronnie', 'Ricketts', datetime.timedelta(seconds=73920), 1),
#  (456, 'Ronnie', 'Ricketts', datetime.timedelta(days=1, seconds=14880), 2),
#  (457, 'Bill', 'Gavin', datetime.timedelta(seconds=82260), 1),
#  (457, 'Bill', 'Gavin', datetime.timedelta(days=1, seconds=5160), 2),
#  (458, 'Lloyd', 'Dowd', datetime.timedelta(seconds=75900), 1),
#  (458, 'Lloyd', 'Dowd', datetime.timedelta(days=1, seconds=16500), 2),
#  (459, 'Tommy', 'Collazo', datetime.timedelta(seconds=67500), 1),
#  (459, 'Tommy', 'Collazo', datetime.timedelta(seconds=83100), 2),
#  (460, 'Leon', 'Bostic', datetime.timedelta(seconds=69720), 1),
#  (460, 'Leon', 'Bostic', datetime.timedelta(days=1, seconds=4020), 2),
#  (461, 'Derek', 'Blakely', datetime.timedelta(seconds=78180), 1),
#  (461, 'Derek', 'Blakely', datetime.timedelta(seconds=81240), 2),
#  (462, 'Warren', 'Sherrod', datetime.timedelta(days=1, seconds=7800), 1),
#  (462, 'Warren', 'Sherrod', datetime.timedelta(days=1, seconds=8400), 2),
#  (463, 'Darrell', 'Power', datetime.timedelta(seconds=77820), 1),
#  (463, 'Darrell', 'Power', datetime.timedelta(days=1, seconds=4500), 2),
#  (464, 'Jerome', 'Kenyon', datetime.timedelta(days=1, seconds=10440), 1),
#  (464, 'Jerome', 'Kenyon', datetime.timedelta(days=2, seconds=16200), 2),
#  (465, 'Floyd', 'Gandy', datetime.timedelta(days=1, seconds=4860), 1),
#  (465, 'Floyd', 'Gandy', datetime.timedelta(days=1, seconds=68160), 2),
#  (466, 'Leo', 'Ebert', datetime.timedelta(days=1, seconds=10740), 1),
#  (466, 'Leo', 'Ebert', datetime.timedelta(days=1, seconds=71220), 2),
#  (467, 'Alvin', 'Deloach', datetime.timedelta(seconds=66240), 1),
#  (467, 'Alvin', 'Deloach', datetime.timedelta(seconds=79080), 2),
#  (468, 'Tim', 'Cary', datetime.timedelta(days=1, seconds=20640), 1),
#  (468, 'Tim', 'Cary', datetime.timedelta(days=1, seconds=81660), 2),
#  (469, 'Wesley', 'Bull', datetime.timedelta(days=1, seconds=6120), 1),
#  (469, 'Wesley', 'Bull', datetime.timedelta(days=1, seconds=66000), 2),
#  (470, 'Gordon', 'Allard', datetime.timedelta(seconds=74880), 1),
#  (470, 'Gordon', 'Allard', datetime.timedelta(seconds=76680), 2),
#  (471, 'Dean', 'Sauer', datetime.timedelta(days=1, seconds=16020), 1),
#  (471, 'Dean', 'Sauer', datetime.timedelta(days=1, seconds=71100), 2),
#  (472, 'Greg', 'Robins', datetime.timedelta(seconds=77460), 1),
#  (472, 'Greg', 'Robins', datetime.timedelta(days=1, seconds=21180), 2),
#  (473, 'Jorge', 'Olivares', datetime.timedelta(seconds=70260), 1),
#  (473, 'Jorge', 'Olivares', datetime.timedelta(days=1, seconds=3360), 2),
#  (474, 'Dustin', 'Gillette', datetime.timedelta(seconds=76320), 1),
#  (474, 'Dustin', 'Gillette', datetime.timedelta(days=1, seconds=6840), 2),
#  (475, 'Pedro', 'Chestnut', datetime.timedelta(seconds=82200), 1),
#  (475, 'Pedro', 'Chestnut', datetime.timedelta(seconds=84300), 2),
#  (476, 'Derrick', 'Bourque', datetime.timedelta(seconds=71160), 1),
#  (476, 'Derrick', 'Bourque', datetime.timedelta(seconds=71340), 2),
#  (477, 'Dan', 'Paine', datetime.timedelta(seconds=76080), 1),
#  (477, 'Dan', 'Paine', datetime.timedelta(days=1, seconds=19080), 2),
#  (478, 'Lewis', 'Lyman', datetime.timedelta(days=1, seconds=15720), 1),
#  (478, 'Lewis', 'Lyman', datetime.timedelta(days=2, seconds=66420), 2),
#  (479, 'Zachary', 'Hite', datetime.timedelta(seconds=71460), 1),
#  (479, 'Zachary', 'Hite', datetime.timedelta(days=1, seconds=10680), 2),
#  (480, 'Corey', 'Hauser', datetime.timedelta(seconds=85020), 1),
#  (480, 'Corey', 'Hauser', datetime.timedelta(seconds=86340), 2),
#  (481, 'Herman', 'Devore', datetime.timedelta(seconds=76320), 1),
#  (481, 'Herman', 'Devore', datetime.timedelta(days=1, seconds=1080), 2),
#  (482, 'Maurice', 'Crawley', datetime.timedelta(seconds=73080), 1),
#  (482, 'Maurice', 'Crawley', datetime.timedelta(seconds=74460), 2),
#  (483, 'Vernon', 'Chapa', datetime.timedelta(seconds=72840), 1),
#  (483, 'Vernon', 'Chapa', datetime.timedelta(seconds=79800), 2),
#  (484, 'Roberto', 'Vu', datetime.timedelta(seconds=82500), 1),
#  (484, 'Roberto', 'Vu', datetime.timedelta(days=1, seconds=2280), 2),
#  (485, 'Clyde', 'Tobias', datetime.timedelta(days=1, seconds=80940), 1),
#  (485, 'Clyde', 'Tobias', datetime.timedelta(days=1, seconds=82740), 2),
#  (486, 'Glen', 'Talbert', datetime.timedelta(days=1, seconds=6960), 1),
#  (486, 'Glen', 'Talbert', datetime.timedelta(days=1, seconds=13140), 2),
#  (487, 'Hector', 'Poindexter', datetime.timedelta(days=1, seconds=2640), 1),
#  (487, 'Hector', 'Poindexter', datetime.timedelta(days=1, seconds=13860), 2),
#  (488, 'Shane', 'Millard', datetime.timedelta(seconds=66000), 1),
#  (488, 'Shane', 'Millard', datetime.timedelta(seconds=85140), 2),
#  (489, 'Ricardo', 'Meador', datetime.timedelta(seconds=84000), 1),
#  (489, 'Ricardo', 'Meador', datetime.timedelta(days=1, seconds=15240), 2),
#  (490, 'Sam', 'Mcduffie', datetime.timedelta(seconds=79740), 1),
#  (490, 'Sam', 'Mcduffie', datetime.timedelta(seconds=80340), 2),
#  (491, 'Rick', 'Mattox', datetime.timedelta(seconds=71460), 1),
#  (491, 'Rick', 'Mattox', datetime.timedelta(seconds=78960), 2),
#  (492, 'Lester', 'Kraus', datetime.timedelta(seconds=69420), 1),
#  (492, 'Lester', 'Kraus', datetime.timedelta(seconds=72480), 2),
#  (493, 'Brent', 'Harkins', datetime.timedelta(days=1, seconds=420), 1),
#  (493, 'Brent', 'Harkins', datetime.timedelta(days=1, seconds=20700), 2),
#  (494, 'Ramon', 'Choate', datetime.timedelta(days=1, seconds=4020), 1),
#  (494, 'Ramon', 'Choate', datetime.timedelta(days=1, seconds=4200), 2),
#  (495, 'Charlie', 'Bess', datetime.timedelta(seconds=65880), 1),
#  (495, 'Charlie', 'Bess', datetime.timedelta(seconds=82740), 2),
#  (496, 'Tyler', 'Wren', datetime.timedelta(seconds=70500), 1),
#  (496, 'Tyler', 'Wren', datetime.timedelta(seconds=85320), 2),
#  (497, 'Gilbert', 'Sledge', datetime.timedelta(seconds=69120), 1),
#  (497, 'Gilbert', 'Sledge', datetime.timedelta(seconds=78180), 2),
#  (498, 'Gene', 'Sanborn', datetime.timedelta(seconds=85680), 1),
#  (498, 'Gene', 'Sanborn', datetime.timedelta(seconds=86100), 2),
#  (499, 'Marc', 'Outlaw', datetime.timedelta(seconds=85260), 1),
#  (499, 'Marc', 'Outlaw', datetime.timedelta(days=1, seconds=3480), 2),
#  (500, 'Reginald', 'Kinder', datetime.timedelta(seconds=70200), 1),
#  (500, 'Reginald', 'Kinder', datetime.timedelta(seconds=73380), 2),
#  ...]

# %% [markdown]
# # 5
#
# ### List the quartile statististics of the movie lengths, grouped by release year.

# %%
# %%sql
# EXPLAIN
#
# SELECT release_year,
# percentile_cont(0.25) WITHIN GROUP (ORDER BY length) AS first_quartile,
# percentile_cont(0.5) WITHIN GROUP (ORDER BY length) AS median,
# percentile_cont(0.75) WITHIN GROUP (ORDER BY length) AS third_quartile
# FROM film
# GROUP BY release_year
# Out:
#  * postgres://dsa_ro_user:***@pgsql.dsa.lan/dvdrental
# 5 rows affected.
# [('GroupAggregate  (cost=113.83..133.85 rows=1 width=28)',),
#  ('  Group Key: release_year',),
#  ('  ->  Sort  (cost=113.83..116.33 rows=1000 width=6)',),
#  ('        Sort Key: release_year',),
#  ('        ->  Seq Scan on film  (cost=0.00..64.00 rows=1000 width=6)',)]

# %%
# %%sql
#
# SELECT release_year,
# percentile_cont(0.25) WITHIN GROUP (ORDER BY length) AS first_quartile,
# percentile_cont(0.5) WITHIN GROUP (ORDER BY length) AS median,
# percentile_cont(0.75) WITHIN GROUP (ORDER BY length) AS third_quartile
# FROM film
# GROUP BY release_year
# Out:
#  * postgres://dsa_ro_user:***@pgsql.dsa.lan/dvdrental
# 1 rows affected.
# [(2006, 80.0, 114.0, 149.25)]

# %% [markdown]
# # Save your notebook, then `File > Close and Halt`
